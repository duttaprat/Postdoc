# %% [markdown]
# ## This script is used for the prepraring dataset for the finetuning DNABERT for SARS-CoV-2 virant clasiification

# %%
import os, tarfile
import glob, time, csv, zipfile, gzip
import pandas as pd
import itertools as it
import sys

# %%
os.getcwd()
# Out:
# '/Users/pratik/Box/Datasets/GISAID_SARS_variant'

# %%
variant_dict = {
    "alpha": 0,
    "beta": 1,
    "delta": 2,
    "gamma": 3,
    "eta":4,
    "iota":5,
    "kappa":6,
    "lambda":7,
    "zeta":8
}

continent_dict={
    "Africa": "AF",
    "Asia": "AS",
    "Europe":"EU",
    "North America": "NA",
    "Oceania": "OC",
    "South America":"SA"
}

# %%
variant_dict['alpha']
# Out:
# 0

# %%
continent_dict['North America']
# Out:
# 'NA'

# %%
#For Mac
parent_dir_path = "/Users/pratik/Box/Datasets/GISAID_SARS_variant/"
#For Windows
#parent_dir_path = "/home/pratik/Work_directory/SARS_finetuned/GISAID"
os.chdir(parent_dir_path)

# %% [markdown]
# ### Function for creating non-overlappingg chunks with starting position zero and other mentioned starting position

# %%
def create_non_overlap_genome(sequence, chunk_size, index, number_of_genome, fasta_file_name):
    #print(index, number_of_genome)
    chunks = []
    indexes= []
    starting_position_list = [0, 1000, 2000]
    for position in starting_position_list:
        temp_chunks = [sequence[i:i+chunk_size] for i in range(position, len(sequence), chunk_size)]
        temp_index= [i for i in range(position, len(sequence), chunk_size)]
        
        #print(temp_index[0:10], len(temp_index))
        if(len(temp_chunks[-1])<chunk_size):
            del temp_chunks[-1]
        
        if (len(temp_chunks)<len(temp_index)):
            del temp_index[-1]
        chunks.extend(temp_chunks)
        indexes.extend(temp_index)
    last_chunk = sequence[-chunk_size:]
    chunks.append(last_chunk)
    indexes.append(len(sequence) - chunk_size)
    #print (len(chunks), len(indexes), len(chunks) - len(indexes))
    indexes = [str(index)+"_"+ str(fasta_file_name)+"_"+str(number_of_genome)+"_"+ str(item) for item in indexes]
    #print (indexes)
    return chunks, indexes

# %% [markdown]
# ### Finetuning data preparation

# %%
def finetune_data_preparation(file_lines, label, index, fasta_file_name):
    final_list = []
    final_index= []
    number_of_genome= 0
    for key,group in it.groupby(file_lines,lambda line: line.startswith('>')):
        if not key:
            #count= count+1
            group = list(group)
            stripped_group = list(map(lambda s: s.strip(), group))
            concat_group = ' '.join(stripped_group) 
            concat_group = concat_group.replace(" ","")
            temp_list, temp_list_indexes = create_non_overlap_genome(concat_group, 3000, index, number_of_genome, fasta_file_name)
            number_of_genome= number_of_genome+1
            final_list.extend(temp_list)
            final_index.extend(temp_list_indexes)
    print (len(final_index), len(final_list))
    temp_df= pd.DataFrame({'Index':final_index, 'Sequence':final_list})
    print ("temp", temp_df.shape)
    temp_df = temp_df.drop_duplicates(subset=['Sequence']).reset_index(drop=True)
    print (temp_df.shape)
    #print (temp_df)
    temp_df['Label']= label
    return (temp_df)

# %% [markdown]
# ## Remove contradict entries and save in a `.csv` file

# %%
def remv_contradict_entries(g, directory):
    print (g.shape)
    df1= g.groupby('Sequence')
    df2= df1.filter(lambda x: len(x) == 1).reset_index(drop=True)
    print (df2.groupby('Label').count())
    df2.to_csv("../3000_chunk_size/Finetuned_SARS_"+directory+".csv", index=False)

# %%
for directory in os.listdir():
    count =0
    print (directory)
    
    #print(continent_dict[directory])
    #input()
    final_df= pd.DataFrame(columns= ['Index','Sequence','Label' ])
    current_path= os.path.join(parent_dir_path,directory)
    #print (current_path)
    folders = os.listdir(directory)
    for subfolder in folders:
        path = os.path.join(current_path, subfolder)
        print (path)
        files= os.listdir(path)
        for file in files:
            if file.endswith("tar"):
                file_path= os.path.join(path, file)
                contents = tarfile.open(file_path)
                #print(contents.getnames())
                for file_name, file_object in zip(contents.getnames(), contents.getmembers()):
                    if file_name.endswith('fasta'):
                        print(file_name)
                        temp_dir_split = file_name.split('.')
                        fasta_file_name = temp_dir_split[0]
                        f=contents.extractfile(file_object)
                        file_content=f.readlines()
                        file_content_str = [x.decode() for x in file_content]
                        label = variant_dict[subfolder]
                        temp_df = finetune_data_preparation(file_content_str, label, continent_dict[directory], fasta_file_name)
                        final_df = final_df.append(temp_df, ignore_index=True)
                        print ("Final",final_df.shape)
    remv_contradict_entries(final_df, directory)
# Out:
# Africa
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/alpha
# 1629314973953.sequences.fasta
# 32004 32004
# temp (32004, 2)
# (10705, 2)
# Final (10705, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/beta
# 1629316238802.sequences.fasta
# 138012 138012
# temp (138012, 2)
# (40785, 2)
# Final (51490, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/delta
# 1629316615035.sequences.fasta
# 29512 29512
# temp (29512, 2)
# (11071, 2)
# Final (62561, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/eta
# 1629317297200.sequences.fasta
# 6412 6412
# temp (6412, 2)
# (3466, 2)
# Final (66027, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/iota
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/kappa
# 1629317487078.sequences.fasta
# 252 252
# temp (252, 2)
# (225, 2)
# Final (66252, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/lambda
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Africa/zeta
# 1629316826903.sequences.fasta
# 280 280
# temp (280, 2)
# (120, 2)
# Final (66372, 3)
# (66372, 3)
#        Index  Sequence
# Label
# 0      10414     10414
# 1      40358     40358
# 2      10895     10895
# 4       3347      3347
# 6        206       206
# 8        101       101
# Asia
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/alpha
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/beta
# 1629321017543.sequences.fasta
# 56617 56617
# temp (56617, 2)
# (19469, 2)
# Final (19469, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/delta
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/eta
# 1629321116083.sequences.fasta
# 8848 8848
# temp (8848, 2)
# (5812, 2)
# Final (25281, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/gamma
# 1629320543386.sequences.fasta
# 4844 4844
# temp (4844, 2)
# (1675, 2)
# Final (26956, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/iota
# 1629321359081.sequences.fasta
# 476 476
# temp (476, 2)
# (425, 2)
# Final (27381, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/kappa
# 1629321299449.sequences.fasta
# 73556 73556
# temp (73556, 2)
# (30264, 2)
# Final (57645, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/lambda
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Asia/zeta
# 1629320920540.sequences.fasta
# 504 504
# temp (504, 2)
# (432, 2)
# Final (58077, 3)
# (58077, 3)
#        Index  Sequence
# Label
# 1      19026     19026
# 3       1596      1596
# 4       5708      5708
# 5        342       342
# 6      29915     29915
# 8        354       354
# Europe
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/alpha
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/beta
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/delta
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/eta
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/gamma
# 1629321882420.sequences.fasta
# 137312 137312
# temp (137312, 2)
# (28159, 2)
# Final (28159, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/iota
# 1629323180991.sequences.fasta
# 5712 5712
# temp (5712, 2)
# (2293, 2)
# Final (30452, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/kappa
# 1629323292487.sequences.fasta
# 20216 20216
# temp (20216, 2)
# (6113, 2)
# Final (36565, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/lambda
# 1629322196621.sequences.fasta
# 1708 1708
# temp (1708, 2)
# (1050, 2)
# Final (37615, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Europe/zeta
# 1629323030691.sequences.fasta
# 45192 45192
# temp (45192, 2)
# (11036, 2)
# Final (48651, 3)
# 1629322790999.sequences.fasta
# 7280 7280
# temp (7280, 2)
# (3185, 2)
# Final (51836, 3)
# (51836, 3)
#        Index  Sequence
# Label
# 3      27891     27891
# 5       2088      2088
# 6       5915      5915
# 7        951       951
# 8      13740     13740
# North America
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/alpha
# 1630017471230.sequences.fasta
# 21196 21196
# temp (21196, 2)
# (9571, 2)
# Final (9571, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/beta
# 1629319610891.sequences.fasta
# 63840 63840
# temp (63840, 2)
# (18583, 2)
# Final (28154, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/delta
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/eta
# 1629319246862.sequences.fasta
# 14028 14028
# temp (14028, 2)
# (3938, 2)
# Final (32092, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/iota
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/kappa
# 1629319061098.sequences.fasta
# 11872 11872
# temp (11872, 2)
# (4346, 2)
# Final (36438, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/lambda
# 1629318739604.sequences.fasta
# 3528 3528
# temp (3528, 2)
# (2031, 2)
# Final (38469, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/North America/zeta
# 1629319354850.sequences.fasta
# 44043 44043
# temp (44043, 2)
# (16725, 2)
# Final (55194, 3)
# (55194, 3)
#        Index  Sequence
# Label
# 0       9344      9344
# 1      18027     18027
# 4       3780      3780
# 6       4137      4137
# 7       1876      1876
# 8      16243     16243
# Oceania
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/alpha
# 1629323574578.sequences.fasta
# 15876 15876
# temp (15876, 2)
# (5668, 2)
# Final (5668, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/beta
# 1629323731996.sequences.fasta
# 1960 1960
# temp (1960, 2)
# (1010, 2)
# Final (6678, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/delta
# 1629323796416.sequences.fasta
# 16100 16100
# temp (16100, 2)
# (5010, 2)
# Final (11688, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/eta
# 1629324106221.sequences.fasta
# 196 196
# temp (196, 2)
# (140, 2)
# Final (11828, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/gamma
# 1629323757740.sequences.fasta
# 196 196
# temp (196, 2)
# (108, 2)
# Final (11936, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/iota
# 1629324129472.sequences.fasta
# 56 56
# temp (56, 2)
# (28, 2)
# Final (11964, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/kappa
# 1629324155720.sequences.fasta
# 2240 2240
# temp (2240, 2)
# (666, 2)
# Final (12630, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/lambda
# 1629324181209.sequences.fasta
# 28 28
# temp (28, 2)
# (28, 2)
# Final (12658, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/Oceania/zeta
# 1629323703456.sequences.fasta
# 140 140
# temp (140, 2)
# (118, 2)
# Final (12776, 3)
# (12776, 3)
#        Index  Sequence
# Label
# 0       5612      5612
# 1        957       957
# 2       4970      4970
# 3        103       103
# 4        132       132
# 5         19        19
# 6        641       641
# 7         24        24
# 8        104       104
# South America
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/alpha
# 1629389233623.sequences.fasta
# 67844 67844
# temp (67844, 2)
# (20171, 2)
# Final (20171, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/beta
# 1629389299611.sequences.fasta
# 504 504
# temp (504, 2)
# (312, 2)
# Final (20483, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/delta
# 1629389326073.sequences.fasta
# 9604 9604
# temp (9604, 2)
# (3428, 2)
# Final (23911, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/eta
# 1629389807077.sequences.fasta
# 28 28
# temp (28, 2)
# (28, 2)
# Final (23939, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/iota
# 1629389834686.sequences.fasta
# 10108 10108
# temp (10108, 2)
# (3310, 2)
# Final (27249, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/kappa
# 1629389859687.sequences.fasta
# 28 28
# temp (28, 2)
# (28, 2)
# Final (27277, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/lambda
# 1629389882085.sequences.fasta
# 6132 6132
# temp (6132, 2)
# (3504, 2)
# Final (30781, 3)
# /Users/pratik/Box/Datasets/GISAID_SARS_variant/South America/zeta
# 1629389399049.sequences.fasta
# 69356 69356
# temp (69356, 2)
# (26581, 2)
# Final (57362, 3)
# (57362, 3)
#        Index  Sequence
# Label
# 0      19908     19908
# 1        263       263
# 2       3354      3354
# 4         24        24
# 5       3140      3140
# 6         24        24
# 7       3265      3265
# 8      26112     26112

# %%
[i for i in range(0, 10, 2)]
# Out:
# [0, 2, 4, 6, 8]
