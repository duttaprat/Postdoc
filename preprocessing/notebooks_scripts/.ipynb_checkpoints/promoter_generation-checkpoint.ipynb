# %%
import os, tarfile
import pyBigWig
import pybedtools
import zipfile, gzip
from gtfparse import read_gtf
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
reference_genome_path = "/mnt/data05/shared/pdutta_data/Human_Genome_Data/UCSC/genome_by_sequence/"
reference_genome_name = "chr1.fa"
data_path= "/mnt/data05/shared/pdutta_data/Human_Genome_Data/UCSC/gencode_annotation/"
file_name="gencodeV38.bb"
gencode_path= "/mnt/data05/shared/pdutta_data/Human_Genome_Data/gencode_annotation/"
gtf_annotation_filename= "gencode.v38.annotation.gtf"
gff_annotation_filename= "gencode.v38.annotation.gff3"
file_path= data_path+file_name
gencode_gtf_file_path= gencode_path+ gtf_annotation_filename
gencode_gff_file_path= gencode_path+ gff_annotation_filename
reference_genome_file_path = reference_genome_path + reference_genome_name
data_save_path= "/mnt/data05/shared/pdutta_data/Human_Genome_Data/region_wise_sequence_new/"

# %%
chr_files= os.listdir(reference_genome_path)
chr_files[0:10]
# Out:
# ['chr21.fa.fai',
#  'chr3.fa.fai',
#  'chr5.fa.fai',
#  'chr6.fa.fai',
#  'chr8.fa.fai',
#  'chr9.fa.fai',
#  'chrY.fa.fai',
#  '.DS_Store',
#  'chr1.fa',
#  'chr10.fa']

# %%
file_path
# Out:
# '/mnt/data05/shared/pdutta_data/Human_Genome_Data/UCSC/gencode_annotation/gencodeV38.bb'

# %%
bb= pyBigWig.open(file_path)

# %%
bb.chroms('chr1')
# Out:
# 248956422

# %%
df = read_gtf(gencode_gff_file_path)
# Out:
# INFO:root:Extracted GTF attributes: []

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand',
#        'frame'],
#       dtype='object')
# (3148136, 8)

# %%
df.head(10)
# Out:
#   seqname  source     feature  start    end  score strand frame
# 0    chr1  HAVANA        gene  11869  14409    NaN      +     0
# 1    chr1  HAVANA  transcript  11869  14409    NaN      +     0
# 2    chr1  HAVANA        exon  11869  12227    NaN      +     0
# 3    chr1  HAVANA        exon  12613  12721    NaN      +     0
# 4    chr1  HAVANA        exon  13221  14409    NaN      +     0
# 5    chr1  HAVANA  transcript  12010  13670    NaN      +     0
# 6    chr1  HAVANA        exon  12010  12057    NaN      +     0
# 7    chr1  HAVANA        exon  12179  12227    NaN      +     0
# 8    chr1  HAVANA        exon  12613  12697    NaN      +     0
# 9    chr1  HAVANA        exon  12975  13052    NaN      +     0

# %%
df.groupby(['feature']).size()
# Out:
# feature
# CDS                                        825914
# exon                                      1499012
# five_prime_UTR                             163360
# gene                                        60649
# start_codon                                 92997
# stop_codon                                  86205
# stop_codon_redefined_as_selenocysteine        119
# three_prime_UTR                            182868
# transcript                                 237012
# dtype: int64

# %%
df1 = read_gtf(gencode_gtf_file_path)
print(df1.columns)
print(df1.shape)
# Out:
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_type', 'gene_name', 'level', 'hgnc_id', 'havana_gene', 'transcript_id', 'transcript_type', 'transcript_name', 'transcript_support_level', 'tag', 'havana_transcript', 'exon_number', 'exon_id', 'ont', 'protein_id', 'ccdsid']
# Index(['seqname', 'source', 'feature', 'start', 'end', 'score', 'strand',
#        'frame', 'gene_id', 'gene_type', 'gene_name', 'level', 'hgnc_id',
#        'havana_gene', 'transcript_id', 'transcript_type', 'transcript_name',
#        'transcript_support_level', 'tag', 'havana_transcript', 'exon_number',
#        'exon_id', 'ont', 'protein_id', 'ccdsid'],
#       dtype='object')
# (3150424, 25)

# %%
df1.head(5)
# Out:
#   seqname  source     feature  start    end  score strand frame  \
# 0    chr1  HAVANA        gene  11869  14409    NaN      +     0
# 1    chr1  HAVANA  transcript  11869  14409    NaN      +     0
# 2    chr1  HAVANA        exon  11869  12227    NaN      +     0
# 3    chr1  HAVANA        exon  12613  12721    NaN      +     0
# 4    chr1  HAVANA        exon  13221  14409    NaN      +     0
#
#              gene_id                           gene_type gene_name level  \
# 0  ENSG00000223972.5  transcribed_unprocessed_pseudogene   DDX11L1     2
# 1  ENSG00000223972.5  transcribed_unprocessed_pseudogene   DDX11L1     2
# 2  ENSG00000223972.5  transcribed_unprocessed_pseudogene   DDX11L1     2
# 3  ENSG00000223972.5  transcribed_unprocessed_pseudogene   DDX11L1     2
# 4  ENSG00000223972.5  transcribed_unprocessed_pseudogene   DDX11L1     2
#
#       hgnc_id           havana_gene      transcript_id       transcript_type  \
# 0  HGNC:37102  OTTHUMG00000000961.2
# ...

# %%
df_transcript= df1[df1['feature']=='transcript']

# %%
df_transcript
# Out:
#         seqname   source     feature  start    end  score strand frame  \
# 1          chr1   HAVANA  transcript  11869  14409    NaN      +     0
# 5          chr1   HAVANA  transcript  12010  13670    NaN      +     0
# 13         chr1   HAVANA  transcript  14404  29570    NaN      -     0
# 26         chr1  ENSEMBL  transcript  17369  17436    NaN      -     0
# 29         chr1   HAVANA  transcript  29554  31097    NaN      +     0
# ...         ...      ...         ...    ...    ...    ...    ...   ...
# 3150406    chrM  ENSEMBL  transcript  14149  14673    NaN      -     0
# 3150411    chrM  ENSEMBL  transcript  14674  14742    NaN      -     0
# 3150414    chrM  ENSEMBL  transcript  14747  15887    NaN      +     0
# 3150419    chrM  ENSEMBL  transcript  15888  15953    NaN      +     0
# 3150422    chrM  ENSEMBL  transcript  15956  16023    NaN      -     0
#
#                    gene_id                           gene_type    gene_name  \
# ...

# %%
df_transcript = df_transcript.loc[((df_transcript['gene_type']=='miRNA') | (df_transcript['gene_type']=='protein_coding') | (df_transcript['gene_type']=='lncRNA')) & (df_transcript['seqname']!='chrM')]
df_transcript
# Out:
#         seqname   source     feature     start       end  score strand frame  \
# 26         chr1  ENSEMBL  transcript     17369     17436    NaN      -     0
# 29         chr1   HAVANA  transcript     29554     31097    NaN      +     0
# 33         chr1   HAVANA  transcript     30267     31109    NaN      +     0
# 37         chr1  ENSEMBL  transcript     30366     30503    NaN      +     0
# 40         chr1   HAVANA  transcript     34554     36081    NaN      -     0
# ...         ...      ...         ...       ...       ...    ...    ...   ...
# 3150254    chrY   HAVANA  transcript  57208519  57212183    NaN      +     0
# 3150260    chrY   HAVANA  transcript  57209306  57210051    NaN      +     0
# 3150263    chrY   HAVANA  transcript  57209887  57212186    NaN      +     0
# 3150266    chrY   HAVANA  transcript  57210344  57212074    NaN      +     0
# 3150270    chrY   HAVANA  transcript  57210591  57212074    NaN      +     0
#
# ...

# %%
unique_transcripts_list = []
for file in chr_files:
    if file.endswith('.fa'):
        print ("File name:", file)
        chr_name = file.split('.')[0]
        df_temp = df_transcript[df_transcript["seqname"]==chr_name]
        print(df_temp.shape)
        df_temp_sort = df_temp.sort_values(by = 'start')
        #.head(40)
        temp_sort_diff =df_temp_sort[df_temp_sort['start'].diff()>300]
        unique_transcripts_list.append(temp_sort_diff['transcript_id'].tolist())
# Out:
# File name: chr1.fa
# (18498, 25)
# File name: chr10.fa
# (7432, 25)
# File name: chr11.fa
# (12811, 25)
# File name: chr12.fa
# (12028, 25)
# File name: chr13.fa
# (3694, 25)
# File name: chr14.fa
# (7629, 25)
# File name: chr15.fa
# (7597, 25)
# File name: chr16.fa
# (10192, 25)
# File name: chr17.fa
# (12801, 25)
# File name: chr18.fa
# (4084, 25)
# File name: chr19.fa
# (13001, 25)
# File name: chr2.fa
# (15654, 25)
# File name: chr20.fa
# (5099, 25)
# File name: chr21.fa
# (2729, 25)
# File name: chr22.fa
# (4398, 25)
# File name: chr3.fa
# (13495, 25)
# File name: chr4.fa
# (8595, 25)
# File name: chr5.fa
# (10126, 25)
# File name: chr6.fa
# (9664, 25)
# File name: chr7.fa
# (9679, 25)
# File name: chr8.fa
# (8786, 25)
# File name: chr9.fa
# (6922, 25)
# File name: chrX.fa
# (6161, 25)
# File name: chrY.fa
# (488, 25)

# %%
len(unique_transcripts_list[1])
# Out:
# 3876

# %%
flat_list= [item for sublist in unique_transcripts_list for item in sublist]
len(flat_list)
# Out:
# 106030

# %%
check_df = df1[df1['transcript_id'].isin(flat_list)].reset_index()
check_df
# Out:
#            index seqname  source     feature     start       end  score  \
# 0             29    chr1  HAVANA  transcript     29554     31097    NaN
# 1             30    chr1  HAVANA        exon     29554     30039    NaN
# 2             31    chr1  HAVANA        exon     30564     30667    NaN
# 3             32    chr1  HAVANA        exon     30976     31097    NaN
# 4             33    chr1  HAVANA  transcript     30267     31109    NaN
# ...          ...     ...     ...         ...       ...       ...    ...
# 1231382  3150265    chrY  HAVANA        exon  57210640  57212186    NaN
# 1231383  3150266    chrY  HAVANA  transcript  57210344  57212074    NaN
# 1231384  3150267    chrY  HAVANA        exon  57210344  57210792    NaN
# 1231385  3150268    chrY  HAVANA        exon  57211552  57211620    NaN
# 1231386  3150269    chrY  HAVANA        exon  57211761  57212074    NaN
#
#         strand frame                   gene_id       gene_type    gene_name  \
# ...

# %%
check_df.to_csv(data_save_path+"gtf_annotation.csv", index=False)
