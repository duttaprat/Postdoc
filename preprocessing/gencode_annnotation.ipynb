# %%
import os, tarfile
import pyBigWig
import zipfile, gzip

# %%
data_path= "/mnt/data05/shared/pdutta_data/Human_Genome_Data/UCSC/gencode_annotation/"
file_name="gencodeV38.bb"
file_path= data_path+file_name

# %%
file_path
# Out:
# '/mnt/data05/shared/pdutta_data/Human_Genome_Data/UCSC/gencode_annotation/gencodeV38.bb'

# %%
bb= pyBigWig.open(file_path)

# %%
list1 = bb.entries('chr1', 0,248956422)

# %%
bb.chroms('chr1')
# Out:
# 248956422

# %%
bb.chroms()
# Out:
# {'chr1': 248956422,
#  'chr10': 133797422,
#  'chr10_GL383545v1_alt': 179254,
#  'chr10_GL383546v1_alt': 309802,
#  'chr10_KI270824v1_alt': 181496,
#  'chr10_KI270825v1_alt': 188315,
#  'chr10_KN196480v1_fix': 277797,
#  'chr10_KQ090021v1_fix': 264545,
#  'chr10_ML143354v1_fix': 454963,
#  'chr10_ML143355v1_fix': 292944,
#  'chr11': 135086622,
#  'chr11_JH159136v1_alt': 200998,
#  'chr11_JH159137v1_alt': 191409,
#  'chr11_KI270721v1_random': 100316,
#  'chr11_KI270829v1_alt': 204059,
#  'chr11_KI270830v1_alt': 177092,
#  'chr11_KI270831v1_alt': 296895,
#  'chr11_KI270832v1_alt': 210133,
#  'chr11_KI270902v1_alt': 106711,
#  'chr11_KI270903v1_alt': 214625,
#  'chr11_KI270927v1_alt': 218612,
#  'chr11_KN196481v1_fix': 108875,
#  'chr11_KN538368v1_alt': 203552,
#  'chr11_KQ090022v1_fix': 181958,
#  'chr11_KQ759759v1_fix': 196940,
#  'chr11_KV766195v1_fix': 140877,
#  'chr11_KZ559108v1_fix': 305244,
#  'chr11_KZ559109v1_fix': 279644,
#  'chr11_KZ559110v1_alt': 301637,
# ...
