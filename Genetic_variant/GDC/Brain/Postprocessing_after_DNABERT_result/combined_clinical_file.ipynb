# %%
import pandas as pd
import numpy as np

# %%
df_gdc_clinical = pd.read_csv("/data/projects/GDC_Cancer_Wise/Brain/Clinical_files/LGG_clinical/clinical.tsv", sep="\t")
df_manifest = pd.read_csv('/data/projects/GDC_Cancer_Wise/Brain/Manifest/Brain_gdc_manifest.2023-08-30.txt', sep='\t')

# %%
df_manifest
# Out:
#                                        id  \
# 0    8a5741e3-ade9-4aa0-bf16-fda229785973
# 1    92d4df10-dc24-495c-889f-98fe42259a3d
# 2    31261c79-49e6-4e8e-9135-7445a93d3ff6
# 3    03ec9184-c32b-40ec-90f6-fcb9ac13897c
# 4    8b174bed-2bd0-4318-8831-8676df9af5a0
# ..                                    ...
# 287  b53ad5a6-36a2-455a-8769-897c0adfb500
# 288  87113bda-e063-4f2c-9ac2-5f02a05d3a9c
# 289  4d278e32-a900-4d28-87be-575ca498db24
# 290  6788564d-7cfb-4bc2-a6e1-010337a37210
# 291  aac6e5e8-85eb-497a-9e0b-2125ef91e378
#
#                                               filename  \
# 0    96ef40c3-8d4c-4fe1-a33a-99f5b205a0bb_wgs_gdc_r...
# 1    6050f994-f394-4c1c-93ce-d36733aa9ae9_wgs_gdc_r...
# 2    7cae6c0b-36fe-411b-bbba-093a4c846d84_wgs_gdc_r...
# 3    e8114ae7-e076-44ca-b2bb-b6c3629b53b0_wgs_gdc_r...
# 4    b73cfd2e-044f-4b41-b404-080d9d18e61d_wgs_gdc_r...
# ..                                                 ...
# 287  5844876a-d390-4c02-acb9-f32647ca7375_wgs_gdc_r...
# ...

# %%
df_gdc_clinical
# Out:
#                                    case_id case_submitter_id project_id  \
# 0     001ad307-4ad3-4f1d-b2fc-efc032871c7e      TCGA-HT-A614   TCGA-LGG
# 1     001ad307-4ad3-4f1d-b2fc-efc032871c7e      TCGA-HT-A614   TCGA-LGG
# 2     0061e9ef-df6a-414e-af64-c88f8192e2d3      TCGA-E1-5311   TCGA-LGG
# 3     0061e9ef-df6a-414e-af64-c88f8192e2d3      TCGA-E1-5311   TCGA-LGG
# 4     0073a136-d5f4-4fd6-88f9-711768f2abc6      TCGA-VM-A8CF   TCGA-LGG
# ...                                    ...               ...        ...
# 1026  fee2114e-f723-4374-91f8-f1dcc6b3eaee      TCGA-HT-7470   TCGA-LGG
# 1027  ffcec8e5-9fd3-4b42-a7cb-74761f713cf4      TCGA-HT-7606   TCGA-LGG
# 1028  ffcec8e5-9fd3-4b42-a7cb-74761f713cf4      TCGA-HT-7606   TCGA-LGG
# 1029  fff304a2-113f-499d-a88c-9d3660c348d9      TCGA-RY-A847   TCGA-LGG
# 1030  fff304a2-113f-499d-a88c-9d3660c348d9      TCGA-RY-A847   TCGA-LGG
#
#      age_at_index age_is_obfuscated cause_of_death cause_of_death_source  \
# ...

# %%
# Print or process the results as needed
print(file_to_case_id)
# Out:
# {}
