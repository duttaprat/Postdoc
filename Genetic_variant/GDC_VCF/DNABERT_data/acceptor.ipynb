# %%
import os, glob
import pandas as pd
import pysam
import numpy as np
import pickle

# %%
cancer_type = "Brain"
non_coding_region="acceptor"
intersected_data = "/home/pdutta/Data/Cancer_wiseGDC/Data/{}/Generated_files/Intersected_Data/intersected_vcf_{}_data.pkl".format(cancer_type, non_coding_region)
reference_path  = "/home/pdutta/Data/Human_Genome_Data/GRCh38.primary_assembly.genome.fa"
output_path = "/home/pdutta/Data/Cancer_wiseGDC/Data/{}/Generated_files/DNABERT_Data/{}/".format(cancer_type, non_coding_region)

# %%
def seq2kmer(seq):
    """
    Convert original sequence to kmers
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    k=6
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def get_sequences(df, reference_fasta):
    data = []
    for idx, row in df.iterrows():
        #print(row)
        chrom = row['chr_name']
        ref_start = row['start']
        ref_end = row['end']
        variant_start = row['START_POS']
        variant_end = row['END_POS']
        ref_nucleotide = row['REF']
        alt = row["ALT"]
        
        # Adjust for 0-based indexing in python
        variant_pos_start = variant_start - ref_start
        variant_pos_end = variant_end - ref_start
        #print(ref_nucleotide , alt, variant_pos_start, variant_pos_end)
        
        
        # Get reference sequence
        #print(chrom)
        ref_seq = reference_fasta.fetch(chrom, ref_start, ref_end)
        #print(ref_seq)
        
        # Handle insertion and deletion to get the correct alt sequence
        # Identify if the variant is an insertion or deletion
        if len(ref_nucleotide) < len(alt):  # Insertion
            delete_size =  len(alt) - len(ref_nucleotide)
            #print(variant_pos_start, variant_pos_end ,delete_size)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:len(ref_seq) - delete_size]

        elif len(ref_nucleotide) > len(alt):  # Deletion
            insert_size = len(ref_nucleotide) - len(alt)
            #print(insert_size)
            extra_bases = reference_fasta.fetch(chrom, ref_end, ref_end + insert_size)
            #print(extra_bases)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:] + extra_bases

        else:  # SNV
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:]
        # print(ref_seq)
        # print(alt_seq)
        # input()


        data.append({
            'chr': chrom,
            'strand': row['strand'],
            'Transcript_ID': row['transcript_id'],
            'Acceptor_start': row['start'],
            'Acceptor_end': row['end'],
            'varinat_start': variant_start,
            'variant_end': variant_end,
            'ref_neucleotide': ref_nucleotide,
            'alternative_neucleotide': alt,
            'reference_seq': ref_seq,
            'alt_seq': alt_seq
        })
            
    
    # Convert the list of dictionaries to a DataFrame
    new_df = pd.DataFrame(data)
    # print(new_df.shape)
    # print(new_df)
    new_df = new_df.drop_duplicates().reset_index()
    print(new_df.shape)
    print("&*")
    data = []
    merged_list = list(zip(new_df['reference_seq'], new_df['alt_seq']))
    merged_list = [item.upper() for tup in merged_list for item in tup]
    #print(merged_list)
    kmer_lst = list(map(seq2kmer, merged_list))
    df_kmer = pd.DataFrame(kmer_lst, columns=['Sequence'])
    df_kmer['Label'] = np.random.choice([0, 1], size=len(df_kmer))
    print(df_kmer.shape)
    return new_df, df_kmer

# %%
## Load the VCF files from pickle
with open(intersected_data, "rb") as file:
    loaded_dictionary = pickle.load(file)
print("****All the VCF files are loaded***")
# Out:
# ****All the VCF files are loaded***

# %%
## Load the reference file
reference_fasta = pysam.FastaFile(reference_path)
print("#####The reference file is loaded######")
# Out:
# #####The reference file is loaded######

# %%
# List all sequence names
sequence_names = reference_fasta.references
print("Sequence names in the FASTA file:", sequence_names)
# Out:
# Sequence names in the FASTA file: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY', 'chrM', 'GL000008.2', 'GL000009.2', 'GL000194.1', 'GL000195.1', 'GL000205.2', 'GL000208.1', 'GL000213.1', 'GL000214.1', 'GL000216.2', 'GL000218.1', 'GL000219.1', 'GL000220.1', 'GL000221.1', 'GL000224.1', 'GL000225.1', 'GL000226.1', 'KI270302.1', 'KI270303.1', 'KI270304.1', 'KI270305.1', 'KI270310.1', 'KI270311.1', 'KI270312.1', 'KI270315.1', 'KI270316.1', 'KI270317.1', 'KI270320.1', 'KI270322.1', 'KI270329.1', 'KI270330.1', 'KI270333.1', 'KI270334.1', 'KI270335.1', 'KI270336.1', 'KI270337.1', 'KI270338.1', 'KI270340.1', 'KI270362.1', 'KI270363.1', 'KI270364.1', 'KI270366.1', 'KI270371.1', 'KI270372.1', 'KI270373.1', 'KI270374.1', 'KI270375.1', 'KI270376.1', 'KI270378.1', 'KI270379.1', 'KI270381.1', 'KI270382.1', 'KI270383.1', 'KI270384.1', 'KI270385.1', 'KI270386.1', 'KI270387.1', 'KI270388.1', 'KI270389.1', 'KI270390.1', 'KI270391.1', 'KI270392.1', 'KI270393.1', 'KI270394.1', 'KI270395.1', 'KI270396.1', 'KI270411.1', 'KI270412.1', 'KI270414.1', 'KI270417.1', 'KI270418.1', 'KI270419.1', 'KI270420.1', 'KI270422.1', 'KI270423.1', 'KI270424.1', 'KI270425.1', 'KI270429.1', 'KI270435.1', 'KI270438.1', 'KI270442.1', 'KI270448.1', 'KI270465.1', 'KI270466.1', 'KI270467.1', 'KI270468.1', 'KI270507.1', 'KI270508.1', 'KI270509.1', 'KI270510.1', 'KI270511.1', 'KI270512.1', 'KI270515.1', 'KI270516.1', 'KI270517.1', 'KI270518.1', 'KI270519.1', 'KI270521.1', 'KI270522.1', 'KI270528.1', 'KI270529.1', 'KI270530.1', 'KI270538.1', 'KI270539.1', 'KI270544.1', 'KI270548.1', 'KI270579.1', 'KI270580.1', 'KI270581.1', 'KI270582.1', 'KI270583.1', 'KI270584.1', 'KI270587.1', 'KI270588.1', 'KI270589.1', 'KI270590.1', 'KI270591.1', 'KI270593.1', 'KI270706.1', 'KI270707.1', 'KI270708.1', 'KI270709.1', 'KI270710.1', 'KI270711.1', 'KI270712.1', 'KI270713.1', 'KI270714.1', 'KI270715.1', 'KI270716.1', 'KI270717.1', 'KI270718.1', 'KI270719.1', 'KI270720.1', 'KI270721.1', 'KI270722.1', 'KI270723.1', 'KI270724.1', 'KI270725.1', 'KI270726.1', 'KI270727.1', 'KI270728.1', 'KI270729.1', 'KI270730.1', 'KI270731.1', 'KI270732.1', 'KI270733.1', 'KI270734.1', 'KI270735.1', 'KI270736.1', 'KI270737.1', 'KI270738.1', 'KI270739.1', 'KI270740.1', 'KI270741.1', 'KI270742.1', 'KI270743.1', 'KI270744.1', 'KI270745.1', 'KI270746.1', 'KI270747.1', 'KI270748.1', 'KI270749.1', 'KI270750.1', 'KI270751.1', 'KI270752.1', 'KI270753.1', 'KI270754.1', 'KI270755.1', 'KI270756.1', 'KI270757.1']

# %%
dnabert_raw_data = {}
for key, value in loaded_dictionary.items():
    #display(value[['chr_name', 'start', 'end', 'strand', 'transcript_type', 'CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT']])
    print("CODE STARTED")
    print(key, value.shape)
    #ins_del_df = value[(value['ALT'].str.len() > value['REF'].str.len()) | (value['REF'].str.len() > value['ALT'].str.len())]
    new_df, df_kmer = get_sequences(value, reference_fasta)
    dnabert_raw_data[key.split("_")[0].split(".")[0]] = new_df
    
    #input()
    out_folder_path = output_path+"Patient_wise/"+ key
    print(out_folder_path, "is created")
    if not os.path.exists(out_folder_path):
        os.makedirs(out_folder_path)
    df_kmer.to_csv(out_folder_path + "/dev.tsv", sep="\t", index= False)
# Out:
# CODE STARTED
# 1d3daf9d-7740-484e-850b-827a6b7d451d_CaVEMan (100, 27)
# (100, 12)
# &*
# (200, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/1d3daf9d-7740-484e-850b-827a6b7d451d_CaVEMan is created
# CODE STARTED
# 54d621a5-8e45-4bbc-92c4-1c7f36212361_sanger_raw_pindel (4556, 24)
# (4555, 12)
# &*
# (9110, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/54d621a5-8e45-4bbc-92c4-1c7f36212361_sanger_raw_pindel is created
# CODE STARTED
# 07f93ac0-50e0-4c1d-b4da-898062a5b6b8_CaVEMan (173, 27)
# (173, 12)
# &*
# (346, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/07f93ac0-50e0-4c1d-b4da-898062a5b6b8_CaVEMan is created
# CODE STARTED
# ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1_sanger_raw_pindel (6312, 24)
# (6310, 12)
# &*
# (12620, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1_sanger_raw_pindel is created
# CODE STARTED
# 2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_CaVEMan (92, 27)
# (92, 12)
# &*
# (184, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_CaVEMan is created
# CODE STARTED
# 0f158d5f-16c7-4fb7-b48c-0ff392f1706b_sanger_raw_pindel (4544, 24)
# (4544, 12)
# &*
# (9088, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/0f158d5f-16c7-4fb7-b48c-0ff392f1706b_sanger_raw_pindel is created
# CODE STARTED
# d6cb373e-d9bc-43a1-8edc-2199b38b95f7_CaVEMan (170, 27)
# (170, 12)
# &*
# (340, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/d6cb373e-d9bc-43a1-8edc-2199b38b95f7_CaVEMan is created
# CODE STARTED
# da5fbf8f-862d-49a6-8119-86f508063e29_sanger_raw_pindel (4522, 24)
# (4521, 12)
# &*
# (9042, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/da5fbf8f-862d-49a6-8119-86f508063e29_sanger_raw_pindel is created
# CODE STARTED
# 9f7f9c66-39bb-48b1-ae8e-91acc8028425_CaVEMan (173, 27)
# (173, 12)
# &*
# (346, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9f7f9c66-39bb-48b1-ae8e-91acc8028425_CaVEMan is created
# CODE STARTED
# b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_CaVEMan (165, 27)
# (165, 12)
# &*
# (330, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_CaVEMan is created
# CODE STARTED
# 24abc004-6712-4df9-83f2-bd98dcc6ea5e_sanger_raw_pindel (4564, 24)
# (4564, 12)
# &*
# (9128, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/24abc004-6712-4df9-83f2-bd98dcc6ea5e_sanger_raw_pindel is created
# CODE STARTED
# 3adc47fa-b27a-4df1-98ab-201ebab3c6bf_CaVEMan (1348, 27)
# (1348, 12)
# &*
# (2696, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3adc47fa-b27a-4df1-98ab-201ebab3c6bf_CaVEMan is created
# CODE STARTED
# cc884f4d-e62d-4214-bfaa-81052a02a246_CaVEMan (160, 27)
# (160, 12)
# &*
# (320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/cc884f4d-e62d-4214-bfaa-81052a02a246_CaVEMan is created
# CODE STARTED
# 535e0e9e-9757-45b3-aafd-2b80908de134_sanger_raw_pindel (4746, 24)
# (4746, 12)
# &*
# (9492, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/535e0e9e-9757-45b3-aafd-2b80908de134_sanger_raw_pindel is created
# CODE STARTED
# b2eaaa93-e870-4b1c-a835-b1d932c75b88_sanger_raw_pindel (5275, 24)
# (5274, 12)
# &*
# (10548, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b2eaaa93-e870-4b1c-a835-b1d932c75b88_sanger_raw_pindel is created
# CODE STARTED
# db856976-cd46-494d-bdc8-b4f3608cf10d_CaVEMan (1029, 27)
# (1029, 12)
# &*
# (2058, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/db856976-cd46-494d-bdc8-b4f3608cf10d_CaVEMan is created
# CODE STARTED
# 3d9d175b-20dc-4916-afa0-95b9acbbec02_CaVEMan (165, 27)
# (165, 12)
# &*
# (330, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3d9d175b-20dc-4916-afa0-95b9acbbec02_CaVEMan is created
# CODE STARTED
# 6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1_CaVEMan (127, 27)
# (127, 12)
# &*
# (254, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1_CaVEMan is created
# CODE STARTED
# da5fbf8f-862d-49a6-8119-86f508063e29_CaVEMan (134, 27)
# (134, 12)
# &*
# (268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/da5fbf8f-862d-49a6-8119-86f508063e29_CaVEMan is created
# CODE STARTED
# 0fc04044-0b33-4af6-a800-01d8cda12702_CaVEMan (103, 27)
# (103, 12)
# &*
# (206, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/0fc04044-0b33-4af6-a800-01d8cda12702_CaVEMan is created
# CODE STARTED
# 3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_CaVEMan (183, 27)
# (183, 12)
# &*
# (366, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_CaVEMan is created
# CODE STARTED
# 7d01d7c7-5138-4883-a4e3-c763151943df_CaVEMan (120, 27)
# (120, 12)
# &*
# (240, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7d01d7c7-5138-4883-a4e3-c763151943df_CaVEMan is created
# CODE STARTED
# 5d65b3c0-5c29-48aa-b6fb-37baf78fe409_CaVEMan (156, 27)
# (156, 12)
# &*
# (312, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/5d65b3c0-5c29-48aa-b6fb-37baf78fe409_CaVEMan is created
# CODE STARTED
# a5dba504-f9af-4ad7-8dd2-4d719440b569_CaVEMan (790, 27)
# (790, 12)
# &*
# (1580, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a5dba504-f9af-4ad7-8dd2-4d719440b569_CaVEMan is created
# CODE STARTED
# a58b5cd5-4625-4070-b672-4eb92cd7775c_sanger_raw_pindel (5457, 24)
# (5457, 12)
# &*
# (10914, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a58b5cd5-4625-4070-b672-4eb92cd7775c_sanger_raw_pindel is created
# CODE STARTED
# cf565879-9f53-4fd1-b0da-065869293342_sanger_raw_pindel (4542, 24)
# (4542, 12)
# &*
# (9084, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/cf565879-9f53-4fd1-b0da-065869293342_sanger_raw_pindel is created
# CODE STARTED
# 4193ad47-7cab-48fe-9466-aec494172f72_CaVEMan (185, 27)
# (185, 12)
# &*
# (370, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/4193ad47-7cab-48fe-9466-aec494172f72_CaVEMan is created
# CODE STARTED
# 1cc1ee58-e45c-4d85-b163-6d097f9d8f1f_CaVEMan (157, 27)
# (157, 12)
# &*
# (314, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/1cc1ee58-e45c-4d85-b163-6d097f9d8f1f_CaVEMan is created
# CODE STARTED
# 0fc04044-0b33-4af6-a800-01d8cda12702_sanger_raw_pindel (4610, 24)
# (4610, 12)
# &*
# (9220, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/0fc04044-0b33-4af6-a800-01d8cda12702_sanger_raw_pindel is created
# CODE STARTED
# cc884f4d-e62d-4214-bfaa-81052a02a246_sanger_raw_pindel (4597, 24)
# (4597, 12)
# &*
# (9194, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/cc884f4d-e62d-4214-bfaa-81052a02a246_sanger_raw_pindel is created
# CODE STARTED
# aae9d68e-f0eb-486b-9520-0b9f547f1ad3_CaVEMan (143, 27)
# (143, 12)
# &*
# (286, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/aae9d68e-f0eb-486b-9520-0b9f547f1ad3_CaVEMan is created
# CODE STARTED
# d101eddd-ad00-4a42-9a95-ece5bd2332a2_sanger_raw_pindel (4379, 24)
# (4378, 12)
# &*
# (8756, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/d101eddd-ad00-4a42-9a95-ece5bd2332a2_sanger_raw_pindel is created
# CODE STARTED
# b5fb53b7-7a70-48a2-84ff-ca6ebe62d053_sanger_raw_pindel (4632, 24)
# (4632, 12)
# &*
# (9264, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b5fb53b7-7a70-48a2-84ff-ca6ebe62d053_sanger_raw_pindel is created
# CODE STARTED
# 7bed15a4-3b1e-487e-954d-e6b55e296dc0_sanger_raw_pindel (4751, 24)
# (4751, 12)
# &*
# (9502, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7bed15a4-3b1e-487e-954d-e6b55e296dc0_sanger_raw_pindel is created
# CODE STARTED
# 9a3edc2a-0eb3-4d88-965d-2801cd19df51_CaVEMan (125, 27)
# (125, 12)
# &*
# (250, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9a3edc2a-0eb3-4d88-965d-2801cd19df51_CaVEMan is created
# CODE STARTED
# db856976-cd46-494d-bdc8-b4f3608cf10d_sanger_raw_pindel (5514, 24)
# (5511, 12)
# &*
# (11022, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/db856976-cd46-494d-bdc8-b4f3608cf10d_sanger_raw_pindel is created
# CODE STARTED
# f3ad237d-b424-4ca4-9659-2ff88a42e584_CaVEMan (102, 27)
# (102, 12)
# &*
# (204, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f3ad237d-b424-4ca4-9659-2ff88a42e584_CaVEMan is created
# CODE STARTED
# 2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_sanger_raw_pindel (4493, 24)
# (4493, 12)
# &*
# (8986, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_sanger_raw_pindel is created
# CODE STARTED
# b78b66b2-2983-4965-99ff-8a7e45a07d8f_sanger_raw_pindel (6450, 24)
# (6448, 12)
# &*
# (12896, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b78b66b2-2983-4965-99ff-8a7e45a07d8f_sanger_raw_pindel is created
# CODE STARTED
# cf565879-9f53-4fd1-b0da-065869293342_CaVEMan (140, 27)
# (140, 12)
# &*
# (280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/cf565879-9f53-4fd1-b0da-065869293342_CaVEMan is created
# CODE STARTED
# fd27f3fc-6f0b-4794-8555-3111ad520493_sanger_raw_pindel (4612, 24)
# (4612, 12)
# &*
# (9224, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/fd27f3fc-6f0b-4794-8555-3111ad520493_sanger_raw_pindel is created
# CODE STARTED
# 8bac8b71-abb7-4ecc-9b61-7112fed7da15_CaVEMan (91, 27)
# (91, 12)
# &*
# (182, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/8bac8b71-abb7-4ecc-9b61-7112fed7da15_CaVEMan is created
# CODE STARTED
# f00eed55-0ad9-41e8-bdf2-144b43f9b9b8_sanger_raw_pindel (4417, 24)
# (4417, 12)
# &*
# (8834, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f00eed55-0ad9-41e8-bdf2-144b43f9b9b8_sanger_raw_pindel is created
# CODE STARTED
# 22653df8-0c37-4f24-8832-95dd239f49b6_sanger_raw_pindel (4647, 24)
# (4647, 12)
# &*
# (9294, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/22653df8-0c37-4f24-8832-95dd239f49b6_sanger_raw_pindel is created
# CODE STARTED
# 2eb74322-a9f0-4dec-befc-b086386102a5_CaVEMan (140, 27)
# (140, 12)
# &*
# (280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2eb74322-a9f0-4dec-befc-b086386102a5_CaVEMan is created
# CODE STARTED
# 535e0e9e-9757-45b3-aafd-2b80908de134_CaVEMan (248, 27)
# (248, 12)
# &*
# (496, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/535e0e9e-9757-45b3-aafd-2b80908de134_CaVEMan is created
# CODE STARTED
# 07f93ac0-50e0-4c1d-b4da-898062a5b6b8_sanger_raw_pindel (4783, 24)
# (4783, 12)
# &*
# (9566, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/07f93ac0-50e0-4c1d-b4da-898062a5b6b8_sanger_raw_pindel is created
# CODE STARTED
# d101eddd-ad00-4a42-9a95-ece5bd2332a2_CaVEMan (112, 27)
# (112, 12)
# &*
# (224, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/d101eddd-ad00-4a42-9a95-ece5bd2332a2_CaVEMan is created
# CODE STARTED
# 6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1_sanger_raw_pindel (4567, 24)
# (4567, 12)
# &*
# (9134, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1_sanger_raw_pindel is created
# CODE STARTED
# 90c2456b-af8b-4e31-ae86-7de05a0f4124_sanger_raw_pindel (5312, 24)
# (5310, 12)
# &*
# (10620, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/90c2456b-af8b-4e31-ae86-7de05a0f4124_sanger_raw_pindel is created
# CODE STARTED
# 2a14ea45-6901-488a-af43-1e6287ec8bb0_CaVEMan (178, 27)
# (178, 12)
# &*
# (356, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2a14ea45-6901-488a-af43-1e6287ec8bb0_CaVEMan is created
# CODE STARTED
# 1cc1ee58-e45c-4d85-b163-6d097f9d8f1f_sanger_raw_pindel (4719, 24)
# (4719, 12)
# &*
# (9438, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/1cc1ee58-e45c-4d85-b163-6d097f9d8f1f_sanger_raw_pindel is created
# CODE STARTED
# 9a81060d-2b6d-4a97-a131-a5cf6c4c3ee4_CaVEMan (169, 27)
# (169, 12)
# &*
# (338, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9a81060d-2b6d-4a97-a131-a5cf6c4c3ee4_CaVEMan is created
# CODE STARTED
# 22653df8-0c37-4f24-8832-95dd239f49b6_CaVEMan (189, 27)
# (189, 12)
# &*
# (378, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/22653df8-0c37-4f24-8832-95dd239f49b6_CaVEMan is created
# CODE STARTED
# 7bed15a4-3b1e-487e-954d-e6b55e296dc0_CaVEMan (175, 27)
# (175, 12)
# &*
# (350, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7bed15a4-3b1e-487e-954d-e6b55e296dc0_CaVEMan is created
# CODE STARTED
# a5dba504-f9af-4ad7-8dd2-4d719440b569_sanger_raw_pindel (5721, 24)
# (5721, 12)
# &*
# (11442, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a5dba504-f9af-4ad7-8dd2-4d719440b569_sanger_raw_pindel is created
# CODE STARTED
# 3adc47fa-b27a-4df1-98ab-201ebab3c6bf_sanger_raw_pindel (6249, 24)
# (6247, 12)
# &*
# (12494, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3adc47fa-b27a-4df1-98ab-201ebab3c6bf_sanger_raw_pindel is created
# CODE STARTED
# b7416dd2-f9ef-4fdc-8dd3-5e9b9e7169a3_sanger_raw_pindel (4573, 24)
# (4573, 12)
# &*
# (9146, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b7416dd2-f9ef-4fdc-8dd3-5e9b9e7169a3_sanger_raw_pindel is created
# CODE STARTED
# f3ad237d-b424-4ca4-9659-2ff88a42e584_sanger_raw_pindel (4353, 24)
# (4352, 12)
# &*
# (8704, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f3ad237d-b424-4ca4-9659-2ff88a42e584_sanger_raw_pindel is created
# CODE STARTED
# 7d01d7c7-5138-4883-a4e3-c763151943df_sanger_raw_pindel (4502, 24)
# (4501, 12)
# &*
# (9002, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7d01d7c7-5138-4883-a4e3-c763151943df_sanger_raw_pindel is created
# CODE STARTED
# bce00d1a-9598-4fef-8e21-da2c5290d906_CaVEMan (138, 27)
# (138, 12)
# &*
# (276, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/bce00d1a-9598-4fef-8e21-da2c5290d906_CaVEMan is created
# CODE STARTED
# 2eb74322-a9f0-4dec-befc-b086386102a5_sanger_raw_pindel (4525, 24)
# (4523, 12)
# &*
# (9046, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2eb74322-a9f0-4dec-befc-b086386102a5_sanger_raw_pindel is created
# CODE STARTED
# ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1_CaVEMan (947, 27)
# (947, 12)
# &*
# (1894, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1_CaVEMan is created
# CODE STARTED
# e5bd9afb-3fbd-4688-a376-795a51fd5079_sanger_raw_pindel (4723, 24)
# (4723, 12)
# &*
# (9446, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/e5bd9afb-3fbd-4688-a376-795a51fd5079_sanger_raw_pindel is created
# CODE STARTED
# a732538e-135a-43dc-a88b-b122a1a36749_CaVEMan (156, 27)
# (156, 12)
# &*
# (312, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a732538e-135a-43dc-a88b-b122a1a36749_CaVEMan is created
# CODE STARTED
# f8b8e0df-4234-4839-b0ee-34a2c9ef4985_sanger_raw_pindel (4462, 24)
# (4461, 12)
# &*
# (8922, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f8b8e0df-4234-4839-b0ee-34a2c9ef4985_sanger_raw_pindel is created
# CODE STARTED
# f00eed55-0ad9-41e8-bdf2-144b43f9b9b8_CaVEMan (140, 27)
# (140, 12)
# &*
# (280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f00eed55-0ad9-41e8-bdf2-144b43f9b9b8_CaVEMan is created
# CODE STARTED
# ca52ea0e-5021-463b-8821-5e7c765812ff_CaVEMan (880, 27)
# (880, 12)
# &*
# (1760, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/ca52ea0e-5021-463b-8821-5e7c765812ff_CaVEMan is created
# CODE STARTED
# a58b5cd5-4625-4070-b672-4eb92cd7775c_CaVEMan (1035, 27)
# (1035, 12)
# &*
# (2070, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a58b5cd5-4625-4070-b672-4eb92cd7775c_CaVEMan is created
# CODE STARTED
# 5d65b3c0-5c29-48aa-b6fb-37baf78fe409_sanger_raw_pindel (4541, 24)
# (4541, 12)
# &*
# (9082, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/5d65b3c0-5c29-48aa-b6fb-37baf78fe409_sanger_raw_pindel is created
# CODE STARTED
# 09435dfd-67f9-4a28-9201-9e82d5bd04de_sanger_raw_pindel (4699, 24)
# (4699, 12)
# &*
# (9398, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/09435dfd-67f9-4a28-9201-9e82d5bd04de_sanger_raw_pindel is created
# CODE STARTED
# c12f0212-31ee-4aa2-88c4-d29c7c9059cb_CaVEMan (118, 27)
# (118, 12)
# &*
# (236, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/c12f0212-31ee-4aa2-88c4-d29c7c9059cb_CaVEMan is created
# CODE STARTED
# aae9d68e-f0eb-486b-9520-0b9f547f1ad3_sanger_raw_pindel (4623, 24)
# (4622, 12)
# &*
# (9244, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/aae9d68e-f0eb-486b-9520-0b9f547f1ad3_sanger_raw_pindel is created
# CODE STARTED
# c12f0212-31ee-4aa2-88c4-d29c7c9059cb_sanger_raw_pindel (4571, 24)
# (4571, 12)
# &*
# (9142, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/c12f0212-31ee-4aa2-88c4-d29c7c9059cb_sanger_raw_pindel is created
# CODE STARTED
# b5fb53b7-7a70-48a2-84ff-ca6ebe62d053_CaVEMan (162, 27)
# (162, 12)
# &*
# (324, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b5fb53b7-7a70-48a2-84ff-ca6ebe62d053_CaVEMan is created
# CODE STARTED
# fd27f3fc-6f0b-4794-8555-3111ad520493_CaVEMan (141, 27)
# (141, 12)
# &*
# (282, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/fd27f3fc-6f0b-4794-8555-3111ad520493_CaVEMan is created
# CODE STARTED
# 3d9d175b-20dc-4916-afa0-95b9acbbec02_sanger_raw_pindel (4688, 24)
# (4688, 12)
# &*
# (9376, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3d9d175b-20dc-4916-afa0-95b9acbbec02_sanger_raw_pindel is created
# CODE STARTED
# ca52ea0e-5021-463b-8821-5e7c765812ff_sanger_raw_pindel (6324, 24)
# (6323, 12)
# &*
# (12646, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/ca52ea0e-5021-463b-8821-5e7c765812ff_sanger_raw_pindel is created
# CODE STARTED
# 0f158d5f-16c7-4fb7-b48c-0ff392f1706b_CaVEMan (186, 27)
# (186, 12)
# &*
# (372, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/0f158d5f-16c7-4fb7-b48c-0ff392f1706b_CaVEMan is created
# CODE STARTED
# eef24407-c46d-45c3-9934-86902ac3ceac_sanger_raw_pindel (4434, 24)
# (4434, 12)
# &*
# (8868, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/eef24407-c46d-45c3-9934-86902ac3ceac_sanger_raw_pindel is created
# CODE STARTED
# f8b8e0df-4234-4839-b0ee-34a2c9ef4985_CaVEMan (134, 27)
# (134, 12)
# &*
# (268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f8b8e0df-4234-4839-b0ee-34a2c9ef4985_CaVEMan is created
# CODE STARTED
# b78b66b2-2983-4965-99ff-8a7e45a07d8f_CaVEMan (1110, 27)
# (1110, 12)
# &*
# (2220, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b78b66b2-2983-4965-99ff-8a7e45a07d8f_CaVEMan is created
# CODE STARTED
# b7416dd2-f9ef-4fdc-8dd3-5e9b9e7169a3_CaVEMan (155, 27)
# (155, 12)
# &*
# (310, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b7416dd2-f9ef-4fdc-8dd3-5e9b9e7169a3_CaVEMan is created
# CODE STARTED
# b2eaaa93-e870-4b1c-a835-b1d932c75b88_CaVEMan (945, 27)
# (945, 12)
# &*
# (1890, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b2eaaa93-e870-4b1c-a835-b1d932c75b88_CaVEMan is created
# CODE STARTED
# 3e28bc65-988d-4112-9397-7773ec79a9a9_sanger_raw_pindel (5379, 24)
# (5377, 12)
# &*
# (10754, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3e28bc65-988d-4112-9397-7773ec79a9a9_sanger_raw_pindel is created
# CODE STARTED
# e5bd9afb-3fbd-4688-a376-795a51fd5079_CaVEMan (160, 27)
# (160, 12)
# &*
# (320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/e5bd9afb-3fbd-4688-a376-795a51fd5079_CaVEMan is created
# CODE STARTED
# 1d3daf9d-7740-484e-850b-827a6b7d451d_sanger_raw_pindel (4670, 24)
# (4670, 12)
# &*
# (9340, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/1d3daf9d-7740-484e-850b-827a6b7d451d_sanger_raw_pindel is created
# CODE STARTED
# bce00d1a-9598-4fef-8e21-da2c5290d906_sanger_raw_pindel (4518, 24)
# (4518, 12)
# &*
# (9036, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/bce00d1a-9598-4fef-8e21-da2c5290d906_sanger_raw_pindel is created
# CODE STARTED
# 8bac8b71-abb7-4ecc-9b61-7112fed7da15_sanger_raw_pindel (4625, 24)
# (4624, 12)
# &*
# (9248, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/8bac8b71-abb7-4ecc-9b61-7112fed7da15_sanger_raw_pindel is created
# CODE STARTED
# 8da9bde9-4b8c-46a2-bcc2-a620a186bab3_sanger_raw_pindel (4570, 24)
# (4570, 12)
# &*
# (9140, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/8da9bde9-4b8c-46a2-bcc2-a620a186bab3_sanger_raw_pindel is created
# CODE STARTED
# 2a14ea45-6901-488a-af43-1e6287ec8bb0_sanger_raw_pindel (4519, 24)
# (4518, 12)
# &*
# (9036, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2a14ea45-6901-488a-af43-1e6287ec8bb0_sanger_raw_pindel is created
# CODE STARTED
# a732538e-135a-43dc-a88b-b122a1a36749_sanger_raw_pindel (4673, 24)
# (4673, 12)
# &*
# (9346, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a732538e-135a-43dc-a88b-b122a1a36749_sanger_raw_pindel is created
# CODE STARTED
# 9a81060d-2b6d-4a97-a131-a5cf6c4c3ee4_sanger_raw_pindel (4683, 24)
# (4683, 12)
# &*
# (9366, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9a81060d-2b6d-4a97-a131-a5cf6c4c3ee4_sanger_raw_pindel is created
# CODE STARTED
# 9f7f9c66-39bb-48b1-ae8e-91acc8028425_sanger_raw_pindel (4577, 24)
# (4577, 12)
# &*
# (9154, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9f7f9c66-39bb-48b1-ae8e-91acc8028425_sanger_raw_pindel is created
# CODE STARTED
# 09435dfd-67f9-4a28-9201-9e82d5bd04de_CaVEMan (201, 27)
# (201, 12)
# &*
# (402, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/09435dfd-67f9-4a28-9201-9e82d5bd04de_CaVEMan is created
# CODE STARTED
# 4193ad47-7cab-48fe-9466-aec494172f72_sanger_raw_pindel (4555, 24)
# (4554, 12)
# &*
# (9108, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/4193ad47-7cab-48fe-9466-aec494172f72_sanger_raw_pindel is created
# CODE STARTED
# dc3f72c3-79b4-411c-8275-a85e9d081abb_sanger_raw_pindel (4650, 24)
# (4650, 12)
# &*
# (9300, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/dc3f72c3-79b4-411c-8275-a85e9d081abb_sanger_raw_pindel is created
# CODE STARTED
# dc3f72c3-79b4-411c-8275-a85e9d081abb_CaVEMan (186, 27)
# (186, 12)
# &*
# (372, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/dc3f72c3-79b4-411c-8275-a85e9d081abb_CaVEMan is created
# CODE STARTED
# 7d9bd465-2e99-4b07-902f-752fa348efb8_CaVEMan (860, 27)
# (860, 12)
# &*
# (1720, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7d9bd465-2e99-4b07-902f-752fa348efb8_CaVEMan is created
# CODE STARTED
# 24abc004-6712-4df9-83f2-bd98dcc6ea5e_CaVEMan (208, 27)
# (208, 12)
# &*
# (416, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/24abc004-6712-4df9-83f2-bd98dcc6ea5e_CaVEMan is created
# CODE STARTED
# 90c2456b-af8b-4e31-ae86-7de05a0f4124_CaVEMan (908, 27)
# (908, 12)
# &*
# (1816, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/90c2456b-af8b-4e31-ae86-7de05a0f4124_CaVEMan is created
# CODE STARTED
# 8da9bde9-4b8c-46a2-bcc2-a620a186bab3_CaVEMan (128, 27)
# (128, 12)
# &*
# (256, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/8da9bde9-4b8c-46a2-bcc2-a620a186bab3_CaVEMan is created
# CODE STARTED
# eef24407-c46d-45c3-9934-86902ac3ceac_CaVEMan (165, 27)
# (165, 12)
# &*
# (330, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/eef24407-c46d-45c3-9934-86902ac3ceac_CaVEMan is created
# CODE STARTED
# 54d621a5-8e45-4bbc-92c4-1c7f36212361_CaVEMan (143, 27)
# (143, 12)
# &*
# (286, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/54d621a5-8e45-4bbc-92c4-1c7f36212361_CaVEMan is created
# CODE STARTED
# 3e28bc65-988d-4112-9397-7773ec79a9a9_CaVEMan (973, 27)
# (973, 12)
# &*
# (1946, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3e28bc65-988d-4112-9397-7773ec79a9a9_CaVEMan is created
# CODE STARTED
# 3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_sanger_raw_pindel (4680, 24)
# (4680, 12)
# &*
# (9360, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_sanger_raw_pindel is created
# CODE STARTED
# b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_sanger_raw_pindel (4792, 24)
# (4792, 12)
# &*
# (9584, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_sanger_raw_pindel is created
# CODE STARTED
# 9a3edc2a-0eb3-4d88-965d-2801cd19df51_sanger_raw_pindel (4011, 24)
# (4011, 12)
# &*
# (8022, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9a3edc2a-0eb3-4d88-965d-2801cd19df51_sanger_raw_pindel is created
# CODE STARTED
# d6cb373e-d9bc-43a1-8edc-2199b38b95f7_sanger_raw_pindel (4695, 24)
# (4694, 12)
# &*
# (9388, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/d6cb373e-d9bc-43a1-8edc-2199b38b95f7_sanger_raw_pindel is created
# CODE STARTED
# 7d9bd465-2e99-4b07-902f-752fa348efb8_sanger_raw_pindel (5404, 24)
# (5402, 12)
# &*
# (10804, 2)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7d9bd465-2e99-4b07-902f-752fa348efb8_sanger_raw_pindel is created

# %%
with open(output_path+"/raw_{}_vcf_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(dnabert_raw_data, file)
