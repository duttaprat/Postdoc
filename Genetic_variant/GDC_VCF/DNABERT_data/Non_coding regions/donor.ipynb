# %%
import os, glob
import pandas as pd
import pysam
import numpy as np
import pickle

# %%
cancer_type = "Lung"
non_coding_region="donor"
intersected_data = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/Intersected_Data/intersected_vcf_{}_data.pkl".format(cancer_type, non_coding_region)
reference_path  = "/home/pdutta/Data/Human_Genome_Data/GRCh38.primary_assembly.genome.fa"

# %%
output_path = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/DNABERT_Data/{}/".format(cancer_type, non_coding_region)
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
def seq2kmer(seq):
    """
    Convert original sequence to kmers
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    k=6
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def get_sequences(df, reference_fasta):
    data = []
    for idx, row in df.iterrows():
        #print(row)
        chrom = row['chr_name']
        ref_start = row['start']
        ref_end = row['end']
        variant_start = row['START_POS']
        variant_end = row['END_POS']
        ref_nucleotide = row['REF']
        alt = row["ALT"]
        
        # Adjust for 0-based indexing in python
        variant_pos_start = variant_start - ref_start
        variant_pos_end = variant_end - ref_start
        #print(ref_nucleotide , alt, variant_pos_start, variant_pos_end)
        
        
        # Get reference sequence
        #print(chrom)
        ref_seq = reference_fasta.fetch(chrom, ref_start, ref_end)
        #print(ref_seq)
        
        # Handle insertion and deletion to get the correct alt sequence
        # Identify if the variant is an insertion or deletion
        if len(ref_nucleotide) < len(alt):  # Insertion
            delete_size =  len(alt) - len(ref_nucleotide)
            #print(variant_pos_start, variant_pos_end ,delete_size)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:len(ref_seq) - delete_size]

        elif len(ref_nucleotide) > len(alt):  # Deletion
            insert_size = len(ref_nucleotide) - len(alt)
            #print(insert_size)
            extra_bases = reference_fasta.fetch(chrom, ref_end, ref_end + insert_size)
            #print(extra_bases)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:] + extra_bases

        else:  # SNV
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:]
        # print(ref_seq)
        # print(alt_seq)
        # input()


        data.append({
            'chr': chrom,
            'strand': row['strand'],
            'Transcript_ID': row['transcript_id'],
            'Acceptor_start': row['start'],
            'Acceptor_end': row['end'],
            'varinat_start': variant_start,
            'variant_end': variant_end,
            'ref_neucleotide': ref_nucleotide,
            'alternative_neucleotide': alt,
            'reference_seq': ref_seq,
            'alt_seq': alt_seq
        })
            
    
    # Convert the list of dictionaries to a DataFrame
    new_df = pd.DataFrame(data)
    # print(new_df.shape)
    # print(new_df)
    new_df = new_df.drop_duplicates().reset_index()
    print(new_df.shape)
    print("&*")
    data = []
    merged_list = list(zip(new_df['reference_seq'], new_df['alt_seq']))
    merged_list = [item.upper() for tup in merged_list for item in tup]
    #print(merged_list)
    kmer_lst = list(map(seq2kmer, merged_list))
    df_kmer = pd.DataFrame(kmer_lst, columns=['Sequence'])
    df_kmer['Label'] = np.random.choice([0, 1], size=len(df_kmer))
    print(df_kmer.shape)
    return new_df, df_kmer

# %%
## Load the VCF files from pickle
with open(intersected_data, "rb") as file:
    loaded_dictionary = pickle.load(file)
print("****All the VCF files are loaded***")
# Out:
# ****All the VCF files are loaded***

# %%
## Load the reference file
reference_fasta = pysam.FastaFile(reference_path)
print("#####The reference file is loaded######")
# Out:
# #####The reference file is loaded######

# %%
# List all sequence names
sequence_names = reference_fasta.references
print("Sequence names in the FASTA file:", sequence_names)
# Out:
# Sequence names in the FASTA file: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY', 'chrM', 'GL000008.2', 'GL000009.2', 'GL000194.1', 'GL000195.1', 'GL000205.2', 'GL000208.1', 'GL000213.1', 'GL000214.1', 'GL000216.2', 'GL000218.1', 'GL000219.1', 'GL000220.1', 'GL000221.1', 'GL000224.1', 'GL000225.1', 'GL000226.1', 'KI270302.1', 'KI270303.1', 'KI270304.1', 'KI270305.1', 'KI270310.1', 'KI270311.1', 'KI270312.1', 'KI270315.1', 'KI270316.1', 'KI270317.1', 'KI270320.1', 'KI270322.1', 'KI270329.1', 'KI270330.1', 'KI270333.1', 'KI270334.1', 'KI270335.1', 'KI270336.1', 'KI270337.1', 'KI270338.1', 'KI270340.1', 'KI270362.1', 'KI270363.1', 'KI270364.1', 'KI270366.1', 'KI270371.1', 'KI270372.1', 'KI270373.1', 'KI270374.1', 'KI270375.1', 'KI270376.1', 'KI270378.1', 'KI270379.1', 'KI270381.1', 'KI270382.1', 'KI270383.1', 'KI270384.1', 'KI270385.1', 'KI270386.1', 'KI270387.1', 'KI270388.1', 'KI270389.1', 'KI270390.1', 'KI270391.1', 'KI270392.1', 'KI270393.1', 'KI270394.1', 'KI270395.1', 'KI270396.1', 'KI270411.1', 'KI270412.1', 'KI270414.1', 'KI270417.1', 'KI270418.1', 'KI270419.1', 'KI270420.1', 'KI270422.1', 'KI270423.1', 'KI270424.1', 'KI270425.1', 'KI270429.1', 'KI270435.1', 'KI270438.1', 'KI270442.1', 'KI270448.1', 'KI270465.1', 'KI270466.1', 'KI270467.1', 'KI270468.1', 'KI270507.1', 'KI270508.1', 'KI270509.1', 'KI270510.1', 'KI270511.1', 'KI270512.1', 'KI270515.1', 'KI270516.1', 'KI270517.1', 'KI270518.1', 'KI270519.1', 'KI270521.1', 'KI270522.1', 'KI270528.1', 'KI270529.1', 'KI270530.1', 'KI270538.1', 'KI270539.1', 'KI270544.1', 'KI270548.1', 'KI270579.1', 'KI270580.1', 'KI270581.1', 'KI270582.1', 'KI270583.1', 'KI270584.1', 'KI270587.1', 'KI270588.1', 'KI270589.1', 'KI270590.1', 'KI270591.1', 'KI270593.1', 'KI270706.1', 'KI270707.1', 'KI270708.1', 'KI270709.1', 'KI270710.1', 'KI270711.1', 'KI270712.1', 'KI270713.1', 'KI270714.1', 'KI270715.1', 'KI270716.1', 'KI270717.1', 'KI270718.1', 'KI270719.1', 'KI270720.1', 'KI270721.1', 'KI270722.1', 'KI270723.1', 'KI270724.1', 'KI270725.1', 'KI270726.1', 'KI270727.1', 'KI270728.1', 'KI270729.1', 'KI270730.1', 'KI270731.1', 'KI270732.1', 'KI270733.1', 'KI270734.1', 'KI270735.1', 'KI270736.1', 'KI270737.1', 'KI270738.1', 'KI270739.1', 'KI270740.1', 'KI270741.1', 'KI270742.1', 'KI270743.1', 'KI270744.1', 'KI270745.1', 'KI270746.1', 'KI270747.1', 'KI270748.1', 'KI270749.1', 'KI270750.1', 'KI270751.1', 'KI270752.1', 'KI270753.1', 'KI270754.1', 'KI270755.1', 'KI270756.1', 'KI270757.1']

# %%
dnabert_raw_data = {}
for key, value in loaded_dictionary.items():
    #display(value[['chr_name', 'start', 'end', 'strand', 'transcript_type', 'CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT']])
    print("CODE STARTED")
    print(key, value.shape)
    #ins_del_df = value[(value['ALT'].str.len() > value['REF'].str.len()) | (value['REF'].str.len() > value['ALT'].str.len())]
    new_df, df_kmer = get_sequences(value, reference_fasta)
    dnabert_raw_data[key] = new_df
    
    #input()
    out_folder_path = output_path+"Patient_wise/"+ key
    print(out_folder_path, "is created")
    if not os.path.exists(out_folder_path):
        os.makedirs(out_folder_path)
    df_kmer.to_csv(out_folder_path + "/dev.tsv", sep="\t", index= False)
# Out:
# CODE STARTED
# 5ae88ff4-b750-4eae-9991-e6b1c9145d97_sanger_raw_pindel (3000, 24)
# (3000, 12)
# &*
# (6000, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5ae88ff4-b750-4eae-9991-e6b1c9145d97_sanger_raw_pindel is created
# CODE STARTED
# f982a734-c385-4a31-b384-466fcba70880_sanger_raw_pindel (3147, 24)
# (3147, 12)
# &*
# (6294, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f982a734-c385-4a31-b384-466fcba70880_sanger_raw_pindel is created
# CODE STARTED
# be48b90f-c501-4b92-bfd8-dc3dc28939e9_sanger_raw_pindel (2493, 24)
# (2493, 12)
# &*
# (4986, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/be48b90f-c501-4b92-bfd8-dc3dc28939e9_sanger_raw_pindel is created
# CODE STARTED
# cef028fb-40ef-4a68-b75f-a8b9bb6055c3_CaVEMan (752, 27)
# (752, 12)
# &*
# (1504, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cef028fb-40ef-4a68-b75f-a8b9bb6055c3_CaVEMan is created
# CODE STARTED
# 2e5f1a81-3424-4cfd-b23c-121a452592a5_sanger_raw_pindel (2467, 24)
# (2467, 12)
# &*
# (4934, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/2e5f1a81-3424-4cfd-b23c-121a452592a5_sanger_raw_pindel is created
# CODE STARTED
# babb0ca1-0eca-4bf5-b5ff-4faec0a9c836_sanger_raw_pindel (2982, 24)
# (2977, 12)
# &*
# (5954, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/babb0ca1-0eca-4bf5-b5ff-4faec0a9c836_sanger_raw_pindel is created
# CODE STARTED
# 9ffea310-a2a7-4212-8083-cce0e9b40ed8_sanger_raw_pindel (2662, 24)
# (2662, 12)
# &*
# (5324, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/9ffea310-a2a7-4212-8083-cce0e9b40ed8_sanger_raw_pindel is created
# CODE STARTED
# e7b27e88-470c-467d-964c-cc01de2ea073_CaVEMan (524, 27)
# (524, 12)
# &*
# (1048, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/e7b27e88-470c-467d-964c-cc01de2ea073_CaVEMan is created
# CODE STARTED
# 18e9819a-20e8-4ac3-a0d9-3291d35111d2_CaVEMan (188, 27)
# (188, 12)
# &*
# (376, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/18e9819a-20e8-4ac3-a0d9-3291d35111d2_CaVEMan is created
# CODE STARTED
# 80f3153d-148d-4800-a924-d64b6f59c9b6_sanger_raw_pindel (2583, 24)
# (2583, 12)
# &*
# (5166, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/80f3153d-148d-4800-a924-d64b6f59c9b6_sanger_raw_pindel is created
# CODE STARTED
# 56b38ebe-4168-46d1-aef9-5e0066ba653f_sanger_raw_pindel (2584, 24)
# (2584, 12)
# &*
# (5168, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/56b38ebe-4168-46d1-aef9-5e0066ba653f_sanger_raw_pindel is created
# CODE STARTED
# 594a7149-2b9d-42e6-a842-2978263a2d8b_CaVEMan (484, 27)
# (484, 12)
# &*
# (968, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/594a7149-2b9d-42e6-a842-2978263a2d8b_CaVEMan is created
# CODE STARTED
# ea912737-4296-49b8-bfd3-8dfb7b8b9bc4_sanger_raw_pindel (2516, 24)
# (2516, 12)
# &*
# (5032, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/ea912737-4296-49b8-bfd3-8dfb7b8b9bc4_sanger_raw_pindel is created
# CODE STARTED
# 683565c8-cd8c-41f5-abad-b626177d5c6f_sanger_raw_pindel (2618, 24)
# (2617, 12)
# &*
# (5234, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/683565c8-cd8c-41f5-abad-b626177d5c6f_sanger_raw_pindel is created
# CODE STARTED
# 04c212e7-d485-4621-b50f-2f2d9f2ea67f_CaVEMan (1360, 27)
# (1360, 12)
# &*
# (2720, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/04c212e7-d485-4621-b50f-2f2d9f2ea67f_CaVEMan is created
# CODE STARTED
# dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_CaVEMan (282, 27)
# (282, 12)
# &*
# (564, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_CaVEMan is created
# CODE STARTED
# 32564de4-55f3-4934-b529-a187c59d4d47_CaVEMan (1642, 27)
# (1642, 12)
# &*
# (3284, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/32564de4-55f3-4934-b529-a187c59d4d47_CaVEMan is created
# CODE STARTED
# 75de6374-86e9-49f9-ac40-6c4cde04f93c_CaVEMan (1176, 27)
# (1176, 12)
# &*
# (2352, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/75de6374-86e9-49f9-ac40-6c4cde04f93c_CaVEMan is created
# CODE STARTED
# 3530b926-f73b-4dcd-96fd-04a3f2f16031_sanger_raw_pindel (2624, 24)
# (2624, 12)
# &*
# (5248, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/3530b926-f73b-4dcd-96fd-04a3f2f16031_sanger_raw_pindel is created
# CODE STARTED
# c2042359-9e2c-4c98-b572-841cfd6c810b_CaVEMan (156, 27)
# (156, 12)
# &*
# (312, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/c2042359-9e2c-4c98-b572-841cfd6c810b_CaVEMan is created
# CODE STARTED
# 056fdb85-1ab9-459c-a4ea-12216debe90e_sanger_raw_pindel (2485, 24)
# (2485, 12)
# &*
# (4970, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/056fdb85-1ab9-459c-a4ea-12216debe90e_sanger_raw_pindel is created
# CODE STARTED
# 0a309d4f-857c-4220-b60a-0998b6d51722_CaVEMan (448, 27)
# (448, 12)
# &*
# (896, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0a309d4f-857c-4220-b60a-0998b6d51722_CaVEMan is created
# CODE STARTED
# 0c64d792-066c-42d3-84c3-d47dd2aa9092_CaVEMan (323, 27)
# (323, 12)
# &*
# (646, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0c64d792-066c-42d3-84c3-d47dd2aa9092_CaVEMan is created
# CODE STARTED
# 1b9c2fd7-e722-4c95-9484-6914a907c3a7_sanger_raw_pindel (2611, 24)
# (2611, 12)
# &*
# (5222, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1b9c2fd7-e722-4c95-9484-6914a907c3a7_sanger_raw_pindel is created
# CODE STARTED
# b8337c01-f353-4c73-b872-0522dbb67b59_sanger_raw_pindel (2643, 24)
# (2643, 12)
# &*
# (5286, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b8337c01-f353-4c73-b872-0522dbb67b59_sanger_raw_pindel is created
# CODE STARTED
# d13f1cbf-ae03-41de-b5e4-3877bd1c403c_sanger_raw_pindel (2466, 24)
# (2466, 12)
# &*
# (4932, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d13f1cbf-ae03-41de-b5e4-3877bd1c403c_sanger_raw_pindel is created
# CODE STARTED
# 0b2a6149-872f-4178-a7df-d8308cdea3fd_sanger_raw_pindel (2964, 24)
# (2964, 12)
# &*
# (5928, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0b2a6149-872f-4178-a7df-d8308cdea3fd_sanger_raw_pindel is created
# CODE STARTED
# c242f484-ecd9-45b2-b0aa-cc7a5b2f50f3_sanger_raw_pindel (2952, 24)
# (2950, 12)
# &*
# (5900, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/c242f484-ecd9-45b2-b0aa-cc7a5b2f50f3_sanger_raw_pindel is created
# CODE STARTED
# 6dda24b6-ccab-479a-9850-e82418150f0e_sanger_raw_pindel (2416, 24)
# (2416, 12)
# &*
# (4832, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6dda24b6-ccab-479a-9850-e82418150f0e_sanger_raw_pindel is created
# CODE STARTED
# 61942802-dbad-47a9-a9a8-c79dbddc60e1_sanger_raw_pindel (2445, 24)
# (2445, 12)
# &*
# (4890, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/61942802-dbad-47a9-a9a8-c79dbddc60e1_sanger_raw_pindel is created
# CODE STARTED
# 4ac41ebb-7ab1-4f4e-84cd-903085da7f5c_CaVEMan (253, 27)
# (253, 12)
# &*
# (506, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/4ac41ebb-7ab1-4f4e-84cd-903085da7f5c_CaVEMan is created
# CODE STARTED
# f71cb7b1-f6b3-4988-b256-b8e4a1676d1e_CaVEMan (128, 27)
# (128, 12)
# &*
# (256, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f71cb7b1-f6b3-4988-b256-b8e4a1676d1e_CaVEMan is created
# CODE STARTED
# 2d7cfb46-769b-404e-8178-26c9c99cc72b_CaVEMan (1514, 27)
# (1514, 12)
# &*
# (3028, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/2d7cfb46-769b-404e-8178-26c9c99cc72b_CaVEMan is created
# CODE STARTED
# 726bc7b4-f9a0-4f45-893f-c716c137d654_CaVEMan (300, 27)
# (300, 12)
# &*
# (600, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/726bc7b4-f9a0-4f45-893f-c716c137d654_CaVEMan is created
# CODE STARTED
# 71c5b0fe-cb27-4bca-b78d-3ed8f15af0ad_CaVEMan (570, 27)
# (570, 12)
# &*
# (1140, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/71c5b0fe-cb27-4bca-b78d-3ed8f15af0ad_CaVEMan is created
# CODE STARTED
# 62e19451-8cab-4640-81b8-2ee11335580a_CaVEMan (705, 27)
# (705, 12)
# &*
# (1410, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/62e19451-8cab-4640-81b8-2ee11335580a_CaVEMan is created
# CODE STARTED
# 01608e28-91d8-402c-8a28-790800e16d22_CaVEMan (131, 27)
# (131, 12)
# &*
# (262, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/01608e28-91d8-402c-8a28-790800e16d22_CaVEMan is created
# CODE STARTED
# d3f69cdc-4d7f-4476-b7a7-34e25d89dc7f_sanger_raw_pindel (2597, 24)
# (2597, 12)
# &*
# (5194, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d3f69cdc-4d7f-4476-b7a7-34e25d89dc7f_sanger_raw_pindel is created
# CODE STARTED
# 84adb5c4-5c01-492d-84c4-a421ddf263a5_sanger_raw_pindel (2579, 24)
# (2579, 12)
# &*
# (5158, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/84adb5c4-5c01-492d-84c4-a421ddf263a5_sanger_raw_pindel is created
# CODE STARTED
# 6361dc74-12ef-4b3c-a52c-dd988a38929e_sanger_raw_pindel (2553, 24)
# (2553, 12)
# &*
# (5106, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6361dc74-12ef-4b3c-a52c-dd988a38929e_sanger_raw_pindel is created
# CODE STARTED
# cfb7b7d5-32f5-4771-b1d4-f92081f77332_sanger_raw_pindel (2561, 24)
# (2561, 12)
# &*
# (5122, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cfb7b7d5-32f5-4771-b1d4-f92081f77332_sanger_raw_pindel is created
# CODE STARTED
# 72a16568-e3c4-4055-814c-dc7e8717451a_sanger_raw_pindel (2535, 24)
# (2535, 12)
# &*
# (5070, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/72a16568-e3c4-4055-814c-dc7e8717451a_sanger_raw_pindel is created
# CODE STARTED
# d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_CaVEMan (209, 27)
# (209, 12)
# &*
# (418, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_CaVEMan is created
# CODE STARTED
# 19dd7b00-4492-46a1-a4f8-e29615372bdc_sanger_raw_pindel (2547, 24)
# (2547, 12)
# &*
# (5094, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/19dd7b00-4492-46a1-a4f8-e29615372bdc_sanger_raw_pindel is created
# CODE STARTED
# f368a047-d2a8-404f-97dd-1c2a8bf52497_CaVEMan (124, 27)
# (124, 12)
# &*
# (248, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f368a047-d2a8-404f-97dd-1c2a8bf52497_CaVEMan is created
# CODE STARTED
# 6a17dfb4-cf62-43f4-9b8c-f2ae482dd6ea_sanger_raw_pindel (2617, 24)
# (2617, 12)
# &*
# (5234, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6a17dfb4-cf62-43f4-9b8c-f2ae482dd6ea_sanger_raw_pindel is created
# CODE STARTED
# 38520d04-f833-4c2d-bb0f-f672efc3f948_sanger_raw_pindel (2535, 24)
# (2535, 12)
# &*
# (5070, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/38520d04-f833-4c2d-bb0f-f672efc3f948_sanger_raw_pindel is created
# CODE STARTED
# ee43b511-44d4-4466-a59e-67fae369046e_CaVEMan (1074, 27)
# (1074, 12)
# &*
# (2148, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/ee43b511-44d4-4466-a59e-67fae369046e_CaVEMan is created
# CODE STARTED
# 6972d298-0451-4b0b-a348-0a329dedde24_sanger_raw_pindel (2602, 24)
# (2602, 12)
# &*
# (5204, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6972d298-0451-4b0b-a348-0a329dedde24_sanger_raw_pindel is created
# CODE STARTED
# 5866b635-fa0d-4141-bd21-aaf8181fdc0a_sanger_raw_pindel (2983, 24)
# (2983, 12)
# &*
# (5966, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5866b635-fa0d-4141-bd21-aaf8181fdc0a_sanger_raw_pindel is created
# CODE STARTED
# 7ded5aec-8bfe-480e-9b11-5fbf7c523966_CaVEMan (343, 27)
# (343, 12)
# &*
# (686, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/7ded5aec-8bfe-480e-9b11-5fbf7c523966_CaVEMan is created
# CODE STARTED
# 08f4046a-15a2-4fe9-a9be-f71ceca3c6f8_sanger_raw_pindel (2575, 24)
# (2575, 12)
# &*
# (5150, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/08f4046a-15a2-4fe9-a9be-f71ceca3c6f8_sanger_raw_pindel is created
# CODE STARTED
# 099b611a-4414-44c3-9458-89b01425d7a4_sanger_raw_pindel (2662, 24)
# (2662, 12)
# &*
# (5324, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/099b611a-4414-44c3-9458-89b01425d7a4_sanger_raw_pindel is created
# CODE STARTED
# 6a5c4bc7-09c6-47f5-a735-4c178dd4e8ae_sanger_raw_pindel (2908, 24)
# (2905, 12)
# &*
# (5810, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6a5c4bc7-09c6-47f5-a735-4c178dd4e8ae_sanger_raw_pindel is created
# CODE STARTED
# 81f5ba7a-68fd-4091-9d7d-2108650c853a_CaVEMan (201, 27)
# (201, 12)
# &*
# (402, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/81f5ba7a-68fd-4091-9d7d-2108650c853a_CaVEMan is created
# CODE STARTED
# ea29e39f-7307-433b-8880-cac11e88365b_CaVEMan (228, 27)
# (228, 12)
# &*
# (456, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/ea29e39f-7307-433b-8880-cac11e88365b_CaVEMan is created
# CODE STARTED
# cc2abefa-bcd1-473a-ae83-3c3249e18c6b_CaVEMan (805, 27)
# (805, 12)
# &*
# (1610, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cc2abefa-bcd1-473a-ae83-3c3249e18c6b_CaVEMan is created
# CODE STARTED
# 38520d04-f833-4c2d-bb0f-f672efc3f948_CaVEMan (189, 27)
# (189, 12)
# &*
# (378, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/38520d04-f833-4c2d-bb0f-f672efc3f948_CaVEMan is created
# CODE STARTED
# a0e302b2-ce1a-42e4-9b55-55c7a2cbba45_sanger_raw_pindel (2592, 24)
# (2592, 12)
# &*
# (5184, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/a0e302b2-ce1a-42e4-9b55-55c7a2cbba45_sanger_raw_pindel is created
# CODE STARTED
# 307940cc-216b-4627-a062-9f4935ba121a_sanger_raw_pindel (2577, 24)
# (2577, 12)
# &*
# (5154, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/307940cc-216b-4627-a062-9f4935ba121a_sanger_raw_pindel is created
# CODE STARTED
# 63a74c24-a480-41b7-ac93-a37bd3ac4597_sanger_raw_pindel (3080, 24)
# (3080, 12)
# &*
# (6160, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/63a74c24-a480-41b7-ac93-a37bd3ac4597_sanger_raw_pindel is created
# CODE STARTED
# 6b8d4980-0c87-4f63-b6be-4a438e4db5b1_sanger_raw_pindel (2706, 24)
# (2705, 12)
# &*
# (5410, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6b8d4980-0c87-4f63-b6be-4a438e4db5b1_sanger_raw_pindel is created
# CODE STARTED
# e636717c-c2ee-4c11-aff9-5bbe27c5e134_sanger_raw_pindel (2892, 24)
# (2890, 12)
# &*
# (5780, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/e636717c-c2ee-4c11-aff9-5bbe27c5e134_sanger_raw_pindel is created
# CODE STARTED
# 4eb1c02a-3a70-4a25-8756-e77074868421_CaVEMan (305, 27)
# (305, 12)
# &*
# (610, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/4eb1c02a-3a70-4a25-8756-e77074868421_CaVEMan is created
# CODE STARTED
# 1e2f7f07-e667-41b1-9ff7-0a745cfe38a7_CaVEMan (135, 27)
# (135, 12)
# &*
# (270, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1e2f7f07-e667-41b1-9ff7-0a745cfe38a7_CaVEMan is created
# CODE STARTED
# 0f89b7f8-8f3f-4f50-95fb-a479ef194fdb_CaVEMan (537, 27)
# (537, 12)
# &*
# (1074, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0f89b7f8-8f3f-4f50-95fb-a479ef194fdb_CaVEMan is created
# CODE STARTED
# e410e2b5-e22e-4349-98ad-ee17dd23329c_CaVEMan (639, 27)
# (639, 12)
# &*
# (1278, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/e410e2b5-e22e-4349-98ad-ee17dd23329c_CaVEMan is created
# CODE STARTED
# fceb79b8-bbde-4125-902c-a8502f7f23be_CaVEMan (211, 27)
# (211, 12)
# &*
# (422, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/fceb79b8-bbde-4125-902c-a8502f7f23be_CaVEMan is created
# CODE STARTED
# 6d430fc0-a93d-424d-981b-441a07a013da_CaVEMan (531, 27)
# (531, 12)
# &*
# (1062, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6d430fc0-a93d-424d-981b-441a07a013da_CaVEMan is created
# CODE STARTED
# 7baef639-bf0c-4f60-9482-d265f9bd99c8_CaVEMan (186, 27)
# (186, 12)
# &*
# (372, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/7baef639-bf0c-4f60-9482-d265f9bd99c8_CaVEMan is created
# CODE STARTED
# 3d03a6cb-4244-4804-b0a7-afc5c64c2d3a_CaVEMan (177, 27)
# (177, 12)
# &*
# (354, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/3d03a6cb-4244-4804-b0a7-afc5c64c2d3a_CaVEMan is created
# CODE STARTED
# 0a100c48-895e-4551-815f-72081297cc49_CaVEMan (320, 27)
# (320, 12)
# &*
# (640, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0a100c48-895e-4551-815f-72081297cc49_CaVEMan is created
# CODE STARTED
# 702bbd12-9713-4261-b533-2b91c7b956c3_CaVEMan (267, 27)
# (267, 12)
# &*
# (534, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/702bbd12-9713-4261-b533-2b91c7b956c3_CaVEMan is created
# CODE STARTED
# 514ab55f-b19d-4b83-8ef2-e506164cb1de_sanger_raw_pindel (2500, 24)
# (2500, 12)
# &*
# (5000, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/514ab55f-b19d-4b83-8ef2-e506164cb1de_sanger_raw_pindel is created
# CODE STARTED
# 1766972a-0ea3-4230-9d94-db6bbad0a77a_CaVEMan (302, 27)
# (302, 12)
# &*
# (604, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1766972a-0ea3-4230-9d94-db6bbad0a77a_CaVEMan is created
# CODE STARTED
# 0c64d792-066c-42d3-84c3-d47dd2aa9092_sanger_raw_pindel (2486, 24)
# (2486, 12)
# &*
# (4972, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0c64d792-066c-42d3-84c3-d47dd2aa9092_sanger_raw_pindel is created
# CODE STARTED
# 703c3593-8f8f-4d8b-a1bf-3eadc806e980_sanger_raw_pindel (2986, 24)
# (2985, 12)
# &*
# (5970, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/703c3593-8f8f-4d8b-a1bf-3eadc806e980_sanger_raw_pindel is created
# CODE STARTED
# 93dce00c-c8e8-4217-9117-22db8e33e784_sanger_raw_pindel (2587, 24)
# (2587, 12)
# &*
# (5174, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/93dce00c-c8e8-4217-9117-22db8e33e784_sanger_raw_pindel is created
# CODE STARTED
# 56b38ebe-4168-46d1-aef9-5e0066ba653f_CaVEMan (268, 27)
# (268, 12)
# &*
# (536, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/56b38ebe-4168-46d1-aef9-5e0066ba653f_CaVEMan is created
# CODE STARTED
# 01608e28-91d8-402c-8a28-790800e16d22_sanger_raw_pindel (2352, 24)
# (2352, 12)
# &*
# (4704, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/01608e28-91d8-402c-8a28-790800e16d22_sanger_raw_pindel is created
# CODE STARTED
# 9bdcc390-1fd2-4ed0-9d06-ba35cad665ba_CaVEMan (1477, 27)
# (1477, 12)
# &*
# (2954, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/9bdcc390-1fd2-4ed0-9d06-ba35cad665ba_CaVEMan is created
# CODE STARTED
# cc8fd25b-b416-44f4-bcef-ff833c100a2b_sanger_raw_pindel (2468, 24)
# (2468, 12)
# &*
# (4936, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cc8fd25b-b416-44f4-bcef-ff833c100a2b_sanger_raw_pindel is created
# CODE STARTED
# dcb7c4ba-7215-4b77-949a-c2d2b783549d_sanger_raw_pindel (2965, 24)
# (2965, 12)
# &*
# (5930, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/dcb7c4ba-7215-4b77-949a-c2d2b783549d_sanger_raw_pindel is created
# CODE STARTED
# f9eece5f-bd50-4997-845c-db1c20681361_CaVEMan (230, 27)
# (230, 12)
# &*
# (460, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f9eece5f-bd50-4997-845c-db1c20681361_CaVEMan is created
# CODE STARTED
# 9270a4a5-791b-4d06-96c4-6347562607fb_CaVEMan (133, 27)
# (133, 12)
# &*
# (266, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/9270a4a5-791b-4d06-96c4-6347562607fb_CaVEMan is created
# CODE STARTED
# 14b5fc32-66f2-4f5e-9d5f-bbd65cd07733_CaVEMan (333, 27)
# (333, 12)
# &*
# (666, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/14b5fc32-66f2-4f5e-9d5f-bbd65cd07733_CaVEMan is created
# CODE STARTED
# aea01681-bede-417d-a615-0a6a7124fa6c_CaVEMan (1507, 27)
# (1507, 12)
# &*
# (3014, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/aea01681-bede-417d-a615-0a6a7124fa6c_CaVEMan is created
# CODE STARTED
# d2fd0752-3acd-45d5-87f1-68b52834215e_sanger_raw_pindel (2697, 24)
# (2696, 12)
# &*
# (5392, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d2fd0752-3acd-45d5-87f1-68b52834215e_sanger_raw_pindel is created
# CODE STARTED
# d5d87ff1-8571-40f3-b187-5d51e0a5615d_CaVEMan (176, 27)
# (176, 12)
# &*
# (352, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d5d87ff1-8571-40f3-b187-5d51e0a5615d_CaVEMan is created
# CODE STARTED
# 5a588951-444c-45ce-a3e7-466965ebff1d_sanger_raw_pindel (2623, 24)
# (2623, 12)
# &*
# (5246, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5a588951-444c-45ce-a3e7-466965ebff1d_sanger_raw_pindel is created
# CODE STARTED
# 32c1fcc3-562e-4813-bdcc-8bac4983f5bd_CaVEMan (1429, 27)
# (1429, 12)
# &*
# (2858, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/32c1fcc3-562e-4813-bdcc-8bac4983f5bd_CaVEMan is created
# CODE STARTED
# c7f9db72-bda2-4b40-bd38-5922d1a66bf3_CaVEMan (396, 27)
# (396, 12)
# &*
# (792, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/c7f9db72-bda2-4b40-bd38-5922d1a66bf3_CaVEMan is created
# CODE STARTED
# 648cfb4f-4175-4124-ba27-6ce8b60a773b_CaVEMan (130, 27)
# (130, 12)
# &*
# (260, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/648cfb4f-4175-4124-ba27-6ce8b60a773b_CaVEMan is created
# CODE STARTED
# d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_sanger_raw_pindel (2627, 24)
# (2627, 12)
# &*
# (5254, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_sanger_raw_pindel is created
# CODE STARTED
# 41bd62a0-238a-4363-b9be-1402ae0224ea_CaVEMan (304, 27)
# (304, 12)
# &*
# (608, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/41bd62a0-238a-4363-b9be-1402ae0224ea_CaVEMan is created
# CODE STARTED
# b6f67aab-59fa-4998-95e0-d49349f4b27b_sanger_raw_pindel (2572, 24)
# (2572, 12)
# &*
# (5144, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b6f67aab-59fa-4998-95e0-d49349f4b27b_sanger_raw_pindel is created
# CODE STARTED
# f991f0d3-32ee-410c-b887-f190f4e6b729_sanger_raw_pindel (2735, 24)
# (2735, 12)
# &*
# (5470, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f991f0d3-32ee-410c-b887-f190f4e6b729_sanger_raw_pindel is created
# CODE STARTED
# f368a047-d2a8-404f-97dd-1c2a8bf52497_sanger_raw_pindel (2551, 24)
# (2551, 12)
# &*
# (5102, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f368a047-d2a8-404f-97dd-1c2a8bf52497_sanger_raw_pindel is created
# CODE STARTED
# 09bd9dff-f572-4f45-ac04-ec1d8f367dae_sanger_raw_pindel (2664, 24)
# (2664, 12)
# &*
# (5328, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/09bd9dff-f572-4f45-ac04-ec1d8f367dae_sanger_raw_pindel is created
# CODE STARTED
# 86fc2062-8120-41e9-a52a-1c112fc7e126_sanger_raw_pindel (2630, 24)
# (2630, 12)
# &*
# (5260, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/86fc2062-8120-41e9-a52a-1c112fc7e126_sanger_raw_pindel is created
# CODE STARTED
# afbf285e-0560-4e1d-9c6e-9741368aa9f5_CaVEMan (1407, 27)
# (1407, 12)
# &*
# (2814, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/afbf285e-0560-4e1d-9c6e-9741368aa9f5_CaVEMan is created
# CODE STARTED
# bbf629fd-658b-4c0f-bb8f-e7a6de5c6986_sanger_raw_pindel (2609, 24)
# (2609, 12)
# &*
# (5218, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bbf629fd-658b-4c0f-bb8f-e7a6de5c6986_sanger_raw_pindel is created
# CODE STARTED
# 91a0c61b-7141-4f5e-ba17-6b17b343e468_sanger_raw_pindel (2567, 24)
# (2567, 12)
# &*
# (5134, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/91a0c61b-7141-4f5e-ba17-6b17b343e468_sanger_raw_pindel is created
# CODE STARTED
# 32564de4-55f3-4934-b529-a187c59d4d47_sanger_raw_pindel (2925, 24)
# (2923, 12)
# &*
# (5846, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/32564de4-55f3-4934-b529-a187c59d4d47_sanger_raw_pindel is created
# CODE STARTED
# 86f90ec0-ef66-484e-a70d-713590be4ad8_sanger_raw_pindel (2550, 24)
# (2550, 12)
# &*
# (5100, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/86f90ec0-ef66-484e-a70d-713590be4ad8_sanger_raw_pindel is created
# CODE STARTED
# f04f56d8-6680-4054-97ab-ce728219aa84_sanger_raw_pindel (2565, 24)
# (2565, 12)
# &*
# (5130, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f04f56d8-6680-4054-97ab-ce728219aa84_sanger_raw_pindel is created
# CODE STARTED
# 12717370-ad9c-4260-97ed-98660520decc_sanger_raw_pindel (2632, 24)
# (2632, 12)
# &*
# (5264, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/12717370-ad9c-4260-97ed-98660520decc_sanger_raw_pindel is created
# CODE STARTED
# 980df119-42bf-401f-849f-d43a26becc2c_CaVEMan (998, 27)
# (998, 12)
# &*
# (1996, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/980df119-42bf-401f-849f-d43a26becc2c_CaVEMan is created
# CODE STARTED
# c339075f-1219-4def-ab5a-ef636995c1b2_sanger_raw_pindel (2595, 24)
# (2595, 12)
# &*
# (5190, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/c339075f-1219-4def-ab5a-ef636995c1b2_sanger_raw_pindel is created
# CODE STARTED
# 1ce5c200-7b11-44ca-a57c-118244fcd33d_CaVEMan (392, 27)
# (392, 12)
# &*
# (784, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1ce5c200-7b11-44ca-a57c-118244fcd33d_CaVEMan is created
# CODE STARTED
# 1453bd9a-202b-42c6-88fd-529acdda7890_CaVEMan (251, 27)
# (251, 12)
# &*
# (502, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1453bd9a-202b-42c6-88fd-529acdda7890_CaVEMan is created
# CODE STARTED
# cee02cc9-d0e3-4544-a093-6cfe5b8fffca_sanger_raw_pindel (2685, 24)
# (2685, 12)
# &*
# (5370, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cee02cc9-d0e3-4544-a093-6cfe5b8fffca_sanger_raw_pindel is created
# CODE STARTED
# 9270a4a5-791b-4d06-96c4-6347562607fb_sanger_raw_pindel (2524, 24)
# (2524, 12)
# &*
# (5048, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/9270a4a5-791b-4d06-96c4-6347562607fb_sanger_raw_pindel is created
# CODE STARTED
# 1113c58e-1cf2-45c9-848e-38cd3f5e07f7_CaVEMan (373, 27)
# (373, 12)
# &*
# (746, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1113c58e-1cf2-45c9-848e-38cd3f5e07f7_CaVEMan is created
# CODE STARTED
# c49e32d2-691a-4cc8-9f20-37395e5a79c2_sanger_raw_pindel (2634, 24)
# (2634, 12)
# &*
# (5268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/c49e32d2-691a-4cc8-9f20-37395e5a79c2_sanger_raw_pindel is created
# CODE STARTED
# f0e3f096-360f-4962-9567-adffc035aa3e_sanger_raw_pindel (3014, 24)
# (3012, 12)
# &*
# (6024, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f0e3f096-360f-4962-9567-adffc035aa3e_sanger_raw_pindel is created
# CODE STARTED
# bd58fa0b-8856-40a8-aec9-cd7b658cbdb7_sanger_raw_pindel (2598, 24)
# (2598, 12)
# &*
# (5196, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bd58fa0b-8856-40a8-aec9-cd7b658cbdb7_sanger_raw_pindel is created
# CODE STARTED
# dcb7c4ba-7215-4b77-949a-c2d2b783549d_CaVEMan (1319, 27)
# (1319, 12)
# &*
# (2638, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/dcb7c4ba-7215-4b77-949a-c2d2b783549d_CaVEMan is created
# CODE STARTED
# a4fc2ed3-dc4d-40fb-b96b-a19ccd2d0891_sanger_raw_pindel (2578, 24)
# (2578, 12)
# &*
# (5156, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/a4fc2ed3-dc4d-40fb-b96b-a19ccd2d0891_sanger_raw_pindel is created
# CODE STARTED
# b30d39e1-f2ff-43c5-9b69-579ca0d2fa28_CaVEMan (326, 27)
# (326, 12)
# &*
# (652, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b30d39e1-f2ff-43c5-9b69-579ca0d2fa28_CaVEMan is created
# CODE STARTED
# d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_sanger_raw_pindel (2623, 24)
# (2623, 12)
# &*
# (5246, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_sanger_raw_pindel is created
# CODE STARTED
# ab7058b9-2f1c-4c18-8e16-dd293c9d5737_CaVEMan (371, 27)
# (371, 12)
# &*
# (742, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/ab7058b9-2f1c-4c18-8e16-dd293c9d5737_CaVEMan is created
# CODE STARTED
# 57889e27-2e19-472d-8294-2f5695a6cead_sanger_raw_pindel (2642, 24)
# (2642, 12)
# &*
# (5284, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/57889e27-2e19-472d-8294-2f5695a6cead_sanger_raw_pindel is created
# CODE STARTED
# fda2d1f9-1690-42a8-80b7-bdcb9e9e4105_CaVEMan (134, 27)
# (134, 12)
# &*
# (268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/fda2d1f9-1690-42a8-80b7-bdcb9e9e4105_CaVEMan is created
# CODE STARTED
# fe71e6b9-f9f0-4628-8d5a-cf49497d0392_sanger_raw_pindel (2680, 24)
# (2680, 12)
# &*
# (5360, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/fe71e6b9-f9f0-4628-8d5a-cf49497d0392_sanger_raw_pindel is created
# CODE STARTED
# 832f644e-7014-4b46-8449-05980f3cacd3_CaVEMan (312, 27)
# (312, 12)
# &*
# (624, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/832f644e-7014-4b46-8449-05980f3cacd3_CaVEMan is created
# CODE STARTED
# 84acc817-abe7-42b0-bd74-94673f34009d_sanger_raw_pindel (2505, 24)
# (2505, 12)
# &*
# (5010, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/84acc817-abe7-42b0-bd74-94673f34009d_sanger_raw_pindel is created
# CODE STARTED
# bda8706f-6d13-40bb-9e1e-d21e4e531498_CaVEMan (229, 27)
# (229, 12)
# &*
# (458, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bda8706f-6d13-40bb-9e1e-d21e4e531498_CaVEMan is created
# CODE STARTED
# 2ff01ec1-7876-4b76-8b9d-62e9f6824d42_CaVEMan (285, 27)
# (285, 12)
# &*
# (570, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/2ff01ec1-7876-4b76-8b9d-62e9f6824d42_CaVEMan is created
# CODE STARTED
# 58e6ffe3-67ac-4ed8-8c56-c8040b429264_sanger_raw_pindel (2602, 24)
# (2602, 12)
# &*
# (5204, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/58e6ffe3-67ac-4ed8-8c56-c8040b429264_sanger_raw_pindel is created
# CODE STARTED
# 39a8c6e2-8708-4d18-badd-85f72282d426_sanger_raw_pindel (2936, 24)
# (2934, 12)
# &*
# (5868, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/39a8c6e2-8708-4d18-badd-85f72282d426_sanger_raw_pindel is created
# CODE STARTED
# dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_sanger_raw_pindel (2474, 24)
# (2474, 12)
# &*
# (4948, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_sanger_raw_pindel is created
# CODE STARTED
# 425008fb-b39f-4355-8c2b-c2ebfc3236ea_CaVEMan (163, 27)
# (163, 12)
# &*
# (326, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/425008fb-b39f-4355-8c2b-c2ebfc3236ea_CaVEMan is created
# CODE STARTED
# ce1b8b0e-6462-4a93-ac94-072418037f5c_sanger_raw_pindel (2557, 24)
# (2557, 12)
# &*
# (5114, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/ce1b8b0e-6462-4a93-ac94-072418037f5c_sanger_raw_pindel is created
# CODE STARTED
# 9ce61ab5-ceec-4148-901b-53ce6a2b084b_sanger_raw_pindel (2620, 24)
# (2620, 12)
# &*
# (5240, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/9ce61ab5-ceec-4148-901b-53ce6a2b084b_sanger_raw_pindel is created
# CODE STARTED
# 6361dc74-12ef-4b3c-a52c-dd988a38929e_CaVEMan (258, 27)
# (258, 12)
# &*
# (516, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6361dc74-12ef-4b3c-a52c-dd988a38929e_CaVEMan is created
# CODE STARTED
# 1425e1ef-ca6d-40a3-879a-54653d6fac38_CaVEMan (272, 27)
# (272, 12)
# &*
# (544, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1425e1ef-ca6d-40a3-879a-54653d6fac38_CaVEMan is created
# CODE STARTED
# aea01681-bede-417d-a615-0a6a7124fa6c_sanger_raw_pindel (2901, 24)
# (2899, 12)
# &*
# (5798, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/aea01681-bede-417d-a615-0a6a7124fa6c_sanger_raw_pindel is created
# CODE STARTED
# 62f26d07-04b1-4c69-a550-3aea5c8d44e3_CaVEMan (1625, 27)
# (1625, 12)
# &*
# (3250, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/62f26d07-04b1-4c69-a550-3aea5c8d44e3_CaVEMan is created
# CODE STARTED
# 92fd3588-7386-4c39-86cc-2029c3dd7c94_CaVEMan (189, 27)
# (189, 12)
# &*
# (378, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/92fd3588-7386-4c39-86cc-2029c3dd7c94_CaVEMan is created
# CODE STARTED
# 6d7f1fbc-57f6-4a77-b457-f570a71990eb_sanger_raw_pindel (2574, 24)
# (2574, 12)
# &*
# (5148, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6d7f1fbc-57f6-4a77-b457-f570a71990eb_sanger_raw_pindel is created
# CODE STARTED
# b99df57e-6f5b-4d35-96cb-8a16ef139cd8_CaVEMan (165, 27)
# (165, 12)
# &*
# (330, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b99df57e-6f5b-4d35-96cb-8a16ef139cd8_CaVEMan is created
# CODE STARTED
# 61c0789e-4c2d-4586-95c1-c3501a8d2a7e_sanger_raw_pindel (2683, 24)
# (2683, 12)
# &*
# (5366, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/61c0789e-4c2d-4586-95c1-c3501a8d2a7e_sanger_raw_pindel is created
# CODE STARTED
# f23649c0-8de7-4b60-9b65-5c557ea08a65_CaVEMan (1481, 27)
# (1481, 12)
# &*
# (2962, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f23649c0-8de7-4b60-9b65-5c557ea08a65_CaVEMan is created
# CODE STARTED
# 392b2647-766f-4e28-b003-44891a79ce8b_sanger_raw_pindel (2950, 24)
# (2949, 12)
# &*
# (5898, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/392b2647-766f-4e28-b003-44891a79ce8b_sanger_raw_pindel is created
# CODE STARTED
# bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_sanger_raw_pindel (2922, 24)
# (2920, 12)
# &*
# (5840, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_sanger_raw_pindel is created
# CODE STARTED
# 16d188a1-5021-4173-9774-63590b68f448_CaVEMan (128, 27)
# (128, 12)
# &*
# (256, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/16d188a1-5021-4173-9774-63590b68f448_CaVEMan is created
# CODE STARTED
# 73f8a07c-aae5-4319-aa0b-55646e277a6b_CaVEMan (172, 27)
# (172, 12)
# &*
# (344, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/73f8a07c-aae5-4319-aa0b-55646e277a6b_CaVEMan is created
# CODE STARTED
# 16d188a1-5021-4173-9774-63590b68f448_sanger_raw_pindel (2622, 24)
# (2622, 12)
# &*
# (5244, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/16d188a1-5021-4173-9774-63590b68f448_sanger_raw_pindel is created
# CODE STARTED
# b13172e7-5667-4fd8-bb69-87c9e1dabfb8_sanger_raw_pindel (2662, 24)
# (2662, 12)
# &*
# (5324, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b13172e7-5667-4fd8-bb69-87c9e1dabfb8_sanger_raw_pindel is created
# CODE STARTED
# 04fc819c-2358-47b5-9cab-bb5b9e9be109_sanger_raw_pindel (2689, 24)
# (2689, 12)
# &*
# (5378, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/04fc819c-2358-47b5-9cab-bb5b9e9be109_sanger_raw_pindel is created
# CODE STARTED
# c2042359-9e2c-4c98-b572-841cfd6c810b_sanger_raw_pindel (2559, 24)
# (2559, 12)
# &*
# (5118, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/c2042359-9e2c-4c98-b572-841cfd6c810b_sanger_raw_pindel is created
# CODE STARTED
# 5e54ae37-bbd4-4cb9-a1e4-886acd28bdd2_sanger_raw_pindel (2919, 24)
# (2917, 12)
# &*
# (5834, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5e54ae37-bbd4-4cb9-a1e4-886acd28bdd2_sanger_raw_pindel is created
# CODE STARTED
# 702bbd12-9713-4261-b533-2b91c7b956c3_sanger_raw_pindel (2621, 24)
# (2621, 12)
# &*
# (5242, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/702bbd12-9713-4261-b533-2b91c7b956c3_sanger_raw_pindel is created
# CODE STARTED
# 33e5de62-6347-4e65-b1de-a96aaad71cdf_CaVEMan (116, 27)
# (116, 12)
# &*
# (232, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/33e5de62-6347-4e65-b1de-a96aaad71cdf_CaVEMan is created
# CODE STARTED
# c0510fdb-e59f-496d-8431-aa0d5cdc81be_CaVEMan (1377, 27)
# (1377, 12)
# &*
# (2754, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/c0510fdb-e59f-496d-8431-aa0d5cdc81be_CaVEMan is created
# CODE STARTED
# 92ad448d-eeff-4224-aae9-402cb243ec22_CaVEMan (178, 27)
# (178, 12)
# &*
# (356, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/92ad448d-eeff-4224-aae9-402cb243ec22_CaVEMan is created
# CODE STARTED
# bc1594b4-9576-41ab-a7a1-0d39c4610173_CaVEMan (292, 27)
# (292, 12)
# &*
# (584, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bc1594b4-9576-41ab-a7a1-0d39c4610173_CaVEMan is created
# CODE STARTED
# eb3f7244-1d54-43b0-975b-10bd414296a8_CaVEMan (244, 27)
# (244, 12)
# &*
# (488, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/eb3f7244-1d54-43b0-975b-10bd414296a8_CaVEMan is created
# CODE STARTED
# f33367dc-d29f-442f-aeba-ecc1b3c534d4_CaVEMan (265, 27)
# (265, 12)
# &*
# (530, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f33367dc-d29f-442f-aeba-ecc1b3c534d4_CaVEMan is created
# CODE STARTED
# 75447975-74de-4c92-b4e3-11c9f57b02f8_CaVEMan (126, 27)
# (126, 12)
# &*
# (252, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/75447975-74de-4c92-b4e3-11c9f57b02f8_CaVEMan is created
# CODE STARTED
# 6c30db02-ef29-471b-9e53-4511ffe2ba1f_CaVEMan (126, 27)
# (126, 12)
# &*
# (252, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6c30db02-ef29-471b-9e53-4511ffe2ba1f_CaVEMan is created
# CODE STARTED
# 1fcdd550-6677-4d21-9722-e0f7edcfd470_sanger_raw_pindel (2540, 24)
# (2540, 12)
# &*
# (5080, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1fcdd550-6677-4d21-9722-e0f7edcfd470_sanger_raw_pindel is created
# CODE STARTED
# 84acc817-abe7-42b0-bd74-94673f34009d_CaVEMan (130, 27)
# (130, 12)
# &*
# (260, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/84acc817-abe7-42b0-bd74-94673f34009d_CaVEMan is created
# CODE STARTED
# cd0dff4b-df83-455b-8c5c-a7d0b96c707f_sanger_raw_pindel (2546, 24)
# (2544, 12)
# &*
# (5088, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cd0dff4b-df83-455b-8c5c-a7d0b96c707f_sanger_raw_pindel is created
# CODE STARTED
# a8262d3b-c0b0-4e0b-b864-ba00aca4960d_sanger_raw_pindel (2465, 24)
# (2465, 12)
# &*
# (4930, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/a8262d3b-c0b0-4e0b-b864-ba00aca4960d_sanger_raw_pindel is created
# CODE STARTED
# 6493d63d-eae9-4fbc-a7a4-0c07ef28fa38_sanger_raw_pindel (2599, 24)
# (2599, 12)
# &*
# (5198, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6493d63d-eae9-4fbc-a7a4-0c07ef28fa38_sanger_raw_pindel is created
# CODE STARTED
# 28608081-9523-4c76-95f7-9fb18596eeaa_CaVEMan (295, 27)
# (295, 12)
# &*
# (590, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/28608081-9523-4c76-95f7-9fb18596eeaa_CaVEMan is created
# CODE STARTED
# 5920a413-3753-4755-a10a-e94e6db880a4_sanger_raw_pindel (2877, 24)
# (2876, 12)
# &*
# (5752, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5920a413-3753-4755-a10a-e94e6db880a4_sanger_raw_pindel is created
# CODE STARTED
# 28608081-9523-4c76-95f7-9fb18596eeaa_sanger_raw_pindel (2511, 24)
# (2511, 12)
# &*
# (5022, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/28608081-9523-4c76-95f7-9fb18596eeaa_sanger_raw_pindel is created
# CODE STARTED
# 62e19451-8cab-4640-81b8-2ee11335580a_sanger_raw_pindel (2830, 24)
# (2830, 12)
# &*
# (5660, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/62e19451-8cab-4640-81b8-2ee11335580a_sanger_raw_pindel is created
# CODE STARTED
# 0354719a-b3e8-45d2-b35b-4665c50391d8_sanger_raw_pindel (2592, 24)
# (2592, 12)
# &*
# (5184, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0354719a-b3e8-45d2-b35b-4665c50391d8_sanger_raw_pindel is created
# CODE STARTED
# bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_CaVEMan (2250, 27)
# (2250, 12)
# &*
# (4500, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_CaVEMan is created
# CODE STARTED
# 27cca99a-2e9b-4bb4-9104-f3201e5b32b7_sanger_raw_pindel (2887, 24)
# (2887, 12)
# &*
# (5774, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/27cca99a-2e9b-4bb4-9104-f3201e5b32b7_sanger_raw_pindel is created
# CODE STARTED
# 1cd83e06-2381-4f80-8bfd-e2dc6a8a97dc_CaVEMan (418, 27)
# (418, 12)
# &*
# (836, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1cd83e06-2381-4f80-8bfd-e2dc6a8a97dc_CaVEMan is created
# CODE STARTED
# cc121407-bbbd-496c-989c-d98b1092e4ab_sanger_raw_pindel (2602, 24)
# (2602, 12)
# &*
# (5204, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cc121407-bbbd-496c-989c-d98b1092e4ab_sanger_raw_pindel is created
# CODE STARTED
# f8777da1-d1ba-4ca7-9d65-a57b7061b6c4_sanger_raw_pindel (3029, 24)
# (3027, 12)
# &*
# (6054, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/f8777da1-d1ba-4ca7-9d65-a57b7061b6c4_sanger_raw_pindel is created
# CODE STARTED
# aa99f75e-1450-4506-ae92-daeb0e7d54b2_CaVEMan (174, 27)
# (174, 12)
# &*
# (348, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/aa99f75e-1450-4506-ae92-daeb0e7d54b2_CaVEMan is created
# CODE STARTED
# fcb77a5c-10fc-40e9-b894-4c56b5111682_CaVEMan (152, 27)
# (152, 12)
# &*
# (304, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/fcb77a5c-10fc-40e9-b894-4c56b5111682_CaVEMan is created
# CODE STARTED
# 6bb58e67-2c9e-408f-9543-d92c12bed2a2_sanger_raw_pindel (2543, 24)
# (2543, 12)
# &*
# (5086, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6bb58e67-2c9e-408f-9543-d92c12bed2a2_sanger_raw_pindel is created
# CODE STARTED
# d62f088d-8ff4-4bdf-84e6-d1d743251c1b_sanger_raw_pindel (2593, 24)
# (2593, 12)
# &*
# (5186, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d62f088d-8ff4-4bdf-84e6-d1d743251c1b_sanger_raw_pindel is created
# CODE STARTED
# b802ae20-c2af-42b9-bc19-c4864c13a1c1_sanger_raw_pindel (2547, 24)
# (2547, 12)
# &*
# (5094, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b802ae20-c2af-42b9-bc19-c4864c13a1c1_sanger_raw_pindel is created
# CODE STARTED
# 702f2a4f-e224-4552-a95c-b67c62d1e70d_sanger_raw_pindel (2492, 24)
# (2492, 12)
# &*
# (4984, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/702f2a4f-e224-4552-a95c-b67c62d1e70d_sanger_raw_pindel is created
# CODE STARTED
# 2ff01ec1-7876-4b76-8b9d-62e9f6824d42_sanger_raw_pindel (2687, 24)
# (2687, 12)
# &*
# (5374, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/2ff01ec1-7876-4b76-8b9d-62e9f6824d42_sanger_raw_pindel is created
# CODE STARTED
# 8fb54b3e-8929-4e00-b946-8f87a082162f_CaVEMan (351, 27)
# (351, 12)
# &*
# (702, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/8fb54b3e-8929-4e00-b946-8f87a082162f_CaVEMan is created
# CODE STARTED
# 93dce00c-c8e8-4217-9117-22db8e33e784_CaVEMan (323, 27)
# (323, 12)
# &*
# (646, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/93dce00c-c8e8-4217-9117-22db8e33e784_CaVEMan is created
# CODE STARTED
# 45ae8240-94e9-4cbf-a3dc-5deae89b7abc_sanger_raw_pindel (2922, 24)
# (2921, 12)
# &*
# (5842, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/45ae8240-94e9-4cbf-a3dc-5deae89b7abc_sanger_raw_pindel is created
# CODE STARTED
# 473c39d6-8536-404b-b3d0-ebf4f0a6f85a_sanger_raw_pindel (2429, 24)
# (2429, 12)
# &*
# (4858, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/473c39d6-8536-404b-b3d0-ebf4f0a6f85a_sanger_raw_pindel is created
# CODE STARTED
# d01acc6e-cde3-4ba1-85fd-ebc6f442777d_sanger_raw_pindel (2550, 24)
# (2550, 12)
# &*
# (5100, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d01acc6e-cde3-4ba1-85fd-ebc6f442777d_sanger_raw_pindel is created
# ...
# &*
# (248, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/764fbb14-de89-43cd-aeab-62f18632db50_CaVEMan is created
# CODE STARTED
# 92113811-d6b8-436b-b491-ffe17ff2ae10_sanger_raw_pindel (2454, 24)
# (2454, 12)
# &*
# (4908, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/92113811-d6b8-436b-b491-ffe17ff2ae10_sanger_raw_pindel is created
# CODE STARTED
# 5ed5cde6-3550-4766-92e1-3e226cf9f4bc_CaVEMan (158, 27)
# (158, 12)
# &*
# (316, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5ed5cde6-3550-4766-92e1-3e226cf9f4bc_CaVEMan is created
# CODE STARTED
# 60eb59a2-75a6-415f-9538-5d2c33b94e2f_sanger_raw_pindel (2499, 24)
# (2499, 12)
# &*
# (4998, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/60eb59a2-75a6-415f-9538-5d2c33b94e2f_sanger_raw_pindel is created
# CODE STARTED
# 4caa0beb-f36d-4e36-a13f-34e1d11a1259_sanger_raw_pindel (2614, 24)
# (2614, 12)
# &*
# (5228, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/4caa0beb-f36d-4e36-a13f-34e1d11a1259_sanger_raw_pindel is created
# CODE STARTED
# 5891a047-6f9a-43f1-8aef-f52d1d3df1a1_CaVEMan (196, 27)
# (196, 12)
# &*
# (392, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5891a047-6f9a-43f1-8aef-f52d1d3df1a1_CaVEMan is created
# CODE STARTED
# b6f67aab-59fa-4998-95e0-d49349f4b27b_CaVEMan (187, 27)
# (187, 12)
# &*
# (374, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b6f67aab-59fa-4998-95e0-d49349f4b27b_CaVEMan is created
# CODE STARTED
# 1ec11928-92e4-4a28-aed6-bd6a2acf47bb_sanger_raw_pindel (2699, 24)
# (2698, 12)
# &*
# (5396, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1ec11928-92e4-4a28-aed6-bd6a2acf47bb_sanger_raw_pindel is created
# CODE STARTED
# 174c6cb7-3e03-4652-992a-de774381c354_CaVEMan (277, 27)
# (277, 12)
# &*
# (554, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/174c6cb7-3e03-4652-992a-de774381c354_CaVEMan is created
# CODE STARTED
# 04fc819c-2358-47b5-9cab-bb5b9e9be109_CaVEMan (160, 27)
# (160, 12)
# &*
# (320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/04fc819c-2358-47b5-9cab-bb5b9e9be109_CaVEMan is created
# CODE STARTED
# 6bb3b2cd-13bc-4ada-8414-75f16fc0f641_CaVEMan (140, 27)
# (140, 12)
# &*
# (280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6bb3b2cd-13bc-4ada-8414-75f16fc0f641_CaVEMan is created
# CODE STARTED
# a8dd0002-25e4-4506-8634-a9da1225cd56_CaVEMan (1719, 27)
# (1719, 12)
# &*
# (3438, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/a8dd0002-25e4-4506-8634-a9da1225cd56_CaVEMan is created
# CODE STARTED
# b199efb6-0989-490c-b9cf-6bbeb764dd15_CaVEMan (629, 27)
# (629, 12)
# &*
# (1258, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b199efb6-0989-490c-b9cf-6bbeb764dd15_CaVEMan is created
# CODE STARTED
# 8d233b00-3073-4810-ae86-bd809788f6eb_sanger_raw_pindel (2607, 24)
# (2607, 12)
# &*
# (5214, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/8d233b00-3073-4810-ae86-bd809788f6eb_sanger_raw_pindel is created
# CODE STARTED
# d6cf6672-bded-4022-af6e-b7b78c75ca44_sanger_raw_pindel (2655, 24)
# (2655, 12)
# &*
# (5310, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d6cf6672-bded-4022-af6e-b7b78c75ca44_sanger_raw_pindel is created
# CODE STARTED
# 503a146d-2e1c-4c55-9947-587fde1c875a_sanger_raw_pindel (2678, 24)
# (2678, 12)
# &*
# (5356, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/503a146d-2e1c-4c55-9947-587fde1c875a_sanger_raw_pindel is created
# CODE STARTED
# b89ad449-f0e8-41a4-a9e5-acc1eab2ca30_sanger_raw_pindel (2469, 24)
# (2469, 12)
# &*
# (4938, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b89ad449-f0e8-41a4-a9e5-acc1eab2ca30_sanger_raw_pindel is created
# CODE STARTED
# 1d6d39c4-b0e1-4d49-ac1d-384212229d5c_CaVEMan (935, 27)
# (935, 12)
# &*
# (1870, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1d6d39c4-b0e1-4d49-ac1d-384212229d5c_CaVEMan is created
# CODE STARTED
# cd0dff4b-df83-455b-8c5c-a7d0b96c707f_CaVEMan (296, 27)
# (296, 12)
# &*
# (592, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/cd0dff4b-df83-455b-8c5c-a7d0b96c707f_CaVEMan is created
# CODE STARTED
# 8a6bd6c0-a25e-476a-9409-84014108dbb6_sanger_raw_pindel (2611, 24)
# (2611, 12)
# &*
# (5222, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/8a6bd6c0-a25e-476a-9409-84014108dbb6_sanger_raw_pindel is created
# CODE STARTED
# 02c4910e-df0d-49bf-aabe-f833e328539e_CaVEMan (392, 27)
# (392, 12)
# &*
# (784, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/02c4910e-df0d-49bf-aabe-f833e328539e_CaVEMan is created
# CODE STARTED
# 86487f64-5ece-46c6-ae2e-afd5b9265d6f_sanger_raw_pindel (2534, 24)
# (2534, 12)
# &*
# (5068, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/86487f64-5ece-46c6-ae2e-afd5b9265d6f_sanger_raw_pindel is created
# CODE STARTED
# 1ca3b5f8-2ac0-4a1e-a137-718a268e00f3_sanger_raw_pindel (2500, 24)
# (2500, 12)
# &*
# (5000, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1ca3b5f8-2ac0-4a1e-a137-718a268e00f3_sanger_raw_pindel is created
# CODE STARTED
# 94304b7e-c8ff-4cca-93c9-51b45a9e0d5a_CaVEMan (187, 27)
# (187, 12)
# &*
# (374, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/94304b7e-c8ff-4cca-93c9-51b45a9e0d5a_CaVEMan is created
# CODE STARTED
# 3d053858-309c-46e0-a154-7cc4472f46f0_CaVEMan (389, 27)
# (389, 12)
# &*
# (778, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/3d053858-309c-46e0-a154-7cc4472f46f0_CaVEMan is created
# CODE STARTED
# 2e5f1a81-3424-4cfd-b23c-121a452592a5_CaVEMan (93, 27)
# (93, 12)
# &*
# (186, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/2e5f1a81-3424-4cfd-b23c-121a452592a5_CaVEMan is created
# CODE STARTED
# a5a632fd-0501-4268-8a40-673bb81e61be_CaVEMan (330, 27)
# (330, 12)
# &*
# (660, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/a5a632fd-0501-4268-8a40-673bb81e61be_CaVEMan is created
# CODE STARTED
# 936b40ef-4709-4503-8bac-e6212ea91145_CaVEMan (125, 27)
# (125, 12)
# &*
# (250, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/936b40ef-4709-4503-8bac-e6212ea91145_CaVEMan is created
# CODE STARTED
# 7c0c6ce6-c3c2-4d53-886b-3a44e5f8eed3_CaVEMan (1614, 27)
# (1614, 12)
# &*
# (3228, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/7c0c6ce6-c3c2-4d53-886b-3a44e5f8eed3_CaVEMan is created
# CODE STARTED
# d519507d-1b62-4925-8702-94326285aabf_CaVEMan (267, 27)
# (267, 12)
# &*
# (534, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d519507d-1b62-4925-8702-94326285aabf_CaVEMan is created
# CODE STARTED
# 936e9461-031c-4b35-9a7f-c93ba17983fc_CaVEMan (275, 27)
# (275, 12)
# &*
# (550, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/936e9461-031c-4b35-9a7f-c93ba17983fc_CaVEMan is created
# CODE STARTED
# 14428874-2d28-48a5-8a7e-eef30da45e47_CaVEMan (419, 27)
# (419, 12)
# &*
# (838, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/14428874-2d28-48a5-8a7e-eef30da45e47_CaVEMan is created
# CODE STARTED
# e7b27e88-470c-467d-964c-cc01de2ea073_sanger_raw_pindel (2766, 24)
# (2766, 12)
# &*
# (5532, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/e7b27e88-470c-467d-964c-cc01de2ea073_sanger_raw_pindel is created
# CODE STARTED
# 7647659b-f8ee-4a3b-afed-c8d52e674362_CaVEMan (149, 27)
# (149, 12)
# &*
# (298, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/7647659b-f8ee-4a3b-afed-c8d52e674362_CaVEMan is created
# CODE STARTED
# 1ec11928-92e4-4a28-aed6-bd6a2acf47bb_CaVEMan (499, 27)
# (499, 12)
# &*
# (998, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/1ec11928-92e4-4a28-aed6-bd6a2acf47bb_CaVEMan is created
# CODE STARTED
# d51caf6f-c2c1-418e-af0c-ac0d5e101a6b_CaVEMan (545, 27)
# (545, 12)
# &*
# (1090, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d51caf6f-c2c1-418e-af0c-ac0d5e101a6b_CaVEMan is created
# CODE STARTED
# 7647659b-f8ee-4a3b-afed-c8d52e674362_sanger_raw_pindel (2557, 24)
# (2557, 12)
# &*
# (5114, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/7647659b-f8ee-4a3b-afed-c8d52e674362_sanger_raw_pindel is created
# CODE STARTED
# b9fcd5bf-b0f6-4f4c-8eef-d12d4208d47e_sanger_raw_pindel (2936, 24)
# (2931, 12)
# &*
# (5862, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/b9fcd5bf-b0f6-4f4c-8eef-d12d4208d47e_sanger_raw_pindel is created
# CODE STARTED
# e452be3b-5a11-4ef7-a350-89e33b7229a3_sanger_raw_pindel (2920, 24)
# (2919, 12)
# &*
# (5838, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/e452be3b-5a11-4ef7-a350-89e33b7229a3_sanger_raw_pindel is created
# CODE STARTED
# ece02edb-5b5d-4e87-a33d-66d25e89a7bb_sanger_raw_pindel (2498, 24)
# (2498, 12)
# &*
# (4996, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/ece02edb-5b5d-4e87-a33d-66d25e89a7bb_sanger_raw_pindel is created
# CODE STARTED
# a06f06ea-d961-48cc-a24d-71f1be6a0b46_CaVEMan (115, 27)
# (115, 12)
# &*
# (230, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/a06f06ea-d961-48cc-a24d-71f1be6a0b46_CaVEMan is created
# CODE STARTED
# d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_CaVEMan (119, 27)
# (119, 12)
# &*
# (238, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_CaVEMan is created
# CODE STARTED
# 0d859bb4-a7ba-440b-9e9e-13c866656670_sanger_raw_pindel (2565, 24)
# (2565, 12)
# &*
# (5130, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/0d859bb4-a7ba-440b-9e9e-13c866656670_sanger_raw_pindel is created
# CODE STARTED
# 842f106a-6971-44fc-aa06-1d0cd7b72783_CaVEMan (155, 27)
# (155, 12)
# &*
# (310, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/842f106a-6971-44fc-aa06-1d0cd7b72783_CaVEMan is created
# CODE STARTED
# 3c3f09c3-0be2-46b7-bdf2-b31fd2218f12_CaVEMan (155, 27)
# (155, 12)
# &*
# (310, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/3c3f09c3-0be2-46b7-bdf2-b31fd2218f12_CaVEMan is created
# CODE STARTED
# 2d0e323f-b465-442a-969d-34d63b9934db_sanger_raw_pindel (2468, 24)
# (2468, 12)
# &*
# (4936, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/2d0e323f-b465-442a-969d-34d63b9934db_sanger_raw_pindel is created
# CODE STARTED
# 3b7706ff-c748-42ce-931e-9346e18b71fd_CaVEMan (262, 27)
# (262, 12)
# &*
# (524, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/3b7706ff-c748-42ce-931e-9346e18b71fd_CaVEMan is created
# CODE STARTED
# 39bef8f9-d66e-4fd1-ab72-bd41684d5304_CaVEMan (270, 27)
# (270, 12)
# &*
# (540, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/39bef8f9-d66e-4fd1-ab72-bd41684d5304_CaVEMan is created
# CODE STARTED
# 726bc7b4-f9a0-4f45-893f-c716c137d654_sanger_raw_pindel (2624, 24)
# (2624, 12)
# &*
# (5248, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/726bc7b4-f9a0-4f45-893f-c716c137d654_sanger_raw_pindel is created
# CODE STARTED
# 258c2003-f592-4015-8b1e-69d3f7b5d2db_sanger_raw_pindel (2572, 24)
# (2572, 12)
# &*
# (5144, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/258c2003-f592-4015-8b1e-69d3f7b5d2db_sanger_raw_pindel is created
# CODE STARTED
# 5a3551b8-e9a9-4236-ac4c-360e5e901a7f_sanger_raw_pindel (2657, 24)
# (2657, 12)
# &*
# (5314, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5a3551b8-e9a9-4236-ac4c-360e5e901a7f_sanger_raw_pindel is created
# CODE STARTED
# bda8706f-6d13-40bb-9e1e-d21e4e531498_sanger_raw_pindel (2535, 24)
# (2534, 12)
# &*
# (5068, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bda8706f-6d13-40bb-9e1e-d21e4e531498_sanger_raw_pindel is created
# CODE STARTED
# d3a8807d-a888-4c26-938d-ea4d386dd056_sanger_raw_pindel (2591, 24)
# (2591, 12)
# &*
# (5182, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/d3a8807d-a888-4c26-938d-ea4d386dd056_sanger_raw_pindel is created
# CODE STARTED
# a39a2a89-5b6f-486f-b5e0-e0971fe1a91b_sanger_raw_pindel (2652, 24)
# (2652, 12)
# &*
# (5304, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/a39a2a89-5b6f-486f-b5e0-e0971fe1a91b_sanger_raw_pindel is created
# CODE STARTED
# ce519e2c-290c-4cd0-9b7c-a15ec3308bb5_CaVEMan (138, 27)
# (138, 12)
# &*
# (276, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/ce519e2c-290c-4cd0-9b7c-a15ec3308bb5_CaVEMan is created
# CODE STARTED
# 7be8c1b4-eabe-4224-8163-3134668d148a_CaVEMan (226, 27)
# (226, 12)
# &*
# (452, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/7be8c1b4-eabe-4224-8163-3134668d148a_CaVEMan is created
# CODE STARTED
# bc2d1b67-edac-433e-bf33-ff7958c5dd35_CaVEMan (438, 27)
# (438, 12)
# &*
# (876, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/bc2d1b67-edac-433e-bf33-ff7958c5dd35_CaVEMan is created
# CODE STARTED
# 514e7809-f6ef-4994-b87a-8e0567d75219_sanger_raw_pindel (2555, 24)
# (2555, 12)
# &*
# (5110, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/514e7809-f6ef-4994-b87a-8e0567d75219_sanger_raw_pindel is created
# CODE STARTED
# 62f26d07-04b1-4c69-a550-3aea5c8d44e3_sanger_raw_pindel (2846, 24)
# (2845, 12)
# &*
# (5690, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/62f26d07-04b1-4c69-a550-3aea5c8d44e3_sanger_raw_pindel is created
# CODE STARTED
# 6c30db02-ef29-471b-9e53-4511ffe2ba1f_sanger_raw_pindel (2610, 24)
# (2610, 12)
# &*
# (5220, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/6c30db02-ef29-471b-9e53-4511ffe2ba1f_sanger_raw_pindel is created
# CODE STARTED
# 24006735-a46f-440e-9e6d-76f393e6fd40_CaVEMan (276, 27)
# (276, 12)
# &*
# (552, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/24006735-a46f-440e-9e6d-76f393e6fd40_CaVEMan is created
# CODE STARTED
# 04d435e6-77af-4869-8db7-aabc8711bfe0_CaVEMan (412, 27)
# (412, 12)
# &*
# (824, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/04d435e6-77af-4869-8db7-aabc8711bfe0_CaVEMan is created
# CODE STARTED
# 5b1766a9-a718-4016-b365-1a8cf2d33c8a_sanger_raw_pindel (2547, 24)
# (2547, 12)
# &*
# (5094, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/5b1766a9-a718-4016-b365-1a8cf2d33c8a_sanger_raw_pindel is created
# CODE STARTED
# 9dfb5a7b-4f2c-4fb5-a364-8307b22a8f16_CaVEMan (168, 27)
# (168, 12)
# &*
# (336, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/donor/Patient_wise/9dfb5a7b-4f2c-4fb5-a364-8307b22a8f16_CaVEMan is created

# %%
with open(output_path+"/raw_{}_vcf_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(dnabert_raw_data, file)
