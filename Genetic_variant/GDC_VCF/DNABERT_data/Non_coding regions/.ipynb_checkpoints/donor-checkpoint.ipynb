# %%
import os, glob
import pandas as pd
import pysam
import numpy as np
import pickle

# %%
cancer_type = "Brain"
non_coding_region="donor"
intersected_data = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/Intersected_Data/intersected_vcf_{}_data.pkl".format(cancer_type, non_coding_region)
reference_path  = "/home/pdutta/Data/Human_Genome_Data/GRCh38.primary_assembly.genome.fa"

# %%
output_path = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/DNABERT_Data/{}/".format(cancer_type, non_coding_region)
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
def seq2kmer(seq):
    """
    Convert original sequence to kmers
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    k=6
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def get_sequences(df, reference_fasta):
    data = []
    for idx, row in df.iterrows():
        #print(row)
        chrom = row['chr_name']
        ref_start = row['start']
        ref_end = row['end']
        variant_start = row['START_POS']
        variant_end = row['END_POS']
        ref_nucleotide = row['REF']
        alt = row["ALT"]
        
        # Adjust for 0-based indexing in python
        variant_pos_start = variant_start - ref_start
        variant_pos_end = variant_end - ref_start
        #print(ref_nucleotide , alt, variant_pos_start, variant_pos_end)
        
        
        # Get reference sequence
        #print(chrom)
        ref_seq = reference_fasta.fetch(chrom, ref_start, ref_end)
        #print(ref_seq)
        
        # Handle insertion and deletion to get the correct alt sequence
        # Identify if the variant is an insertion or deletion
        if len(ref_nucleotide) < len(alt):  # Insertion
            delete_size =  len(alt) - len(ref_nucleotide)
            #print(variant_pos_start, variant_pos_end ,delete_size)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:len(ref_seq) - delete_size]

        elif len(ref_nucleotide) > len(alt):  # Deletion
            insert_size = len(ref_nucleotide) - len(alt)
            #print(insert_size)
            extra_bases = reference_fasta.fetch(chrom, ref_end, ref_end + insert_size)
            #print(extra_bases)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:] + extra_bases

        else:  # SNV
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:]
        # print(ref_seq)
        # print(alt_seq)
        # input()


        data.append({
            'chr': chrom,
            'strand': row['strand'],
            'Transcript_ID': row['transcript_id'],
            'Acceptor_start': row['start'],
            'Acceptor_end': row['end'],
            'varinat_start': variant_start,
            'variant_end': variant_end,
            'ref_neucleotide': ref_nucleotide,
            'alternative_neucleotide': alt,
            'reference_seq': ref_seq,
            'alt_seq': alt_seq
        })
            
    
    # Convert the list of dictionaries to a DataFrame
    new_df = pd.DataFrame(data)
    # print(new_df.shape)
    # print(new_df)
    new_df = new_df.drop_duplicates().reset_index()
    print(new_df.shape)
    print("&*")
    data = []
    merged_list = list(zip(new_df['reference_seq'], new_df['alt_seq']))
    merged_list = [item.upper() for tup in merged_list for item in tup]
    #print(merged_list)
    kmer_lst = list(map(seq2kmer, merged_list))
    df_kmer = pd.DataFrame(kmer_lst, columns=['Sequence'])
    df_kmer['Label'] = np.random.choice([0, 1], size=len(df_kmer))
    print(df_kmer.shape)
    return new_df, df_kmer

# %%
## Load the VCF files from pickle
with open(intersected_data, "rb") as file:
    loaded_dictionary = pickle.load(file)
print("****All the VCF files are loaded***")
# Out:
# ****All the VCF files are loaded***

# %%
## Load the reference file
reference_fasta = pysam.FastaFile(reference_path)
print("#####The reference file is loaded######")
# Out:
# #####The reference file is loaded######

# %%
# List all sequence names
sequence_names = reference_fasta.references
print("Sequence names in the FASTA file:", sequence_names)
# Out:
# Sequence names in the FASTA file: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY', 'chrM', 'GL000008.2', 'GL000009.2', 'GL000194.1', 'GL000195.1', 'GL000205.2', 'GL000208.1', 'GL000213.1', 'GL000214.1', 'GL000216.2', 'GL000218.1', 'GL000219.1', 'GL000220.1', 'GL000221.1', 'GL000224.1', 'GL000225.1', 'GL000226.1', 'KI270302.1', 'KI270303.1', 'KI270304.1', 'KI270305.1', 'KI270310.1', 'KI270311.1', 'KI270312.1', 'KI270315.1', 'KI270316.1', 'KI270317.1', 'KI270320.1', 'KI270322.1', 'KI270329.1', 'KI270330.1', 'KI270333.1', 'KI270334.1', 'KI270335.1', 'KI270336.1', 'KI270337.1', 'KI270338.1', 'KI270340.1', 'KI270362.1', 'KI270363.1', 'KI270364.1', 'KI270366.1', 'KI270371.1', 'KI270372.1', 'KI270373.1', 'KI270374.1', 'KI270375.1', 'KI270376.1', 'KI270378.1', 'KI270379.1', 'KI270381.1', 'KI270382.1', 'KI270383.1', 'KI270384.1', 'KI270385.1', 'KI270386.1', 'KI270387.1', 'KI270388.1', 'KI270389.1', 'KI270390.1', 'KI270391.1', 'KI270392.1', 'KI270393.1', 'KI270394.1', 'KI270395.1', 'KI270396.1', 'KI270411.1', 'KI270412.1', 'KI270414.1', 'KI270417.1', 'KI270418.1', 'KI270419.1', 'KI270420.1', 'KI270422.1', 'KI270423.1', 'KI270424.1', 'KI270425.1', 'KI270429.1', 'KI270435.1', 'KI270438.1', 'KI270442.1', 'KI270448.1', 'KI270465.1', 'KI270466.1', 'KI270467.1', 'KI270468.1', 'KI270507.1', 'KI270508.1', 'KI270509.1', 'KI270510.1', 'KI270511.1', 'KI270512.1', 'KI270515.1', 'KI270516.1', 'KI270517.1', 'KI270518.1', 'KI270519.1', 'KI270521.1', 'KI270522.1', 'KI270528.1', 'KI270529.1', 'KI270530.1', 'KI270538.1', 'KI270539.1', 'KI270544.1', 'KI270548.1', 'KI270579.1', 'KI270580.1', 'KI270581.1', 'KI270582.1', 'KI270583.1', 'KI270584.1', 'KI270587.1', 'KI270588.1', 'KI270589.1', 'KI270590.1', 'KI270591.1', 'KI270593.1', 'KI270706.1', 'KI270707.1', 'KI270708.1', 'KI270709.1', 'KI270710.1', 'KI270711.1', 'KI270712.1', 'KI270713.1', 'KI270714.1', 'KI270715.1', 'KI270716.1', 'KI270717.1', 'KI270718.1', 'KI270719.1', 'KI270720.1', 'KI270721.1', 'KI270722.1', 'KI270723.1', 'KI270724.1', 'KI270725.1', 'KI270726.1', 'KI270727.1', 'KI270728.1', 'KI270729.1', 'KI270730.1', 'KI270731.1', 'KI270732.1', 'KI270733.1', 'KI270734.1', 'KI270735.1', 'KI270736.1', 'KI270737.1', 'KI270738.1', 'KI270739.1', 'KI270740.1', 'KI270741.1', 'KI270742.1', 'KI270743.1', 'KI270744.1', 'KI270745.1', 'KI270746.1', 'KI270747.1', 'KI270748.1', 'KI270749.1', 'KI270750.1', 'KI270751.1', 'KI270752.1', 'KI270753.1', 'KI270754.1', 'KI270755.1', 'KI270756.1', 'KI270757.1']

# %%
dnabert_raw_data = {}
for key, value in loaded_dictionary.items():
    #display(value[['chr_name', 'start', 'end', 'strand', 'transcript_type', 'CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT']])
    print("CODE STARTED")
    print(key, value.shape)
    #ins_del_df = value[(value['ALT'].str.len() > value['REF'].str.len()) | (value['REF'].str.len() > value['ALT'].str.len())]
    new_df, df_kmer = get_sequences(value, reference_fasta)
    dnabert_raw_data[key] = new_df
    
    #input()
    out_folder_path = output_path+"Patient_wise/"+ key
    print(out_folder_path, "is created")
    if not os.path.exists(out_folder_path):
        os.makedirs(out_folder_path)
    df_kmer.to_csv(out_folder_path + "/dev.tsv", sep="\t", index= False)
# Out:
# CODE STARTED
# 9e35e7c1-b8e9-441b-9520-3195359f8e43_sanger_raw_pindel (2543, 24)
# (2543, 12)
# &*
# (5086, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9e35e7c1-b8e9-441b-9520-3195359f8e43_sanger_raw_pindel is created
# CODE STARTED
# 2c5b021f-f9e1-4a42-8755-8704f006016b_sanger_raw_pindel (2837, 24)
# (2834, 12)
# &*
# (5668, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2c5b021f-f9e1-4a42-8755-8704f006016b_sanger_raw_pindel is created
# CODE STARTED
# 1d3daf9d-7740-484e-850b-827a6b7d451d_CaVEMan (123, 27)
# (123, 12)
# &*
# (246, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/1d3daf9d-7740-484e-850b-827a6b7d451d_CaVEMan is created
# CODE STARTED
# 54d621a5-8e45-4bbc-92c4-1c7f36212361_sanger_raw_pindel (2567, 24)
# (2566, 12)
# &*
# (5132, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/54d621a5-8e45-4bbc-92c4-1c7f36212361_sanger_raw_pindel is created
# CODE STARTED
# 07f93ac0-50e0-4c1d-b4da-898062a5b6b8_CaVEMan (173, 27)
# (173, 12)
# &*
# (346, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/07f93ac0-50e0-4c1d-b4da-898062a5b6b8_CaVEMan is created
# CODE STARTED
# f37e99f6-0108-48da-b8bb-b041394bf194_CaVEMan (261, 27)
# (261, 12)
# &*
# (522, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f37e99f6-0108-48da-b8bb-b041394bf194_CaVEMan is created
# CODE STARTED
# 3a531416-d811-4dea-9507-cd6286a85a7f_sanger_raw_pindel (2592, 24)
# (2592, 12)
# &*
# (5184, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3a531416-d811-4dea-9507-cd6286a85a7f_sanger_raw_pindel is created
# CODE STARTED
# 96a823e7-9a5c-4a58-a424-a051cf4f4b29_sanger_raw_pindel (2614, 24)
# (2614, 12)
# &*
# (5228, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/96a823e7-9a5c-4a58-a424-a051cf4f4b29_sanger_raw_pindel is created
# CODE STARTED
# e420f20d-792a-4ea1-92cf-995cbcbc91b7_CaVEMan (191, 27)
# (191, 12)
# &*
# (382, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e420f20d-792a-4ea1-92cf-995cbcbc91b7_CaVEMan is created
# CODE STARTED
# ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1_sanger_raw_pindel (3429, 24)
# (3427, 12)
# &*
# (6854, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1_sanger_raw_pindel is created
# CODE STARTED
# b20bcb30-fa83-4da4-85f7-e55efefd6ea1_CaVEMan (120, 27)
# (120, 12)
# &*
# (240, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b20bcb30-fa83-4da4-85f7-e55efefd6ea1_CaVEMan is created
# CODE STARTED
# b0218338-6d83-491f-b51d-844d209f54b3_CaVEMan (172, 27)
# (172, 12)
# &*
# (344, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b0218338-6d83-491f-b51d-844d209f54b3_CaVEMan is created
# CODE STARTED
# 2f48d7c8-1a93-4c71-8b96-2ea6fc7c7478_CaVEMan (173, 27)
# (173, 12)
# &*
# (346, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2f48d7c8-1a93-4c71-8b96-2ea6fc7c7478_CaVEMan is created
# CODE STARTED
# 09fc667c-0462-49c1-8ab6-a0ce2a80b3c9_sanger_raw_pindel (2611, 24)
# (2611, 12)
# &*
# (5222, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/09fc667c-0462-49c1-8ab6-a0ce2a80b3c9_sanger_raw_pindel is created
# CODE STARTED
# 3f11b5e7-dc63-4116-a60c-1b8c9e5f6cd2_CaVEMan (1085, 27)
# (1085, 12)
# &*
# (2170, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3f11b5e7-dc63-4116-a60c-1b8c9e5f6cd2_CaVEMan is created
# CODE STARTED
# b38d4d3c-9994-41fe-8559-46ad3c339d9e_CaVEMan (111, 27)
# (111, 12)
# &*
# (222, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b38d4d3c-9994-41fe-8559-46ad3c339d9e_CaVEMan is created
# CODE STARTED
# 9c9fa09e-4db1-4f42-b64b-7c7302b81c29_sanger_raw_pindel (2640, 24)
# (2640, 12)
# &*
# (5280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9c9fa09e-4db1-4f42-b64b-7c7302b81c29_sanger_raw_pindel is created
# CODE STARTED
# 9a2beddf-39e1-4ed9-8654-2ebad59e71d3_sanger_raw_pindel (2923, 24)
# (2919, 12)
# &*
# (5838, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9a2beddf-39e1-4ed9-8654-2ebad59e71d3_sanger_raw_pindel is created
# CODE STARTED
# 432e2c06-8ce1-462b-84cf-10e601601654_sanger_raw_pindel (2654, 24)
# (2654, 12)
# &*
# (5308, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/432e2c06-8ce1-462b-84cf-10e601601654_sanger_raw_pindel is created
# CODE STARTED
# 4b8b2d4f-7d98-47d1-a4d2-34dfa17b9c68_sanger_raw_pindel (2591, 24)
# (2591, 12)
# &*
# (5182, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4b8b2d4f-7d98-47d1-a4d2-34dfa17b9c68_sanger_raw_pindel is created
# CODE STARTED
# 6e784527-f65d-48bc-9eb8-5f14230bb909_sanger_raw_pindel (2532, 24)
# (2532, 12)
# &*
# (5064, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6e784527-f65d-48bc-9eb8-5f14230bb909_sanger_raw_pindel is created
# CODE STARTED
# 5443dde1-df0d-4ddd-8a42-c9b8c17bf30c_sanger_raw_pindel (3036, 24)
# (3033, 12)
# &*
# (6066, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5443dde1-df0d-4ddd-8a42-c9b8c17bf30c_sanger_raw_pindel is created
# CODE STARTED
# 890b509a-fedd-4cd3-959b-515f8ff0e7ed_sanger_raw_pindel (2617, 24)
# (2617, 12)
# &*
# (5234, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/890b509a-fedd-4cd3-959b-515f8ff0e7ed_sanger_raw_pindel is created
# CODE STARTED
# f45d1f3c-c34f-4def-bb78-03d6fc3cc6fc_sanger_raw_pindel (3373, 24)
# (3370, 12)
# &*
# (6740, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f45d1f3c-c34f-4def-bb78-03d6fc3cc6fc_sanger_raw_pindel is created
# CODE STARTED
# 09943319-e446-4462-b6a6-6e7f08af8775_CaVEMan (162, 27)
# (162, 12)
# &*
# (324, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/09943319-e446-4462-b6a6-6e7f08af8775_CaVEMan is created
# CODE STARTED
# e570a351-99be-4019-9eae-4bda80014c63_CaVEMan (203, 27)
# (203, 12)
# &*
# (406, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e570a351-99be-4019-9eae-4bda80014c63_CaVEMan is created
# CODE STARTED
# 8c749b96-8fd0-41d9-84ce-7f74e500b095_CaVEMan (164, 27)
# (164, 12)
# &*
# (328, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/8c749b96-8fd0-41d9-84ce-7f74e500b095_CaVEMan is created
# CODE STARTED
# 0cba3131-13e4-44db-abdc-d7c9e711137c_CaVEMan (165, 27)
# (165, 12)
# &*
# (330, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0cba3131-13e4-44db-abdc-d7c9e711137c_CaVEMan is created
# CODE STARTED
# 3b89e48e-3e35-402f-b7f0-6e773839de4e_CaVEMan (202, 27)
# (202, 12)
# &*
# (404, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3b89e48e-3e35-402f-b7f0-6e773839de4e_CaVEMan is created
# CODE STARTED
# 890b509a-fedd-4cd3-959b-515f8ff0e7ed_CaVEMan (152, 27)
# (152, 12)
# &*
# (304, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/890b509a-fedd-4cd3-959b-515f8ff0e7ed_CaVEMan is created
# CODE STARTED
# 2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_CaVEMan (112, 27)
# (112, 12)
# &*
# (224, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_CaVEMan is created
# CODE STARTED
# 6ab2b17b-fef4-4451-b366-329f4bba3fdb_sanger_raw_pindel (2672, 24)
# (2672, 12)
# &*
# (5344, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6ab2b17b-fef4-4451-b366-329f4bba3fdb_sanger_raw_pindel is created
# CODE STARTED
# dd045b58-4d6a-4404-a412-6aa9e99e282e_CaVEMan (223, 27)
# (223, 12)
# &*
# (446, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/dd045b58-4d6a-4404-a412-6aa9e99e282e_CaVEMan is created
# CODE STARTED
# cb50a28d-47d9-4b34-9515-9dfd7a03ac14_CaVEMan (176, 27)
# (176, 12)
# &*
# (352, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/cb50a28d-47d9-4b34-9515-9dfd7a03ac14_CaVEMan is created
# CODE STARTED
# 053e38af-bce4-4e7a-84a2-f5badeb4ce7d_CaVEMan (195, 27)
# (195, 12)
# &*
# (390, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/053e38af-bce4-4e7a-84a2-f5badeb4ce7d_CaVEMan is created
# CODE STARTED
# 0f158d5f-16c7-4fb7-b48c-0ff392f1706b_sanger_raw_pindel (2623, 24)
# (2623, 12)
# &*
# (5246, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0f158d5f-16c7-4fb7-b48c-0ff392f1706b_sanger_raw_pindel is created
# CODE STARTED
# 67c83385-8497-4c2d-932e-9a3b9bb90ec9_CaVEMan (146, 27)
# (146, 12)
# &*
# (292, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/67c83385-8497-4c2d-932e-9a3b9bb90ec9_CaVEMan is created
# CODE STARTED
# b845bff2-f0eb-4375-95f0-0ebecab03c29_CaVEMan (193, 27)
# (193, 12)
# &*
# (386, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b845bff2-f0eb-4375-95f0-0ebecab03c29_CaVEMan is created
# CODE STARTED
# 54d3a64c-00f6-4cc2-8263-2c84b8309371_CaVEMan (120, 27)
# (120, 12)
# &*
# (240, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/54d3a64c-00f6-4cc2-8263-2c84b8309371_CaVEMan is created
# CODE STARTED
# 97121631-b6cd-4f6f-9dfb-1c3a668150e2_CaVEMan (161, 27)
# (161, 12)
# &*
# (322, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/97121631-b6cd-4f6f-9dfb-1c3a668150e2_CaVEMan is created
# CODE STARTED
# b2fdc5e6-fcac-4ffa-8287-111d9bae30e0_sanger_raw_pindel (2590, 24)
# (2589, 12)
# &*
# (5178, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b2fdc5e6-fcac-4ffa-8287-111d9bae30e0_sanger_raw_pindel is created
# CODE STARTED
# e420f20d-792a-4ea1-92cf-995cbcbc91b7_sanger_raw_pindel (2644, 24)
# (2644, 12)
# &*
# (5288, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e420f20d-792a-4ea1-92cf-995cbcbc91b7_sanger_raw_pindel is created
# CODE STARTED
# 309343e2-1a1b-4651-a0af-118cdc8abd75_CaVEMan (332, 27)
# (332, 12)
# &*
# (664, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/309343e2-1a1b-4651-a0af-118cdc8abd75_CaVEMan is created
# CODE STARTED
# d6cb373e-d9bc-43a1-8edc-2199b38b95f7_CaVEMan (199, 27)
# (199, 12)
# &*
# (398, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d6cb373e-d9bc-43a1-8edc-2199b38b95f7_CaVEMan is created
# CODE STARTED
# bda972d3-48e6-4781-8692-a3effd0aa91c_CaVEMan (291, 27)
# (291, 12)
# &*
# (582, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/bda972d3-48e6-4781-8692-a3effd0aa91c_CaVEMan is created
# CODE STARTED
# a08a494c-e685-4f80-981f-68a0d19b9a38_sanger_raw_pindel (2622, 24)
# (2622, 12)
# &*
# (5244, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/a08a494c-e685-4f80-981f-68a0d19b9a38_sanger_raw_pindel is created
# CODE STARTED
# bf01253b-df8a-4e9d-afe1-21a4b0cf777e_sanger_raw_pindel (2665, 24)
# (2664, 12)
# &*
# (5328, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/bf01253b-df8a-4e9d-afe1-21a4b0cf777e_sanger_raw_pindel is created
# CODE STARTED
# 8350a310-4c75-4f7d-b47d-1ee4d1ebab13_sanger_raw_pindel (2581, 24)
# (2581, 12)
# &*
# (5162, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/8350a310-4c75-4f7d-b47d-1ee4d1ebab13_sanger_raw_pindel is created
# CODE STARTED
# 7ffc1178-c3fa-4c19-b49c-004d327df6f0_CaVEMan (184, 27)
# (184, 12)
# &*
# (368, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/7ffc1178-c3fa-4c19-b49c-004d327df6f0_CaVEMan is created
# CODE STARTED
# d36bdeac-1edf-4599-ac3d-b42811ec5b18_CaVEMan (127, 27)
# (127, 12)
# &*
# (254, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d36bdeac-1edf-4599-ac3d-b42811ec5b18_CaVEMan is created
# CODE STARTED
# ce08aa4a-de2d-44f3-88ed-84313aa294af_sanger_raw_pindel (2934, 24)
# (2933, 12)
# &*
# (5866, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/ce08aa4a-de2d-44f3-88ed-84313aa294af_sanger_raw_pindel is created
# CODE STARTED
# 184bba0f-b80e-41da-aef8-d54cd7193f11_sanger_raw_pindel (2621, 24)
# (2621, 12)
# &*
# (5242, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/184bba0f-b80e-41da-aef8-d54cd7193f11_sanger_raw_pindel is created
# CODE STARTED
# 9b7a2f48-e658-41b9-9d4a-68d83082cc29_CaVEMan (232, 27)
# (232, 12)
# &*
# (464, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9b7a2f48-e658-41b9-9d4a-68d83082cc29_CaVEMan is created
# CODE STARTED
# da5fbf8f-862d-49a6-8119-86f508063e29_sanger_raw_pindel (2573, 24)
# (2573, 12)
# &*
# (5146, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/da5fbf8f-862d-49a6-8119-86f508063e29_sanger_raw_pindel is created
# CODE STARTED
# 3e40a973-7f9d-400a-8990-634196168c13_CaVEMan (134, 27)
# (134, 12)
# &*
# (268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3e40a973-7f9d-400a-8990-634196168c13_CaVEMan is created
# CODE STARTED
# 03ba06a3-5dc6-4dad-84ed-7fe3196d7402_sanger_raw_pindel (3245, 24)
# (3244, 12)
# &*
# (6488, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/03ba06a3-5dc6-4dad-84ed-7fe3196d7402_sanger_raw_pindel is created
# CODE STARTED
# 9f7f9c66-39bb-48b1-ae8e-91acc8028425_CaVEMan (213, 27)
# (213, 12)
# &*
# (426, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9f7f9c66-39bb-48b1-ae8e-91acc8028425_CaVEMan is created
# CODE STARTED
# e2beccb1-840b-4e6a-84e5-b07e25289593_CaVEMan (1118, 27)
# (1118, 12)
# &*
# (2236, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e2beccb1-840b-4e6a-84e5-b07e25289593_CaVEMan is created
# CODE STARTED
# b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_CaVEMan (215, 27)
# (215, 12)
# &*
# (430, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_CaVEMan is created
# CODE STARTED
# 03bdaae4-92e0-4229-9657-94510e2c3db7_CaVEMan (187, 27)
# (187, 12)
# &*
# (374, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/03bdaae4-92e0-4229-9657-94510e2c3db7_CaVEMan is created
# CODE STARTED
# af56a9e4-b896-4d47-b9c0-930eb68862bd_sanger_raw_pindel (2694, 24)
# (2694, 12)
# &*
# (5388, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/af56a9e4-b896-4d47-b9c0-930eb68862bd_sanger_raw_pindel is created
# CODE STARTED
# a55817f2-61f8-43f3-a017-7585f5f29121_CaVEMan (1156, 27)
# (1156, 12)
# &*
# (2312, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/a55817f2-61f8-43f3-a017-7585f5f29121_CaVEMan is created
# CODE STARTED
# 447a08c8-3488-45d1-9262-23c42341296f_sanger_raw_pindel (2599, 24)
# (2599, 12)
# &*
# (5198, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/447a08c8-3488-45d1-9262-23c42341296f_sanger_raw_pindel is created
# CODE STARTED
# cb2bb421-2b7c-4c1c-9020-4e7012b3fc2c_CaVEMan (1709, 27)
# (1709, 12)
# &*
# (3418, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/cb2bb421-2b7c-4c1c-9020-4e7012b3fc2c_CaVEMan is created
# CODE STARTED
# 9e35e7c1-b8e9-441b-9520-3195359f8e43_CaVEMan (198, 27)
# (198, 12)
# &*
# (396, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9e35e7c1-b8e9-441b-9520-3195359f8e43_CaVEMan is created
# CODE STARTED
# 038750e2-9994-4420-bfa9-a3756683ddd1_sanger_raw_pindel (2587, 24)
# (2587, 12)
# &*
# (5174, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/038750e2-9994-4420-bfa9-a3756683ddd1_sanger_raw_pindel is created
# CODE STARTED
# e28e9e35-1eba-4eb9-998f-ac7b9eb3f6ca_sanger_raw_pindel (2628, 24)
# (2628, 12)
# &*
# (5256, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e28e9e35-1eba-4eb9-998f-ac7b9eb3f6ca_sanger_raw_pindel is created
# CODE STARTED
# 24abc004-6712-4df9-83f2-bd98dcc6ea5e_sanger_raw_pindel (2566, 24)
# (2566, 12)
# &*
# (5132, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/24abc004-6712-4df9-83f2-bd98dcc6ea5e_sanger_raw_pindel is created
# CODE STARTED
# 4f11a51f-c10a-4e56-b193-4e8d1cadf21c_CaVEMan (227, 27)
# (227, 12)
# &*
# (454, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4f11a51f-c10a-4e56-b193-4e8d1cadf21c_CaVEMan is created
# CODE STARTED
# 3adc47fa-b27a-4df1-98ab-201ebab3c6bf_CaVEMan (2369, 27)
# (2369, 12)
# &*
# (4738, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3adc47fa-b27a-4df1-98ab-201ebab3c6bf_CaVEMan is created
# CODE STARTED
# b0a32ca7-5793-4f50-97f8-8adf5254a205_sanger_raw_pindel (2556, 24)
# (2556, 12)
# &*
# (5112, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b0a32ca7-5793-4f50-97f8-8adf5254a205_sanger_raw_pindel is created
# CODE STARTED
# cc884f4d-e62d-4214-bfaa-81052a02a246_CaVEMan (166, 27)
# (166, 12)
# &*
# (332, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/cc884f4d-e62d-4214-bfaa-81052a02a246_CaVEMan is created
# CODE STARTED
# 4905d6d3-7595-43dd-98ae-f507ebb7dff4_CaVEMan (1266, 27)
# (1266, 12)
# &*
# (2532, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4905d6d3-7595-43dd-98ae-f507ebb7dff4_CaVEMan is created
# CODE STARTED
# 3824268d-4d2e-4811-9efe-906c3a37005d_CaVEMan (191, 27)
# (191, 12)
# &*
# (382, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3824268d-4d2e-4811-9efe-906c3a37005d_CaVEMan is created
# CODE STARTED
# 535e0e9e-9757-45b3-aafd-2b80908de134_sanger_raw_pindel (2642, 24)
# (2642, 12)
# &*
# (5284, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/535e0e9e-9757-45b3-aafd-2b80908de134_sanger_raw_pindel is created
# CODE STARTED
# 0733a98f-95bd-4aa5-b908-c9cc314cfc15_sanger_raw_pindel (2601, 24)
# (2601, 12)
# &*
# (5202, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0733a98f-95bd-4aa5-b908-c9cc314cfc15_sanger_raw_pindel is created
# CODE STARTED
# 0691dda3-8f8d-4677-9a79-ff91e50ce19f_CaVEMan (210, 27)
# (210, 12)
# &*
# (420, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0691dda3-8f8d-4677-9a79-ff91e50ce19f_CaVEMan is created
# CODE STARTED
# b2eaaa93-e870-4b1c-a835-b1d932c75b88_sanger_raw_pindel (2883, 24)
# (2883, 12)
# &*
# (5766, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b2eaaa93-e870-4b1c-a835-b1d932c75b88_sanger_raw_pindel is created
# CODE STARTED
# b330f405-d765-4b01-ab1b-4c9a396f6c2b_CaVEMan (203, 27)
# (203, 12)
# &*
# (406, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b330f405-d765-4b01-ab1b-4c9a396f6c2b_CaVEMan is created
# CODE STARTED
# cfecd6d7-930a-40f1-8161-f2b4a37dc9fb_CaVEMan (153, 27)
# (153, 12)
# &*
# (306, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/cfecd6d7-930a-40f1-8161-f2b4a37dc9fb_CaVEMan is created
# CODE STARTED
# db856976-cd46-494d-bdc8-b4f3608cf10d_CaVEMan (1321, 27)
# (1321, 12)
# &*
# (2642, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/db856976-cd46-494d-bdc8-b4f3608cf10d_CaVEMan is created
# CODE STARTED
# f37e99f6-0108-48da-b8bb-b041394bf194_sanger_raw_pindel (2629, 24)
# (2629, 12)
# &*
# (5258, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f37e99f6-0108-48da-b8bb-b041394bf194_sanger_raw_pindel is created
# CODE STARTED
# 5fe46057-1c78-4e85-befa-ba04610ecd10_CaVEMan (222, 27)
# (222, 12)
# &*
# (444, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5fe46057-1c78-4e85-befa-ba04610ecd10_CaVEMan is created
# CODE STARTED
# c844a8f1-9588-4e70-a89c-12014aeef8a7_CaVEMan (1999, 27)
# (1999, 12)
# &*
# (3998, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/c844a8f1-9588-4e70-a89c-12014aeef8a7_CaVEMan is created
# CODE STARTED
# 3d9d175b-20dc-4916-afa0-95b9acbbec02_CaVEMan (187, 27)
# (187, 12)
# &*
# (374, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3d9d175b-20dc-4916-afa0-95b9acbbec02_CaVEMan is created
# CODE STARTED
# d716a0ce-10ef-4c47-912a-9ba374898ffe_CaVEMan (174, 27)
# (174, 12)
# &*
# (348, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d716a0ce-10ef-4c47-912a-9ba374898ffe_CaVEMan is created
# CODE STARTED
# 6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1_CaVEMan (133, 27)
# (133, 12)
# &*
# (266, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1_CaVEMan is created
# CODE STARTED
# da5fbf8f-862d-49a6-8119-86f508063e29_CaVEMan (210, 27)
# (210, 12)
# &*
# (420, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/da5fbf8f-862d-49a6-8119-86f508063e29_CaVEMan is created
# CODE STARTED
# 0fc04044-0b33-4af6-a800-01d8cda12702_CaVEMan (127, 27)
# (127, 12)
# &*
# (254, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0fc04044-0b33-4af6-a800-01d8cda12702_CaVEMan is created
# CODE STARTED
# 812d6f3d-c4f9-4e10-9039-4ebe9b3100c3_CaVEMan (200, 27)
# (200, 12)
# &*
# (400, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/812d6f3d-c4f9-4e10-9039-4ebe9b3100c3_CaVEMan is created
# CODE STARTED
# 715eb351-d741-4dfe-95b4-6618c48ab5a9_CaVEMan (1421, 27)
# (1421, 12)
# &*
# (2842, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/715eb351-d741-4dfe-95b4-6618c48ab5a9_CaVEMan is created
# CODE STARTED
# b5b88df3-ba1e-48a9-b45f-7ac4d282ad76_CaVEMan (1454, 27)
# (1454, 12)
# &*
# (2908, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b5b88df3-ba1e-48a9-b45f-7ac4d282ad76_CaVEMan is created
# CODE STARTED
# 8db95363-6eb3-4a90-affd-0c948a05c27c_CaVEMan (780, 27)
# (780, 12)
# &*
# (1560, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/8db95363-6eb3-4a90-affd-0c948a05c27c_CaVEMan is created
# CODE STARTED
# 3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_CaVEMan (210, 27)
# (210, 12)
# &*
# (420, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_CaVEMan is created
# CODE STARTED
# bb91fbd6-7e62-4a15-9e60-3d95e26f4aec_CaVEMan (149, 27)
# (149, 12)
# &*
# (298, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/bb91fbd6-7e62-4a15-9e60-3d95e26f4aec_CaVEMan is created
# CODE STARTED
# 350c00b7-9287-4fb5-a8ef-4bc9cdb19e50_CaVEMan (221, 27)
# (221, 12)
# &*
# (442, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/350c00b7-9287-4fb5-a8ef-4bc9cdb19e50_CaVEMan is created
# CODE STARTED
# 2cfd51ad-618c-4193-81ee-52bdd92e0cc8_sanger_raw_pindel (2604, 24)
# (2604, 12)
# &*
# (5208, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2cfd51ad-618c-4193-81ee-52bdd92e0cc8_sanger_raw_pindel is created
# CODE STARTED
# 93f3f095-f6d4-40f4-845f-fb313af513a0_sanger_raw_pindel (2714, 24)
# (2714, 12)
# &*
# (5428, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/93f3f095-f6d4-40f4-845f-fb313af513a0_sanger_raw_pindel is created
# CODE STARTED
# 62dd1c1f-e4c3-496f-8ca3-bedd0f7e8211_CaVEMan (185, 27)
# (185, 12)
# &*
# (370, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/62dd1c1f-e4c3-496f-8ca3-bedd0f7e8211_CaVEMan is created
# CODE STARTED
# 7d01d7c7-5138-4883-a4e3-c763151943df_CaVEMan (152, 27)
# (152, 12)
# &*
# (304, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/7d01d7c7-5138-4883-a4e3-c763151943df_CaVEMan is created
# CODE STARTED
# bf01253b-df8a-4e9d-afe1-21a4b0cf777e_CaVEMan (181, 27)
# (181, 12)
# &*
# (362, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/bf01253b-df8a-4e9d-afe1-21a4b0cf777e_CaVEMan is created
# CODE STARTED
# f2851c73-3fa8-455f-9dc1-128ff4f1bc41_CaVEMan (159, 27)
# (159, 12)
# &*
# (318, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f2851c73-3fa8-455f-9dc1-128ff4f1bc41_CaVEMan is created
# CODE STARTED
# 9555409b-2f6c-4d24-9b39-5b8183cb3f8c_sanger_raw_pindel (2613, 24)
# (2613, 12)
# &*
# (5226, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9555409b-2f6c-4d24-9b39-5b8183cb3f8c_sanger_raw_pindel is created
# CODE STARTED
# e40fc3cf-2691-47df-a5f3-87e5bbcd9a50_sanger_raw_pindel (2543, 24)
# (2543, 12)
# &*
# (5086, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e40fc3cf-2691-47df-a5f3-87e5bbcd9a50_sanger_raw_pindel is created
# CODE STARTED
# f277dc80-abac-41d1-a23f-460da23b2555_CaVEMan (259, 27)
# (259, 12)
# &*
# (518, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f277dc80-abac-41d1-a23f-460da23b2555_CaVEMan is created
# CODE STARTED
# 5d65b3c0-5c29-48aa-b6fb-37baf78fe409_CaVEMan (157, 27)
# (157, 12)
# &*
# (314, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5d65b3c0-5c29-48aa-b6fb-37baf78fe409_CaVEMan is created
# CODE STARTED
# 432e2c06-8ce1-462b-84cf-10e601601654_CaVEMan (233, 27)
# (233, 12)
# &*
# (466, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/432e2c06-8ce1-462b-84cf-10e601601654_CaVEMan is created
# CODE STARTED
# 03bdaae4-92e0-4229-9657-94510e2c3db7_sanger_raw_pindel (2656, 24)
# (2656, 12)
# &*
# (5312, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/03bdaae4-92e0-4229-9657-94510e2c3db7_sanger_raw_pindel is created
# CODE STARTED
# a5dba504-f9af-4ad7-8dd2-4d719440b569_CaVEMan (852, 27)
# (852, 12)
# &*
# (1704, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/a5dba504-f9af-4ad7-8dd2-4d719440b569_CaVEMan is created
# CODE STARTED
# a58b5cd5-4625-4070-b672-4eb92cd7775c_sanger_raw_pindel (3027, 24)
# (3025, 12)
# &*
# (6050, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/a58b5cd5-4625-4070-b672-4eb92cd7775c_sanger_raw_pindel is created
# CODE STARTED
# a6302a12-8657-44b4-95c1-3fbeb0cf9bf1_sanger_raw_pindel (2981, 24)
# (2974, 12)
# &*
# (5948, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/a6302a12-8657-44b4-95c1-3fbeb0cf9bf1_sanger_raw_pindel is created
# CODE STARTED
# cf565879-9f53-4fd1-b0da-065869293342_sanger_raw_pindel (2588, 24)
# (2588, 12)
# &*
# (5176, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/cf565879-9f53-4fd1-b0da-065869293342_sanger_raw_pindel is created
# CODE STARTED
# 6650dfa0-01b8-411a-bc01-bf1cad6c111b_sanger_raw_pindel (2591, 24)
# (2591, 12)
# &*
# (5182, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6650dfa0-01b8-411a-bc01-bf1cad6c111b_sanger_raw_pindel is created
# CODE STARTED
# 4193ad47-7cab-48fe-9466-aec494172f72_CaVEMan (193, 27)
# (193, 12)
# &*
# (386, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4193ad47-7cab-48fe-9466-aec494172f72_CaVEMan is created
# CODE STARTED
# f2a6974c-658d-4da7-a8dc-bd0d4a7a19e4_sanger_raw_pindel (2638, 24)
# (2638, 12)
# &*
# (5276, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f2a6974c-658d-4da7-a8dc-bd0d4a7a19e4_sanger_raw_pindel is created
# CODE STARTED
# 1cc1ee58-e45c-4d85-b163-6d097f9d8f1f_CaVEMan (175, 27)
# (175, 12)
# &*
# (350, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/1cc1ee58-e45c-4d85-b163-6d097f9d8f1f_CaVEMan is created
# CODE STARTED
# 0fc04044-0b33-4af6-a800-01d8cda12702_sanger_raw_pindel (2606, 24)
# (2606, 12)
# &*
# (5212, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0fc04044-0b33-4af6-a800-01d8cda12702_sanger_raw_pindel is created
# CODE STARTED
# 4132ab70-457f-41a9-aae3-340f9fe109e2_CaVEMan (198, 27)
# (198, 12)
# &*
# (396, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4132ab70-457f-41a9-aae3-340f9fe109e2_CaVEMan is created
# CODE STARTED
# 2c8c8efe-48eb-4b04-9bd7-9c621a887609_sanger_raw_pindel (2598, 24)
# (2598, 12)
# &*
# (5196, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2c8c8efe-48eb-4b04-9bd7-9c621a887609_sanger_raw_pindel is created
# CODE STARTED
# cc884f4d-e62d-4214-bfaa-81052a02a246_sanger_raw_pindel (2569, 24)
# (2569, 12)
# &*
# (5138, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/cc884f4d-e62d-4214-bfaa-81052a02a246_sanger_raw_pindel is created
# CODE STARTED
# f2a6974c-658d-4da7-a8dc-bd0d4a7a19e4_CaVEMan (142, 27)
# (142, 12)
# &*
# (284, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f2a6974c-658d-4da7-a8dc-bd0d4a7a19e4_CaVEMan is created
# CODE STARTED
# 762bed3b-5d4a-41f6-9198-831f5c7a7348_sanger_raw_pindel (5201, 24)
# (5199, 12)
# &*
# (10398, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/762bed3b-5d4a-41f6-9198-831f5c7a7348_sanger_raw_pindel is created
# CODE STARTED
# d9410fc4-1d9e-4fc0-bf39-5188714586e4_sanger_raw_pindel (3001, 24)
# (2995, 12)
# &*
# (5990, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d9410fc4-1d9e-4fc0-bf39-5188714586e4_sanger_raw_pindel is created
# CODE STARTED
# 0733a98f-95bd-4aa5-b908-c9cc314cfc15_CaVEMan (118, 27)
# (118, 12)
# &*
# (236, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0733a98f-95bd-4aa5-b908-c9cc314cfc15_CaVEMan is created
# CODE STARTED
# 4e8fe8a4-1788-4501-b0e0-d57b86f56e23_CaVEMan (172, 27)
# (172, 12)
# &*
# (344, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4e8fe8a4-1788-4501-b0e0-d57b86f56e23_CaVEMan is created
# CODE STARTED
# 02eb77ff-2e07-4d56-9c32-d9fa415c7ce2_sanger_raw_pindel (2690, 24)
# (2690, 12)
# &*
# (5380, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/02eb77ff-2e07-4d56-9c32-d9fa415c7ce2_sanger_raw_pindel is created
# CODE STARTED
# 6e784527-f65d-48bc-9eb8-5f14230bb909_CaVEMan (130, 27)
# (130, 12)
# &*
# (260, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6e784527-f65d-48bc-9eb8-5f14230bb909_CaVEMan is created
# CODE STARTED
# 5c3a5246-abf8-4c2e-95a0-00d969edff44_CaVEMan (1495, 27)
# (1495, 12)
# &*
# (2990, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5c3a5246-abf8-4c2e-95a0-00d969edff44_CaVEMan is created
# CODE STARTED
# 27dbf455-43fa-452c-aea6-494c65fc06af_CaVEMan (211, 27)
# (211, 12)
# &*
# (422, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/27dbf455-43fa-452c-aea6-494c65fc06af_CaVEMan is created
# CODE STARTED
# 4b38150a-2406-4f40-9f81-ee76e30f77b9_sanger_raw_pindel (2598, 24)
# (2598, 12)
# &*
# (5196, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4b38150a-2406-4f40-9f81-ee76e30f77b9_sanger_raw_pindel is created
# CODE STARTED
# aae9d68e-f0eb-486b-9520-0b9f547f1ad3_CaVEMan (147, 27)
# (147, 12)
# &*
# (294, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/aae9d68e-f0eb-486b-9520-0b9f547f1ad3_CaVEMan is created
# CODE STARTED
# 3f11b5e7-dc63-4116-a60c-1b8c9e5f6cd2_sanger_raw_pindel (2914, 24)
# (2912, 12)
# &*
# (5824, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3f11b5e7-dc63-4116-a60c-1b8c9e5f6cd2_sanger_raw_pindel is created
# CODE STARTED
# d101eddd-ad00-4a42-9a95-ece5bd2332a2_sanger_raw_pindel (2489, 24)
# (2489, 12)
# &*
# (4978, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d101eddd-ad00-4a42-9a95-ece5bd2332a2_sanger_raw_pindel is created
# CODE STARTED
# b5fb53b7-7a70-48a2-84ff-ca6ebe62d053_sanger_raw_pindel (2683, 24)
# (2683, 12)
# &*
# (5366, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b5fb53b7-7a70-48a2-84ff-ca6ebe62d053_sanger_raw_pindel is created
# CODE STARTED
# c9a63b40-b4c3-44ca-8a8c-eb42a538438d_sanger_raw_pindel (2872, 24)
# (2869, 12)
# &*
# (5738, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/c9a63b40-b4c3-44ca-8a8c-eb42a538438d_sanger_raw_pindel is created
# CODE STARTED
# 218059b3-97aa-4c4e-a228-2a27a2293789_sanger_raw_pindel (2905, 24)
# (2902, 12)
# &*
# (5804, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/218059b3-97aa-4c4e-a228-2a27a2293789_sanger_raw_pindel is created
# CODE STARTED
# 4f11a51f-c10a-4e56-b193-4e8d1cadf21c_sanger_raw_pindel (2644, 24)
# (2644, 12)
# &*
# (5288, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4f11a51f-c10a-4e56-b193-4e8d1cadf21c_sanger_raw_pindel is created
# CODE STARTED
# 0b66e90d-56ae-4857-933f-8df4ca7a202f_sanger_raw_pindel (2611, 24)
# (2611, 12)
# &*
# (5222, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0b66e90d-56ae-4857-933f-8df4ca7a202f_sanger_raw_pindel is created
# CODE STARTED
# 5834fc99-c986-4023-b646-78c1613dcc71_CaVEMan (96, 27)
# (96, 12)
# &*
# (192, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5834fc99-c986-4023-b646-78c1613dcc71_CaVEMan is created
# CODE STARTED
# 852ad6d3-e66a-4063-ba70-e2a97c50fca9_sanger_raw_pindel (2576, 24)
# (2576, 12)
# &*
# (5152, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/852ad6d3-e66a-4063-ba70-e2a97c50fca9_sanger_raw_pindel is created
# CODE STARTED
# 7bed15a4-3b1e-487e-954d-e6b55e296dc0_sanger_raw_pindel (2659, 24)
# (2658, 12)
# &*
# (5316, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/7bed15a4-3b1e-487e-954d-e6b55e296dc0_sanger_raw_pindel is created
# CODE STARTED
# f9554b80-de24-4930-b651-7b2ae3b4ba8c_CaVEMan (221, 27)
# (221, 12)
# &*
# (442, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f9554b80-de24-4930-b651-7b2ae3b4ba8c_CaVEMan is created
# CODE STARTED
# 9a3edc2a-0eb3-4d88-965d-2801cd19df51_CaVEMan (155, 27)
# (155, 12)
# &*
# (310, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9a3edc2a-0eb3-4d88-965d-2801cd19df51_CaVEMan is created
# CODE STARTED
# 3e40a973-7f9d-400a-8990-634196168c13_sanger_raw_pindel (2563, 24)
# (2563, 12)
# &*
# (5126, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3e40a973-7f9d-400a-8990-634196168c13_sanger_raw_pindel is created
# CODE STARTED
# db856976-cd46-494d-bdc8-b4f3608cf10d_sanger_raw_pindel (2972, 24)
# (2970, 12)
# &*
# (5940, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/db856976-cd46-494d-bdc8-b4f3608cf10d_sanger_raw_pindel is created
# CODE STARTED
# f3ad237d-b424-4ca4-9659-2ff88a42e584_CaVEMan (108, 27)
# (108, 12)
# &*
# (216, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f3ad237d-b424-4ca4-9659-2ff88a42e584_CaVEMan is created
# CODE STARTED
# af63b73a-b8aa-4a3e-8d82-9fd0f130e942_CaVEMan (160, 27)
# (160, 12)
# &*
# (320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/af63b73a-b8aa-4a3e-8d82-9fd0f130e942_CaVEMan is created
# CODE STARTED
# 455fc2b4-b5da-40ba-9330-b8eed45ef66b_CaVEMan (217, 27)
# (217, 12)
# &*
# (434, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/455fc2b4-b5da-40ba-9330-b8eed45ef66b_CaVEMan is created
# CODE STARTED
# 2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_sanger_raw_pindel (2550, 24)
# (2550, 12)
# &*
# (5100, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7_sanger_raw_pindel is created
# CODE STARTED
# e4330135-7dbe-42c2-998d-387c2f5a229a_sanger_raw_pindel (2400, 24)
# (2400, 12)
# &*
# (4800, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e4330135-7dbe-42c2-998d-387c2f5a229a_sanger_raw_pindel is created
# CODE STARTED
# 4b38150a-2406-4f40-9f81-ee76e30f77b9_CaVEMan (134, 27)
# (134, 12)
# &*
# (268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4b38150a-2406-4f40-9f81-ee76e30f77b9_CaVEMan is created
# CODE STARTED
# 410db725-9a2f-4df3-8ace-6eedd4988cec_CaVEMan (1972, 27)
# (1972, 12)
# &*
# (3944, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/410db725-9a2f-4df3-8ace-6eedd4988cec_CaVEMan is created
# CODE STARTED
# f076e644-bc06-4a93-8754-785d2c33371e_CaVEMan (155, 27)
# (155, 12)
# &*
# (310, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f076e644-bc06-4a93-8754-785d2c33371e_CaVEMan is created
# CODE STARTED
# 97121631-b6cd-4f6f-9dfb-1c3a668150e2_sanger_raw_pindel (2529, 24)
# (2529, 12)
# &*
# (5058, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/97121631-b6cd-4f6f-9dfb-1c3a668150e2_sanger_raw_pindel is created
# CODE STARTED
# b330f405-d765-4b01-ab1b-4c9a396f6c2b_sanger_raw_pindel (2641, 24)
# (2641, 12)
# &*
# (5282, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b330f405-d765-4b01-ab1b-4c9a396f6c2b_sanger_raw_pindel is created
# CODE STARTED
# 948b350f-fc72-4694-9c71-b67e71f57351_sanger_raw_pindel (2620, 24)
# (2618, 12)
# &*
# (5236, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/948b350f-fc72-4694-9c71-b67e71f57351_sanger_raw_pindel is created
# CODE STARTED
# 6b579148-fb81-4e57-a9ff-c282a0a1b848_CaVEMan (204, 27)
# (204, 12)
# &*
# (408, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6b579148-fb81-4e57-a9ff-c282a0a1b848_CaVEMan is created
# CODE STARTED
# b0218338-6d83-491f-b51d-844d209f54b3_sanger_raw_pindel (2618, 24)
# (2618, 12)
# &*
# (5236, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b0218338-6d83-491f-b51d-844d209f54b3_sanger_raw_pindel is created
# CODE STARTED
# bb91fbd6-7e62-4a15-9e60-3d95e26f4aec_sanger_raw_pindel (2642, 24)
# (2642, 12)
# &*
# (5284, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/bb91fbd6-7e62-4a15-9e60-3d95e26f4aec_sanger_raw_pindel is created
# CODE STARTED
# 0ccd86e3-96fd-4cfb-b0dd-16247e0571e2_CaVEMan (2217, 27)
# (2217, 12)
# &*
# (4434, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0ccd86e3-96fd-4cfb-b0dd-16247e0571e2_CaVEMan is created
# CODE STARTED
# 038750e2-9994-4420-bfa9-a3756683ddd1_CaVEMan (133, 27)
# (133, 12)
# &*
# (266, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/038750e2-9994-4420-bfa9-a3756683ddd1_CaVEMan is created
# CODE STARTED
# 09fc667c-0462-49c1-8ab6-a0ce2a80b3c9_CaVEMan (240, 27)
# (240, 12)
# &*
# (480, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/09fc667c-0462-49c1-8ab6-a0ce2a80b3c9_CaVEMan is created
# CODE STARTED
# 69cd1c55-296a-4f72-9ada-b846d6c88175_CaVEMan (1528, 27)
# (1528, 12)
# &*
# (3056, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/69cd1c55-296a-4f72-9ada-b846d6c88175_CaVEMan is created
# CODE STARTED
# b78b66b2-2983-4965-99ff-8a7e45a07d8f_sanger_raw_pindel (3494, 24)
# (3490, 12)
# &*
# (6980, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b78b66b2-2983-4965-99ff-8a7e45a07d8f_sanger_raw_pindel is created
# CODE STARTED
# 798dfed8-b716-4958-88cf-e32a5294c4bc_sanger_raw_pindel (2543, 24)
# (2543, 12)
# &*
# (5086, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/798dfed8-b716-4958-88cf-e32a5294c4bc_sanger_raw_pindel is created
# CODE STARTED
# 4eb5be8a-421e-4f46-bbdb-c8688f140f48_CaVEMan (138, 27)
# (138, 12)
# &*
# (276, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4eb5be8a-421e-4f46-bbdb-c8688f140f48_CaVEMan is created
# CODE STARTED
# 03c1c33e-c4a8-4c31-8a29-0d8b3e7bda83_sanger_raw_pindel (2668, 24)
# (2667, 12)
# &*
# (5334, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/03c1c33e-c4a8-4c31-8a29-0d8b3e7bda83_sanger_raw_pindel is created
# CODE STARTED
# 756521ee-9f67-49e6-9cea-d2d933750d74_sanger_raw_pindel (2596, 24)
# (2596, 12)
# &*
# (5192, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/756521ee-9f67-49e6-9cea-d2d933750d74_sanger_raw_pindel is created
# CODE STARTED
# cf565879-9f53-4fd1-b0da-065869293342_CaVEMan (156, 27)
# (156, 12)
# &*
# (312, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/cf565879-9f53-4fd1-b0da-065869293342_CaVEMan is created
# CODE STARTED
# ce08aa4a-de2d-44f3-88ed-84313aa294af_CaVEMan (1257, 27)
# (1257, 12)
# &*
# (2514, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/ce08aa4a-de2d-44f3-88ed-84313aa294af_CaVEMan is created
# CODE STARTED
# fd27f3fc-6f0b-4794-8555-3111ad520493_sanger_raw_pindel (2534, 24)
# (2534, 12)
# &*
# (5068, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/fd27f3fc-6f0b-4794-8555-3111ad520493_sanger_raw_pindel is created
# CODE STARTED
# 49718673-b69a-4d8b-a00c-b6595aa5848b_CaVEMan (229, 27)
# (229, 12)
# &*
# (458, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/49718673-b69a-4d8b-a00c-b6595aa5848b_CaVEMan is created
# CODE STARTED
# 410db725-9a2f-4df3-8ace-6eedd4988cec_sanger_raw_pindel (3386, 24)
# (3386, 12)
# &*
# (6772, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/410db725-9a2f-4df3-8ace-6eedd4988cec_sanger_raw_pindel is created
# CODE STARTED
# b4b13f9e-a571-43dd-86d7-6c01601ca3a8_sanger_raw_pindel (2634, 24)
# (2634, 12)
# &*
# (5268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b4b13f9e-a571-43dd-86d7-6c01601ca3a8_sanger_raw_pindel is created
# CODE STARTED
# 8bac8b71-abb7-4ecc-9b61-7112fed7da15_CaVEMan (113, 27)
# (113, 12)
# &*
# (226, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/8bac8b71-abb7-4ecc-9b61-7112fed7da15_CaVEMan is created
# CODE STARTED
# 6ab2b17b-fef4-4451-b366-329f4bba3fdb_CaVEMan (208, 27)
# (208, 12)
# &*
# (416, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6ab2b17b-fef4-4451-b366-329f4bba3fdb_CaVEMan is created
# CODE STARTED
# b845bff2-f0eb-4375-95f0-0ebecab03c29_sanger_raw_pindel (2529, 24)
# (2529, 12)
# &*
# (5058, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b845bff2-f0eb-4375-95f0-0ebecab03c29_sanger_raw_pindel is created
# CODE STARTED
# f00eed55-0ad9-41e8-bdf2-144b43f9b9b8_sanger_raw_pindel (2533, 24)
# (2533, 12)
# &*
# (5066, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f00eed55-0ad9-41e8-bdf2-144b43f9b9b8_sanger_raw_pindel is created
# CODE STARTED
# 2f48d7c8-1a93-4c71-8b96-2ea6fc7c7478_sanger_raw_pindel (2625, 24)
# (2625, 12)
# &*
# (5250, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2f48d7c8-1a93-4c71-8b96-2ea6fc7c7478_sanger_raw_pindel is created
# CODE STARTED
# 948b350f-fc72-4694-9c71-b67e71f57351_CaVEMan (215, 27)
# (215, 12)
# &*
# (430, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/948b350f-fc72-4694-9c71-b67e71f57351_CaVEMan is created
# CODE STARTED
# 1bd7e755-4353-437a-ab8c-69e3df92824d_sanger_raw_pindel (2590, 24)
# (2590, 12)
# &*
# (5180, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/1bd7e755-4353-437a-ab8c-69e3df92824d_sanger_raw_pindel is created
# CODE STARTED
# 762bed3b-5d4a-41f6-9198-831f5c7a7348_CaVEMan (537, 27)
# (537, 12)
# &*
# (1074, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/762bed3b-5d4a-41f6-9198-831f5c7a7348_CaVEMan is created
# CODE STARTED
# f15d872a-7e31-4111-9d92-5ac813a8bc4f_CaVEMan (177, 27)
# (177, 12)
# &*
# (354, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f15d872a-7e31-4111-9d92-5ac813a8bc4f_CaVEMan is created
# CODE STARTED
# 7577bbca-7ad7-4058-bf0e-787b38c673aa_sanger_raw_pindel (2633, 24)
# (2633, 12)
# &*
# (5266, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/7577bbca-7ad7-4058-bf0e-787b38c673aa_sanger_raw_pindel is created
# CODE STARTED
# 6ba2bd1e-3062-4778-bd42-d26f533505ba_sanger_raw_pindel (2602, 24)
# (2602, 12)
# &*
# (5204, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6ba2bd1e-3062-4778-bd42-d26f533505ba_sanger_raw_pindel is created
# CODE STARTED
# 22653df8-0c37-4f24-8832-95dd239f49b6_sanger_raw_pindel (2597, 24)
# (2597, 12)
# &*
# (5194, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/22653df8-0c37-4f24-8832-95dd239f49b6_sanger_raw_pindel is created
# CODE STARTED
# b4b13f9e-a571-43dd-86d7-6c01601ca3a8_CaVEMan (187, 27)
# (187, 12)
# &*
# (374, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b4b13f9e-a571-43dd-86d7-6c01601ca3a8_CaVEMan is created
# CODE STARTED
# f15d872a-7e31-4111-9d92-5ac813a8bc4f_sanger_raw_pindel (2595, 24)
# (2595, 12)
# &*
# (5190, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f15d872a-7e31-4111-9d92-5ac813a8bc4f_sanger_raw_pindel is created
# CODE STARTED
# 2eb74322-a9f0-4dec-befc-b086386102a5_CaVEMan (166, 27)
# (166, 12)
# &*
# (332, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2eb74322-a9f0-4dec-befc-b086386102a5_CaVEMan is created
# CODE STARTED
# 535e0e9e-9757-45b3-aafd-2b80908de134_CaVEMan (259, 27)
# (259, 12)
# &*
# (518, 2)
# ...
# CODE STARTED
# 6ce0f8f2-a580-40a3-9b25-54a1ac040ac3_CaVEMan (188, 27)
# (188, 12)
# &*
# (376, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6ce0f8f2-a580-40a3-9b25-54a1ac040ac3_CaVEMan is created
# CODE STARTED
# 12d99dd9-7d89-4964-8077-9873109a0303_CaVEMan (1523, 27)
# (1523, 12)
# &*
# (3046, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/12d99dd9-7d89-4964-8077-9873109a0303_CaVEMan is created
# CODE STARTED
# 6e42d5ce-7b2f-40d1-82af-1b29f27b89d7_CaVEMan (125, 27)
# (125, 12)
# &*
# (250, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6e42d5ce-7b2f-40d1-82af-1b29f27b89d7_CaVEMan is created
# CODE STARTED
# 90c2456b-af8b-4e31-ae86-7de05a0f4124_CaVEMan (1113, 27)
# (1113, 12)
# &*
# (2226, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/90c2456b-af8b-4e31-ae86-7de05a0f4124_CaVEMan is created
# CODE STARTED
# 935fb4b5-91c3-4b57-b18a-d33597f1221c_sanger_raw_pindel (2592, 24)
# (2592, 12)
# &*
# (5184, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/935fb4b5-91c3-4b57-b18a-d33597f1221c_sanger_raw_pindel is created
# CODE STARTED
# 8da9bde9-4b8c-46a2-bcc2-a620a186bab3_CaVEMan (161, 27)
# (161, 12)
# &*
# (322, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/8da9bde9-4b8c-46a2-bcc2-a620a186bab3_CaVEMan is created
# CODE STARTED
# b38d4d3c-9994-41fe-8559-46ad3c339d9e_sanger_raw_pindel (2435, 24)
# (2435, 12)
# &*
# (4870, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b38d4d3c-9994-41fe-8559-46ad3c339d9e_sanger_raw_pindel is created
# CODE STARTED
# eef24407-c46d-45c3-9934-86902ac3ceac_CaVEMan (160, 27)
# (160, 12)
# &*
# (320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/eef24407-c46d-45c3-9934-86902ac3ceac_CaVEMan is created
# CODE STARTED
# 0cba3131-13e4-44db-abdc-d7c9e711137c_sanger_raw_pindel (2624, 24)
# (2624, 12)
# &*
# (5248, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0cba3131-13e4-44db-abdc-d7c9e711137c_sanger_raw_pindel is created
# CODE STARTED
# 324bda04-9380-4bf8-9ebd-6f28759a5393_sanger_raw_pindel (2651, 24)
# (2651, 12)
# &*
# (5302, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/324bda04-9380-4bf8-9ebd-6f28759a5393_sanger_raw_pindel is created
# CODE STARTED
# d36bdeac-1edf-4599-ac3d-b42811ec5b18_sanger_raw_pindel (2512, 24)
# (2512, 12)
# &*
# (5024, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d36bdeac-1edf-4599-ac3d-b42811ec5b18_sanger_raw_pindel is created
# CODE STARTED
# c6b9e176-a36b-4eb2-aa15-6a0155c1aeb5_CaVEMan (213, 27)
# (213, 12)
# &*
# (426, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/c6b9e176-a36b-4eb2-aa15-6a0155c1aeb5_CaVEMan is created
# CODE STARTED
# 09943319-e446-4462-b6a6-6e7f08af8775_sanger_raw_pindel (2586, 24)
# (2586, 12)
# &*
# (5172, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/09943319-e446-4462-b6a6-6e7f08af8775_sanger_raw_pindel is created
# CODE STARTED
# f90f1702-d5f1-43f4-b167-2c440f941bf6_CaVEMan (243, 27)
# (243, 12)
# &*
# (486, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f90f1702-d5f1-43f4-b167-2c440f941bf6_CaVEMan is created
# CODE STARTED
# 60647a7d-45c2-4b62-aa5b-8373774f14df_sanger_raw_pindel (2598, 24)
# (2598, 12)
# &*
# (5196, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/60647a7d-45c2-4b62-aa5b-8373774f14df_sanger_raw_pindel is created
# CODE STARTED
# c6b9e176-a36b-4eb2-aa15-6a0155c1aeb5_sanger_raw_pindel (2591, 24)
# (2591, 12)
# &*
# (5182, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/c6b9e176-a36b-4eb2-aa15-6a0155c1aeb5_sanger_raw_pindel is created
# CODE STARTED
# 2c8c8efe-48eb-4b04-9bd7-9c621a887609_CaVEMan (142, 27)
# (142, 12)
# &*
# (284, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2c8c8efe-48eb-4b04-9bd7-9c621a887609_CaVEMan is created
# CODE STARTED
# 8350a310-4c75-4f7d-b47d-1ee4d1ebab13_CaVEMan (212, 27)
# (212, 12)
# &*
# (424, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/8350a310-4c75-4f7d-b47d-1ee4d1ebab13_CaVEMan is created
# CODE STARTED
# f2851c73-3fa8-455f-9dc1-128ff4f1bc41_sanger_raw_pindel (2504, 24)
# (2504, 12)
# &*
# (5008, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f2851c73-3fa8-455f-9dc1-128ff4f1bc41_sanger_raw_pindel is created
# CODE STARTED
# dd9fc4a4-afd5-4fc8-8a76-5b341c38ecba_sanger_raw_pindel (2631, 24)
# (2631, 12)
# &*
# (5262, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/dd9fc4a4-afd5-4fc8-8a76-5b341c38ecba_sanger_raw_pindel is created
# CODE STARTED
# 5136de1c-084e-4165-b932-eebc4c765cc8_CaVEMan (298, 27)
# (298, 12)
# &*
# (596, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5136de1c-084e-4165-b932-eebc4c765cc8_CaVEMan is created
# CODE STARTED
# 12d99dd9-7d89-4964-8077-9873109a0303_sanger_raw_pindel (2922, 24)
# (2920, 12)
# &*
# (5840, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/12d99dd9-7d89-4964-8077-9873109a0303_sanger_raw_pindel is created
# CODE STARTED
# 9b51bdd3-0ec9-42ca-9a09-a978bcef3ab0_CaVEMan (196, 27)
# (196, 12)
# &*
# (392, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9b51bdd3-0ec9-42ca-9a09-a978bcef3ab0_CaVEMan is created
# CODE STARTED
# 54d621a5-8e45-4bbc-92c4-1c7f36212361_CaVEMan (153, 27)
# (153, 12)
# &*
# (306, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/54d621a5-8e45-4bbc-92c4-1c7f36212361_CaVEMan is created
# CODE STARTED
# b2fdc5e6-fcac-4ffa-8287-111d9bae30e0_CaVEMan (193, 27)
# (193, 12)
# &*
# (386, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b2fdc5e6-fcac-4ffa-8287-111d9bae30e0_CaVEMan is created
# CODE STARTED
# 324bda04-9380-4bf8-9ebd-6f28759a5393_CaVEMan (149, 27)
# (149, 12)
# &*
# (298, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/324bda04-9380-4bf8-9ebd-6f28759a5393_CaVEMan is created
# CODE STARTED
# f701f323-9730-49f0-bbba-37a2f7566282_sanger_raw_pindel (2644, 24)
# (2644, 12)
# &*
# (5288, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f701f323-9730-49f0-bbba-37a2f7566282_sanger_raw_pindel is created
# CODE STARTED
# 03777cdf-6779-4d23-93af-5b74fb982d7b_CaVEMan (143, 27)
# (143, 12)
# &*
# (286, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/03777cdf-6779-4d23-93af-5b74fb982d7b_CaVEMan is created
# CODE STARTED
# 3e28bc65-988d-4112-9397-7773ec79a9a9_CaVEMan (1267, 27)
# (1267, 12)
# &*
# (2534, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3e28bc65-988d-4112-9397-7773ec79a9a9_CaVEMan is created
# CODE STARTED
# f45d1f3c-c34f-4def-bb78-03d6fc3cc6fc_CaVEMan (2146, 27)
# (2146, 12)
# &*
# (4292, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f45d1f3c-c34f-4def-bb78-03d6fc3cc6fc_CaVEMan is created
# CODE STARTED
# 6643318c-9d33-4434-a98a-ceefa9c5c157_sanger_raw_pindel (2691, 24)
# (2691, 12)
# &*
# (5382, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6643318c-9d33-4434-a98a-ceefa9c5c157_sanger_raw_pindel is created
# CODE STARTED
# 0ccd86e3-96fd-4cfb-b0dd-16247e0571e2_sanger_raw_pindel (2906, 24)
# (2905, 12)
# &*
# (5810, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0ccd86e3-96fd-4cfb-b0dd-16247e0571e2_sanger_raw_pindel is created
# CODE STARTED
# a97e1e32-967f-4275-ac62-6ff478e82973_CaVEMan (300, 27)
# (300, 12)
# &*
# (600, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/a97e1e32-967f-4275-ac62-6ff478e82973_CaVEMan is created
# CODE STARTED
# 18d154c8-cdcf-4606-ac66-099b22cfd0e8_CaVEMan (223, 27)
# (223, 12)
# &*
# (446, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/18d154c8-cdcf-4606-ac66-099b22cfd0e8_CaVEMan is created
# CODE STARTED
# e40fc3cf-2691-47df-a5f3-87e5bbcd9a50_CaVEMan (164, 27)
# (164, 12)
# &*
# (328, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e40fc3cf-2691-47df-a5f3-87e5bbcd9a50_CaVEMan is created
# CODE STARTED
# 5c3a5246-abf8-4c2e-95a0-00d969edff44_sanger_raw_pindel (3223, 24)
# (3221, 12)
# &*
# (6442, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5c3a5246-abf8-4c2e-95a0-00d969edff44_sanger_raw_pindel is created
# CODE STARTED
# 5710b72b-8318-49f9-937a-f775a5c8c160_sanger_raw_pindel (2634, 24)
# (2634, 12)
# &*
# (5268, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/5710b72b-8318-49f9-937a-f775a5c8c160_sanger_raw_pindel is created
# CODE STARTED
# 3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_sanger_raw_pindel (2587, 24)
# (2587, 12)
# &*
# (5174, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3adefeae-8c71-47a0-a9d5-3d0005aa0ef4_sanger_raw_pindel is created
# CODE STARTED
# 959b7cb2-b128-42de-8558-fe7d3eca74fd_sanger_raw_pindel (2626, 24)
# (2626, 12)
# &*
# (5252, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/959b7cb2-b128-42de-8558-fe7d3eca74fd_sanger_raw_pindel is created
# CODE STARTED
# 798dfed8-b716-4958-88cf-e32a5294c4bc_CaVEMan (143, 27)
# (143, 12)
# &*
# (286, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/798dfed8-b716-4958-88cf-e32a5294c4bc_CaVEMan is created
# CODE STARTED
# d481a290-6b89-442b-b5f3-c855e34bb3ca_sanger_raw_pindel (2643, 24)
# (2643, 12)
# &*
# (5286, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d481a290-6b89-442b-b5f3-c855e34bb3ca_sanger_raw_pindel is created
# CODE STARTED
# 93f3f095-f6d4-40f4-845f-fb313af513a0_CaVEMan (175, 27)
# (175, 12)
# &*
# (350, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/93f3f095-f6d4-40f4-845f-fb313af513a0_CaVEMan is created
# CODE STARTED
# 7ffc1178-c3fa-4c19-b49c-004d327df6f0_sanger_raw_pindel (2664, 24)
# (2664, 12)
# &*
# (5328, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/7ffc1178-c3fa-4c19-b49c-004d327df6f0_sanger_raw_pindel is created
# CODE STARTED
# b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_sanger_raw_pindel (2686, 24)
# (2686, 12)
# &*
# (5372, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b01b9f70-fc7d-43d1-bc8a-6c435ffd3705_sanger_raw_pindel is created
# CODE STARTED
# 9a3edc2a-0eb3-4d88-965d-2801cd19df51_sanger_raw_pindel (2349, 24)
# (2349, 12)
# &*
# (4698, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9a3edc2a-0eb3-4d88-965d-2801cd19df51_sanger_raw_pindel is created
# CODE STARTED
# 053e38af-bce4-4e7a-84a2-f5badeb4ce7d_sanger_raw_pindel (2627, 24)
# (2626, 12)
# &*
# (5252, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/053e38af-bce4-4e7a-84a2-f5badeb4ce7d_sanger_raw_pindel is created
# CODE STARTED
# d6cb373e-d9bc-43a1-8edc-2199b38b95f7_sanger_raw_pindel (2620, 24)
# (2620, 12)
# &*
# (5240, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/d6cb373e-d9bc-43a1-8edc-2199b38b95f7_sanger_raw_pindel is created
# CODE STARTED
# b5d89740-5891-4229-b002-9ccb43ddb270_sanger_raw_pindel (2605, 24)
# (2605, 12)
# &*
# (5210, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b5d89740-5891-4229-b002-9ccb43ddb270_sanger_raw_pindel is created
# CODE STARTED
# 9b7a2f48-e658-41b9-9d4a-68d83082cc29_sanger_raw_pindel (2585, 24)
# (2585, 12)
# &*
# (5170, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/9b7a2f48-e658-41b9-9d4a-68d83082cc29_sanger_raw_pindel is created
# CODE STARTED
# 3ef06a77-9df6-401c-8b2b-2bfcbf6944e8_CaVEMan (156, 27)
# (156, 12)
# &*
# (312, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/3ef06a77-9df6-401c-8b2b-2bfcbf6944e8_CaVEMan is created
# CODE STARTED
# 6ba2bd1e-3062-4778-bd42-d26f533505ba_CaVEMan (160, 27)
# (160, 12)
# &*
# (320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/6ba2bd1e-3062-4778-bd42-d26f533505ba_CaVEMan is created
# CODE STARTED
# e4330135-7dbe-42c2-998d-387c2f5a229a_CaVEMan (133, 27)
# (133, 12)
# &*
# (266, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/e4330135-7dbe-42c2-998d-387c2f5a229a_CaVEMan is created
# CODE STARTED
# b5b88df3-ba1e-48a9-b45f-7ac4d282ad76_sanger_raw_pindel (2994, 24)
# (2990, 12)
# &*
# (5980, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/b5b88df3-ba1e-48a9-b45f-7ac4d282ad76_sanger_raw_pindel is created
# CODE STARTED
# a97e1e32-967f-4275-ac62-6ff478e82973_sanger_raw_pindel (2716, 24)
# (2716, 12)
# &*
# (5432, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/a97e1e32-967f-4275-ac62-6ff478e82973_sanger_raw_pindel is created
# CODE STARTED
# 0f396f9e-2143-4473-a4df-8f624906961a_sanger_raw_pindel (2707, 24)
# (2707, 12)
# &*
# (5414, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/0f396f9e-2143-4473-a4df-8f624906961a_sanger_raw_pindel is created
# CODE STARTED
# dd9fc4a4-afd5-4fc8-8a76-5b341c38ecba_CaVEMan (222, 27)
# (222, 12)
# &*
# (444, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/dd9fc4a4-afd5-4fc8-8a76-5b341c38ecba_CaVEMan is created
# CODE STARTED
# 4905d6d3-7595-43dd-98ae-f507ebb7dff4_sanger_raw_pindel (2861, 24)
# (2861, 12)
# &*
# (5722, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/4905d6d3-7595-43dd-98ae-f507ebb7dff4_sanger_raw_pindel is created
# CODE STARTED
# 2cfd51ad-618c-4193-81ee-52bdd92e0cc8_CaVEMan (228, 27)
# (228, 12)
# &*
# (456, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/2cfd51ad-618c-4193-81ee-52bdd92e0cc8_CaVEMan is created
# CODE STARTED
# 02eb77ff-2e07-4d56-9c32-d9fa415c7ce2_CaVEMan (204, 27)
# (204, 12)
# &*
# (408, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/02eb77ff-2e07-4d56-9c32-d9fa415c7ce2_CaVEMan is created
# CODE STARTED
# fdfbb80c-8e66-499a-ac59-f311d6f4b6fa_sanger_raw_pindel (2604, 24)
# (2604, 12)
# &*
# (5208, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/fdfbb80c-8e66-499a-ac59-f311d6f4b6fa_sanger_raw_pindel is created
# CODE STARTED
# c9a63b40-b4c3-44ca-8a8c-eb42a538438d_CaVEMan (1603, 27)
# (1603, 12)
# &*
# (3206, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/c9a63b40-b4c3-44ca-8a8c-eb42a538438d_CaVEMan is created
# CODE STARTED
# 7d9bd465-2e99-4b07-902f-752fa348efb8_sanger_raw_pindel (2967, 24)
# (2966, 12)
# &*
# (5932, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/7d9bd465-2e99-4b07-902f-752fa348efb8_sanger_raw_pindel is created
# CODE STARTED
# f701f323-9730-49f0-bbba-37a2f7566282_CaVEMan (168, 27)
# (168, 12)
# &*
# (336, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Brain/Generated_files/DNABERT_Data/donor/Patient_wise/f701f323-9730-49f0-bbba-37a2f7566282_CaVEMan is created

# %%
with open(output_path+"/raw_{}_vcf_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(dnabert_raw_data, file)
