# %%
import os, glob
import pandas as pd
import pysam
import numpy as np
import pickle

# %%
cancer_type = "Lung"
non_coding_region="acceptor"
intersected_data = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/Intersected_Data/intersected_vcf_{}_data.pkl".format(cancer_type, non_coding_region)
reference_path  = "/home/pdutta/Data/Human_Genome_Data/GRCh38.primary_assembly.genome.fa"

# %%
output_path = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/DNABERT_Data/{}/".format(cancer_type, non_coding_region)
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
def seq2kmer(seq):
    """
    Convert original sequence to kmers
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    k=6
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def get_sequences(df, reference_fasta):
    data = []
    for idx, row in df.iterrows():
        #print(row)
        chrom = row['chr_name']
        ref_start = row['start']
        ref_end = row['end']
        variant_start = row['START_POS']
        variant_end = row['END_POS']
        ref_nucleotide = row['REF']
        alt = row["ALT"]
        
        # Adjust for 0-based indexing in python
        variant_pos_start = variant_start - ref_start
        variant_pos_end = variant_end - ref_start
        #print(ref_nucleotide , alt, variant_pos_start, variant_pos_end)
        
        
        # Get reference sequence
        #print(chrom)
        ref_seq = reference_fasta.fetch(chrom, ref_start, ref_end)
        #print(ref_seq)
        
        # Handle insertion and deletion to get the correct alt sequence
        # Identify if the variant is an insertion or deletion
        if len(ref_nucleotide) < len(alt):  # Insertion
            delete_size =  len(alt) - len(ref_nucleotide)
            #print(variant_pos_start, variant_pos_end ,delete_size)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:len(ref_seq) - delete_size]

        elif len(ref_nucleotide) > len(alt):  # Deletion
            insert_size = len(ref_nucleotide) - len(alt)
            #print(insert_size)
            extra_bases = reference_fasta.fetch(chrom, ref_end, ref_end + insert_size)
            #print(extra_bases)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:] + extra_bases

        else:  # SNV
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:]
        # print(ref_seq)
        # print(alt_seq)
        # input()


        data.append({
            'chr': chrom,
            'strand': row['strand'],
            'Transcript_ID': row['transcript_id'],
            'Acceptor_start': row['start'],
            'Acceptor_end': row['end'],
            'varinat_start': variant_start,
            'variant_end': variant_end,
            'ref_neucleotide': ref_nucleotide,
            'alternative_neucleotide': alt,
            'reference_seq': ref_seq,
            'alt_seq': alt_seq
        })
            
    
    # Convert the list of dictionaries to a DataFrame
    new_df = pd.DataFrame(data)
    # print(new_df.shape)
    # print(new_df)
    new_df = new_df.drop_duplicates().reset_index()
    print(new_df.shape)
    print("&*")
    data = []
    merged_list = list(zip(new_df['reference_seq'], new_df['alt_seq']))
    merged_list = [item.upper() for tup in merged_list for item in tup]
    #print(merged_list)
    kmer_lst = list(map(seq2kmer, merged_list))
    df_kmer = pd.DataFrame(kmer_lst, columns=['Sequence'])
    df_kmer['Label'] = np.random.choice([0, 1], size=len(df_kmer))
    print(df_kmer.shape)
    return new_df, df_kmer

# %%
print(pd.__version__)
# Out:
# 2.1.1

# %%
## Load the VCF files from pickle
with open(intersected_data, "rb") as file:
    loaded_dictionary = pickle.load(file)
print("****All the VCF files are loaded***")
# Out:
# ****All the VCF files are loaded***

# %%
len(loaded_dictionary)
# Out:
# 824

# %%
## Load the reference file
reference_fasta = pysam.FastaFile(reference_path)
print("#####The reference file is loaded######")
# Out:
# #####The reference file is loaded######

# %%
# List all sequence names
sequence_names = reference_fasta.references
print("Sequence names in the FASTA file:", sequence_names)
# Out:
# Sequence names in the FASTA file: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY', 'chrM', 'GL000008.2', 'GL000009.2', 'GL000194.1', 'GL000195.1', 'GL000205.2', 'GL000208.1', 'GL000213.1', 'GL000214.1', 'GL000216.2', 'GL000218.1', 'GL000219.1', 'GL000220.1', 'GL000221.1', 'GL000224.1', 'GL000225.1', 'GL000226.1', 'KI270302.1', 'KI270303.1', 'KI270304.1', 'KI270305.1', 'KI270310.1', 'KI270311.1', 'KI270312.1', 'KI270315.1', 'KI270316.1', 'KI270317.1', 'KI270320.1', 'KI270322.1', 'KI270329.1', 'KI270330.1', 'KI270333.1', 'KI270334.1', 'KI270335.1', 'KI270336.1', 'KI270337.1', 'KI270338.1', 'KI270340.1', 'KI270362.1', 'KI270363.1', 'KI270364.1', 'KI270366.1', 'KI270371.1', 'KI270372.1', 'KI270373.1', 'KI270374.1', 'KI270375.1', 'KI270376.1', 'KI270378.1', 'KI270379.1', 'KI270381.1', 'KI270382.1', 'KI270383.1', 'KI270384.1', 'KI270385.1', 'KI270386.1', 'KI270387.1', 'KI270388.1', 'KI270389.1', 'KI270390.1', 'KI270391.1', 'KI270392.1', 'KI270393.1', 'KI270394.1', 'KI270395.1', 'KI270396.1', 'KI270411.1', 'KI270412.1', 'KI270414.1', 'KI270417.1', 'KI270418.1', 'KI270419.1', 'KI270420.1', 'KI270422.1', 'KI270423.1', 'KI270424.1', 'KI270425.1', 'KI270429.1', 'KI270435.1', 'KI270438.1', 'KI270442.1', 'KI270448.1', 'KI270465.1', 'KI270466.1', 'KI270467.1', 'KI270468.1', 'KI270507.1', 'KI270508.1', 'KI270509.1', 'KI270510.1', 'KI270511.1', 'KI270512.1', 'KI270515.1', 'KI270516.1', 'KI270517.1', 'KI270518.1', 'KI270519.1', 'KI270521.1', 'KI270522.1', 'KI270528.1', 'KI270529.1', 'KI270530.1', 'KI270538.1', 'KI270539.1', 'KI270544.1', 'KI270548.1', 'KI270579.1', 'KI270580.1', 'KI270581.1', 'KI270582.1', 'KI270583.1', 'KI270584.1', 'KI270587.1', 'KI270588.1', 'KI270589.1', 'KI270590.1', 'KI270591.1', 'KI270593.1', 'KI270706.1', 'KI270707.1', 'KI270708.1', 'KI270709.1', 'KI270710.1', 'KI270711.1', 'KI270712.1', 'KI270713.1', 'KI270714.1', 'KI270715.1', 'KI270716.1', 'KI270717.1', 'KI270718.1', 'KI270719.1', 'KI270720.1', 'KI270721.1', 'KI270722.1', 'KI270723.1', 'KI270724.1', 'KI270725.1', 'KI270726.1', 'KI270727.1', 'KI270728.1', 'KI270729.1', 'KI270730.1', 'KI270731.1', 'KI270732.1', 'KI270733.1', 'KI270734.1', 'KI270735.1', 'KI270736.1', 'KI270737.1', 'KI270738.1', 'KI270739.1', 'KI270740.1', 'KI270741.1', 'KI270742.1', 'KI270743.1', 'KI270744.1', 'KI270745.1', 'KI270746.1', 'KI270747.1', 'KI270748.1', 'KI270749.1', 'KI270750.1', 'KI270751.1', 'KI270752.1', 'KI270753.1', 'KI270754.1', 'KI270755.1', 'KI270756.1', 'KI270757.1']

# %%
dnabert_raw_data = {}
for key, value in loaded_dictionary.items():
    #display(value[['chr_name', 'start', 'end', 'strand', 'transcript_type', 'CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT']])
    print("CODE STARTED")
    print(key, value.shape)
    #ins_del_df = value[(value['ALT'].str.len() > value['REF'].str.len()) | (value['REF'].str.len() > value['ALT'].str.len())]
    new_df, df_kmer = get_sequences(value, reference_fasta)
    dnabert_raw_data[key] = new_df
    
    #input()
    out_folder_path = output_path+"Patient_wise/"+ key
    print(out_folder_path, "is created")
    if not os.path.exists(out_folder_path):
        os.makedirs(out_folder_path)
    df_kmer.to_csv(out_folder_path + "/dev.tsv", sep="\t", index= False)
# Out:
# CODE STARTED
# 5ae88ff4-b750-4eae-9991-e6b1c9145d97_sanger_raw_pindel (5397, 24)
# (5394, 12)
# &*
# (10788, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5ae88ff4-b750-4eae-9991-e6b1c9145d97_sanger_raw_pindel is created
# CODE STARTED
# f982a734-c385-4a31-b384-466fcba70880_sanger_raw_pindel (5666, 24)
# (5666, 12)
# &*
# (11332, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f982a734-c385-4a31-b384-466fcba70880_sanger_raw_pindel is created
# CODE STARTED
# be48b90f-c501-4b92-bfd8-dc3dc28939e9_sanger_raw_pindel (4448, 24)
# (4448, 12)
# &*
# (8896, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/be48b90f-c501-4b92-bfd8-dc3dc28939e9_sanger_raw_pindel is created
# CODE STARTED
# cef028fb-40ef-4a68-b75f-a8b9bb6055c3_CaVEMan (631, 27)
# (631, 12)
# &*
# (1262, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cef028fb-40ef-4a68-b75f-a8b9bb6055c3_CaVEMan is created
# CODE STARTED
# 2e5f1a81-3424-4cfd-b23c-121a452592a5_sanger_raw_pindel (4342, 24)
# (4342, 12)
# &*
# (8684, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/2e5f1a81-3424-4cfd-b23c-121a452592a5_sanger_raw_pindel is created
# CODE STARTED
# babb0ca1-0eca-4bf5-b5ff-4faec0a9c836_sanger_raw_pindel (5337, 24)
# (5334, 12)
# &*
# (10668, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/babb0ca1-0eca-4bf5-b5ff-4faec0a9c836_sanger_raw_pindel is created
# CODE STARTED
# 9ffea310-a2a7-4212-8083-cce0e9b40ed8_sanger_raw_pindel (4699, 24)
# (4697, 12)
# &*
# (9394, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/9ffea310-a2a7-4212-8083-cce0e9b40ed8_sanger_raw_pindel is created
# CODE STARTED
# e7b27e88-470c-467d-964c-cc01de2ea073_CaVEMan (485, 27)
# (485, 12)
# &*
# (970, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/e7b27e88-470c-467d-964c-cc01de2ea073_CaVEMan is created
# CODE STARTED
# 18e9819a-20e8-4ac3-a0d9-3291d35111d2_CaVEMan (152, 27)
# (152, 12)
# &*
# (304, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/18e9819a-20e8-4ac3-a0d9-3291d35111d2_CaVEMan is created
# CODE STARTED
# 80f3153d-148d-4800-a924-d64b6f59c9b6_sanger_raw_pindel (4565, 24)
# (4564, 12)
# &*
# (9128, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/80f3153d-148d-4800-a924-d64b6f59c9b6_sanger_raw_pindel is created
# CODE STARTED
# 56b38ebe-4168-46d1-aef9-5e0066ba653f_sanger_raw_pindel (4628, 24)
# (4628, 12)
# &*
# (9256, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/56b38ebe-4168-46d1-aef9-5e0066ba653f_sanger_raw_pindel is created
# CODE STARTED
# 594a7149-2b9d-42e6-a842-2978263a2d8b_CaVEMan (432, 27)
# (432, 12)
# &*
# (864, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/594a7149-2b9d-42e6-a842-2978263a2d8b_CaVEMan is created
# CODE STARTED
# ea912737-4296-49b8-bfd3-8dfb7b8b9bc4_sanger_raw_pindel (4361, 24)
# (4361, 12)
# &*
# (8722, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/ea912737-4296-49b8-bfd3-8dfb7b8b9bc4_sanger_raw_pindel is created
# CODE STARTED
# 683565c8-cd8c-41f5-abad-b626177d5c6f_sanger_raw_pindel (4652, 24)
# (4652, 12)
# &*
# (9304, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/683565c8-cd8c-41f5-abad-b626177d5c6f_sanger_raw_pindel is created
# CODE STARTED
# 04c212e7-d485-4621-b50f-2f2d9f2ea67f_CaVEMan (1078, 27)
# (1078, 12)
# &*
# (2156, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/04c212e7-d485-4621-b50f-2f2d9f2ea67f_CaVEMan is created
# CODE STARTED
# dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_CaVEMan (239, 27)
# (239, 12)
# &*
# (478, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_CaVEMan is created
# CODE STARTED
# 32564de4-55f3-4934-b529-a187c59d4d47_CaVEMan (1198, 27)
# (1198, 12)
# &*
# (2396, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/32564de4-55f3-4934-b529-a187c59d4d47_CaVEMan is created
# CODE STARTED
# 75de6374-86e9-49f9-ac40-6c4cde04f93c_CaVEMan (751, 27)
# (751, 12)
# &*
# (1502, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/75de6374-86e9-49f9-ac40-6c4cde04f93c_CaVEMan is created
# CODE STARTED
# 3530b926-f73b-4dcd-96fd-04a3f2f16031_sanger_raw_pindel (4650, 24)
# (4650, 12)
# &*
# (9300, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/3530b926-f73b-4dcd-96fd-04a3f2f16031_sanger_raw_pindel is created
# CODE STARTED
# c2042359-9e2c-4c98-b572-841cfd6c810b_CaVEMan (140, 27)
# (140, 12)
# &*
# (280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/c2042359-9e2c-4c98-b572-841cfd6c810b_CaVEMan is created
# CODE STARTED
# 056fdb85-1ab9-459c-a4ea-12216debe90e_sanger_raw_pindel (4509, 24)
# (4509, 12)
# &*
# (9018, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/056fdb85-1ab9-459c-a4ea-12216debe90e_sanger_raw_pindel is created
# CODE STARTED
# 0a309d4f-857c-4220-b60a-0998b6d51722_CaVEMan (433, 27)
# (433, 12)
# &*
# (866, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0a309d4f-857c-4220-b60a-0998b6d51722_CaVEMan is created
# CODE STARTED
# 0c64d792-066c-42d3-84c3-d47dd2aa9092_CaVEMan (286, 27)
# (286, 12)
# &*
# (572, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0c64d792-066c-42d3-84c3-d47dd2aa9092_CaVEMan is created
# CODE STARTED
# 1b9c2fd7-e722-4c95-9484-6914a907c3a7_sanger_raw_pindel (4638, 24)
# (4638, 12)
# &*
# (9276, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1b9c2fd7-e722-4c95-9484-6914a907c3a7_sanger_raw_pindel is created
# CODE STARTED
# b8337c01-f353-4c73-b872-0522dbb67b59_sanger_raw_pindel (4649, 24)
# (4649, 12)
# &*
# (9298, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b8337c01-f353-4c73-b872-0522dbb67b59_sanger_raw_pindel is created
# CODE STARTED
# d13f1cbf-ae03-41de-b5e4-3877bd1c403c_sanger_raw_pindel (4379, 24)
# (4379, 12)
# &*
# (8758, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d13f1cbf-ae03-41de-b5e4-3877bd1c403c_sanger_raw_pindel is created
# CODE STARTED
# 0b2a6149-872f-4178-a7df-d8308cdea3fd_sanger_raw_pindel (5254, 24)
# (5252, 12)
# &*
# (10504, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0b2a6149-872f-4178-a7df-d8308cdea3fd_sanger_raw_pindel is created
# CODE STARTED
# c242f484-ecd9-45b2-b0aa-cc7a5b2f50f3_sanger_raw_pindel (5385, 24)
# (5383, 12)
# &*
# (10766, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/c242f484-ecd9-45b2-b0aa-cc7a5b2f50f3_sanger_raw_pindel is created
# CODE STARTED
# 6dda24b6-ccab-479a-9850-e82418150f0e_sanger_raw_pindel (4230, 24)
# (4230, 12)
# &*
# (8460, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6dda24b6-ccab-479a-9850-e82418150f0e_sanger_raw_pindel is created
# CODE STARTED
# 61942802-dbad-47a9-a9a8-c79dbddc60e1_sanger_raw_pindel (4265, 24)
# (4265, 12)
# &*
# (8530, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/61942802-dbad-47a9-a9a8-c79dbddc60e1_sanger_raw_pindel is created
# CODE STARTED
# 4ac41ebb-7ab1-4f4e-84cd-903085da7f5c_CaVEMan (261, 27)
# (261, 12)
# &*
# (522, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/4ac41ebb-7ab1-4f4e-84cd-903085da7f5c_CaVEMan is created
# CODE STARTED
# f71cb7b1-f6b3-4988-b256-b8e4a1676d1e_CaVEMan (104, 27)
# (104, 12)
# &*
# (208, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f71cb7b1-f6b3-4988-b256-b8e4a1676d1e_CaVEMan is created
# CODE STARTED
# 2d7cfb46-769b-404e-8178-26c9c99cc72b_CaVEMan (1292, 27)
# (1292, 12)
# &*
# (2584, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/2d7cfb46-769b-404e-8178-26c9c99cc72b_CaVEMan is created
# CODE STARTED
# 726bc7b4-f9a0-4f45-893f-c716c137d654_CaVEMan (267, 27)
# (267, 12)
# &*
# (534, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/726bc7b4-f9a0-4f45-893f-c716c137d654_CaVEMan is created
# CODE STARTED
# 71c5b0fe-cb27-4bca-b78d-3ed8f15af0ad_CaVEMan (564, 27)
# (564, 12)
# &*
# (1128, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/71c5b0fe-cb27-4bca-b78d-3ed8f15af0ad_CaVEMan is created
# CODE STARTED
# 62e19451-8cab-4640-81b8-2ee11335580a_CaVEMan (576, 27)
# (576, 12)
# &*
# (1152, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/62e19451-8cab-4640-81b8-2ee11335580a_CaVEMan is created
# CODE STARTED
# 01608e28-91d8-402c-8a28-790800e16d22_CaVEMan (104, 27)
# (104, 12)
# &*
# (208, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/01608e28-91d8-402c-8a28-790800e16d22_CaVEMan is created
# CODE STARTED
# d3f69cdc-4d7f-4476-b7a7-34e25d89dc7f_sanger_raw_pindel (4566, 24)
# (4566, 12)
# &*
# (9132, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d3f69cdc-4d7f-4476-b7a7-34e25d89dc7f_sanger_raw_pindel is created
# CODE STARTED
# 84adb5c4-5c01-492d-84c4-a421ddf263a5_sanger_raw_pindel (4662, 24)
# (4661, 12)
# &*
# (9322, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/84adb5c4-5c01-492d-84c4-a421ddf263a5_sanger_raw_pindel is created
# CODE STARTED
# 6361dc74-12ef-4b3c-a52c-dd988a38929e_sanger_raw_pindel (4548, 24)
# (4548, 12)
# &*
# (9096, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6361dc74-12ef-4b3c-a52c-dd988a38929e_sanger_raw_pindel is created
# CODE STARTED
# cfb7b7d5-32f5-4771-b1d4-f92081f77332_sanger_raw_pindel (4624, 24)
# (4622, 12)
# &*
# (9244, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cfb7b7d5-32f5-4771-b1d4-f92081f77332_sanger_raw_pindel is created
# CODE STARTED
# 72a16568-e3c4-4055-814c-dc7e8717451a_sanger_raw_pindel (4387, 24)
# (4387, 12)
# &*
# (8774, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/72a16568-e3c4-4055-814c-dc7e8717451a_sanger_raw_pindel is created
# CODE STARTED
# d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_CaVEMan (229, 27)
# (229, 12)
# &*
# (458, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_CaVEMan is created
# CODE STARTED
# 19dd7b00-4492-46a1-a4f8-e29615372bdc_sanger_raw_pindel (4511, 24)
# (4510, 12)
# &*
# (9020, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/19dd7b00-4492-46a1-a4f8-e29615372bdc_sanger_raw_pindel is created
# CODE STARTED
# f368a047-d2a8-404f-97dd-1c2a8bf52497_CaVEMan (116, 27)
# (116, 12)
# &*
# (232, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f368a047-d2a8-404f-97dd-1c2a8bf52497_CaVEMan is created
# CODE STARTED
# 6a17dfb4-cf62-43f4-9b8c-f2ae482dd6ea_sanger_raw_pindel (4519, 24)
# (4519, 12)
# &*
# (9038, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6a17dfb4-cf62-43f4-9b8c-f2ae482dd6ea_sanger_raw_pindel is created
# CODE STARTED
# 38520d04-f833-4c2d-bb0f-f672efc3f948_sanger_raw_pindel (4386, 24)
# (4386, 12)
# &*
# (8772, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/38520d04-f833-4c2d-bb0f-f672efc3f948_sanger_raw_pindel is created
# CODE STARTED
# ee43b511-44d4-4466-a59e-67fae369046e_CaVEMan (949, 27)
# (949, 12)
# &*
# (1898, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/ee43b511-44d4-4466-a59e-67fae369046e_CaVEMan is created
# CODE STARTED
# 6972d298-0451-4b0b-a348-0a329dedde24_sanger_raw_pindel (4433, 24)
# (4433, 12)
# &*
# (8866, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6972d298-0451-4b0b-a348-0a329dedde24_sanger_raw_pindel is created
# CODE STARTED
# 5866b635-fa0d-4141-bd21-aaf8181fdc0a_sanger_raw_pindel (5354, 24)
# (5352, 12)
# &*
# (10704, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5866b635-fa0d-4141-bd21-aaf8181fdc0a_sanger_raw_pindel is created
# CODE STARTED
# 7ded5aec-8bfe-480e-9b11-5fbf7c523966_CaVEMan (321, 27)
# (321, 12)
# &*
# (642, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/7ded5aec-8bfe-480e-9b11-5fbf7c523966_CaVEMan is created
# CODE STARTED
# 08f4046a-15a2-4fe9-a9be-f71ceca3c6f8_sanger_raw_pindel (4482, 24)
# (4482, 12)
# &*
# (8964, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/08f4046a-15a2-4fe9-a9be-f71ceca3c6f8_sanger_raw_pindel is created
# CODE STARTED
# 099b611a-4414-44c3-9458-89b01425d7a4_sanger_raw_pindel (4755, 24)
# (4754, 12)
# &*
# (9508, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/099b611a-4414-44c3-9458-89b01425d7a4_sanger_raw_pindel is created
# CODE STARTED
# 6a5c4bc7-09c6-47f5-a735-4c178dd4e8ae_sanger_raw_pindel (5306, 24)
# (5303, 12)
# &*
# (10606, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6a5c4bc7-09c6-47f5-a735-4c178dd4e8ae_sanger_raw_pindel is created
# CODE STARTED
# 81f5ba7a-68fd-4091-9d7d-2108650c853a_CaVEMan (175, 27)
# (175, 12)
# &*
# (350, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/81f5ba7a-68fd-4091-9d7d-2108650c853a_CaVEMan is created
# CODE STARTED
# ea29e39f-7307-433b-8880-cac11e88365b_CaVEMan (197, 27)
# (197, 12)
# &*
# (394, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/ea29e39f-7307-433b-8880-cac11e88365b_CaVEMan is created
# CODE STARTED
# cc2abefa-bcd1-473a-ae83-3c3249e18c6b_CaVEMan (683, 27)
# (683, 12)
# &*
# (1366, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cc2abefa-bcd1-473a-ae83-3c3249e18c6b_CaVEMan is created
# CODE STARTED
# 38520d04-f833-4c2d-bb0f-f672efc3f948_CaVEMan (205, 27)
# (205, 12)
# &*
# (410, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/38520d04-f833-4c2d-bb0f-f672efc3f948_CaVEMan is created
# CODE STARTED
# a0e302b2-ce1a-42e4-9b55-55c7a2cbba45_sanger_raw_pindel (4665, 24)
# (4664, 12)
# &*
# (9328, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/a0e302b2-ce1a-42e4-9b55-55c7a2cbba45_sanger_raw_pindel is created
# CODE STARTED
# 307940cc-216b-4627-a062-9f4935ba121a_sanger_raw_pindel (4563, 24)
# (4563, 12)
# &*
# (9126, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/307940cc-216b-4627-a062-9f4935ba121a_sanger_raw_pindel is created
# CODE STARTED
# 63a74c24-a480-41b7-ac93-a37bd3ac4597_sanger_raw_pindel (5383, 24)
# (5383, 12)
# &*
# (10766, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/63a74c24-a480-41b7-ac93-a37bd3ac4597_sanger_raw_pindel is created
# CODE STARTED
# 6b8d4980-0c87-4f63-b6be-4a438e4db5b1_sanger_raw_pindel (4959, 24)
# (4958, 12)
# &*
# (9916, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6b8d4980-0c87-4f63-b6be-4a438e4db5b1_sanger_raw_pindel is created
# CODE STARTED
# e636717c-c2ee-4c11-aff9-5bbe27c5e134_sanger_raw_pindel (5253, 24)
# (5252, 12)
# &*
# (10504, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/e636717c-c2ee-4c11-aff9-5bbe27c5e134_sanger_raw_pindel is created
# CODE STARTED
# 4eb1c02a-3a70-4a25-8756-e77074868421_CaVEMan (270, 27)
# (270, 12)
# &*
# (540, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/4eb1c02a-3a70-4a25-8756-e77074868421_CaVEMan is created
# CODE STARTED
# 1e2f7f07-e667-41b1-9ff7-0a745cfe38a7_CaVEMan (115, 27)
# (115, 12)
# &*
# (230, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1e2f7f07-e667-41b1-9ff7-0a745cfe38a7_CaVEMan is created
# CODE STARTED
# 0f89b7f8-8f3f-4f50-95fb-a479ef194fdb_CaVEMan (495, 27)
# (495, 12)
# &*
# (990, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0f89b7f8-8f3f-4f50-95fb-a479ef194fdb_CaVEMan is created
# CODE STARTED
# e410e2b5-e22e-4349-98ad-ee17dd23329c_CaVEMan (631, 27)
# (631, 12)
# &*
# (1262, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/e410e2b5-e22e-4349-98ad-ee17dd23329c_CaVEMan is created
# CODE STARTED
# fceb79b8-bbde-4125-902c-a8502f7f23be_CaVEMan (146, 27)
# (146, 12)
# &*
# (292, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/fceb79b8-bbde-4125-902c-a8502f7f23be_CaVEMan is created
# CODE STARTED
# 6d430fc0-a93d-424d-981b-441a07a013da_CaVEMan (456, 27)
# (456, 12)
# &*
# (912, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6d430fc0-a93d-424d-981b-441a07a013da_CaVEMan is created
# CODE STARTED
# 7baef639-bf0c-4f60-9482-d265f9bd99c8_CaVEMan (176, 27)
# (176, 12)
# &*
# (352, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/7baef639-bf0c-4f60-9482-d265f9bd99c8_CaVEMan is created
# CODE STARTED
# 3d03a6cb-4244-4804-b0a7-afc5c64c2d3a_CaVEMan (203, 27)
# (203, 12)
# &*
# (406, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/3d03a6cb-4244-4804-b0a7-afc5c64c2d3a_CaVEMan is created
# CODE STARTED
# 0a100c48-895e-4551-815f-72081297cc49_CaVEMan (309, 27)
# (309, 12)
# &*
# (618, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0a100c48-895e-4551-815f-72081297cc49_CaVEMan is created
# CODE STARTED
# 702bbd12-9713-4261-b533-2b91c7b956c3_CaVEMan (255, 27)
# (255, 12)
# &*
# (510, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/702bbd12-9713-4261-b533-2b91c7b956c3_CaVEMan is created
# CODE STARTED
# 514ab55f-b19d-4b83-8ef2-e506164cb1de_sanger_raw_pindel (4443, 24)
# (4443, 12)
# &*
# (8886, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/514ab55f-b19d-4b83-8ef2-e506164cb1de_sanger_raw_pindel is created
# CODE STARTED
# 1766972a-0ea3-4230-9d94-db6bbad0a77a_CaVEMan (281, 27)
# (281, 12)
# &*
# (562, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1766972a-0ea3-4230-9d94-db6bbad0a77a_CaVEMan is created
# CODE STARTED
# 0c64d792-066c-42d3-84c3-d47dd2aa9092_sanger_raw_pindel (4376, 24)
# (4376, 12)
# &*
# (8752, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0c64d792-066c-42d3-84c3-d47dd2aa9092_sanger_raw_pindel is created
# CODE STARTED
# 703c3593-8f8f-4d8b-a1bf-3eadc806e980_sanger_raw_pindel (5353, 24)
# (5349, 12)
# &*
# (10698, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/703c3593-8f8f-4d8b-a1bf-3eadc806e980_sanger_raw_pindel is created
# CODE STARTED
# 93dce00c-c8e8-4217-9117-22db8e33e784_sanger_raw_pindel (4675, 24)
# (4675, 12)
# &*
# (9350, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/93dce00c-c8e8-4217-9117-22db8e33e784_sanger_raw_pindel is created
# CODE STARTED
# 56b38ebe-4168-46d1-aef9-5e0066ba653f_CaVEMan (264, 27)
# (264, 12)
# &*
# (528, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/56b38ebe-4168-46d1-aef9-5e0066ba653f_CaVEMan is created
# CODE STARTED
# 01608e28-91d8-402c-8a28-790800e16d22_sanger_raw_pindel (3996, 24)
# (3996, 12)
# &*
# (7992, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/01608e28-91d8-402c-8a28-790800e16d22_sanger_raw_pindel is created
# CODE STARTED
# 9bdcc390-1fd2-4ed0-9d06-ba35cad665ba_CaVEMan (1227, 27)
# (1227, 12)
# &*
# (2454, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/9bdcc390-1fd2-4ed0-9d06-ba35cad665ba_CaVEMan is created
# CODE STARTED
# cc8fd25b-b416-44f4-bcef-ff833c100a2b_sanger_raw_pindel (4425, 24)
# (4424, 12)
# &*
# (8848, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cc8fd25b-b416-44f4-bcef-ff833c100a2b_sanger_raw_pindel is created
# CODE STARTED
# dcb7c4ba-7215-4b77-949a-c2d2b783549d_sanger_raw_pindel (5393, 24)
# (5392, 12)
# &*
# (10784, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/dcb7c4ba-7215-4b77-949a-c2d2b783549d_sanger_raw_pindel is created
# CODE STARTED
# f9eece5f-bd50-4997-845c-db1c20681361_CaVEMan (236, 27)
# (236, 12)
# &*
# (472, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f9eece5f-bd50-4997-845c-db1c20681361_CaVEMan is created
# CODE STARTED
# 9270a4a5-791b-4d06-96c4-6347562607fb_CaVEMan (145, 27)
# (145, 12)
# &*
# (290, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/9270a4a5-791b-4d06-96c4-6347562607fb_CaVEMan is created
# CODE STARTED
# 14b5fc32-66f2-4f5e-9d5f-bbd65cd07733_CaVEMan (270, 27)
# (270, 12)
# &*
# (540, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/14b5fc32-66f2-4f5e-9d5f-bbd65cd07733_CaVEMan is created
# CODE STARTED
# aea01681-bede-417d-a615-0a6a7124fa6c_CaVEMan (1236, 27)
# (1236, 12)
# &*
# (2472, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/aea01681-bede-417d-a615-0a6a7124fa6c_CaVEMan is created
# CODE STARTED
# d2fd0752-3acd-45d5-87f1-68b52834215e_sanger_raw_pindel (4916, 24)
# (4915, 12)
# &*
# (9830, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d2fd0752-3acd-45d5-87f1-68b52834215e_sanger_raw_pindel is created
# CODE STARTED
# d5d87ff1-8571-40f3-b187-5d51e0a5615d_CaVEMan (190, 27)
# (190, 12)
# &*
# (380, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d5d87ff1-8571-40f3-b187-5d51e0a5615d_CaVEMan is created
# CODE STARTED
# 5a588951-444c-45ce-a3e7-466965ebff1d_sanger_raw_pindel (4549, 24)
# (4548, 12)
# &*
# (9096, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5a588951-444c-45ce-a3e7-466965ebff1d_sanger_raw_pindel is created
# CODE STARTED
# 32c1fcc3-562e-4813-bdcc-8bac4983f5bd_CaVEMan (1116, 27)
# (1116, 12)
# &*
# (2232, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/32c1fcc3-562e-4813-bdcc-8bac4983f5bd_CaVEMan is created
# CODE STARTED
# c7f9db72-bda2-4b40-bd38-5922d1a66bf3_CaVEMan (333, 27)
# (333, 12)
# &*
# (666, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/c7f9db72-bda2-4b40-bd38-5922d1a66bf3_CaVEMan is created
# CODE STARTED
# 648cfb4f-4175-4124-ba27-6ce8b60a773b_CaVEMan (160, 27)
# (160, 12)
# &*
# (320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/648cfb4f-4175-4124-ba27-6ce8b60a773b_CaVEMan is created
# CODE STARTED
# d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_sanger_raw_pindel (4677, 24)
# (4677, 12)
# &*
# (9354, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2_sanger_raw_pindel is created
# CODE STARTED
# 41bd62a0-238a-4363-b9be-1402ae0224ea_CaVEMan (242, 27)
# (242, 12)
# &*
# (484, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/41bd62a0-238a-4363-b9be-1402ae0224ea_CaVEMan is created
# CODE STARTED
# b6f67aab-59fa-4998-95e0-d49349f4b27b_sanger_raw_pindel (4519, 24)
# (4519, 12)
# &*
# (9038, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b6f67aab-59fa-4998-95e0-d49349f4b27b_sanger_raw_pindel is created
# CODE STARTED
# f991f0d3-32ee-410c-b887-f190f4e6b729_sanger_raw_pindel (4894, 24)
# (4893, 12)
# &*
# (9786, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f991f0d3-32ee-410c-b887-f190f4e6b729_sanger_raw_pindel is created
# CODE STARTED
# f368a047-d2a8-404f-97dd-1c2a8bf52497_sanger_raw_pindel (4473, 24)
# (4473, 12)
# &*
# (8946, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f368a047-d2a8-404f-97dd-1c2a8bf52497_sanger_raw_pindel is created
# CODE STARTED
# 09bd9dff-f572-4f45-ac04-ec1d8f367dae_sanger_raw_pindel (4684, 24)
# (4684, 12)
# &*
# (9368, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/09bd9dff-f572-4f45-ac04-ec1d8f367dae_sanger_raw_pindel is created
# CODE STARTED
# 86fc2062-8120-41e9-a52a-1c112fc7e126_sanger_raw_pindel (4636, 24)
# (4636, 12)
# &*
# (9272, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/86fc2062-8120-41e9-a52a-1c112fc7e126_sanger_raw_pindel is created
# CODE STARTED
# afbf285e-0560-4e1d-9c6e-9741368aa9f5_CaVEMan (1144, 27)
# (1144, 12)
# &*
# (2288, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/afbf285e-0560-4e1d-9c6e-9741368aa9f5_CaVEMan is created
# CODE STARTED
# bbf629fd-658b-4c0f-bb8f-e7a6de5c6986_sanger_raw_pindel (4575, 24)
# (4574, 12)
# &*
# (9148, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bbf629fd-658b-4c0f-bb8f-e7a6de5c6986_sanger_raw_pindel is created
# CODE STARTED
# 91a0c61b-7141-4f5e-ba17-6b17b343e468_sanger_raw_pindel (4574, 24)
# (4574, 12)
# &*
# (9148, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/91a0c61b-7141-4f5e-ba17-6b17b343e468_sanger_raw_pindel is created
# CODE STARTED
# 32564de4-55f3-4934-b529-a187c59d4d47_sanger_raw_pindel (5379, 24)
# (5377, 12)
# &*
# (10754, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/32564de4-55f3-4934-b529-a187c59d4d47_sanger_raw_pindel is created
# CODE STARTED
# 86f90ec0-ef66-484e-a70d-713590be4ad8_sanger_raw_pindel (4420, 24)
# (4420, 12)
# &*
# (8840, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/86f90ec0-ef66-484e-a70d-713590be4ad8_sanger_raw_pindel is created
# CODE STARTED
# f04f56d8-6680-4054-97ab-ce728219aa84_sanger_raw_pindel (4601, 24)
# (4601, 12)
# &*
# (9202, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f04f56d8-6680-4054-97ab-ce728219aa84_sanger_raw_pindel is created
# CODE STARTED
# 12717370-ad9c-4260-97ed-98660520decc_sanger_raw_pindel (4660, 24)
# (4660, 12)
# &*
# (9320, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/12717370-ad9c-4260-97ed-98660520decc_sanger_raw_pindel is created
# CODE STARTED
# 980df119-42bf-401f-849f-d43a26becc2c_CaVEMan (851, 27)
# (851, 12)
# &*
# (1702, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/980df119-42bf-401f-849f-d43a26becc2c_CaVEMan is created
# CODE STARTED
# c339075f-1219-4def-ab5a-ef636995c1b2_sanger_raw_pindel (4558, 24)
# (4558, 12)
# &*
# (9116, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/c339075f-1219-4def-ab5a-ef636995c1b2_sanger_raw_pindel is created
# CODE STARTED
# 1ce5c200-7b11-44ca-a57c-118244fcd33d_CaVEMan (348, 27)
# (348, 12)
# &*
# (696, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1ce5c200-7b11-44ca-a57c-118244fcd33d_CaVEMan is created
# CODE STARTED
# 1453bd9a-202b-42c6-88fd-529acdda7890_CaVEMan (258, 27)
# (258, 12)
# &*
# (516, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1453bd9a-202b-42c6-88fd-529acdda7890_CaVEMan is created
# CODE STARTED
# cee02cc9-d0e3-4544-a093-6cfe5b8fffca_sanger_raw_pindel (4793, 24)
# (4792, 12)
# &*
# (9584, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cee02cc9-d0e3-4544-a093-6cfe5b8fffca_sanger_raw_pindel is created
# CODE STARTED
# 9270a4a5-791b-4d06-96c4-6347562607fb_sanger_raw_pindel (4488, 24)
# (4488, 12)
# &*
# (8976, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/9270a4a5-791b-4d06-96c4-6347562607fb_sanger_raw_pindel is created
# CODE STARTED
# 1113c58e-1cf2-45c9-848e-38cd3f5e07f7_CaVEMan (350, 27)
# (350, 12)
# &*
# (700, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1113c58e-1cf2-45c9-848e-38cd3f5e07f7_CaVEMan is created
# CODE STARTED
# c49e32d2-691a-4cc8-9f20-37395e5a79c2_sanger_raw_pindel (4711, 24)
# (4711, 12)
# &*
# (9422, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/c49e32d2-691a-4cc8-9f20-37395e5a79c2_sanger_raw_pindel is created
# CODE STARTED
# f0e3f096-360f-4962-9567-adffc035aa3e_sanger_raw_pindel (5322, 24)
# (5321, 12)
# &*
# (10642, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f0e3f096-360f-4962-9567-adffc035aa3e_sanger_raw_pindel is created
# CODE STARTED
# bd58fa0b-8856-40a8-aec9-cd7b658cbdb7_sanger_raw_pindel (4596, 24)
# (4596, 12)
# &*
# (9192, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bd58fa0b-8856-40a8-aec9-cd7b658cbdb7_sanger_raw_pindel is created
# CODE STARTED
# dcb7c4ba-7215-4b77-949a-c2d2b783549d_CaVEMan (1048, 27)
# (1048, 12)
# &*
# (2096, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/dcb7c4ba-7215-4b77-949a-c2d2b783549d_CaVEMan is created
# CODE STARTED
# a4fc2ed3-dc4d-40fb-b96b-a19ccd2d0891_sanger_raw_pindel (4559, 24)
# (4559, 12)
# &*
# (9118, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/a4fc2ed3-dc4d-40fb-b96b-a19ccd2d0891_sanger_raw_pindel is created
# CODE STARTED
# b30d39e1-f2ff-43c5-9b69-579ca0d2fa28_CaVEMan (330, 27)
# (330, 12)
# &*
# (660, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b30d39e1-f2ff-43c5-9b69-579ca0d2fa28_CaVEMan is created
# CODE STARTED
# d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_sanger_raw_pindel (4686, 24)
# (4686, 12)
# &*
# (9372, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_sanger_raw_pindel is created
# CODE STARTED
# ab7058b9-2f1c-4c18-8e16-dd293c9d5737_CaVEMan (343, 27)
# (343, 12)
# &*
# (686, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/ab7058b9-2f1c-4c18-8e16-dd293c9d5737_CaVEMan is created
# CODE STARTED
# 57889e27-2e19-472d-8294-2f5695a6cead_sanger_raw_pindel (4686, 24)
# (4685, 12)
# &*
# (9370, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/57889e27-2e19-472d-8294-2f5695a6cead_sanger_raw_pindel is created
# CODE STARTED
# fda2d1f9-1690-42a8-80b7-bdcb9e9e4105_CaVEMan (149, 27)
# (149, 12)
# &*
# (298, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/fda2d1f9-1690-42a8-80b7-bdcb9e9e4105_CaVEMan is created
# CODE STARTED
# fe71e6b9-f9f0-4628-8d5a-cf49497d0392_sanger_raw_pindel (4813, 24)
# (4813, 12)
# &*
# (9626, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/fe71e6b9-f9f0-4628-8d5a-cf49497d0392_sanger_raw_pindel is created
# CODE STARTED
# 832f644e-7014-4b46-8449-05980f3cacd3_CaVEMan (273, 27)
# (273, 12)
# &*
# (546, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/832f644e-7014-4b46-8449-05980f3cacd3_CaVEMan is created
# CODE STARTED
# 84acc817-abe7-42b0-bd74-94673f34009d_sanger_raw_pindel (4467, 24)
# (4467, 12)
# &*
# (8934, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/84acc817-abe7-42b0-bd74-94673f34009d_sanger_raw_pindel is created
# CODE STARTED
# bda8706f-6d13-40bb-9e1e-d21e4e531498_CaVEMan (210, 27)
# (210, 12)
# &*
# (420, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bda8706f-6d13-40bb-9e1e-d21e4e531498_CaVEMan is created
# CODE STARTED
# 2ff01ec1-7876-4b76-8b9d-62e9f6824d42_CaVEMan (270, 27)
# (270, 12)
# &*
# (540, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/2ff01ec1-7876-4b76-8b9d-62e9f6824d42_CaVEMan is created
# CODE STARTED
# 58e6ffe3-67ac-4ed8-8c56-c8040b429264_sanger_raw_pindel (4507, 24)
# (4506, 12)
# &*
# (9012, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/58e6ffe3-67ac-4ed8-8c56-c8040b429264_sanger_raw_pindel is created
# CODE STARTED
# 39a8c6e2-8708-4d18-badd-85f72282d426_sanger_raw_pindel (5379, 24)
# (5377, 12)
# &*
# (10754, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/39a8c6e2-8708-4d18-badd-85f72282d426_sanger_raw_pindel is created
# CODE STARTED
# dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_sanger_raw_pindel (4377, 24)
# (4377, 12)
# &*
# (8754, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f_sanger_raw_pindel is created
# CODE STARTED
# 425008fb-b39f-4355-8c2b-c2ebfc3236ea_CaVEMan (140, 27)
# (140, 12)
# &*
# (280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/425008fb-b39f-4355-8c2b-c2ebfc3236ea_CaVEMan is created
# CODE STARTED
# ce1b8b0e-6462-4a93-ac94-072418037f5c_sanger_raw_pindel (4373, 24)
# (4373, 12)
# &*
# (8746, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/ce1b8b0e-6462-4a93-ac94-072418037f5c_sanger_raw_pindel is created
# CODE STARTED
# 9ce61ab5-ceec-4148-901b-53ce6a2b084b_sanger_raw_pindel (4549, 24)
# (4548, 12)
# &*
# (9096, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/9ce61ab5-ceec-4148-901b-53ce6a2b084b_sanger_raw_pindel is created
# CODE STARTED
# 6361dc74-12ef-4b3c-a52c-dd988a38929e_CaVEMan (197, 27)
# (197, 12)
# &*
# (394, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6361dc74-12ef-4b3c-a52c-dd988a38929e_CaVEMan is created
# CODE STARTED
# 1425e1ef-ca6d-40a3-879a-54653d6fac38_CaVEMan (258, 27)
# (258, 12)
# &*
# (516, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1425e1ef-ca6d-40a3-879a-54653d6fac38_CaVEMan is created
# CODE STARTED
# aea01681-bede-417d-a615-0a6a7124fa6c_sanger_raw_pindel (5404, 24)
# (5402, 12)
# &*
# (10804, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/aea01681-bede-417d-a615-0a6a7124fa6c_sanger_raw_pindel is created
# CODE STARTED
# 62f26d07-04b1-4c69-a550-3aea5c8d44e3_CaVEMan (1216, 27)
# (1216, 12)
# &*
# (2432, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/62f26d07-04b1-4c69-a550-3aea5c8d44e3_CaVEMan is created
# CODE STARTED
# 92fd3588-7386-4c39-86cc-2029c3dd7c94_CaVEMan (191, 27)
# (191, 12)
# &*
# (382, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/92fd3588-7386-4c39-86cc-2029c3dd7c94_CaVEMan is created
# CODE STARTED
# 6d7f1fbc-57f6-4a77-b457-f570a71990eb_sanger_raw_pindel (4511, 24)
# (4511, 12)
# &*
# (9022, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6d7f1fbc-57f6-4a77-b457-f570a71990eb_sanger_raw_pindel is created
# CODE STARTED
# b99df57e-6f5b-4d35-96cb-8a16ef139cd8_CaVEMan (121, 27)
# (121, 12)
# &*
# (242, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b99df57e-6f5b-4d35-96cb-8a16ef139cd8_CaVEMan is created
# CODE STARTED
# 61c0789e-4c2d-4586-95c1-c3501a8d2a7e_sanger_raw_pindel (4745, 24)
# (4744, 12)
# &*
# (9488, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/61c0789e-4c2d-4586-95c1-c3501a8d2a7e_sanger_raw_pindel is created
# CODE STARTED
# f23649c0-8de7-4b60-9b65-5c557ea08a65_CaVEMan (1259, 27)
# (1259, 12)
# &*
# (2518, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f23649c0-8de7-4b60-9b65-5c557ea08a65_CaVEMan is created
# CODE STARTED
# 392b2647-766f-4e28-b003-44891a79ce8b_sanger_raw_pindel (5533, 24)
# (5530, 12)
# &*
# (11060, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/392b2647-766f-4e28-b003-44891a79ce8b_sanger_raw_pindel is created
# CODE STARTED
# bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_sanger_raw_pindel (5291, 24)
# (5290, 12)
# &*
# (10580, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_sanger_raw_pindel is created
# CODE STARTED
# 16d188a1-5021-4173-9774-63590b68f448_CaVEMan (126, 27)
# (126, 12)
# &*
# (252, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/16d188a1-5021-4173-9774-63590b68f448_CaVEMan is created
# CODE STARTED
# 73f8a07c-aae5-4319-aa0b-55646e277a6b_CaVEMan (184, 27)
# (184, 12)
# &*
# (368, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/73f8a07c-aae5-4319-aa0b-55646e277a6b_CaVEMan is created
# CODE STARTED
# 16d188a1-5021-4173-9774-63590b68f448_sanger_raw_pindel (4640, 24)
# (4640, 12)
# &*
# (9280, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/16d188a1-5021-4173-9774-63590b68f448_sanger_raw_pindel is created
# CODE STARTED
# b13172e7-5667-4fd8-bb69-87c9e1dabfb8_sanger_raw_pindel (4786, 24)
# (4786, 12)
# &*
# (9572, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b13172e7-5667-4fd8-bb69-87c9e1dabfb8_sanger_raw_pindel is created
# CODE STARTED
# 04fc819c-2358-47b5-9cab-bb5b9e9be109_sanger_raw_pindel (4746, 24)
# (4746, 12)
# &*
# (9492, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/04fc819c-2358-47b5-9cab-bb5b9e9be109_sanger_raw_pindel is created
# CODE STARTED
# c2042359-9e2c-4c98-b572-841cfd6c810b_sanger_raw_pindel (4493, 24)
# (4493, 12)
# &*
# (8986, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/c2042359-9e2c-4c98-b572-841cfd6c810b_sanger_raw_pindel is created
# CODE STARTED
# 5e54ae37-bbd4-4cb9-a1e4-886acd28bdd2_sanger_raw_pindel (5348, 24)
# (5345, 12)
# &*
# (10690, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5e54ae37-bbd4-4cb9-a1e4-886acd28bdd2_sanger_raw_pindel is created
# CODE STARTED
# 702bbd12-9713-4261-b533-2b91c7b956c3_sanger_raw_pindel (4679, 24)
# (4679, 12)
# &*
# (9358, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/702bbd12-9713-4261-b533-2b91c7b956c3_sanger_raw_pindel is created
# CODE STARTED
# 33e5de62-6347-4e65-b1de-a96aaad71cdf_CaVEMan (143, 27)
# (143, 12)
# &*
# (286, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/33e5de62-6347-4e65-b1de-a96aaad71cdf_CaVEMan is created
# CODE STARTED
# c0510fdb-e59f-496d-8431-aa0d5cdc81be_CaVEMan (1025, 27)
# (1025, 12)
# &*
# (2050, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/c0510fdb-e59f-496d-8431-aa0d5cdc81be_CaVEMan is created
# CODE STARTED
# 92ad448d-eeff-4224-aae9-402cb243ec22_CaVEMan (166, 27)
# (166, 12)
# &*
# (332, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/92ad448d-eeff-4224-aae9-402cb243ec22_CaVEMan is created
# CODE STARTED
# bc1594b4-9576-41ab-a7a1-0d39c4610173_CaVEMan (252, 27)
# (252, 12)
# &*
# (504, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bc1594b4-9576-41ab-a7a1-0d39c4610173_CaVEMan is created
# CODE STARTED
# eb3f7244-1d54-43b0-975b-10bd414296a8_CaVEMan (186, 27)
# (186, 12)
# &*
# (372, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/eb3f7244-1d54-43b0-975b-10bd414296a8_CaVEMan is created
# CODE STARTED
# f33367dc-d29f-442f-aeba-ecc1b3c534d4_CaVEMan (261, 27)
# (261, 12)
# &*
# (522, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f33367dc-d29f-442f-aeba-ecc1b3c534d4_CaVEMan is created
# CODE STARTED
# 75447975-74de-4c92-b4e3-11c9f57b02f8_CaVEMan (115, 27)
# (115, 12)
# &*
# (230, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/75447975-74de-4c92-b4e3-11c9f57b02f8_CaVEMan is created
# CODE STARTED
# 6c30db02-ef29-471b-9e53-4511ffe2ba1f_CaVEMan (123, 27)
# (123, 12)
# &*
# (246, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6c30db02-ef29-471b-9e53-4511ffe2ba1f_CaVEMan is created
# CODE STARTED
# 1fcdd550-6677-4d21-9722-e0f7edcfd470_sanger_raw_pindel (4478, 24)
# (4478, 12)
# &*
# (8956, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1fcdd550-6677-4d21-9722-e0f7edcfd470_sanger_raw_pindel is created
# CODE STARTED
# 84acc817-abe7-42b0-bd74-94673f34009d_CaVEMan (116, 27)
# (116, 12)
# &*
# (232, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/84acc817-abe7-42b0-bd74-94673f34009d_CaVEMan is created
# CODE STARTED
# cd0dff4b-df83-455b-8c5c-a7d0b96c707f_sanger_raw_pindel (4376, 24)
# (4376, 12)
# &*
# (8752, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cd0dff4b-df83-455b-8c5c-a7d0b96c707f_sanger_raw_pindel is created
# CODE STARTED
# a8262d3b-c0b0-4e0b-b864-ba00aca4960d_sanger_raw_pindel (4307, 24)
# (4307, 12)
# &*
# (8614, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/a8262d3b-c0b0-4e0b-b864-ba00aca4960d_sanger_raw_pindel is created
# CODE STARTED
# 6493d63d-eae9-4fbc-a7a4-0c07ef28fa38_sanger_raw_pindel (4734, 24)
# (4734, 12)
# &*
# (9468, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6493d63d-eae9-4fbc-a7a4-0c07ef28fa38_sanger_raw_pindel is created
# CODE STARTED
# 28608081-9523-4c76-95f7-9fb18596eeaa_CaVEMan (221, 27)
# (221, 12)
# &*
# (442, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/28608081-9523-4c76-95f7-9fb18596eeaa_CaVEMan is created
# CODE STARTED
# 5920a413-3753-4755-a10a-e94e6db880a4_sanger_raw_pindel (5262, 24)
# (5260, 12)
# &*
# (10520, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5920a413-3753-4755-a10a-e94e6db880a4_sanger_raw_pindel is created
# CODE STARTED
# 28608081-9523-4c76-95f7-9fb18596eeaa_sanger_raw_pindel (4401, 24)
# (4400, 12)
# &*
# (8800, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/28608081-9523-4c76-95f7-9fb18596eeaa_sanger_raw_pindel is created
# CODE STARTED
# 62e19451-8cab-4640-81b8-2ee11335580a_sanger_raw_pindel (5122, 24)
# (5122, 12)
# &*
# (10244, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/62e19451-8cab-4640-81b8-2ee11335580a_sanger_raw_pindel is created
# CODE STARTED
# 0354719a-b3e8-45d2-b35b-4665c50391d8_sanger_raw_pindel (4567, 24)
# (4567, 12)
# &*
# (9134, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0354719a-b3e8-45d2-b35b-4665c50391d8_sanger_raw_pindel is created
# CODE STARTED
# bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_CaVEMan (1149, 27)
# (1149, 12)
# &*
# (2298, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bf8079a4-f5cf-4e9e-8ec9-a33c657f528b_CaVEMan is created
# CODE STARTED
# 27cca99a-2e9b-4bb4-9104-f3201e5b32b7_sanger_raw_pindel (5248, 24)
# (5246, 12)
# &*
# (10492, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/27cca99a-2e9b-4bb4-9104-f3201e5b32b7_sanger_raw_pindel is created
# CODE STARTED
# 1cd83e06-2381-4f80-8bfd-e2dc6a8a97dc_CaVEMan (395, 27)
# (395, 12)
# &*
# (790, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1cd83e06-2381-4f80-8bfd-e2dc6a8a97dc_CaVEMan is created
# CODE STARTED
# cc121407-bbbd-496c-989c-d98b1092e4ab_sanger_raw_pindel (4566, 24)
# (4566, 12)
# &*
# (9132, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cc121407-bbbd-496c-989c-d98b1092e4ab_sanger_raw_pindel is created
# CODE STARTED
# f8777da1-d1ba-4ca7-9d65-a57b7061b6c4_sanger_raw_pindel (5470, 24)
# (5468, 12)
# &*
# (10936, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/f8777da1-d1ba-4ca7-9d65-a57b7061b6c4_sanger_raw_pindel is created
# CODE STARTED
# aa99f75e-1450-4506-ae92-daeb0e7d54b2_CaVEMan (170, 27)
# (170, 12)
# &*
# (340, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/aa99f75e-1450-4506-ae92-daeb0e7d54b2_CaVEMan is created
# CODE STARTED
# fcb77a5c-10fc-40e9-b894-4c56b5111682_CaVEMan (151, 27)
# (151, 12)
# &*
# (302, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/fcb77a5c-10fc-40e9-b894-4c56b5111682_CaVEMan is created
# CODE STARTED
# 6bb58e67-2c9e-408f-9543-d92c12bed2a2_sanger_raw_pindel (4625, 24)
# (4625, 12)
# &*
# (9250, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6bb58e67-2c9e-408f-9543-d92c12bed2a2_sanger_raw_pindel is created
# CODE STARTED
# d62f088d-8ff4-4bdf-84e6-d1d743251c1b_sanger_raw_pindel (4545, 24)
# (4545, 12)
# &*
# (9090, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d62f088d-8ff4-4bdf-84e6-d1d743251c1b_sanger_raw_pindel is created
# CODE STARTED
# b802ae20-c2af-42b9-bc19-c4864c13a1c1_sanger_raw_pindel (4537, 24)
# (4537, 12)
# &*
# (9074, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b802ae20-c2af-42b9-bc19-c4864c13a1c1_sanger_raw_pindel is created
# CODE STARTED
# 702f2a4f-e224-4552-a95c-b67c62d1e70d_sanger_raw_pindel (4263, 24)
# (4263, 12)
# &*
# (8526, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/702f2a4f-e224-4552-a95c-b67c62d1e70d_sanger_raw_pindel is created
# CODE STARTED
# 2ff01ec1-7876-4b76-8b9d-62e9f6824d42_sanger_raw_pindel (4801, 24)
# (4799, 12)
# &*
# (9598, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/2ff01ec1-7876-4b76-8b9d-62e9f6824d42_sanger_raw_pindel is created
# CODE STARTED
# 8fb54b3e-8929-4e00-b946-8f87a082162f_CaVEMan (292, 27)
# (292, 12)
# &*
# (584, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/8fb54b3e-8929-4e00-b946-8f87a082162f_CaVEMan is created
# CODE STARTED
# 93dce00c-c8e8-4217-9117-22db8e33e784_CaVEMan (284, 27)
# (284, 12)
# &*
# (568, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/93dce00c-c8e8-4217-9117-22db8e33e784_CaVEMan is created
# CODE STARTED
# 45ae8240-94e9-4cbf-a3dc-5deae89b7abc_sanger_raw_pindel (5329, 24)
# (5328, 12)
# &*
# (10656, 2)
# ...
# (4335, 12)
# &*
# (8670, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/92113811-d6b8-436b-b491-ffe17ff2ae10_sanger_raw_pindel is created
# CODE STARTED
# 5ed5cde6-3550-4766-92e1-3e226cf9f4bc_CaVEMan (155, 27)
# (155, 12)
# &*
# (310, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5ed5cde6-3550-4766-92e1-3e226cf9f4bc_CaVEMan is created
# CODE STARTED
# 60eb59a2-75a6-415f-9538-5d2c33b94e2f_sanger_raw_pindel (4407, 24)
# (4407, 12)
# &*
# (8814, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/60eb59a2-75a6-415f-9538-5d2c33b94e2f_sanger_raw_pindel is created
# CODE STARTED
# 4caa0beb-f36d-4e36-a13f-34e1d11a1259_sanger_raw_pindel (4578, 24)
# (4578, 12)
# &*
# (9156, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/4caa0beb-f36d-4e36-a13f-34e1d11a1259_sanger_raw_pindel is created
# CODE STARTED
# 5891a047-6f9a-43f1-8aef-f52d1d3df1a1_CaVEMan (192, 27)
# (192, 12)
# &*
# (384, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5891a047-6f9a-43f1-8aef-f52d1d3df1a1_CaVEMan is created
# CODE STARTED
# b6f67aab-59fa-4998-95e0-d49349f4b27b_CaVEMan (164, 27)
# (164, 12)
# &*
# (328, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b6f67aab-59fa-4998-95e0-d49349f4b27b_CaVEMan is created
# CODE STARTED
# 1ec11928-92e4-4a28-aed6-bd6a2acf47bb_sanger_raw_pindel (4904, 24)
# (4904, 12)
# &*
# (9808, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1ec11928-92e4-4a28-aed6-bd6a2acf47bb_sanger_raw_pindel is created
# CODE STARTED
# 174c6cb7-3e03-4652-992a-de774381c354_CaVEMan (227, 27)
# (227, 12)
# &*
# (454, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/174c6cb7-3e03-4652-992a-de774381c354_CaVEMan is created
# CODE STARTED
# 04fc819c-2358-47b5-9cab-bb5b9e9be109_CaVEMan (124, 27)
# (124, 12)
# &*
# (248, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/04fc819c-2358-47b5-9cab-bb5b9e9be109_CaVEMan is created
# CODE STARTED
# 6bb3b2cd-13bc-4ada-8414-75f16fc0f641_CaVEMan (130, 27)
# (130, 12)
# &*
# (260, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6bb3b2cd-13bc-4ada-8414-75f16fc0f641_CaVEMan is created
# CODE STARTED
# a8dd0002-25e4-4506-8634-a9da1225cd56_CaVEMan (1472, 27)
# (1472, 12)
# &*
# (2944, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/a8dd0002-25e4-4506-8634-a9da1225cd56_CaVEMan is created
# CODE STARTED
# b199efb6-0989-490c-b9cf-6bbeb764dd15_CaVEMan (585, 27)
# (585, 12)
# &*
# (1170, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b199efb6-0989-490c-b9cf-6bbeb764dd15_CaVEMan is created
# CODE STARTED
# 8d233b00-3073-4810-ae86-bd809788f6eb_sanger_raw_pindel (4617, 24)
# (4617, 12)
# &*
# (9234, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/8d233b00-3073-4810-ae86-bd809788f6eb_sanger_raw_pindel is created
# CODE STARTED
# d6cf6672-bded-4022-af6e-b7b78c75ca44_sanger_raw_pindel (4785, 24)
# (4785, 12)
# &*
# (9570, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d6cf6672-bded-4022-af6e-b7b78c75ca44_sanger_raw_pindel is created
# CODE STARTED
# 503a146d-2e1c-4c55-9947-587fde1c875a_sanger_raw_pindel (4830, 24)
# (4830, 12)
# &*
# (9660, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/503a146d-2e1c-4c55-9947-587fde1c875a_sanger_raw_pindel is created
# CODE STARTED
# b89ad449-f0e8-41a4-a9e5-acc1eab2ca30_sanger_raw_pindel (4195, 24)
# (4195, 12)
# &*
# (8390, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b89ad449-f0e8-41a4-a9e5-acc1eab2ca30_sanger_raw_pindel is created
# CODE STARTED
# 1d6d39c4-b0e1-4d49-ac1d-384212229d5c_CaVEMan (783, 27)
# (783, 12)
# &*
# (1566, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1d6d39c4-b0e1-4d49-ac1d-384212229d5c_CaVEMan is created
# CODE STARTED
# cd0dff4b-df83-455b-8c5c-a7d0b96c707f_CaVEMan (296, 27)
# (296, 12)
# &*
# (592, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/cd0dff4b-df83-455b-8c5c-a7d0b96c707f_CaVEMan is created
# CODE STARTED
# 8a6bd6c0-a25e-476a-9409-84014108dbb6_sanger_raw_pindel (4637, 24)
# (4637, 12)
# &*
# (9274, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/8a6bd6c0-a25e-476a-9409-84014108dbb6_sanger_raw_pindel is created
# CODE STARTED
# 02c4910e-df0d-49bf-aabe-f833e328539e_CaVEMan (362, 27)
# (362, 12)
# &*
# (724, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/02c4910e-df0d-49bf-aabe-f833e328539e_CaVEMan is created
# CODE STARTED
# 86487f64-5ece-46c6-ae2e-afd5b9265d6f_sanger_raw_pindel (4520, 24)
# (4519, 12)
# &*
# (9038, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/86487f64-5ece-46c6-ae2e-afd5b9265d6f_sanger_raw_pindel is created
# CODE STARTED
# 1ca3b5f8-2ac0-4a1e-a137-718a268e00f3_sanger_raw_pindel (4390, 24)
# (4389, 12)
# &*
# (8778, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1ca3b5f8-2ac0-4a1e-a137-718a268e00f3_sanger_raw_pindel is created
# CODE STARTED
# 94304b7e-c8ff-4cca-93c9-51b45a9e0d5a_CaVEMan (171, 27)
# (171, 12)
# &*
# (342, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/94304b7e-c8ff-4cca-93c9-51b45a9e0d5a_CaVEMan is created
# CODE STARTED
# 3d053858-309c-46e0-a154-7cc4472f46f0_CaVEMan (346, 27)
# (346, 12)
# &*
# (692, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/3d053858-309c-46e0-a154-7cc4472f46f0_CaVEMan is created
# CODE STARTED
# 2e5f1a81-3424-4cfd-b23c-121a452592a5_CaVEMan (106, 27)
# (106, 12)
# &*
# (212, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/2e5f1a81-3424-4cfd-b23c-121a452592a5_CaVEMan is created
# CODE STARTED
# a5a632fd-0501-4268-8a40-673bb81e61be_CaVEMan (286, 27)
# (286, 12)
# &*
# (572, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/a5a632fd-0501-4268-8a40-673bb81e61be_CaVEMan is created
# CODE STARTED
# 936b40ef-4709-4503-8bac-e6212ea91145_CaVEMan (94, 27)
# (94, 12)
# &*
# (188, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/936b40ef-4709-4503-8bac-e6212ea91145_CaVEMan is created
# CODE STARTED
# 7c0c6ce6-c3c2-4d53-886b-3a44e5f8eed3_CaVEMan (1244, 27)
# (1244, 12)
# &*
# (2488, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/7c0c6ce6-c3c2-4d53-886b-3a44e5f8eed3_CaVEMan is created
# CODE STARTED
# d519507d-1b62-4925-8702-94326285aabf_CaVEMan (303, 27)
# (303, 12)
# &*
# (606, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d519507d-1b62-4925-8702-94326285aabf_CaVEMan is created
# CODE STARTED
# 936e9461-031c-4b35-9a7f-c93ba17983fc_CaVEMan (228, 27)
# (228, 12)
# &*
# (456, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/936e9461-031c-4b35-9a7f-c93ba17983fc_CaVEMan is created
# CODE STARTED
# 14428874-2d28-48a5-8a7e-eef30da45e47_CaVEMan (437, 27)
# (437, 12)
# &*
# (874, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/14428874-2d28-48a5-8a7e-eef30da45e47_CaVEMan is created
# CODE STARTED
# e7b27e88-470c-467d-964c-cc01de2ea073_sanger_raw_pindel (4873, 24)
# (4871, 12)
# &*
# (9742, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/e7b27e88-470c-467d-964c-cc01de2ea073_sanger_raw_pindel is created
# CODE STARTED
# 7647659b-f8ee-4a3b-afed-c8d52e674362_CaVEMan (127, 27)
# (127, 12)
# &*
# (254, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/7647659b-f8ee-4a3b-afed-c8d52e674362_CaVEMan is created
# CODE STARTED
# 1ec11928-92e4-4a28-aed6-bd6a2acf47bb_CaVEMan (491, 27)
# (491, 12)
# &*
# (982, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/1ec11928-92e4-4a28-aed6-bd6a2acf47bb_CaVEMan is created
# CODE STARTED
# d51caf6f-c2c1-418e-af0c-ac0d5e101a6b_CaVEMan (561, 27)
# (561, 12)
# &*
# (1122, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d51caf6f-c2c1-418e-af0c-ac0d5e101a6b_CaVEMan is created
# CODE STARTED
# 7647659b-f8ee-4a3b-afed-c8d52e674362_sanger_raw_pindel (4666, 24)
# (4666, 12)
# &*
# (9332, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/7647659b-f8ee-4a3b-afed-c8d52e674362_sanger_raw_pindel is created
# CODE STARTED
# b9fcd5bf-b0f6-4f4c-8eef-d12d4208d47e_sanger_raw_pindel (5285, 24)
# (5284, 12)
# &*
# (10568, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/b9fcd5bf-b0f6-4f4c-8eef-d12d4208d47e_sanger_raw_pindel is created
# CODE STARTED
# e452be3b-5a11-4ef7-a350-89e33b7229a3_sanger_raw_pindel (5523, 24)
# (5520, 12)
# &*
# (11040, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/e452be3b-5a11-4ef7-a350-89e33b7229a3_sanger_raw_pindel is created
# CODE STARTED
# ece02edb-5b5d-4e87-a33d-66d25e89a7bb_sanger_raw_pindel (4480, 24)
# (4480, 12)
# &*
# (8960, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/ece02edb-5b5d-4e87-a33d-66d25e89a7bb_sanger_raw_pindel is created
# CODE STARTED
# a06f06ea-d961-48cc-a24d-71f1be6a0b46_CaVEMan (93, 27)
# (93, 12)
# &*
# (186, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/a06f06ea-d961-48cc-a24d-71f1be6a0b46_CaVEMan is created
# CODE STARTED
# d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_CaVEMan (110, 27)
# (110, 12)
# &*
# (220, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d2aa40fd-da17-4bc0-ad47-421cf50bc3cd_CaVEMan is created
# CODE STARTED
# 0d859bb4-a7ba-440b-9e9e-13c866656670_sanger_raw_pindel (4504, 24)
# (4503, 12)
# &*
# (9006, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/0d859bb4-a7ba-440b-9e9e-13c866656670_sanger_raw_pindel is created
# CODE STARTED
# 842f106a-6971-44fc-aa06-1d0cd7b72783_CaVEMan (147, 27)
# (147, 12)
# &*
# (294, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/842f106a-6971-44fc-aa06-1d0cd7b72783_CaVEMan is created
# CODE STARTED
# 3c3f09c3-0be2-46b7-bdf2-b31fd2218f12_CaVEMan (145, 27)
# (145, 12)
# &*
# (290, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/3c3f09c3-0be2-46b7-bdf2-b31fd2218f12_CaVEMan is created
# CODE STARTED
# 2d0e323f-b465-442a-969d-34d63b9934db_sanger_raw_pindel (4294, 24)
# (4294, 12)
# &*
# (8588, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/2d0e323f-b465-442a-969d-34d63b9934db_sanger_raw_pindel is created
# CODE STARTED
# 3b7706ff-c748-42ce-931e-9346e18b71fd_CaVEMan (250, 27)
# (250, 12)
# &*
# (500, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/3b7706ff-c748-42ce-931e-9346e18b71fd_CaVEMan is created
# CODE STARTED
# 39bef8f9-d66e-4fd1-ab72-bd41684d5304_CaVEMan (264, 27)
# (264, 12)
# &*
# (528, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/39bef8f9-d66e-4fd1-ab72-bd41684d5304_CaVEMan is created
# CODE STARTED
# 726bc7b4-f9a0-4f45-893f-c716c137d654_sanger_raw_pindel (4690, 24)
# (4690, 12)
# &*
# (9380, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/726bc7b4-f9a0-4f45-893f-c716c137d654_sanger_raw_pindel is created
# CODE STARTED
# 258c2003-f592-4015-8b1e-69d3f7b5d2db_sanger_raw_pindel (4549, 24)
# (4549, 12)
# &*
# (9098, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/258c2003-f592-4015-8b1e-69d3f7b5d2db_sanger_raw_pindel is created
# CODE STARTED
# 5a3551b8-e9a9-4236-ac4c-360e5e901a7f_sanger_raw_pindel (4765, 24)
# (4765, 12)
# &*
# (9530, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5a3551b8-e9a9-4236-ac4c-360e5e901a7f_sanger_raw_pindel is created
# CODE STARTED
# bda8706f-6d13-40bb-9e1e-d21e4e531498_sanger_raw_pindel (4546, 24)
# (4546, 12)
# &*
# (9092, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bda8706f-6d13-40bb-9e1e-d21e4e531498_sanger_raw_pindel is created
# CODE STARTED
# d3a8807d-a888-4c26-938d-ea4d386dd056_sanger_raw_pindel (4605, 24)
# (4604, 12)
# &*
# (9208, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/d3a8807d-a888-4c26-938d-ea4d386dd056_sanger_raw_pindel is created
# CODE STARTED
# a39a2a89-5b6f-486f-b5e0-e0971fe1a91b_sanger_raw_pindel (4638, 24)
# (4638, 12)
# &*
# (9276, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/a39a2a89-5b6f-486f-b5e0-e0971fe1a91b_sanger_raw_pindel is created
# CODE STARTED
# ce519e2c-290c-4cd0-9b7c-a15ec3308bb5_CaVEMan (148, 27)
# (148, 12)
# &*
# (296, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/ce519e2c-290c-4cd0-9b7c-a15ec3308bb5_CaVEMan is created
# CODE STARTED
# 7be8c1b4-eabe-4224-8163-3134668d148a_CaVEMan (232, 27)
# (232, 12)
# &*
# (464, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/7be8c1b4-eabe-4224-8163-3134668d148a_CaVEMan is created
# CODE STARTED
# bc2d1b67-edac-433e-bf33-ff7958c5dd35_CaVEMan (384, 27)
# (384, 12)
# &*
# (768, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/bc2d1b67-edac-433e-bf33-ff7958c5dd35_CaVEMan is created
# CODE STARTED
# 514e7809-f6ef-4994-b87a-8e0567d75219_sanger_raw_pindel (4521, 24)
# (4521, 12)
# &*
# (9042, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/514e7809-f6ef-4994-b87a-8e0567d75219_sanger_raw_pindel is created
# CODE STARTED
# 62f26d07-04b1-4c69-a550-3aea5c8d44e3_sanger_raw_pindel (5348, 24)
# (5347, 12)
# &*
# (10694, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/62f26d07-04b1-4c69-a550-3aea5c8d44e3_sanger_raw_pindel is created
# CODE STARTED
# 6c30db02-ef29-471b-9e53-4511ffe2ba1f_sanger_raw_pindel (4725, 24)
# (4724, 12)
# &*
# (9448, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/6c30db02-ef29-471b-9e53-4511ffe2ba1f_sanger_raw_pindel is created
# CODE STARTED
# 24006735-a46f-440e-9e6d-76f393e6fd40_CaVEMan (225, 27)
# (225, 12)
# &*
# (450, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/24006735-a46f-440e-9e6d-76f393e6fd40_CaVEMan is created
# CODE STARTED
# 04d435e6-77af-4869-8db7-aabc8711bfe0_CaVEMan (372, 27)
# (372, 12)
# &*
# (744, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/04d435e6-77af-4869-8db7-aabc8711bfe0_CaVEMan is created
# CODE STARTED
# 5b1766a9-a718-4016-b365-1a8cf2d33c8a_sanger_raw_pindel (4559, 24)
# (4559, 12)
# &*
# (9118, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/5b1766a9-a718-4016-b365-1a8cf2d33c8a_sanger_raw_pindel is created
# CODE STARTED
# 9dfb5a7b-4f2c-4fb5-a364-8307b22a8f16_CaVEMan (186, 27)
# (186, 12)
# &*
# (372, 2)
# /home/pdutta/Data/Cancer_wiseGDC/New_data/Lung/Generated_files/DNABERT_Data/acceptor/Patient_wise/9dfb5a7b-4f2c-4fb5-a364-8307b22a8f16_CaVEMan is created

# %%
with open(output_path+"/raw_{}_vcf_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(dnabert_raw_data, file)

# %%
len(dnabert_raw_data)
# Out:
# 824
