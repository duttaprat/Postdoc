# %%
import os, glob
import pandas as pd
import pysam
import numpy as np
import pickle

# %%
cancer_type = "Brain"
non_coding_region="acceptor"
intersected_data = "/home/pdutta/Data/Cancer_wiseGDC/Data/{}/Generated_files/Intersected_Data/intersected_vcf_{}_data.pkl".format(cancer_type, non_coding_region)
reference_path  = "/home/pdutta/Data/Human_Genome_Data/GRCh38.primary_assembly.genome.fa"
output_path = "/home/pdutta/Data/Cancer_wiseGDC/Data/{}/Generated_files/DNABERT_Data/{}/".format(cancer_type, non_coding_region)

# %%
def seq2kmer(seq):
    """
    Convert original sequence to kmers
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    k=6
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def get_sequences(df, reference_fasta):
    data = []
    for idx, row in df.iterrows():
        #print(row)
        chrom = row['chr_name']
        ref_start = row['start']
        ref_end = row['end']
        variant_start = row['START_POS']
        variant_end = row['END_POS']
        ref_nucleotide = row['REF']
        alt = row["ALT"]
        
        # Adjust for 0-based indexing in python
        variant_pos_start = variant_start - ref_start
        variant_pos_end = variant_end - ref_start
        #print(ref_nucleotide , alt, variant_pos_start, variant_pos_end)
        
        
        # Get reference sequence
        #print(chrom)
        ref_seq = reference_fasta.fetch(chrom, ref_start, ref_end)
        #print(ref_seq)
        
        # Handle insertion and deletion to get the correct alt sequence
        # Identify if the variant is an insertion or deletion
        if len(ref_nucleotide) < len(alt):  # Insertion
            delete_size =  len(alt) - len(ref_nucleotide)
            #print(variant_pos_start, variant_pos_end ,delete_size)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:len(ref_seq) - delete_size]

        elif len(ref_nucleotide) > len(alt):  # Deletion
            insert_size = len(ref_nucleotide) - len(alt)
            #print(insert_size)
            extra_bases = reference_fasta.fetch(chrom, ref_end, ref_end + insert_size)
            #print(extra_bases)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:] + extra_bases

        else:  # SNV
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:]
        # print(ref_seq)
        # print(alt_seq)
        # input()


        data.append({
            'chr': chrom,
            'strand': row['strand'],
            'Transcript_ID': row['transcript_id'],
            'Acceptor_start': row['start'],
            'Acceptor_end': row['end'],
            'varinat_start': variant_start,
            'variant_end': variant_end,
            'ref_neucleotide': ref_nucleotide,
            'alternative_neucleotide': alt,
            'reference_seq': ref_seq,
            'alt_seq': alt_seq
        })
            
    
    # Convert the list of dictionaries to a DataFrame
    new_df = pd.DataFrame(data)
    # print(new_df.shape)
    # print(new_df)
    new_df = new_df.drop_duplicates().reset_index()
    print(new_df.shape)
    print("&*")
    data = []
    merged_list = list(zip(new_df['reference_seq'], new_df['alt_seq']))
    merged_list = [item.upper() for tup in merged_list for item in tup]
    #print(merged_list)
    kmer_lst = list(map(seq2kmer, merged_list))
    df_kmer = pd.DataFrame(kmer_lst, columns=['Sequence'])
    df_kmer['Label'] = np.random.choice([0, 1], size=len(df_kmer))
    print(df_kmer.shape)
    return new_df, df_kmer

# %%
## Load the VCF files from pickle
with open(intersected_data, "rb") as file:
    loaded_dictionary = pickle.load(file)
print("****All the VCF files are loaded***")
# Out:
# ****All the VCF files are loaded***

# %%
## Load the reference file
reference_fasta = pysam.FastaFile(reference_path)
print("#####The reference file is loaded######")
# Out:
# #####The reference file is loaded######

# %%
# List all sequence names
sequence_names = reference_fasta.references
print("Sequence names in the FASTA file:", sequence_names)
# Out:
# Sequence names in the FASTA file: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX', 'chrY', 'chrM', 'GL000008.2', 'GL000009.2', 'GL000194.1', 'GL000195.1', 'GL000205.2', 'GL000208.1', 'GL000213.1', 'GL000214.1', 'GL000216.2', 'GL000218.1', 'GL000219.1', 'GL000220.1', 'GL000221.1', 'GL000224.1', 'GL000225.1', 'GL000226.1', 'KI270302.1', 'KI270303.1', 'KI270304.1', 'KI270305.1', 'KI270310.1', 'KI270311.1', 'KI270312.1', 'KI270315.1', 'KI270316.1', 'KI270317.1', 'KI270320.1', 'KI270322.1', 'KI270329.1', 'KI270330.1', 'KI270333.1', 'KI270334.1', 'KI270335.1', 'KI270336.1', 'KI270337.1', 'KI270338.1', 'KI270340.1', 'KI270362.1', 'KI270363.1', 'KI270364.1', 'KI270366.1', 'KI270371.1', 'KI270372.1', 'KI270373.1', 'KI270374.1', 'KI270375.1', 'KI270376.1', 'KI270378.1', 'KI270379.1', 'KI270381.1', 'KI270382.1', 'KI270383.1', 'KI270384.1', 'KI270385.1', 'KI270386.1', 'KI270387.1', 'KI270388.1', 'KI270389.1', 'KI270390.1', 'KI270391.1', 'KI270392.1', 'KI270393.1', 'KI270394.1', 'KI270395.1', 'KI270396.1', 'KI270411.1', 'KI270412.1', 'KI270414.1', 'KI270417.1', 'KI270418.1', 'KI270419.1', 'KI270420.1', 'KI270422.1', 'KI270423.1', 'KI270424.1', 'KI270425.1', 'KI270429.1', 'KI270435.1', 'KI270438.1', 'KI270442.1', 'KI270448.1', 'KI270465.1', 'KI270466.1', 'KI270467.1', 'KI270468.1', 'KI270507.1', 'KI270508.1', 'KI270509.1', 'KI270510.1', 'KI270511.1', 'KI270512.1', 'KI270515.1', 'KI270516.1', 'KI270517.1', 'KI270518.1', 'KI270519.1', 'KI270521.1', 'KI270522.1', 'KI270528.1', 'KI270529.1', 'KI270530.1', 'KI270538.1', 'KI270539.1', 'KI270544.1', 'KI270548.1', 'KI270579.1', 'KI270580.1', 'KI270581.1', 'KI270582.1', 'KI270583.1', 'KI270584.1', 'KI270587.1', 'KI270588.1', 'KI270589.1', 'KI270590.1', 'KI270591.1', 'KI270593.1', 'KI270706.1', 'KI270707.1', 'KI270708.1', 'KI270709.1', 'KI270710.1', 'KI270711.1', 'KI270712.1', 'KI270713.1', 'KI270714.1', 'KI270715.1', 'KI270716.1', 'KI270717.1', 'KI270718.1', 'KI270719.1', 'KI270720.1', 'KI270721.1', 'KI270722.1', 'KI270723.1', 'KI270724.1', 'KI270725.1', 'KI270726.1', 'KI270727.1', 'KI270728.1', 'KI270729.1', 'KI270730.1', 'KI270731.1', 'KI270732.1', 'KI270733.1', 'KI270734.1', 'KI270735.1', 'KI270736.1', 'KI270737.1', 'KI270738.1', 'KI270739.1', 'KI270740.1', 'KI270741.1', 'KI270742.1', 'KI270743.1', 'KI270744.1', 'KI270745.1', 'KI270746.1', 'KI270747.1', 'KI270748.1', 'KI270749.1', 'KI270750.1', 'KI270751.1', 'KI270752.1', 'KI270753.1', 'KI270754.1', 'KI270755.1', 'KI270756.1', 'KI270757.1']

# %%
dnabert_raw_data = {}
for key, value in loaded_dictionary.items():
    #display(value[['chr_name', 'start', 'end', 'strand', 'transcript_type', 'CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT']])
    print("CODE STARTED")
    print(key, value.shape)
    out_folder_path = output_path+"Patient_wise/"+ key.split("_")[0].split(".")[0]
    print(out_folder_path, "is created")
    #ins_del_df = value[(value['ALT'].str.len() > value['REF'].str.len()) | (value['REF'].str.len() > value['ALT'].str.len())]
    new_df, df_kmer = get_sequences(value, reference_fasta)
    dnabert_raw_data[key.split("_")[0].split(".")[0]] = new_df
    
    #input()
    if not os.path.exists(out_folder_path):
        os.makedirs(out_folder_path)
    df_kmer.to_csv(out_folder_path + "/dev.tsv", sep="\t", index= False)
# Out:
# CODE STARTED
# 54d621a5-8e45-4bbc-92c4-1c7f36212361 (5236, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/54d621a5-8e45-4bbc-92c4-1c7f36212361 is created
# (5235, 12)
# &*
# (10470, 2)
# CODE STARTED
# ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1 (7679, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1 is created
# (7677, 12)
# &*
# (15354, 2)
# CODE STARTED
# 0f158d5f-16c7-4fb7-b48c-0ff392f1706b (5290, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/0f158d5f-16c7-4fb7-b48c-0ff392f1706b is created
# (5290, 12)
# &*
# (10580, 2)
# CODE STARTED
# da5fbf8f-862d-49a6-8119-86f508063e29 (5240, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/da5fbf8f-862d-49a6-8119-86f508063e29 is created
# (5239, 12)
# &*
# (10478, 2)
# CODE STARTED
# 24abc004-6712-4df9-83f2-bd98dcc6ea5e (5228, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/24abc004-6712-4df9-83f2-bd98dcc6ea5e is created
# (5228, 12)
# &*
# (10456, 2)
# CODE STARTED
# 535e0e9e-9757-45b3-aafd-2b80908de134 (5478, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/535e0e9e-9757-45b3-aafd-2b80908de134 is created
# (5478, 12)
# &*
# (10956, 2)
# CODE STARTED
# b2eaaa93-e870-4b1c-a835-b1d932c75b88 (6497, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b2eaaa93-e870-4b1c-a835-b1d932c75b88 is created
# (6496, 12)
# &*
# (12992, 2)
# CODE STARTED
# a58b5cd5-4625-4070-b672-4eb92cd7775c (6910, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a58b5cd5-4625-4070-b672-4eb92cd7775c is created
# (6905, 12)
# &*
# (13810, 2)
# CODE STARTED
# cf565879-9f53-4fd1-b0da-065869293342 (5290, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/cf565879-9f53-4fd1-b0da-065869293342 is created
# (5290, 12)
# &*
# (10580, 2)
# CODE STARTED
# 0fc04044-0b33-4af6-a800-01d8cda12702 (5396, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/0fc04044-0b33-4af6-a800-01d8cda12702 is created
# (5396, 12)
# &*
# (10792, 2)
# CODE STARTED
# cc884f4d-e62d-4214-bfaa-81052a02a246 (5408, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/cc884f4d-e62d-4214-bfaa-81052a02a246 is created
# (5408, 12)
# &*
# (10816, 2)
# CODE STARTED
# d101eddd-ad00-4a42-9a95-ece5bd2332a2 (4970, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/d101eddd-ad00-4a42-9a95-ece5bd2332a2 is created
# (4969, 12)
# &*
# (9938, 2)
# CODE STARTED
# b5fb53b7-7a70-48a2-84ff-ca6ebe62d053 (5434, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b5fb53b7-7a70-48a2-84ff-ca6ebe62d053 is created
# (5434, 12)
# &*
# (10868, 2)
# CODE STARTED
# 7bed15a4-3b1e-487e-954d-e6b55e296dc0 (5520, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7bed15a4-3b1e-487e-954d-e6b55e296dc0 is created
# (5520, 12)
# &*
# (11040, 2)
# CODE STARTED
# db856976-cd46-494d-bdc8-b4f3608cf10d (6978, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/db856976-cd46-494d-bdc8-b4f3608cf10d is created
# (6975, 12)
# &*
# (13950, 2)
# CODE STARTED
# 2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7 (5172, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7 is created
# (5167, 12)
# &*
# (10334, 2)
# CODE STARTED
# b78b66b2-2983-4965-99ff-8a7e45a07d8f (8106, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b78b66b2-2983-4965-99ff-8a7e45a07d8f is created
# (8104, 12)
# &*
# (16208, 2)
# CODE STARTED
# fd27f3fc-6f0b-4794-8555-3111ad520493 (5313, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/fd27f3fc-6f0b-4794-8555-3111ad520493 is created
# (5308, 12)
# &*
# (10616, 2)
# CODE STARTED
# f00eed55-0ad9-41e8-bdf2-144b43f9b9b8 (5141, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f00eed55-0ad9-41e8-bdf2-144b43f9b9b8 is created
# (5141, 12)
# &*
# (10282, 2)
# CODE STARTED
# 22653df8-0c37-4f24-8832-95dd239f49b6 (5432, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/22653df8-0c37-4f24-8832-95dd239f49b6 is created
# (5432, 12)
# &*
# (10864, 2)
# CODE STARTED
# 07f93ac0-50e0-4c1d-b4da-898062a5b6b8 (5625, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/07f93ac0-50e0-4c1d-b4da-898062a5b6b8 is created
# (5625, 12)
# &*
# (11250, 2)
# CODE STARTED
# 6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1 (5327, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/6cb08eef-31fc-4ad7-9cc7-6176c4ea09a1 is created
# (5327, 12)
# &*
# (10654, 2)
# CODE STARTED
# 90c2456b-af8b-4e31-ae86-7de05a0f4124 (6603, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/90c2456b-af8b-4e31-ae86-7de05a0f4124 is created
# (6601, 12)
# &*
# (13202, 2)
# CODE STARTED
# 1cc1ee58-e45c-4d85-b163-6d097f9d8f1f (5428, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/1cc1ee58-e45c-4d85-b163-6d097f9d8f1f is created
# (5428, 12)
# &*
# (10856, 2)
# CODE STARTED
# a5dba504-f9af-4ad7-8dd2-4d719440b569 (6474, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a5dba504-f9af-4ad7-8dd2-4d719440b569 is created
# (6474, 12)
# &*
# (12948, 2)
# CODE STARTED
# 3adc47fa-b27a-4df1-98ab-201ebab3c6bf (7777, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3adc47fa-b27a-4df1-98ab-201ebab3c6bf is created
# (7775, 12)
# &*
# (15550, 2)
# CODE STARTED
# b7416dd2-f9ef-4fdc-8dd3-5e9b9e7169a3 (5348, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b7416dd2-f9ef-4fdc-8dd3-5e9b9e7169a3 is created
# (5348, 12)
# &*
# (10696, 2)
# CODE STARTED
# f3ad237d-b424-4ca4-9659-2ff88a42e584 (5000, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f3ad237d-b424-4ca4-9659-2ff88a42e584 is created
# (4999, 12)
# &*
# (9998, 2)
# CODE STARTED
# 7d01d7c7-5138-4883-a4e3-c763151943df (5195, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7d01d7c7-5138-4883-a4e3-c763151943df is created
# (5194, 12)
# &*
# (10388, 2)
# CODE STARTED
# 2eb74322-a9f0-4dec-befc-b086386102a5 (5343, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2eb74322-a9f0-4dec-befc-b086386102a5 is created
# (5341, 12)
# &*
# (10682, 2)
# CODE STARTED
# e5bd9afb-3fbd-4688-a376-795a51fd5079 (5468, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/e5bd9afb-3fbd-4688-a376-795a51fd5079 is created
# (5468, 12)
# &*
# (10936, 2)
# CODE STARTED
# f8b8e0df-4234-4839-b0ee-34a2c9ef4985 (5158, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/f8b8e0df-4234-4839-b0ee-34a2c9ef4985 is created
# (5157, 12)
# &*
# (10314, 2)
# CODE STARTED
# 5d65b3c0-5c29-48aa-b6fb-37baf78fe409 (5248, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/5d65b3c0-5c29-48aa-b6fb-37baf78fe409 is created
# (5248, 12)
# &*
# (10496, 2)
# CODE STARTED
# 09435dfd-67f9-4a28-9201-9e82d5bd04de (5470, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/09435dfd-67f9-4a28-9201-9e82d5bd04de is created
# (5470, 12)
# &*
# (10940, 2)
# CODE STARTED
# aae9d68e-f0eb-486b-9520-0b9f547f1ad3 (5323, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/aae9d68e-f0eb-486b-9520-0b9f547f1ad3 is created
# (5322, 12)
# &*
# (10644, 2)
# CODE STARTED
# c12f0212-31ee-4aa2-88c4-d29c7c9059cb (5247, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/c12f0212-31ee-4aa2-88c4-d29c7c9059cb is created
# (5247, 12)
# &*
# (10494, 2)
# CODE STARTED
# 3d9d175b-20dc-4916-afa0-95b9acbbec02 (5445, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3d9d175b-20dc-4916-afa0-95b9acbbec02 is created
# (5445, 12)
# &*
# (10890, 2)
# CODE STARTED
# ca52ea0e-5021-463b-8821-5e7c765812ff (7910, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/ca52ea0e-5021-463b-8821-5e7c765812ff is created
# (7904, 12)
# &*
# (15808, 2)
# CODE STARTED
# eef24407-c46d-45c3-9934-86902ac3ceac (5111, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/eef24407-c46d-45c3-9934-86902ac3ceac is created
# (5111, 12)
# &*
# (10222, 2)
# CODE STARTED
# 3e28bc65-988d-4112-9397-7773ec79a9a9 (6733, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3e28bc65-988d-4112-9397-7773ec79a9a9 is created
# (6731, 12)
# &*
# (13462, 2)
# CODE STARTED
# 1d3daf9d-7740-484e-850b-827a6b7d451d (5420, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/1d3daf9d-7740-484e-850b-827a6b7d451d is created
# (5420, 12)
# &*
# (10840, 2)
# CODE STARTED
# bce00d1a-9598-4fef-8e21-da2c5290d906 (5218, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/bce00d1a-9598-4fef-8e21-da2c5290d906 is created
# (5218, 12)
# &*
# (10436, 2)
# CODE STARTED
# 8bac8b71-abb7-4ecc-9b61-7112fed7da15 (5384, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/8bac8b71-abb7-4ecc-9b61-7112fed7da15 is created
# (5383, 12)
# &*
# (10766, 2)
# CODE STARTED
# 8da9bde9-4b8c-46a2-bcc2-a620a186bab3 (5293, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/8da9bde9-4b8c-46a2-bcc2-a620a186bab3 is created
# (5293, 12)
# &*
# (10586, 2)
# CODE STARTED
# 2a14ea45-6901-488a-af43-1e6287ec8bb0 (5305, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/2a14ea45-6901-488a-af43-1e6287ec8bb0 is created
# (5304, 12)
# &*
# (10608, 2)
# CODE STARTED
# a732538e-135a-43dc-a88b-b122a1a36749 (5437, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/a732538e-135a-43dc-a88b-b122a1a36749 is created
# (5432, 12)
# &*
# (10864, 2)
# CODE STARTED
# 9a81060d-2b6d-4a97-a131-a5cf6c4c3ee4 (5480, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9a81060d-2b6d-4a97-a131-a5cf6c4c3ee4 is created
# (5480, 12)
# &*
# (10960, 2)
# CODE STARTED
# 9f7f9c66-39bb-48b1-ae8e-91acc8028425 (5261, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9f7f9c66-39bb-48b1-ae8e-91acc8028425 is created
# (5261, 12)
# &*
# (10522, 2)
# CODE STARTED
# 4193ad47-7cab-48fe-9466-aec494172f72 (5213, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/4193ad47-7cab-48fe-9466-aec494172f72 is created
# (5212, 12)
# &*
# (10424, 2)
# CODE STARTED
# dc3f72c3-79b4-411c-8275-a85e9d081abb (5404, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/dc3f72c3-79b4-411c-8275-a85e9d081abb is created
# (5404, 12)
# &*
# (10808, 2)
# CODE STARTED
# 3adefeae-8c71-47a0-a9d5-3d0005aa0ef4 (5406, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/3adefeae-8c71-47a0-a9d5-3d0005aa0ef4 is created
# (5406, 12)
# &*
# (10812, 2)
# CODE STARTED
# b01b9f70-fc7d-43d1-bc8a-6c435ffd3705 (5584, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/b01b9f70-fc7d-43d1-bc8a-6c435ffd3705 is created
# (5584, 12)
# &*
# (11168, 2)
# CODE STARTED
# 9a3edc2a-0eb3-4d88-965d-2801cd19df51 (4571, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/9a3edc2a-0eb3-4d88-965d-2801cd19df51 is created
# (4571, 12)
# &*
# (9142, 2)
# CODE STARTED
# d6cb373e-d9bc-43a1-8edc-2199b38b95f7 (5396, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/d6cb373e-d9bc-43a1-8edc-2199b38b95f7 is created
# (5395, 12)
# &*
# (10790, 2)
# CODE STARTED
# 7d9bd465-2e99-4b07-902f-752fa348efb8 (6658, 24)
# /home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/DNABERT_Data/acceptor/Patient_wise/7d9bd465-2e99-4b07-902f-752fa348efb8 is created
# (6656, 12)
# &*
# (13312, 2)

# %%
with open(output_path+"/raw_{}_vcf_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(dnabert_raw_data, file)
