# %%
import os, io
import pandas as pd
import pysam
import pickle
import pybedtools
print(pybedtools.__file__)
pybedtools.helpers.set_tempdir('/home/pdutta/temp')
from IPython.display import display, HTML
# Out:
# /home/pdutta/anaconda3/envs/GDC_VCF/lib/python3.10/site-packages/pybedtools/__init__.py

# %%
cancer_type="Breast"

# %%
vcf_folder_path="/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Downloaded_files/VCF".format(cancer_type)
reference_genome_path="/home/pdutta/Data/Human_Genome_Data/GRCh38_latest_genomic.fna"

# %%
non_coding_region="donor"

# %%
df= pd.read_csv("/home/pdutta/Data/Noncoding_region/Unique_{}_RAW_Combined_BED.tsv".format(non_coding_region), sep="\t")
df
# Out:
#        chr_name     start       end strand  \
# 0          chr1     12189     12268      +
# 1          chr1     12659     12738      +
# 2          chr1     12683     12762      +
# 3          chr1     13336     13415      +
# 4          chr1     15756     15835      -
# ...         ...       ...       ...    ...
# 297951     chrY  57211531  57211610      +
# 297952     chrY  57211582  57211661      +
# 297953     chrY  57213164  57213243      -
# 297954     chrY  57213840  57213919      -
# 297955     chrY  57214310  57214389      -
#
#                                             transcript_id  \
# 0                    ENST00000450305.2, ENST00000456328.2
# 1                                       ENST00000450305.2
# 2                                       ENST00000456328.2
# 3                                       ENST00000450305.2
# 4                                       ENST00000488147.1
# ...                                                   ...
# 297951                            ENST00000464205.6_PAR_Y
# 297952  ENST00000340131.12_PAR_Y, ENST00000359512.8_PA...
# 297953                            ENST00000507418.6_PAR_Y
# 297954                            ENST00000507418.6_PAR_Y
# 297955                            ENST00000507418.6_PAR_Y
#
#                                                   exon_id  \
# 0                    ENSE00001671638.2, ENSE00002234944.1
# 1                                       ENSE00001758273.2
# 2                                       ENSE00003582793.1
# 3                                       ENSE00001746346.2
# 4                                       ENSE00002030414.1
# ...                                                   ...
# 297951                                  ENSE00003785071.1
# 297952  ENSE00003627301.1, ENSE00003905275.1, ENSE0000...
# 297953                                  ENSE00002036959.1
# 297954                                  ENSE00002046926.1
# 297955                                  ENSE00002072208.1
#
#                                           transcript_type
# 0       transcribed_unprocessed_pseudogene, processed_...
# 1                      transcribed_unprocessed_pseudogene
# 2                                    processed_transcript
# 3                      transcribed_unprocessed_pseudogene
# 4                                  unprocessed_pseudogene
# ...                                                   ...
# 297951                               processed_transcript
# 297952                    retained_intron, protein_coding
# 297953                             unprocessed_pseudogene
# 297954                             unprocessed_pseudogene
# 297955                             unprocessed_pseudogene
#
# [297956 rows x 7 columns]

# %%
donor_bed = pybedtools.BedTool.from_dataframe(df)

# %%
reference_fasta = pysam.FastaFile(reference_genome_path)

# %%
def get_vcf_gz_files_except_logs(root_folder):
    all_files = []

    # Walk through the directory tree
    for dirpath, dirnames, filenames in os.walk(root_folder):
        # If "logs" is in dirnames, remove it to avoid traversing it
        if 'logs' in dirnames:
            dirnames.remove('logs')

        # Add only the filenames with the extension .vcf.gz in the current directory to the all_files list
        for filename in filenames:
            if filename.endswith('.vcf.gz'):
                all_files.append(os.path.join(dirpath, filename))
    return all_files

# %%
def vcf_to_dataframe(vcf_path):
    """
    Convert a .vcf.gz file into a pandas DataFrame.

    Parameters:
    - vcf_path (str): path to the .vcf.gz file

    Returns:
    - pd.DataFrame: VCF data as a DataFrame
    """

    try:
        # Open the VCF file
        vcf_file = pysam.VariantFile(vcf_path)
    except ValueError as e:
        print(f"Failed to open file {vcf_path}: {e}")
        with open("/data/projects/GDC_Cancer_Wise/Brain/Data/"+vcf_path.split("/")[-2]+"_error_log.txt", "a") as error_log:
            error_log.write(f"{vcf_path}\n")
        return None

    # Extracting the data and the columns
    data = []
    
    columns =  ["CHROM", "START_POS", "ID", "REF", "ALT", "QUAL", "FILTER"] + list(vcf_file.header.info.keys()) 
    for record in vcf_file:
        basic_data = [record.chrom, record.pos, record.id, record.ref, 
                      ','.join(str(alt) for alt in record.alts), record.qual, record.filter.keys()[0] if record.filter.keys() else 'PASS']
        row_data = [record.info.get(key) for key in vcf_file.header.info.keys()]
        data.append(basic_data + row_data)

    df = pd.DataFrame(data, columns=columns)
    df["START_POS"] = df["START_POS"]-1
    end = df["START_POS"] + df['REF'].str.len()
    df.insert(2, 'END_POS', end)

    # Close the VCF file
    vcf_file.close()

    return df

# %%
files = get_vcf_gz_files_except_logs(vcf_folder_path)

# %%
len(files)
# Out:
# 228

# %%
intersected_vcf_data = {}
df_statistics  = pd.DataFrame(columns= ["filename", "Patient_ID", 'work_flow',  'VCF_instance','VCF_feature','Intersected_instances', 'VCF_column_names' ])

# %%
for file_path in files:
    file_name =  file_path.split('/')[-1]
    parts = file_name.split('.')
    print(parts)
    df_vcf = vcf_to_dataframe(file_path)
    #print(df_vcf)
    if df_vcf is None:
        continue
    vcf_bed = pybedtools.BedTool.from_dataframe(df_vcf)
    intersect_vcf_donor = donor_bed.intersect(vcf_bed, wa=True, wb=True)
    column_list  = df.columns.to_list() + df_vcf.columns.to_list()
    df_intersection = intersect_vcf_donor.to_dataframe(names=column_list)
    df_intersection = df_intersection[(df_intersection['REF'].str.len() < 10) & (df_intersection['ALT'].str.len() < 10)]
    #print(df_intersection)
    #print(df_statistics)
    #input()
    #gdc_tag = parts[-4]
    patient_ID = parts[0]
    work_flow = parts[2]
    instance =  df_vcf.shape[0]
    feature = df_vcf.shape[1]
    intersected_instance = df_intersection.shape[0]
    feature_list = list(df_vcf.columns)
    print(patient_ID, work_flow, instance, feature,intersected_instance,  feature_list)
    df_statistics.loc[len(df_statistics)] = [file_name, patient_ID, work_flow, instance, feature,intersected_instance,  feature_list]
    intersected_vcf_data[patient_ID+"_"+work_flow] = df_intersection
# Out:
# ['460f332f-38b4-4c94-997f-a79c230aa8e1', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 460f332f-38b4-4c94-997f-a79c230aa8e1 CaVEMan 276752 20 1593 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['a7c26dde-f8c4-4534-9c04-a90203311791', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# a7c26dde-f8c4-4534-9c04-a90203311791 sanger_raw_pindel 1100363 17 2934 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['3e85698b-e8b1-4170-9340-c5a1e4587229', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 3e85698b-e8b1-4170-9340-c5a1e4587229 sanger_raw_pindel 1060575 17 3018 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['6a556615-d80f-4b48-94af-a6f25089b40c', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6a556615-d80f-4b48-94af-a6f25089b40c sanger_raw_pindel 1271057 17 3552 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['67ad415a-14a6-41a0-9ca1-95f681d100d6', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 67ad415a-14a6-41a0-9ca1-95f681d100d6 CaVEMan 242809 20 1022 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['
['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f1b5e30c-3b47-4c4b-b903-e6683e976b88', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# f1b5e30c-3b47-4c4b-b903-e6683e976b88 sanger_raw_pindel 1164376 17 3265 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['3b89281a-6482-4f5e-b9d5-6dae1dac0319', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 3b89281a-6482-4f5e-b9d5-6dae1dac0319 CaVEMan 245976 20 1275 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['9d46208f-d70d-48a4-819d-5ed7b579575a', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 9d46208f-d70d-48a4-819d-5ed7b579575a CaVEMan 291706 20 1447 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['3abc2f2e-528b-4cfa-872f-e39cccd186c8', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 3abc2f2e-528b-4cfa-872f-e39cccd186c8 sanger_raw_pindel 1076658 17 2936 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']

# %%
output_path = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/Intersected_Data".format(cancer_type)
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
df_statistics.to_csv(output_path+"/intersected_VCF_{}_statistics.tsv".format(non_coding_region), sep="\t", index=False)

# %%
with open(output_path+"/intersected_vcf_{}_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(intersected_vcf_data, file)

# %%
df_statistics
# Out:
#                                               filename  \
# 0    460f332f-38b4-4c94-997f-a79c230aa8e1.wgs.CaVEM...
# 1    a7c26dde-f8c4-4534-9c04-a90203311791.wgs.sange...
# 2    3e85698b-e8b1-4170-9340-c5a1e4587229.wgs.sange...
# 3    6a556615-d80f-4b48-94af-a6f25089b40c.wgs.sange...
# 4    67ad415a-14a6-41a0-9ca1-95f681d100d6.wgs.CaVEM...
# ..                                                 ...
# 223  ce4c7393-c094-4d9e-8e59-591959707529.wgs.sange...
# 224  f1b5e30c-3b47-4c4b-b903-e6683e976b88.wgs.sange...
# 225  3b89281a-6482-4f5e-b9d5-6dae1dac0319.wgs.CaVEM...
# 226  9d46208f-d70d-48a4-819d-5ed7b579575a.wgs.CaVEM...
# 227  3abc2f2e-528b-4cfa-872f-e39cccd186c8.wgs.sange...
#
#                                Patient_ID          work_flow  VCF_instance  \
# 0    460f332f-38b4-4c94-997f-a79c230aa8e1            CaVEMan        276752
# 1    a7c26dde-f8c4-4534-9c04-a90203311791  sanger_raw_pindel       1100363
# 2    3e85698b-e8b1-4170-9340-c5a1e4587229  sanger_raw_pindel       1060575
# 3    6a556615-d80f-4b48-94af-a6f25089b40c  sanger_raw_pindel       1271057
# 4    67ad415a-14a6-41a0-9ca1-95f681d100d6            CaVEMan        242809
# ..                                    ...                ...           ...
# 223  ce4c7393-c094-4d9e-8e59-591959707529  sanger_raw_pindel       1085859
# 224  f1b5e30c-3b47-4c4b-b903-e6683e976b88  sanger_raw_pindel       1164376
# 225  3b89281a-6482-4f5e-b9d5-6dae1dac0319            CaVEMan        245976
# 226  9d46208f-d70d-48a4-819d-5ed7b579575a            CaVEMan        291706
# 227  3abc2f2e-528b-4cfa-872f-e39cccd186c8  sanger_raw_pindel       1076658
#
#      VCF_feature  Intersected_instances  \
# 0             20                   1593
# 1             17                   2934
# 2             17                   3018
# 3             17                   3552
# 4             20                   1022
# ..           ...                    ...
# 223           17                   2833
# 224           17                   3265
# 225           20                   1275
# 226           20                   1447
# 227           17                   2936
#
#                                       VCF_column_names
# 0    [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 1    [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 2    [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 3    [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 4    [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# ..                                                 ...
# 223  [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 224  [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 225  [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 226  [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
# 227  [CHROM, START_POS, END_POS, ID, REF, ALT, QUAL...
#
# [228 rows x 7 columns]
