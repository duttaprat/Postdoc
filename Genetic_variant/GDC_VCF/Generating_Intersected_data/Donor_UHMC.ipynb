# %%
import os, io
import pandas as pd
import pysam
import pickle
import pybedtools
print(pybedtools.__file__)
pybedtools.helpers.set_tempdir('/home/pdutta/temp')
from IPython.display import display, HTML
# Out:
# /home/pdutta/anaconda3/lib/python3.9/site-packages/pybedtools/__init__.py

# %%
vcf_folder_path="/home/pdutta/Data/Cancer_wiseGDC/Data/Brain/WGS_VCF_Files"
reference_genome_path="/home/pdutta/Data/Human_Genome_Data/GRCh38_latest_genomic.fna"

# %%
non_coding_region="donor"

# %%
df= pd.read_csv("/home/pdutta/Data/Noncoding_region/Unique_{}_RAW_Combined_BED.tsv".format(non_coding_region), sep="\t")
df
# Out:
#        chr_name     start       end strand  \
# 0          chr1     12189     12268      +
# 1          chr1     12659     12738      +
# 2          chr1     12683     12762      +
# 3          chr1     13336     13415      +
# 4          chr1     15756     15835      -
# ...         ...       ...       ...    ...
# 297951     chrY  57211531  57211610      +
# 297952     chrY  57211582  57211661      +
# 297953     chrY  57213164  57213243      -
# 297954     chrY  57213840  57213919      -
# 297955     chrY  57214310  57214389      -
#
#                                             transcript_id  \
# 0                    ENST00000450305.2, ENST00000456328.2
# 1                                       ENST00000450305.2
# 2                                       ENST00000456328.2
# 3                                       ENST00000450305.2
# 4                                       ENST00000488147.1
# ...                                                   ...
# 297951                            ENST00000464205.6_PAR_Y
# 297952  ENST00000340131.12_PAR_Y, ENST00000359512.8_PA...
# 297953                            ENST00000507418.6_PAR_Y
# 297954                            ENST00000507418.6_PAR_Y
# 297955                            ENST00000507418.6_PAR_Y
#
#                                                   exon_id  \
# 0                    ENSE00001671638.2, ENSE00002234944.1
# 1                                       ENSE00001758273.2
# 2                                       ENSE00003582793.1
# 3                                       ENSE00001746346.2
# 4                                       ENSE00002030414.1
# ...                                                   ...
# 297951                                  ENSE00003785071.1
# 297952  ENSE00003627301.1, ENSE00003905275.1, ENSE0000...
# 297953                                  ENSE00002036959.1
# 297954                                  ENSE00002046926.1
# 297955                                  ENSE00002072208.1
#
#                                           transcript_type
# 0       transcribed_unprocessed_pseudogene, processed_...
# 1                      transcribed_unprocessed_pseudogene
# 2                                    processed_transcript
# 3                      transcribed_unprocessed_pseudogene
# 4                                  unprocessed_pseudogene
# ...                                                   ...
# 297951                               processed_transcript
# 297952                    retained_intron, protein_coding
# 297953                             unprocessed_pseudogene
# 297954                             unprocessed_pseudogene
# 297955                             unprocessed_pseudogene
#
# [297956 rows x 7 columns]

# %%
donor_bed = pybedtools.BedTool.from_dataframe(df)

# %%
reference_fasta = pysam.FastaFile(reference_genome_path)

# %%
def get_vcf_gz_files_except_logs(root_folder):
    all_files = []

    # Walk through the directory tree
    for dirpath, dirnames, filenames in os.walk(root_folder):
        # If "logs" is in dirnames, remove it to avoid traversing it
        if 'logs' in dirnames:
            dirnames.remove('logs')

        # Add only the filenames with the extension .vcf.gz in the current directory to the all_files list
        for filename in filenames:
            if filename.endswith('.vcf.gz'):
                all_files.append(os.path.join(dirpath, filename))
    return all_files

# %%
def vcf_to_dataframe(vcf_path):
    """
    Convert a .vcf.gz file into a pandas DataFrame.

    Parameters:
    - vcf_path (str): path to the .vcf.gz file

    Returns:
    - pd.DataFrame: VCF data as a DataFrame
    """

    try:
        # Open the VCF file
        vcf_file = pysam.VariantFile(vcf_path)
    except ValueError as e:
        print(f"Failed to open file {vcf_path}: {e}")
        with open("/data/projects/GDC_Cancer_Wise/Brain/Data/"+vcf_path.split("/")[-2]+"_error_log.txt", "a") as error_log:
            error_log.write(f"{vcf_path}\n")
        return None

    # Extracting the data and the columns
    data = []
    
    columns =  ["CHROM", "START_POS", "ID", "REF", "ALT", "QUAL", "FILTER"] + list(vcf_file.header.info.keys()) 
    for record in vcf_file:
        basic_data = [record.chrom, record.pos, record.id, record.ref, 
                      ','.join(str(alt) for alt in record.alts), record.qual, record.filter.keys()[0] if record.filter.keys() else 'PASS']
        row_data = [record.info.get(key) for key in vcf_file.header.info.keys()]
        data.append(basic_data + row_data)

    df = pd.DataFrame(data, columns=columns)
    df["START_POS"] = df["START_POS"]-1
    end = df["START_POS"] + df['REF'].str.len()
    df.insert(2, 'END_POS', end)

    # Close the VCF file
    vcf_file.close()

    return df

# %%
files = get_vcf_gz_files_except_logs(vcf_folder_path)

# %%
len(files)
# Out:
# 110

# %%
intersected_vcf_data = {}
df_statistics  = pd.DataFrame(columns= ["filename", "Patient_ID", 'work_flow',  'VCF_instance','VCF_feature','Intersected_instances', 'VCF_column_names' ])

# %%
for file_path in files:
    file_name =  file_path.split('/')[-1]
    parts = file_name.split('.')
    print(parts)
    df_vcf = vcf_to_dataframe(file_path)
    #print(df_vcf)
    if df_vcf is None:
        continue
    vcf_bed = pybedtools.BedTool.from_dataframe(df_vcf)
    intersect_vcf_donor = donor_bed.intersect(vcf_bed, wa=True, wb=True)
    column_list  = df.columns.to_list() + df_vcf.columns.to_list()
    df_intersection = intersect_vcf_donor.to_dataframe(names=column_list)
    df_intersection = df_intersection[(df_intersection['REF'].str.len() < 10) & (df_intersection['ALT'].str.len() < 10)]
    #print(df_intersection)
    #print(df_statistics)
    #input()
    #gdc_tag = parts[-4]
    patient_ID = parts[0]
    work_flow = parts[2]
    instance =  df_vcf.shape[0]
    feature = df_vcf.shape[1]
    intersected_instance = df_intersection.shape[0]
    feature_list = list(df_vcf.columns)
    print(patient_ID, work_flow, instance, feature,intersected_instance,  feature_list)
    df_statistics.loc[len(df_statistics)] = [file_name, patient_ID, work_flow, instance, feature,intersected_instance,  feature_list]
    intersected_vcf_data[patient_ID+"_"+work_flow] = df_intersection
# Out:
# ['1d3daf9d-7740-484e-850b-827a6b7d451d', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1d3daf9d-7740-484e-850b-827a6b7d451d CaVEMan 39764 20 123 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['54d621a5-8e45-4bbc-92c4-1c7f36212361', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 54d621a5-8e45-4bbc-92c4-1c7f36212361 sanger_raw_pindel 853961 17 2567 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['07f93ac0-50e0-4c1d-b4da-898062a5b6b8', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 07f93ac0-50e0-4c1d-b4da-898062a5b6b8 CaVEMan 57346 20 173 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# ef6c3ecc-0bb6-4035-9c45-57740f5bcaa1 sanger_raw_pindel 1249059 17 3429 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 2c9bbb8f-4b4d-4c0e-a158-1fb0fb95aca7 CaVEMan 42442 20 112 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['0f158d5f-16c7-4fb7-b48c-0ff392f1706b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 
['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['4193ad47-7cab-48fe-9466-aec494172f72', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 4193ad47-7cab-48fe-9466-aec494172f72 sanger_raw_pindel 845728 17 2528 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['dc3f72c3-79b4-411c-8275-a85e9d081abb', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# dc3f72c3-79b4-411c-8275-a85e9d081abb sanger_raw_pindel 867463 17 2620 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['dc3f72c3-79b4-411c-8275-a85e9d081abb', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# dc3f72c3-79b4-411c-8275-a85e9d081abb CaVEMan 58369 20 155 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['7d9bd465-2e99-4b07-902f-752fa348efb8', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 7d9bd465-2e99-4b07-902f-752fa348efb8 CaVEMan 203722 20 1063 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['24abc004-6712-4df9-83f2-bd98dcc6ea5e', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 24abc004-6712-4df9-83f2-bd98dcc6ea5e CaVEMan 57637 20 278 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['90c2456b-af8b-4e31-ae86-7de05a0f4124', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 90c2456b-af8b-4e31-ae86-7de05a0f4124 CaVEMan 215669 20 1113 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['8da9bde9-4b8c-46a2-bcc2-a620a186bab3', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 8da9bde9-4b8c-46a2-bcc2-a620a186bab3 CaVEMan 48621 20 161 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['eef24407-c46d-45c3-9934-86902ac3ceac', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# eef24407-c46d-45c3-9934-86902ac3ceac CaVEMan 44368 20 160 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['54d621a5-8e45-4bbc-92c4-1c7f36212361', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 54d621a5-8e45-4bbc-92c4-1c7f36212361 CaVEMan 46676 20 153 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['3e28bc65-988d-4112-9397-7773ec79a9a9', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 3e28bc65-988d-4112-9397-7773ec79a9a9 CaVEMan 257218 20 1267 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['3adefeae-8c71-47a0-a9d5-3d0005aa0ef4', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 3adefeae-8c71-47a0-a9d5-3d0005aa0ef4 sanger_raw_pindel 884112 17 2587 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['b01b9f70-fc7d-43d1-bc8a-6c435ffd3705', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# b01b9f70-fc7d-43d1-bc8a-6c435ffd3705 sanger_raw_pindel 908507 17 2686 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['9a3edc2a-0eb3-4d88-965d-2801cd19df51', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 9a3edc2a-0eb3-4d88-965d-2801cd19df51 sanger_raw_pindel 728647 17 2349 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['d6cb373e-d9bc-43a1-8edc-2199b38b95f7', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d6cb373e-d9bc-43a1-8edc-2199b38b95f7 sanger_raw_pindel 880376 17 2620 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['7d9bd465-2e99-4b07-902f-752fa348efb8', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 7d9bd465-2e99-4b07-902f-752fa348efb8 sanger_raw_pindel 1096330 17 2967 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']

# %%
output_path = "/home/pdutta/Data/Cancer_wiseGDC/Data/Brain/Generated_files/Intersected_Data"
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
df_statistics.to_csv(output_path+"/intersected_VCF_{}_statistics.tsv".format(non_coding_region), sep="\t", index=False)

# %%
with open(output_path+"/intersected_vcf_{}_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(intersected_vcf_data, file)

# %%
df_statistics
