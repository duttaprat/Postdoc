# %%
import os, glob
import pandas as pd
import pysam
import numpy as np
import pickle

# %%
cancer_type = "Brain"
intersected_base_path = "/data/projects/GDC_Cancer_Wise/New_data/{}/Generated_files/Intersected_Data/300bp_TFBS".format(cancer_type)
reference_genome_path="/data/projects/Resources/Gencode_genome_annotation/GRCh38.primary_assembly.genome.fa"

# %%
output_path = "/data/projects/GDC_Cancer_Wise/New_data/{}/Generated_files/DNABERT_Data/Somatic/TFBS_300bp".format(cancer_type)
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
top_models_df= pd.read_csv("/home/campus.stonybrook.edu/pdutta/Github/Postdoc/DNABERT_data_processing/TFBS/important_tfbs.txt", sep="\t", header=None)
top_models_df
# Out:
#            0
# 0        FOS
# 1      H2AFZ
# 2    H2AK5ac
# 3   H2BK12ac
# 4    H2BK5ac
# 5      H3F3A
# 6    H3K14ac
# 7    H3K27ac
# 8   H3K27me3
# 9   H3K36me3
# 10   H3K4me1
# 11   H3K4me2
# 12  H3K79me1
# 13  H3K79me2
# 14    H3K9ac
# 15   H3K9me1
# 16   H3K9me3
# 17  H4K20me1
# 18    H4K5ac
# 19    H4K8ac
# 20     IKZF1
# 21     RAD21
# 22     RBM22
# 23     RUNX3
# 24    TRIM22
# 25    ZBTB33
# 26    ZNF143
# 27      NFE2
# 28     PRDM1
# 29     SCRT2
# 30     ZFHX2
# 31    ZNF121
# 32    ZNF366
# 33    ZNF770

# %%
def seq2kmer(seq):
    """
    Convert original sequence to kmers
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    k=6
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def get_sequences(df, reference_fasta):
    data = []
    for idx, row in df.iterrows():
        #print(row)
        chrom = row[0]
        ref_start = row[1]
        ref_end = row[2]
        variant_start = row['START_POS']
        variant_end = row['END_POS']
        ref_nucleotide = row['REF']
        alt = row["ALT"]
        
        # Adjust for 0-based indexing in python
        variant_pos_start = variant_start - ref_start
        variant_pos_end = variant_end - ref_start
        #print(ref_nucleotide , alt, variant_pos_start, variant_pos_end)
        
        
        # Get reference sequence
        #print(chrom)
        ref_seq = reference_fasta.fetch(chrom, ref_start, ref_end)
        #print(ref_seq)
        
        # Handle insertion and deletion to get the correct alt sequence
        # Identify if the variant is an insertion or deletion
        if len(ref_nucleotide) < len(alt):  # Insertion
            delete_size =  len(alt) - len(ref_nucleotide)
            #print(variant_pos_start, variant_pos_end ,delete_size)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:len(ref_seq) - delete_size]

        elif len(ref_nucleotide) > len(alt):  # Deletion
            insert_size = len(ref_nucleotide) - len(alt)
            #print(insert_size)
            extra_bases = reference_fasta.fetch(chrom, ref_end, ref_end + insert_size)
            #print(extra_bases)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:] + extra_bases

        else:  # SNV
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:]
        # print(ref_seq)
        # print(alt_seq)
        # input()


        data.append({
            'chr': chrom,
            #'strand': row['strand'],
            #'Transcript_ID': row['transcript_id'],
            'Chip_Seq_start': row[1],
            'Chip_Seq_end': row[2],
            'varinat_start': variant_start,
            'variant_end': variant_end,
            'ref_neucleotide': ref_nucleotide,
            'alternative_neucleotide': alt,
            'reference_seq': ref_seq,
            'alt_seq': alt_seq
        })
            
    
    # Convert the list of dictionaries to a DataFrame
    new_df = pd.DataFrame(data)
    # print(new_df.shape)
    # print(new_df)
    new_df = new_df.drop_duplicates().reset_index()
    #print(new_df.shape)
    #print("&*")
    data = []
    merged_list = list(zip(new_df['reference_seq'], new_df['alt_seq']))
    merged_list = [item.upper() for tup in merged_list for item in tup]
    #print(merged_list)
    kmer_lst = list(map(seq2kmer, merged_list))
    df_kmer = pd.DataFrame(kmer_lst, columns=['Sequence'])
    df_kmer['Label'] = np.random.choice([0, 1], size=len(df_kmer))
    #print(df_kmer.shape)
    return new_df, df_kmer

# %%
## Load the reference file
reference_fasta = pysam.FastaFile(reference_genome_path)
print("#####The reference file is loaded######")
# Out:
# #####The reference file is loaded######

# %%
missing_files = []



for index, row in top_models_df.iterrows():
    intersected_data = f"{intersected_base_path}/{row[0]}/intersected_vcf_data.pkl"
    print(intersected_data)
    
    try:
        with open(intersected_data, "rb") as file:
            loaded_dictionary = pickle.load(file)
        print(f"****All the VCF files are loaded for {row[0]}***") 

        dnabert_raw_data = {}
        for key, value in loaded_dictionary.items():
            new_df, df_kmer = get_sequences(value, reference_fasta)
            dnabert_raw_data[key] = new_df
            # Apply mutations
            # Assuming grouped_df is already created and sorted properly
            # Modify your grouped DataFrame construction and apply the new function
            out_folder_path = f"{output_path}/{row[0]}/Patient_wise/{key}"
            if not os.path.exists(out_folder_path):
                os.makedirs(out_folder_path)
            df_kmer.to_csv(out_folder_path + "/dev.tsv", sep="\t", index=False)
        
        with open(f"{output_path}/{row[0]}/raw_vcf_data.pkl", "wb") as file:
            pickle.dump(dnabert_raw_data, file)

    except FileNotFoundError:
        print(f"File not found for {row[0]}, skipping...")
        missing_files.append(row[0])

# Optionally, save the list of missing files/tags to a text file
missing_files_path = f"{output_path}/missing_files.txt"
with open(missing_files_path, "w") as f:
    for tag in missing_files:
        f.write(f"{tag}\n")

print(f"Missing files recorded at {missing_files_path}")
# Out:
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/FOS/intersected_vcf_data.pkl
# ****All the VCF files are loaded for FOS***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H2AFZ/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H2AFZ***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H2AK5ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H2AK5ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H2BK12ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H2BK12ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H2BK5ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H2BK5ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3F3A/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3F3A***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K14ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K14ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K27ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K27ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K27me3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K27me3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K36me3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K36me3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K4me1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K4me1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K4me2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K4me2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K79me1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K79me1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K79me2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K79me2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K9ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K9ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K9me1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K9me1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H3K9me3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H3K9me3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H4K20me1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H4K20me1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H4K5ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H4K5ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/H4K8ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H4K8ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/IKZF1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for IKZF1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/RAD21/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RAD21***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/RBM22/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RBM22***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/RUNX3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RUNX3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/TRIM22/intersected_vcf_data.pkl
# ****All the VCF files are loaded for TRIM22***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/ZBTB33/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZBTB33***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/ZNF143/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF143***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/NFE2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for NFE2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/PRDM1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for PRDM1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/SCRT2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SCRT2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/ZFHX2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZFHX2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/ZNF121/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF121***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/ZNF366/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF366***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/300bp_TFBS/ZNF770/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF770***
# Missing files recorded at /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/DNABERT_Data/Somatic/TFBS_300bp/missing_files.txt
