# %%
import os, glob
import pandas as pd
import pysam
import numpy as np
import pickle

# %%
cancer_type = "Brain"
intersected_base_path = "/data/projects/GDC_Cancer_Wise/New_data/{}/Generated_files/Intersected_Data/TFBS_remaining".format(cancer_type)
reference_genome_path="/data/projects/Resources/Gencode_genome_annotation/GRCh38.primary_assembly.genome.fa"

# %%
output_path = "/data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/DNABERT_Data/TFBS_remaining"
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
top_models_df= pd.read_csv("/home/campus.stonybrook.edu/pdutta/Github/Postdoc/DNABERT_data_processing/TFBS/top_TFBS_models.tsv", sep="\t") 
top_models_df
# Out:
#        tags                                             config  eval_acc
# 0     RBM14  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...  0.968908
# 1      SAFB  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...  0.968090
# 2     TAF15  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...  0.959936
# 3      SPI1  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...  0.957358
# 4      USF1  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...  0.951848
# ..      ...                                                ...       ...
# 134   ESRRA  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...  0.851964
# 135  ZNF652  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...  0.851404
# 136    ATF3  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...  0.851240
# 137   RBM25  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...  0.850664
# 138    CHD2  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...  0.850362
#
# [139 rows x 3 columns]

# %%
def seq2kmer(seq):
    """
    Convert original sequence to kmers
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    k=6
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def get_sequences(df, reference_fasta):
    data = []
    for idx, row in df.iterrows():
        #print(row)
        chrom = row[0]
        ref_start = row[1]
        ref_end = row[2]
        variant_start = row['START_POS']
        variant_end = row['END_POS']
        ref_nucleotide = row['REF']
        alt = row["ALT"]
        
        # Adjust for 0-based indexing in python
        variant_pos_start = variant_start - ref_start
        variant_pos_end = variant_end - ref_start
        #print(ref_nucleotide , alt, variant_pos_start, variant_pos_end)
        
        
        # Get reference sequence
        #print(chrom)
        ref_seq = reference_fasta.fetch(chrom, ref_start, ref_end)
        #print(ref_seq)
        
        # Handle insertion and deletion to get the correct alt sequence
        # Identify if the variant is an insertion or deletion
        if len(ref_nucleotide) < len(alt):  # Insertion
            delete_size =  len(alt) - len(ref_nucleotide)
            #print(variant_pos_start, variant_pos_end ,delete_size)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:len(ref_seq) - delete_size]

        elif len(ref_nucleotide) > len(alt):  # Deletion
            insert_size = len(ref_nucleotide) - len(alt)
            #print(insert_size)
            extra_bases = reference_fasta.fetch(chrom, ref_end, ref_end + insert_size)
            #print(extra_bases)
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:] + extra_bases

        else:  # SNV
            alt_seq = ref_seq[:variant_pos_start] + alt + ref_seq[variant_pos_end:]
        # print(ref_seq)
        # print(alt_seq)
        # input()


        data.append({
            'chr': chrom,
            #'strand': row['strand'],
            #'Transcript_ID': row['transcript_id'],
            'Chip_Seq_start': row[0],
            'Chip_Seq_end': row[1],
            'varinat_start': variant_start,
            'variant_end': variant_end,
            'ref_neucleotide': ref_nucleotide,
            'alternative_neucleotide': alt,
            'reference_seq': ref_seq,
            'alt_seq': alt_seq
        })
            
    
    # Convert the list of dictionaries to a DataFrame
    new_df = pd.DataFrame(data)
    # print(new_df.shape)
    # print(new_df)
    new_df = new_df.drop_duplicates().reset_index()
    #print(new_df.shape)
    #print("&*")
    data = []
    merged_list = list(zip(new_df['reference_seq'], new_df['alt_seq']))
    merged_list = [item.upper() for tup in merged_list for item in tup]
    #print(merged_list)
    kmer_lst = list(map(seq2kmer, merged_list))
    df_kmer = pd.DataFrame(kmer_lst, columns=['Sequence'])
    df_kmer['Label'] = np.random.choice([0, 1], size=len(df_kmer))
    #print(df_kmer.shape)
    return new_df, df_kmer

# %%
## Load the reference file
reference_fasta = pysam.FastaFile(reference_genome_path)
print("#####The reference file is loaded######")
# Out:
# #####The reference file is loaded######

# %%
missing_files = []



for index, row in top_models_df.iterrows():
    intersected_data = f"{intersected_base_path}/{row['tags']}/intersected_vcf_data.pkl"
    print(intersected_data)
    
    try:
        with open(intersected_data, "rb") as file:
            loaded_dictionary = pickle.load(file)
        print(f"****All the VCF files are loaded for {row['tags']}***") 

        dnabert_raw_data = {}
        for key, value in loaded_dictionary.items():
            new_df, df_kmer = get_sequences(value, reference_fasta)
            dnabert_raw_data[key] = new_df

            out_folder_path = f"{output_path}/{row['tags']}/Patient_wise/{key}"
            if not os.path.exists(out_folder_path):
                os.makedirs(out_folder_path)
            df_kmer.to_csv(out_folder_path + "/dev.tsv", sep="\t", index=False)
        
        with open(f"{output_path}/{row['tags']}/raw_vcf_data.pkl", "wb") as file:
            pickle.dump(dnabert_raw_data, file)

    except FileNotFoundError:
        print(f"File not found for {row['tags']}, skipping...")
        missing_files.append(row['tags'])

# Optionally, save the list of missing files/tags to a text file
missing_files_path = f"{output_path}/missing_files.txt"
with open(missing_files_path, "w") as f:
    for tag in missing_files:
        f.write(f"{tag}\n")

print(f"Missing files recorded at {missing_files_path}")
# Out:
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RBM14/intersected_vcf_data.pkl
# File not found for RBM14, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SAFB/intersected_vcf_data.pkl
# File not found for SAFB, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/TAF15/intersected_vcf_data.pkl
# ****All the VCF files are loaded for TAF15***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SPI1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SPI1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/USF1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for USF1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF426/intersected_vcf_data.pkl
# File not found for ZNF426, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MAFK/intersected_vcf_data.pkl
# ****All the VCF files are loaded for MAFK***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/FUS/intersected_vcf_data.pkl
# File not found for FUS, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MAFF/intersected_vcf_data.pkl
# File not found for MAFF, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/THAP1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for THAP1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SRSF1/intersected_vcf_data.pkl
# File not found for SRSF1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF146/intersected_vcf_data.pkl
# File not found for ZNF146, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/HNRNPLL/intersected_vcf_data.pkl
# ****All the VCF files are loaded for HNRNPLL***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/PCBP1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for PCBP1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/AGO1/intersected_vcf_data.pkl
# File not found for AGO1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/FOS/intersected_vcf_data.pkl
# File not found for FOS, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF654/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF654***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/NFE2L2/intersected_vcf_data.pkl
# File not found for NFE2L2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/C11orf30/intersected_vcf_data.pkl
# ****All the VCF files are loaded for C11orf30***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CEBPB/intersected_vcf_data.pkl
# ****All the VCF files are loaded for CEBPB***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/HNRNPL/intersected_vcf_data.pkl
# File not found for HNRNPL, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/EGR2/intersected_vcf_data.pkl
# File not found for EGR2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/E2F4/intersected_vcf_data.pkl
# File not found for E2F4, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZFHX2/intersected_vcf_data.pkl
# File not found for ZFHX2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF770/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF770***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MITF/intersected_vcf_data.pkl
# ****All the VCF files are loaded for MITF***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RAD212/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RAD212***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/GLIS2/intersected_vcf_data.pkl
# File not found for GLIS2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF143/intersected_vcf_data.pkl
# File not found for ZNF143, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MAFG/intersected_vcf_data.pkl
# File not found for MAFG, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF777/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF777***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF555/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF555***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF316/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF316***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/USF2/intersected_vcf_data.pkl
# File not found for USF2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/FOSL2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for FOSL2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MXD3/intersected_vcf_data.pkl
# File not found for MXD3, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/BLC3/intersected_vcf_data.pkl
# File not found for BLC3, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RBM39/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RBM39***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZBED52/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZBED52***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SIN3B/intersected_vcf_data.pkl
# File not found for SIN3B, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/UBTF/intersected_vcf_data.pkl
# ****All the VCF files are loaded for UBTF***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RAD21M/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RAD21M***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/NR3C1/intersected_vcf_data.pkl
# File not found for NR3C1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/PAX5/intersected_vcf_data.pkl
# File not found for PAX5, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/FOXA2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for FOXA2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZBTB26/intersected_vcf_data.pkl
# File not found for ZBTB26, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SAP30/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SAP30***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF585B/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF585B***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZC3H11A/intersected_vcf_data.pkl
# File not found for ZC3H11A, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/AGO2/intersected_vcf_data.pkl
# File not found for AGO2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF623/intersected_vcf_data.pkl
# File not found for ZNF623, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/FOXA1/intersected_vcf_data.pkl
# File not found for FOXA1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/EGR1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for EGR1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SMC3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SMC3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/U2AF1/intersected_vcf_data.pkl
# File not found for U2AF1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MYC/intersected_vcf_data.pkl
# File not found for MYC, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SRF/intersected_vcf_data.pkl
# File not found for SRF, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CREB1/intersected_vcf_data.pkl
# File not found for CREB1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/TFDP12/intersected_vcf_data.pkl
# ****All the VCF files are loaded for TFDP12***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RBBP5/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RBBP5***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF292/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF292***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/GABPB1/intersected_vcf_data.pkl
# File not found for GABPB1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/STAT3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for STAT3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MAZ/intersected_vcf_data.pkl
# File not found for MAZ, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZIC2/intersected_vcf_data.pkl
# File not found for ZIC2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZFP36/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZFP36***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/TFAP4/intersected_vcf_data.pkl
# ****All the VCF files are loaded for TFAP4***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF121/intersected_vcf_data.pkl
# File not found for ZNF121, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SUZ12/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SUZ12***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/KDM5B/intersected_vcf_data.pkl
# ****All the VCF files are loaded for KDM5B***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/FOXP2/intersected_vcf_data.pkl
# File not found for FOXP2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/KLF9/intersected_vcf_data.pkl
# File not found for KLF9, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/POLR2A/intersected_vcf_data.pkl
# File not found for POLR2A, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ELK1/intersected_vcf_data.pkl
# File not found for ELK1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RUNX3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for RUNX3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SMAD42/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SMAD42***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CBFA2T2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for CBFA2T2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/XRCC5/intersected_vcf_data.pkl
# File not found for XRCC5, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CEBPZ/intersected_vcf_data.pkl
# File not found for CEBPZ, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/NONO/intersected_vcf_data.pkl
# ****All the VCF files are loaded for NONO***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF785/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF785***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MEIS2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for MEIS2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/TAF1/intersected_vcf_data.pkl
# File not found for TAF1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/HNF4G/intersected_vcf_data.pkl
# ****All the VCF files are loaded for HNF4G***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CEBPG/intersected_vcf_data.pkl
# File not found for CEBPG, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/HNRNPH1/intersected_vcf_data.pkl
# File not found for HNRNPH1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZSCAN4/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZSCAN4***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZBTB6/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZBTB6***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/POLR2AphosphoS5/intersected_vcf_data.pkl
# File not found for POLR2AphosphoS5, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/GLIS1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for GLIS1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/NFYC/intersected_vcf_data.pkl
# ****All the VCF files are loaded for NFYC***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SREBF2/intersected_vcf_data.pkl
# File not found for SREBF2, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CBFA2T3/intersected_vcf_data.pkl
# File not found for CBFA2T3, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/POU2F2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for POU2F2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZFX/intersected_vcf_data.pkl
# File not found for ZFX, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CBX1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for CBX1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/JUND/intersected_vcf_data.pkl
# ****All the VCF files are loaded for JUND***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RARA/intersected_vcf_data.pkl
# File not found for RARA, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZSCAN5A/intersected_vcf_data.pkl
# File not found for ZSCAN5A, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/PHF20/intersected_vcf_data.pkl
# File not found for PHF20, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/PKNOX1/intersected_vcf_data.pkl
# File not found for PKNOX1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SETDB1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SETDB1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/U2AF2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for U2AF2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/FOXP1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for FOXP1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/NR2F62/intersected_vcf_data.pkl
# File not found for NR2F62, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RXRA/intersected_vcf_data.pkl
# File not found for RXRA, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/HBP1/intersected_vcf_data.pkl
# File not found for HBP1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SP5/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SP5***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/IRF5/intersected_vcf_data.pkl
# ****All the VCF files are loaded for IRF5***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SIX5/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SIX5***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/H4K12ac/intersected_vcf_data.pkl
# File not found for H4K12ac, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF398/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF398***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MYRF/intersected_vcf_data.pkl
# File not found for MYRF, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/HDAC6/intersected_vcf_data.pkl
# File not found for HDAC6, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/GLI4/intersected_vcf_data.pkl
# ****All the VCF files are loaded for GLI4***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF560/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF560***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF596/intersected_vcf_data.pkl
# File not found for ZNF596, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF521/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF521***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/DEAF1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for DEAF1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RUNX1/intersected_vcf_data.pkl
# File not found for RUNX1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MNT/intersected_vcf_data.pkl
# File not found for MNT, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/SCRT2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for SCRT2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF263/intersected_vcf_data.pkl
# File not found for ZNF263, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/H2AK9ac/intersected_vcf_data.pkl
# ****All the VCF files are loaded for H2AK9ac***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/TEAD32/intersected_vcf_data.pkl
# ****All the VCF files are loaded for TEAD32***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/MBD2/intersected_vcf_data.pkl
# ****All the VCF files are loaded for MBD2***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZBTB8A/intersected_vcf_data.pkl
# File not found for ZBTB8A, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZFP642/intersected_vcf_data.pkl
# File not found for ZFP642, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/GTF2F1/intersected_vcf_data.pkl
# File not found for GTF2F1, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZMYM3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZMYM3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/HMGXB4/intersected_vcf_data.pkl
# ****All the VCF files are loaded for HMGXB4***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/VEZF1/intersected_vcf_data.pkl
# ****All the VCF files are loaded for VEZF1***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZBTB20/intersected_vcf_data.pkl
# File not found for ZBTB20, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/GATA4/intersected_vcf_data.pkl
# File not found for GATA4, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ESRRA/intersected_vcf_data.pkl
# File not found for ESRRA, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ZNF652/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ZNF652***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/ATF3/intersected_vcf_data.pkl
# ****All the VCF files are loaded for ATF3***
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/RBM25/intersected_vcf_data.pkl
# File not found for RBM25, skipping...
# /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/Intersected_Data/TFBS_remaining/CHD2/intersected_vcf_data.pkl
# File not found for CHD2, skipping...
# Missing files recorded at /data/projects/GDC_Cancer_Wise/New_data/Brain/Generated_files/DNABERT_Data/TFBS_remaining/missing_files.txt

# %%
len(missing_files)
# Out:
# 100

# %%
6
