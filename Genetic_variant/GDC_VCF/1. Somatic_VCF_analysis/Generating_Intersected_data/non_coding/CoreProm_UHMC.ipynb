# %%
import os, io
import pandas as pd
import pysam
import pickle
import pybedtools
print(pybedtools.__file__)
pybedtools.helpers.set_tempdir('/home/pdutta/temp')
from IPython.display import display, HTML
# Out:
# /home/pdutta/anaconda3/envs/GDC_VCF/lib/python3.10/site-packages/pybedtools/__init__.py

# %%
cancer_type="Lung"

# %%
vcf_folder_path="/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Downloaded_files/VCF".format(cancer_type)
reference_genome_path="/home/pdutta/Data/Human_Genome_Data/GRCh38_latest_genomic.fna"

# %%
non_coding_region="core_prom"

# %%
df= pd.read_csv("/home/pdutta/Data/Noncoding_region/{}_bed.tsv".format(non_coding_region), sep="\t")
columns = ['Chr', 'start', 'end', 'gene_id', 'transcript_id', 'exon_id', 'strand', 'TSS']
df = df[columns]
# Renaming columns
df.rename(columns={'Chr': 'chr_name'}, inplace=True)
df
# Out:
#        chr_name      start        end             gene_id       transcript_id  \
# 0          chr7  127588366  127588455  ENSG00000004059.11  ENST00000000233.10
# 1          chr7  117479980  117480069  ENSG00000001626.16  ENST00000003084.11
# 2          chr7   92134433   92134522  ENSG00000001630.17  ENST00000003100.13
# 3          chr7  150800724  150800813   ENSG00000002933.9   ENST00000004103.8
# 4          chr7   95596472   95596561   ENSG00000004799.8   ENST00000005178.6
# ...         ...        ...        ...                 ...                 ...
# 236970    chr15   80152965   80153054  ENSG00000103876.14   ENST00000684569.1
# 236971    chr15   72375945   72376034  ENSG00000213614.11   ENST00000684602.1
# 236972    chr15   72375928   72376017  ENSG00000213614.11   ENST00000684667.1
# 236973    chr15   44663644   44663733  ENSG00000104133.16   ENST00000684676.1
# 236974    chr15   99733393   99733482  ENSG00000183060.16   ENST00000684762.1
#
#                    exon_id strand        TSS
# 0        ENSE00001872691.2      +  127588411
# 1        ENSE00001343851.2      +  117480025
# 2       ENSE00001216550.10      -   92134477
# 3        ENSE00001827596.2      +  150800769
# 4        ENSE00001133344.6      -   95596516
# ...                    ...    ...        ...
# 236970   ENSE00003921718.1      +   80153010
# 236971   ENSE00002620879.1      -   72375989
# 236972   ENSE00002584031.1      -   72375972
# 236973   ENSE00003922470.1      -   44663688
# 236974   ENSE00001781053.1      -   99733437
#
# [236975 rows x 8 columns]

# %%
core_prom_bed = pybedtools.BedTool.from_dataframe(df)

# %%
reference_fasta = pysam.FastaFile(reference_genome_path)

# %%
def get_vcf_gz_files_except_logs(root_folder):
    all_files = []

    # Walk through the directory tree
    for dirpath, dirnames, filenames in os.walk(root_folder):
        # If "logs" is in dirnames, remove it to avoid traversing it
        if 'logs' in dirnames:
            dirnames.remove('logs')

        # Add only the filenames with the extension .vcf.gz in the current directory to the all_files list
        for filename in filenames:
            if filename.endswith('.vcf.gz'):
                all_files.append(os.path.join(dirpath, filename))
    return all_files

# %%
def vcf_to_dataframe(vcf_path):
    """
    Convert a .vcf.gz file into a pandas DataFrame.

    Parameters:
    - vcf_path (str): path to the .vcf.gz file

    Returns:
    - pd.DataFrame: VCF data as a DataFrame
    """

    try:
        # Open the VCF file
        vcf_file = pysam.VariantFile(vcf_path)
    except ValueError as e:
        print(f"Failed to open file {vcf_path}: {e}")
        with open("/data/projects/GDC_Cancer_Wise/Brain/Data/"+vcf_path.split("/")[-2]+"_error_log.txt", "a") as error_log:
            error_log.write(f"{vcf_path}\n")
        return None

    # Extracting the data and the columns
    data = []
    
    columns =  ["CHROM", "START_POS", "ID", "REF", "ALT", "QUAL", "FILTER"] + list(vcf_file.header.info.keys()) 
    for record in vcf_file:
        basic_data = [record.chrom, record.pos, record.id, record.ref, 
                      ','.join(str(alt) for alt in record.alts), record.qual, record.filter.keys()[0] if record.filter.keys() else 'PASS']
        row_data = [record.info.get(key) for key in vcf_file.header.info.keys()]
        data.append(basic_data + row_data)

    df = pd.DataFrame(data, columns=columns)
    df["START_POS"] = df["START_POS"]-1
    end = df["START_POS"] + df['REF'].str.len()
    df.insert(2, 'END_POS', end)

    # Close the VCF file
    vcf_file.close()

    return df

# %%
files = get_vcf_gz_files_except_logs(vcf_folder_path)

# %%
len(files)
# Out:
# 824

# %%
intersected_vcf_data = {}
df_statistics  = pd.DataFrame(columns= ["filename", "Patient_ID", 'work_flow',  'VCF_instance','VCF_feature','Intersected_instances', 'VCF_column_names' ])

# %%
for file_path in files:
    file_name =  file_path.split('/')[-1]
    parts = file_name.split('.')
    print(parts)
    df_vcf = vcf_to_dataframe(file_path)
    #print(df_vcf)
    if df_vcf is None:
        continue
    vcf_bed = pybedtools.BedTool.from_dataframe(df_vcf)
    intersect_vcf_core_prom = core_prom_bed.intersect(vcf_bed, wa=True, wb=True)
    column_list  = df.columns.to_list() + df_vcf.columns.to_list()
    df_intersection = intersect_vcf_core_prom.to_dataframe(names=column_list)
    df_intersection = df_intersection[(df_intersection['REF'].str.len() < 10) & (df_intersection['ALT'].str.len() < 10)]
    #print(df_intersection)
    #print(df_statistics)
    #input()
    #gdc_tag = parts[-4]
    patient_ID = parts[0]
    work_flow = parts[2]
    instance =  df_vcf.shape[0]
    feature = df_vcf.shape[1]
    intersected_instance = df_intersection.shape[0]
    feature_list = list(df_vcf.columns)
    print(patient_ID, work_flow, instance, feature,intersected_instance,  feature_list)
    df_statistics.loc[len(df_statistics)] = [file_name, patient_ID, work_flow, instance, feature,intersected_instance,  feature_list]
    intersected_vcf_data[patient_ID+"_"+work_flow] = df_intersection
# Out:
# ['5ae88ff4-b750-4eae-9991-e6b1c9145d97', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 5ae88ff4-b750-4eae-9991-e6b1c9145d97 sanger_raw_pindel 1099753 17 5058 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f982a734-c385-4a31-b384-466fcba70880', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# f982a734-c385-4a31-b384-466fcba70880 sanger_raw_pindel 1062157 17 4968 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['be48b90f-c501-4b92-bfd8-dc3dc28939e9', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# be48b90f-c501-4b92-bfd8-dc3dc28939e9 sanger_raw_pindel 843320 17 4159 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['cef028fb-40ef-4a68-b75f-a8b9bb6055c3', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# cef028fb-40ef-4a68-b75f-a8b9bb6055c3 CaVEMan 161514 20 905 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['2e5f1a81-3424-4cfd-b23c-121a452592a5', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 2e5f1a81-3424-4cfd-b23c-121a452592a5 sanger_raw_pindel 813957 17 3908 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['babb0ca1-0eca-4bf5-b5ff-4faec0a9c836', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# babb0ca1-0eca-4bf5-b5ff-4faec0a9c836 sanger_raw_pindel 1091811 17 5030 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['9ffea310-a2a7-4212-8083-cce0e9b40ed8', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 9ffea310-a2a7-4212-8083-cce0e9b40ed8 sanger_raw_pindel 904234 17 4429 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['e7b27e88-470c-467d-964c-cc01de2ea073', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# e7b27e88-470c-467d-964c-cc01de2ea073 CaVEMan 130874 20 772 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['18e9819a-20e8-4ac3-a0d9-3291d35111d2', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 18e9819a-20e8-4ac3-a0d9-3291d35111d2 CaVEMan 62100 20 299 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['80f3153d-148d-4800-a924-d64b6f59c9b6', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 80f3153d-148d-4800-a924-d64b6f59c9b6 sanger_raw_pindel 855337 17 4227 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['56b38ebe-4168-46d1-aef9-5e0066ba653f', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 56b38ebe-4168-46d1-aef9-5e0066ba653f sanger_raw_pindel 874443 17 4241 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['594a7149-2b9d-42e6-a842-2978263a2d8b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 594a7149-2b9d-42e6-a842-2978263a2d8b CaVEMan 156342 20 843 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['ea912737-4296-49b8-bfd3-8dfb7b8b9bc4', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# ea912737-4296-49b8-bfd3-8dfb7b8b9bc4 sanger_raw_pindel 817358 17 4045 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['683565c8-cd8c-41f5-abad-b626177d5c6f', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 683565c8-cd8c-41f5-abad-b626177d5c6f sanger_raw_pindel 866230 17 4088 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['04c212e7-d485-4621-b50f-2f2d9f2ea67f', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 04c212e7-d485-4621-b50f-2f2d9f2ea67f CaVEMan 295153 20 2126 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f CaVEMan 79003 20 366 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['32564de4-55f3-4934-b529-a187c59d4d47', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 32564de4-55f3-4934-b529-a187c59d4d47 CaVEMan 296220 20 2858 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['75de6374-86e9-49f9-ac40-6c4cde04f93c', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 75de6374-86e9-49f9-ac40-6c4cde04f93c CaVEMan 203844 20 2026 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['3530b926-f73b-4dcd-96fd-04a3f2f16031', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 3530b926-f73b-4dcd-96fd-04a3f2f16031 sanger_raw_pindel 879117 17 4237 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['c2042359-9e2c-4c98-b572-841cfd6c810b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# c2042359-9e2c-4c98-b572-841cfd6c810b CaVEMan 58124 20 213 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['056fdb85-1ab9-459c-a4ea-12216debe90e', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 056fdb85-1ab9-459c-a4ea-12216debe90e sanger_raw_pindel 837129 17 4055 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['0a309d4f-857c-4220-b60a-0998b6d51722', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 0a309d4f-857c-4220-b60a-0998b6d51722 CaVEMan 123067 20 798 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['0c64d792-066c-42d3-84c3-d47dd2aa9092', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 0c64d792-066c-42d3-84c3-d47dd2aa9092 CaVEMan 84764 20 370 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['1b9c2fd7-e722-4c95-9484-6914a907c3a7', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 1b9c2fd7-e722-4c95-9484-6914a907c3a7 sanger_raw_pindel 881039 17 4276 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['b8337c01-f353-4c73-b872-0522dbb67b59', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# b8337c01-f353-4c73-b872-0522dbb67b59 sanger_raw_pindel 892071 17 4246 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['d13f1cbf-ae03-41de-b5e4-3877bd1c403c', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d13f1cbf-ae03-41de-b5e4-3877bd1c403c sanger_raw_pindel 798390 17 4111 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['0b2a6149-872f-4178-a7df-d8308cdea3fd', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 0b2a6149-872f-4178-a7df-d8308cdea3fd sanger_raw_pindel 1058701 17 4956 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['c242f484-ecd9-45b2-b0aa-cc7a5b2f50f3', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# c242f484-ecd9-45b2-b0aa-cc7a5b2f50f3 sanger_raw_pindel 1094543 17 4940 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['6dda24b6-ccab-479a-9850-e82418150f0e', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6dda24b6-ccab-479a-9850-e82418150f0e sanger_raw_pindel 785956 17 3795 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['61942802-dbad-47a9-a9a8-c79dbddc60e1', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 61942802-dbad-47a9-a9a8-c79dbddc60e1 sanger_raw_pindel 795399 17 3887 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['4ac41ebb-7ab1-4f4e-84cd-903085da7f5c', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 4ac41ebb-7ab1-4f4e-84cd-903085da7f5c CaVEMan 87755 20 450 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['f71cb7b1-f6b3-4988-b256-b8e4a1676d1e', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# f71cb7b1-f6b3-4988-b256-b8e4a1676d1e CaVEMan 44230 20 200 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['2d7cfb46-769b-404e-8178-26c9c99cc72b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 2d7cfb46-769b-404e-8178-26c9c99cc72b CaVEMan 316785 20 2442 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['726bc7b4-f9a0-4f45-893f-c716c137d654', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 726bc7b4-f9a0-4f45-893f-c716c137d654 CaVEMan 75276 20 364 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['71c5b0fe-cb27-4bca-b78d-3ed8f15af0ad', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 71c5b0fe-cb27-4bca-b78d-3ed8f15af0ad CaVEMan 160636 20 802 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['62e19451-8cab-4640-81b8-2ee11335580a', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 62e19451-8cab-4640-81b8-2ee11335580a CaVEMan 190615 20 1120 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['01608e28-91d8-402c-8a28-790800e16d22', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 01608e28-91d8-402c-8a28-790800e16d22 CaVEMan 37098 20 156 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['d3f69cdc-4d7f-4476-b7a7-34e25d89dc7f', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d3f69cdc-4d7f-4476-b7a7-34e25d89dc7f sanger_raw_pindel 865246 17 4173 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['84adb5c4-5c01-492d-84c4-a421ddf263a5', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 84adb5c4-5c01-492d-84c4-a421ddf263a5 sanger_raw_pindel 853718 17 4206 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['6361dc74-12ef-4b3c-a52c-dd988a38929e', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6361dc74-12ef-4b3c-a52c-dd988a38929e sanger_raw_pindel 854302 17 4154 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['cfb7b7d5-32f5-4771-b1d4-f92081f77332', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# cfb7b7d5-32f5-4771-b1d4-f92081f77332 sanger_raw_pindel 870407 17 4380 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['72a16568-e3c4-4055-814c-dc7e8717451a', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 72a16568-e3c4-4055-814c-dc7e8717451a sanger_raw_pindel 833256 17 4113 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2 CaVEMan 68833 20 366 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['19dd7b00-4492-46a1-a4f8-e29615372bdc', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 19dd7b00-4492-46a1-a4f8-e29615372bdc sanger_raw_pindel 837622 17 4095 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f368a047-d2a8-404f-97dd-1c2a8bf52497', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# f368a047-d2a8-404f-97dd-1c2a8bf52497 CaVEMan 43170 20 225 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['6a17dfb4-cf62-43f4-9b8c-f2ae482dd6ea', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6a17dfb4-cf62-43f4-9b8c-f2ae482dd6ea sanger_raw_pindel 836110 17 4173 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['38520d04-f833-4c2d-bb0f-f672efc3f948', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 38520d04-f833-4c2d-bb0f-f672efc3f948 sanger_raw_pindel 820543 17 4026 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['ee43b511-44d4-4466-a59e-67fae369046e', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# ee43b511-44d4-4466-a59e-67fae369046e CaVEMan 237986 20 1615 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['6972d298-0451-4b0b-a348-0a329dedde24', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6972d298-0451-4b0b-a348-0a329dedde24 sanger_raw_pindel 843858 17 4087 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['5866b635-fa0d-4141-bd21-aaf8181fdc0a', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 5866b635-fa0d-4141-bd21-aaf8181fdc0a sanger_raw_pindel 1089106 17 4948 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['7ded5aec-8bfe-480e-9b11-5fbf7c523966', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 7ded5aec-8bfe-480e-9b11-5fbf7c523966 CaVEMan 95166 20 585 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['08f4046a-15a2-4fe9-a9be-f71ceca3c6f8', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 08f4046a-15a2-4fe9-a9be-f71ceca3c6f8 sanger_raw_pindel 837512 17 4221 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['099b611a-4414-44c3-9458-89b01425d7a4', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 099b611a-4414-44c3-9458-89b01425d7a4 sanger_raw_pindel 921618 17 4497 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['6a5c4bc7-09c6-47f5-a735-4c178dd4e8ae', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6a5c4bc7-09c6-47f5-a735-4c178dd4e8ae sanger_raw_pindel 1072276 17 5068 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['81f5ba7a-68fd-4091-9d7d-2108650c853a', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 81f5ba7a-68fd-4091-9d7d-2108650c853a CaVEMan 62864 20 257 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['ea29e39f-7307-433b-8880-cac11e88365b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# ea29e39f-7307-433b-8880-cac11e88365b CaVEMan 61354 20 295 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['cc2abefa-bcd1-473a-ae83-3c3249e18c6b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# cc2abefa-bcd1-473a-ae83-3c3249e18c6b CaVEMan 186695 20 987 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['38520d04-f833-4c2d-bb0f-f672efc3f948', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 38520d04-f833-4c2d-bb0f-f672efc3f948 CaVEMan 60482 20 289 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['a0e302b2-ce1a-42e4-9b55-55c7a2cbba45', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# a0e302b2-ce1a-42e4-9b55-55c7a2cbba45 sanger_raw_pindel 889876 17 4231 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['307940cc-216b-4627-a062-9f4935ba121a', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 307940cc-216b-4627-a062-9f4935ba121a sanger_raw_pindel 851390 17 4210 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['63a74c24-a480-41b7-ac93-a37bd3ac4597', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 63a74c24-a480-41b7-ac93-a37bd3ac4597 sanger_raw_pindel 994482 17 4937 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['6b8d4980-0c87-4f63-b6be-4a438e4db5b1', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6b8d4980-0c87-4f63-b6be-4a438e4db5b1 sanger_raw_pindel 952414 17 4615 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['e636717c-c2ee-4c11-aff9-5bbe27c5e134', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# e636717c-c2ee-4c11-aff9-5bbe27c5e134 sanger_raw_pindel 1065124 17 5026 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['4eb1c02a-3a70-4a25-8756-e77074868421', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 4eb1c02a-3a70-4a25-8756-e77074868421 CaVEMan 79441 20 451 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['1e2f7f07-e667-41b1-9ff7-0a745cfe38a7', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1e2f7f07-e667-41b1-9ff7-0a745cfe38a7 CaVEMan 37191 20 199 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['0f89b7f8-8f3f-4f50-95fb-a479ef194fdb', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 0f89b7f8-8f3f-4f50-95fb-a479ef194fdb CaVEMan 130488 20 681 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['e410e2b5-e22e-4349-98ad-ee17dd23329c', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# e410e2b5-e22e-4349-98ad-ee17dd23329c CaVEMan 172295 20 921 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['fceb79b8-bbde-4125-902c-a8502f7f23be', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# fceb79b8-bbde-4125-902c-a8502f7f23be CaVEMan 58923 20 288 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['6d430fc0-a93d-424d-981b-441a07a013da', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 6d430fc0-a93d-424d-981b-441a07a013da CaVEMan 122256 20 769 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['7baef639-bf0c-4f60-9482-d265f9bd99c8', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 7baef639-bf0c-4f60-9482-d265f9bd99c8 CaVEMan 56173 20 312 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['3d03a6cb-4244-4804-b0a7-afc5c64c2d3a', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 3d03a6cb-4244-4804-b0a7-afc5c64c2d3a CaVEMan 61843 20 394 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['0a100c48-895e-4551-815f-72081297cc49', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 0a100c48-895e-4551-815f-72081297cc49 CaVEMan 112706 20 479 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['702bbd12-9713-4261-b533-2b91c7b956c3', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 702bbd12-9713-4261-b533-2b91c7b956c3 CaVEMan 86774 20 404 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['514ab55f-b19d-4b83-8ef2-e506164cb1de', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 514ab55f-b19d-4b83-8ef2-e506164cb1de sanger_raw_pindel 826966 17 4010 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['1766972a-0ea3-4230-9d94-db6bbad0a77a', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1766972a-0ea3-4230-9d94-db6bbad0a77a CaVEMan 108519 20 561 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['0c64d792-066c-42d3-84c3-d47dd2aa9092', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 0c64d792-066c-42d3-84c3-d47dd2aa9092 sanger_raw_pindel 811050 17 3877 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['703c3593-8f8f-4d8b-a1bf-3eadc806e980', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 703c3593-8f8f-4d8b-a1bf-3eadc806e980 sanger_raw_pindel 1096946 17 5060 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['93dce00c-c8e8-4217-9117-22db8e33e784', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 93dce00c-c8e8-4217-9117-22db8e33e784 sanger_raw_pindel 863680 17 4322 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['56b38ebe-4168-46d1-aef9-5e0066ba653f', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 56b38ebe-4168-46d1-aef9-5e0066ba653f CaVEMan 69042 20 349 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['01608e28-91d8-402c-8a28-790800e16d22', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 01608e28-91d8-402c-8a28-790800e16d22 sanger_raw_pindel 742797 17 3654 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['9bdcc390-1fd2-4ed0-9d06-ba35cad665ba', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 9bdcc390-1fd2-4ed0-9d06-ba35cad665ba CaVEMan 341038 20 2268 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['cc8fd25b-b416-44f4-bcef-ff833c100a2b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# cc8fd25b-b416-44f4-bcef-ff833c100a2b sanger_raw_pindel 829968 17 4139 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['dcb7c4ba-7215-4b77-949a-c2d2b783549d', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# dcb7c4ba-7215-4b77-949a-c2d2b783549d sanger_raw_pindel 1090720 17 5107 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f9eece5f-bd50-4997-845c-db1c20681361', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# f9eece5f-bd50-4997-845c-db1c20681361 CaVEMan 76158 20 376 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['9270a4a5-791b-4d06-96c4-6347562607fb', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 9270a4a5-791b-4d06-96c4-6347562607fb CaVEMan 49898 20 234 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['14b5fc32-66f2-4f5e-9d5f-bbd65cd07733', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 14b5fc32-66f2-4f5e-9d5f-bbd65cd07733 CaVEMan 97450 20 524 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['aea01681-bede-417d-a615-0a6a7124fa6c', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# aea01681-bede-417d-a615-0a6a7124fa6c CaVEMan 324615 20 2226 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['d2fd0752-3acd-45d5-87f1-68b52834215e', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d2fd0752-3acd-45d5-87f1-68b52834215e sanger_raw_pindel 920690 17 4579 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['d5d87ff1-8571-40f3-b187-5d51e0a5615d', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# d5d87ff1-8571-40f3-b187-5d51e0a5615d CaVEMan 74505 20 392 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['5a588951-444c-45ce-a3e7-466965ebff1d', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 5a588951-444c-45ce-a3e7-466965ebff1d sanger_raw_pindel 851127 17 4237 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['32c1fcc3-562e-4813-bdcc-8bac4983f5bd', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 32c1fcc3-562e-4813-bdcc-8bac4983f5bd CaVEMan 318885 20 2170 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['c7f9db72-bda2-4b40-bd38-5922d1a66bf3', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# c7f9db72-bda2-4b40-bd38-5922d1a66bf3 CaVEMan 111452 20 534 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['648cfb4f-4175-4124-ba27-6ce8b60a773b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 648cfb4f-4175-4124-ba27-6ce8b60a773b CaVEMan 51879 20 203 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d8b3fd4f-266a-4dd5-a93d-44ea17f71ab2 sanger_raw_pindel 892699 17 4327 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['41bd62a0-238a-4363-b9be-1402ae0224ea', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 41bd62a0-238a-4363-b9be-1402ae0224ea CaVEMan 79503 20 395 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['b6f67aab-59fa-4998-95e0-d49349f4b27b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# b6f67aab-59fa-4998-95e0-d49349f4b27b sanger_raw_pindel 861622 17 4242 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f991f0d3-32ee-410c-b887-f190f4e6b729', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# f991f0d3-32ee-410c-b887-f190f4e6b729 sanger_raw_pindel 952977 17 4588 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f368a047-d2a8-404f-97dd-1c2a8bf52497', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# f368a047-d2a8-404f-97dd-1c2a8bf52497 sanger_raw_pindel 853131 17 4157 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['09bd9dff-f572-4f45-ac04-ec1d8f367dae', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 09bd9dff-f572-4f45-ac04-ec1d8f367dae sanger_raw_pindel 888369 17 4253 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['86fc2062-8120-41e9-a52a-1c112fc7e126', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 86fc2062-8120-41e9-a52a-1c112fc7e126 sanger_raw_pindel 884884 17 4349 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['afbf285e-0560-4e1d-9c6e-9741368aa9f5', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# afbf285e-0560-4e1d-9c6e-9741368aa9f5 CaVEMan 302497 20 2183 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['bbf629fd-658b-4c0f-bb8f-e7a6de5c6986', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# bbf629fd-658b-4c0f-bb8f-e7a6de5c6986 sanger_raw_pindel 869396 17 4253 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['91a0c61b-7141-4f5e-ba17-6b17b343e468', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 91a0c61b-7141-4f5e-ba17-6b17b343e468 sanger_raw_pindel 853948 17 4332 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['32564de4-55f3-4934-b529-a187c59d4d47', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 32564de4-55f3-4934-b529-a187c59d4d47 sanger_raw_pindel 1098952 17 5035 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['86f90ec0-ef66-484e-a70d-713590be4ad8', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 86f90ec0-ef66-484e-a70d-713590be4ad8 sanger_raw_pindel 835168 17 3971 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f04f56d8-6680-4054-97ab-ce728219aa84', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# f04f56d8-6680-4054-97ab-ce728219aa84 sanger_raw_pindel 870724 17 4337 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['12717370-ad9c-4260-97ed-98660520decc', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 12717370-ad9c-4260-97ed-98660520decc sanger_raw_pindel 869905 17 4342 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['980df119-42bf-401f-849f-d43a26becc2c', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 980df119-42bf-401f-849f-d43a26becc2c CaVEMan 208168 20 1102 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['c339075f-1219-4def-ab5a-ef636995c1b2', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# c339075f-1219-4def-ab5a-ef636995c1b2 sanger_raw_pindel 866638 17 4246 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['1ce5c200-7b11-44ca-a57c-118244fcd33d', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1ce5c200-7b11-44ca-a57c-118244fcd33d CaVEMan 94528 20 564 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['1453bd9a-202b-42c6-88fd-529acdda7890', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1453bd9a-202b-42c6-88fd-529acdda7890 CaVEMan 72562 20 330 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['cee02cc9-d0e3-4544-a093-6cfe5b8fffca', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# cee02cc9-d0e3-4544-a093-6cfe5b8fffca sanger_raw_pindel 918931 17 4543 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['9270a4a5-791b-4d06-96c4-6347562607fb', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 9270a4a5-791b-4d06-96c4-6347562607fb sanger_raw_pindel 849071 17 4210 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['1113c58e-1cf2-45c9-848e-38cd3f5e07f7', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1113c58e-1cf2-45c9-848e-38cd3f5e07f7 CaVEMan 93421 20 474 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['c49e32d2-691a-4cc8-9f20-37395e5a79c2', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# c49e32d2-691a-4cc8-9f20-37395e5a79c2 sanger_raw_pindel 902682 17 4332 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f0e3f096-360f-4962-9567-adffc035aa3e', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# f0e3f096-360f-4962-9567-adffc035aa3e sanger_raw_pindel 1089805 17 4914 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['bd58fa0b-8856-40a8-aec9-cd7b658cbdb7', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# bd58fa0b-8856-40a8-aec9-cd7b658cbdb7 sanger_raw_pindel 850469 17 4184 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['dcb7c4ba-7215-4b77-949a-c2d2b783549d', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# dcb7c4ba-7215-4b77-949a-c2d2b783549d CaVEMan 272054 20 2309 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['a4fc2ed3-dc4d-40fb-b96b-a19ccd2d0891', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# a4fc2ed3-dc4d-40fb-b96b-a19ccd2d0891 sanger_raw_pindel 854839 17 4183 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['b30d39e1-f2ff-43c5-9b69-579ca0d2fa28', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# b30d39e1-f2ff-43c5-9b69-579ca0d2fa28 CaVEMan 84327 20 404 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['d2aa40fd-da17-4bc0-ad47-421cf50bc3cd', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d2aa40fd-da17-4bc0-ad47-421cf50bc3cd sanger_raw_pindel 890897 17 4409 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['ab7058b9-2f1c-4c18-8e16-dd293c9d5737', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# ab7058b9-2f1c-4c18-8e16-dd293c9d5737 CaVEMan 97826 20 585 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['57889e27-2e19-472d-8294-2f5695a6cead', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 57889e27-2e19-472d-8294-2f5695a6cead sanger_raw_pindel 887753 17 4381 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['fda2d1f9-1690-42a8-80b7-bdcb9e9e4105', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# fda2d1f9-1690-42a8-80b7-bdcb9e9e4105 CaVEMan 43813 20 239 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['fe71e6b9-f9f0-4628-8d5a-cf49497d0392', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# fe71e6b9-f9f0-4628-8d5a-cf49497d0392 sanger_raw_pindel 913075 17 4466 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['832f644e-7014-4b46-8449-05980f3cacd3', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 832f644e-7014-4b46-8449-05980f3cacd3 CaVEMan 77786 20 432 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['84acc817-abe7-42b0-bd74-94673f34009d', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 84acc817-abe7-42b0-bd74-94673f34009d sanger_raw_pindel 821160 17 4065 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['bda8706f-6d13-40bb-9e1e-d21e4e531498', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# bda8706f-6d13-40bb-9e1e-d21e4e531498 CaVEMan 72288 20 317 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['2ff01ec1-7876-4b76-8b9d-62e9f6824d42', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 2ff01ec1-7876-4b76-8b9d-62e9f6824d42 CaVEMan 88576 20 444 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['58e6ffe3-67ac-4ed8-8c56-c8040b429264', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 58e6ffe3-67ac-4ed8-8c56-c8040b429264 sanger_raw_pindel 869500 17 4225 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['39a8c6e2-8708-4d18-badd-85f72282d426', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 39a8c6e2-8708-4d18-badd-85f72282d426 sanger_raw_pindel 1096209 17 4997 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# dc43e82c-bd66-4e09-a203-7b7e8c2e3a0f sanger_raw_pindel 809890 17 3806 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['425008fb-b39f-4355-8c2b-c2ebfc3236ea', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 425008fb-b39f-4355-8c2b-c2ebfc3236ea CaVEMan 68066 20 252 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['ce1b8b0e-6462-4a93-ac94-072418037f5c', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# ce1b8b0e-6462-4a93-ac94-072418037f5c sanger_raw_pindel 812425 17 4089 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['9ce61ab5-ceec-4148-901b-53ce6a2b084b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 9ce61ab5-ceec-4148-901b-53ce6a2b084b sanger_raw_pindel 874786 17 4215 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['6361dc74-12ef-4b3c-a52c-dd988a38929e', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 6361dc74-12ef-4b3c-a52c-dd988a38929e CaVEMan 70655 20 333 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['1425e1ef-ca6d-40a3-879a-54653d6fac38', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1425e1ef-ca6d-40a3-879a-54653d6fac38 CaVEMan 79117 20 461 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['aea01681-bede-417d-a615-0a6a7124fa6c', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# aea01681-bede-417d-a615-0a6a7124fa6c sanger_raw_pindel 1075246 17 4983 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['62f26d07-04b1-4c69-a550-3aea5c8d44e3', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 62f26d07-04b1-4c69-a550-3aea5c8d44e3 CaVEMan 315916 20 2756 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['92fd3588-7386-4c39-86cc-2029c3dd7c94', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 92fd3588-7386-4c39-86cc-2029c3dd7c94 CaVEMan 58305 20 350 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['6d7f1fbc-57f6-4a77-b457-f570a71990eb', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6d7f1fbc-57f6-4a77-b457-f570a71990eb sanger_raw_pindel 838489 17 4130 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['b99df57e-6f5b-4d35-96cb-8a16ef139cd8', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# b99df57e-6f5b-4d35-96cb-8a16ef139cd8 CaVEMan 49668 20 242 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['61c0789e-4c2d-4586-95c1-c3501a8d2a7e', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 61c0789e-4c2d-4586-95c1-c3501a8d2a7e sanger_raw_pindel 894972 17 4307 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['f23649c0-8de7-4b60-9b65-5c557ea08a65', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# f23649c0-8de7-4b60-9b65-5c557ea08a65 CaVEMan 295608 20 2268 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['392b2647-766f-4e28-b003-44891a79ce8b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 392b2647-766f-4e28-b003-44891a79ce8b sanger_raw_pindel 1101816 17 4987 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['bf8079a4-f5cf-4e9e-8ec9-a33c657f528b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# bf8079a4-f5cf-4e9e-8ec9-a33c657f528b sanger_raw_pindel 1073301 17 5009 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['16d188a1-5021-4173-9774-63590b68f448', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 16d188a1-5021-4173-9774-63590b68f448 CaVEMan 40742 20 158 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['73f8a07c-aae5-4319-aa0b-55646e277a6b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 73f8a07c-aae5-4319-aa0b-55646e277a6b CaVEMan 56079 20 242 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['16d188a1-5021-4173-9774-63590b68f448', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 16d188a1-5021-4173-9774-63590b68f448 sanger_raw_pindel 866945 17 4259 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['b13172e7-5667-4fd8-bb69-87c9e1dabfb8', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# b13172e7-5667-4fd8-bb69-87c9e1dabfb8 sanger_raw_pindel 894669 17 4339 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['04fc819c-2358-47b5-9cab-bb5b9e9be109', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 04fc819c-2358-47b5-9cab-bb5b9e9be109 sanger_raw_pindel 907216 17 4381 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['c2042359-9e2c-4c98-b572-841cfd6c810b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# c2042359-9e2c-4c98-b572-841cfd6c810b sanger_raw_pindel 843397 17 4184 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['5e54ae37-bbd4-4cb9-a1e4-886acd28bdd2', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 5e54ae37-bbd4-4cb9-a1e4-886acd28bdd2 sanger_raw_pindel 1085846 17 5081 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['702bbd12-9713-4261-b533-2b91c7b956c3', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 702bbd12-9713-4261-b533-2b91c7b956c3 sanger_raw_pindel 889228 17 4413 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ...
# ['8d233b00-3073-4810-ae86-bd809788f6eb', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 8d233b00-3073-4810-ae86-bd809788f6eb sanger_raw_pindel 857721 17 4282 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['d6cf6672-bded-4022-af6e-b7b78c75ca44', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d6cf6672-bded-4022-af6e-b7b78c75ca44 sanger_raw_pindel 909734 17 4415 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['503a146d-2e1c-4c55-9947-587fde1c875a', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 503a146d-2e1c-4c55-9947-587fde1c875a sanger_raw_pindel 924205 17 4470 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['b89ad449-f0e8-41a4-a9e5-acc1eab2ca30', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# b89ad449-f0e8-41a4-a9e5-acc1eab2ca30 sanger_raw_pindel 790934 17 3922 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['1d6d39c4-b0e1-4d49-ac1d-384212229d5c', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1d6d39c4-b0e1-4d49-ac1d-384212229d5c CaVEMan 209759 20 1378 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['cd0dff4b-df83-455b-8c5c-a7d0b96c707f', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# cd0dff4b-df83-455b-8c5c-a7d0b96c707f CaVEMan 69951 20 535 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['8a6bd6c0-a25e-476a-9409-84014108dbb6', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 8a6bd6c0-a25e-476a-9409-84014108dbb6 sanger_raw_pindel 881218 17 4348 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['02c4910e-df0d-49bf-aabe-f833e328539e', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 02c4910e-df0d-49bf-aabe-f833e328539e CaVEMan 93389 20 522 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['86487f64-5ece-46c6-ae2e-afd5b9265d6f', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 86487f64-5ece-46c6-ae2e-afd5b9265d6f sanger_raw_pindel 848748 17 4196 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['1ca3b5f8-2ac0-4a1e-a137-718a268e00f3', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 1ca3b5f8-2ac0-4a1e-a137-718a268e00f3 sanger_raw_pindel 820381 17 4004 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['94304b7e-c8ff-4cca-93c9-51b45a9e0d5a', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 94304b7e-c8ff-4cca-93c9-51b45a9e0d5a CaVEMan 60453 20 289 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['3d053858-309c-46e0-a154-7cc4472f46f0', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 3d053858-309c-46e0-a154-7cc4472f46f0 CaVEMan 110187 20 554 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['2e5f1a81-3424-4cfd-b23c-121a452592a5', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 2e5f1a81-3424-4cfd-b23c-121a452592a5 CaVEMan 37764 20 162 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['a5a632fd-0501-4268-8a40-673bb81e61be', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# a5a632fd-0501-4268-8a40-673bb81e61be CaVEMan 80088 20 389 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['936b40ef-4709-4503-8bac-e6212ea91145', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 936b40ef-4709-4503-8bac-e6212ea91145 CaVEMan 36587 20 178 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['7c0c6ce6-c3c2-4d53-886b-3a44e5f8eed3', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 7c0c6ce6-c3c2-4d53-886b-3a44e5f8eed3 CaVEMan 311663 20 2742 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['d519507d-1b62-4925-8702-94326285aabf', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# d519507d-1b62-4925-8702-94326285aabf CaVEMan 84599 20 534 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['936e9461-031c-4b35-9a7f-c93ba17983fc', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 936e9461-031c-4b35-9a7f-c93ba17983fc CaVEMan 72751 20 300 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['14428874-2d28-48a5-8a7e-eef30da45e47', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 14428874-2d28-48a5-8a7e-eef30da45e47 CaVEMan 126536 20 599 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['e7b27e88-470c-467d-964c-cc01de2ea073', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# e7b27e88-470c-467d-964c-cc01de2ea073 sanger_raw_pindel 948798 17 4572 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['7647659b-f8ee-4a3b-afed-c8d52e674362', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 7647659b-f8ee-4a3b-afed-c8d52e674362 CaVEMan 51305 20 225 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['1ec11928-92e4-4a28-aed6-bd6a2acf47bb', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 1ec11928-92e4-4a28-aed6-bd6a2acf47bb CaVEMan 125646 20 710 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['d51caf6f-c2c1-418e-af0c-ac0d5e101a6b', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# d51caf6f-c2c1-418e-af0c-ac0d5e101a6b CaVEMan 98400 20 670 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['7647659b-f8ee-4a3b-afed-c8d52e674362', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 7647659b-f8ee-4a3b-afed-c8d52e674362 sanger_raw_pindel 871681 17 4263 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['b9fcd5bf-b0f6-4f4c-8eef-d12d4208d47e', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# b9fcd5bf-b0f6-4f4c-8eef-d12d4208d47e sanger_raw_pindel 1050349 17 4829 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['e452be3b-5a11-4ef7-a350-89e33b7229a3', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# e452be3b-5a11-4ef7-a350-89e33b7229a3 sanger_raw_pindel 1099883 17 4839 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['ece02edb-5b5d-4e87-a33d-66d25e89a7bb', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# ece02edb-5b5d-4e87-a33d-66d25e89a7bb sanger_raw_pindel 836022 17 4033 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['a06f06ea-d961-48cc-a24d-71f1be6a0b46', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# a06f06ea-d961-48cc-a24d-71f1be6a0b46 CaVEMan 36885 20 172 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['d2aa40fd-da17-4bc0-ad47-421cf50bc3cd', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# d2aa40fd-da17-4bc0-ad47-421cf50bc3cd CaVEMan 40858 20 251 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['0d859bb4-a7ba-440b-9e9e-13c866656670', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 0d859bb4-a7ba-440b-9e9e-13c866656670 sanger_raw_pindel 851924 17 4262 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['842f106a-6971-44fc-aa06-1d0cd7b72783', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 842f106a-6971-44fc-aa06-1d0cd7b72783 CaVEMan 52563 20 313 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['3c3f09c3-0be2-46b7-bdf2-b31fd2218f12', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 3c3f09c3-0be2-46b7-bdf2-b31fd2218f12 CaVEMan 54354 20 240 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['2d0e323f-b465-442a-969d-34d63b9934db', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 2d0e323f-b465-442a-969d-34d63b9934db sanger_raw_pindel 793466 17 4023 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['3b7706ff-c748-42ce-931e-9346e18b71fd', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 3b7706ff-c748-42ce-931e-9346e18b71fd CaVEMan 76634 20 335 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['39bef8f9-d66e-4fd1-ab72-bd41684d5304', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 39bef8f9-d66e-4fd1-ab72-bd41684d5304 CaVEMan 69249 20 297 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['726bc7b4-f9a0-4f45-893f-c716c137d654', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 726bc7b4-f9a0-4f45-893f-c716c137d654 sanger_raw_pindel 880608 17 4250 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['258c2003-f592-4015-8b1e-69d3f7b5d2db', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 258c2003-f592-4015-8b1e-69d3f7b5d2db sanger_raw_pindel 852603 17 4352 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['5a3551b8-e9a9-4236-ac4c-360e5e901a7f', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 5a3551b8-e9a9-4236-ac4c-360e5e901a7f sanger_raw_pindel 907148 17 4523 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['bda8706f-6d13-40bb-9e1e-d21e4e531498', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# bda8706f-6d13-40bb-9e1e-d21e4e531498 sanger_raw_pindel 843050 17 4222 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['d3a8807d-a888-4c26-938d-ea4d386dd056', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# d3a8807d-a888-4c26-938d-ea4d386dd056 sanger_raw_pindel 876416 17 4151 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['a39a2a89-5b6f-486f-b5e0-e0971fe1a91b', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# a39a2a89-5b6f-486f-b5e0-e0971fe1a91b sanger_raw_pindel 887646 17 4400 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['ce519e2c-290c-4cd0-9b7c-a15ec3308bb5', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# ce519e2c-290c-4cd0-9b7c-a15ec3308bb5 CaVEMan 38220 20 156 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['7be8c1b4-eabe-4224-8163-3134668d148a', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 7be8c1b4-eabe-4224-8163-3134668d148a CaVEMan 65386 20 340 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['bc2d1b67-edac-433e-bf33-ff7958c5dd35', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# bc2d1b67-edac-433e-bf33-ff7958c5dd35 CaVEMan 107232 20 662 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['514e7809-f6ef-4994-b87a-8e0567d75219', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 514e7809-f6ef-4994-b87a-8e0567d75219 sanger_raw_pindel 844144 17 4246 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['62f26d07-04b1-4c69-a550-3aea5c8d44e3', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 62f26d07-04b1-4c69-a550-3aea5c8d44e3 sanger_raw_pindel 1055184 17 4980 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['6c30db02-ef29-471b-9e53-4511ffe2ba1f', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 6c30db02-ef29-471b-9e53-4511ffe2ba1f sanger_raw_pindel 896332 17 4485 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['24006735-a46f-440e-9e6d-76f393e6fd40', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 24006735-a46f-440e-9e6d-76f393e6fd40 CaVEMan 71527 20 477 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['04d435e6-77af-4869-8db7-aabc8711bfe0', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 04d435e6-77af-4869-8db7-aabc8711bfe0 CaVEMan 111292 20 798 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']
# ['5b1766a9-a718-4016-b365-1a8cf2d33c8a', 'wgs', 'sanger_raw_pindel', 'raw_somatic_mutation', 'vcf', 'gz']
# 5b1766a9-a718-4016-b365-1a8cf2d33c8a sanger_raw_pindel 862564 17 4163 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'FF017', 'LEN', 'OLD_VARIANT', 'PC', 'RE', 'REP', 'RS', 'S1', 'S2']
# ['9dfb5a7b-4f2c-4fb5-a364-8307b22a8f16', 'wgs', 'CaVEMan', 'raw_somatic_mutation', 'vcf', 'gz']
# 9dfb5a7b-4f2c-4fb5-a364-8307b22a8f16 CaVEMan 54220 20 388 ['CHROM', 'START_POS', 'END_POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'ASMD', 'ASRD', 'CLPM', 'DP', 'DS', 'GP', 'MP', 'SG', 'SNP', 'SP', 'TG', 'TP']

# %%
output_path = "/home/pdutta/Data/Cancer_wiseGDC/New_data/{}/Generated_files/Intersected_Data".format(cancer_type)
if not os.path.exists(output_path):
    os.makedirs(output_path)

# %%
df_statistics.to_csv(output_path+"/intersected_VCF_{}_statistics.tsv".format(non_coding_region), sep="\t", index=False)

# %%
with open(output_path+"/intersected_vcf_{}_data.pkl".format(non_coding_region), "wb") as file:
    pickle.dump(intersected_vcf_data, file)
