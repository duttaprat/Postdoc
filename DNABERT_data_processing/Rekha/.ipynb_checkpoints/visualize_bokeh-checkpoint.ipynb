# %%
import pandas as pd
import numpy as np

# %%
import numpy as np # we will use this later, so import it now

from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.layouts import column
from bokeh.models import ColumnDataSource, RangeTool
from bokeh.plotting import figure, show
from bokeh.sampledata.stocks import AAPL

# %%
dates = np.array(AAPL['date'], dtype=np.datetime64)
source = ColumnDataSource(data=dict(date=dates, close=AAPL['adj_close']))

# %%
AAPL.keys()
# Out:
# dict_keys(['date', 'open', 'high', 'low', 'close', 'volume', 'adj_close'])

# %%
source
# Out:
# ColumnDataSource(id='1003', ...)

# %%
dates
# Out:
# array(['2000-03-01', '2000-03-02', '2000-03-03', ..., '2013-02-27',
#        '2013-02-28', '2013-03-01'], dtype='datetime64[D]')

# %%
p = figure(height=300, width=1000, tools="xpan", toolbar_location=None,
           x_axis_type="datetime", x_axis_location="above",
           background_fill_color="#efefef", x_range=(dates[1500], dates[2500]))

# %%
p.line('date', 'close', source=source)
p.yaxis.axis_label = 'Price'

select = figure(title="Drag the middle and edges of the selection box to change the range above",
                height=130, width=800, y_range=p.y_range,
                x_axis_type="datetime", y_axis_type=None,
                tools="", toolbar_location=None, background_fill_color="#efefef")

range_tool = RangeTool(x_range=p.x_range)
range_tool.overlay.fill_color = "navy"
range_tool.overlay.fill_alpha = 0.2

select.line('date', 'close', source=source)
select.ygrid.grid_line_color = None
select.add_tools(range_tool)
select.toolbar.active_multi = range_tool

show(column(p, select))
# Out:
#   <div class="bk-root" id="d754487a-e985-4d88-8967-7b9eb8897255" data-root-id="1060"></div>

# %%
from bokeh.sampledata.glucose import data
data.head()
# Out:
#                       isig  glucose
# datetime
# 2010-03-24 09:51:00  22.59      258
# 2010-03-24 09:56:00  22.52      260
# 2010-03-24 10:01:00  22.23      258
# 2010-03-24 10:06:00  21.56      254
# 2010-03-24 10:11:00  20.79      246

# %%
week = data.loc['2010-10-01':'2010-10-08']

# %%
p = figure(x_axis_type="datetime", title="Glocose Range", plot_height=350, plot_width=800)
p.xgrid.grid_line_color=None
p.ygrid.grid_line_alpha=0.5
p.xaxis.axis_label = 'Time'
p.yaxis.axis_label = 'Value'
p.line(week.index, week.glucose)\\

show(p)
# Out:
#   <div class="bk-root" id="99750fb7-9535-45f9-a9e4-71c9dfb4a77c" data-root-id="1305"></div>

# %%
prob_arr = "/home/pdutta/Data/Rekha_data/Enhancer/WholeGenome/chr21/prob.npy"

# %%
with open(prob_arr, 'rb') as f:
    a = np.load(f)

# %%
a
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
len(np.where(a>0.3)[0])
# Out:
# 1127

# %%
position_arr = np.arange(5010001, 5010001+len(a))

# %%
position_arr
# Out:
# array([ 5010001,  5010002,  5010003, ..., 46699975, 46699976, 46699977])

# %%
len(a)
# Out:
# 41689977

# %%
df = pd.DataFrame({'position':position_arr, 'probability':a})

# %%
df
# Out:
#           position  probability
# 0          5010001          0.0
# 1          5010002          0.0
# 2          5010003          0.0
# 3          5010004          0.0
# 4          5010005          0.0
# ...            ...          ...
# 41689972  46699973          0.0
# 41689973  46699974          0.0
# 41689974  46699975          0.0
# 41689975  46699976          0.0
# 41689976  46699977          0.0
#
# [41689977 rows x 2 columns]

# %%
df[df['probability']>0.2]
# Out:
#           position  probability
# 3200531    8210532     0.201041
# 3200532    8210533     0.201041
# 3200533    8210534     0.201041
# 3200534    8210535     0.201041
# 3200535    8210536     0.201041
# ...            ...          ...
# 41284586  46294587     0.210554
# 41284587  46294588     0.206008
# 41284588  46294589     0.206008
# 41284589  46294590     0.203483
# 41284590  46294591     0.200308
#
# [5936 rows x 2 columns]

# %%
positions = np.array(df['position'])
source = ColumnDataSource(data=dict(position=df.head(3000000)['position'], probability=df.head(3000000)['probability']))
p = figure(height=300, width=1000, tools="xpan",
           x_axis_type="linear", x_axis_location="above",
           background_fill_color="#efefef", x_range=(positions[1500], positions[2500]))
p.xgrid.grid_line_color=None
p.ygrid.grid_line_alpha=0.5
p.xaxis.axis_label = 'position'
p.yaxis.axis_label = 'Probaibilty value'
p.line('position', 'probability', source=source)
show(p)
# Out:
#   <div class="bk-root" id="b84388a4-4999-417e-ae8d-a9c30a95b384" data-root-id="4602"></div>

# %%
start= 3190717
end = 3202717

# %%
y = a[start:end]

# %%
y.max()
# Out:
# 0.3091599928143968

# %%
x= np.arange(start,end)

# %%
x
# Out:
# array([3190717, 3190718, 3190719, ..., 3202714, 3202715, 3202716])

# %%
p = figure(x_axis_type="linear", title="Probability Range", plot_height=350, plot_width=1200, tools="xpan", x_axis_location="above",background_fill_color="#efefef")
p.xgrid.grid_line_color=None
p.ygrid.grid_line_alpha=0.5
p.xaxis.axis_label = 'position'
p.yaxis.axis_label = 'Probaibilty value'
p.line(x, y)


# select = figure(title="Drag the middle and edges of the selection box to change the range above",
#                 height=130, width=1200, y_range=p.y_range,
#                 x_axis_type="linear", y_axis_type=None,
#                 tools="", background_fill_color="#efefef")

# range_tool = RangeTool(x_range=)
# range_tool.overlay.fill_color = "navy"
# range_tool.overlay.fill_alpha = 0.2

# select.line(x,y)
# select.ygrid.grid_line_color = None
# select.add_tools(range_tool)
# select.toolbar.active_multi = range_tool

# show(column(p, select))
show(p)
# Out:
#   <div class="bk-root" id="28308bc9-dca7-4cd8-a21a-0175c9c62da2" data-root-id="3004"></div>
