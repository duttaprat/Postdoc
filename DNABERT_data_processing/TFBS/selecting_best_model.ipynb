# %%
import pandas as pd
import wandb
import os, shutil

# %%
api = wandb.Api()
entity, project = "pratik24111991", "TFBS_Finetuned_Models_Work"
runs = api.runs(entity + "/" + project)

# %%
summary_list, config_list, name_list, tag_list = [], [], [], []
for run in runs:
    # .summary contains output keys/values for
    # metrics such as accuracy.
    #  We call ._json_dict to omit large files
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append({k: v for k, v in run.config.items() if not k.startswith("_")})

    # .name is the human-readable name of the run.
    name_list.append(run.name)
    tag_list.append(run.tags)

runs_df = pd.DataFrame(
    {"summary": summary_list, "config": config_list, "name": name_list, "tags":tag_list}
)

# %%
runs_df
# Out:
#                                                 summary  \
# 0                           {'_wandb': {'runtime': 63}}
# 1     {'_step': 126, 'train_loss': 0.701253188507897...
# 2     {'eval_f1': 0.6248965880072537, 'eval_auc': 0....
# 3     {'eval_acc': 0.8145533532446375, 'train_loss':...
# 4     {'eval_auc': 0.3969597065276369, 'eval_recall'...
# ...                                                 ...
# 3370  {'eval_Validation loss': 0.6931307792663575, '...
# 3371  {'eval_auc': 0.8798126755400077, 'eval_Validat...
# 3372  {'Confusion Matrix': {'size': 59356, '_type': ...
# 3373  {'_runtime': 604.1279644966125, 'train_loss': ...
# 3374  {'_step': 327, '_runtime': 602.4626541137695, ...
#
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...                                                 ...
# 3370  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3371  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3372  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3373  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3374  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name  \
# 0     TFBS_NonTFBS_March_27th_2024_03_29_55_logstep=...
# 1     TFBS_NonTFBS_March_27th_2024_03_25_06_logstep=...
# 2     TFBS_NonTFBS_March_27th_2024_03_20_46_logstep=...
# 3     TFBS_NonTFBS_March_27th_2024_03_20_18_logstep=...
# 4     TFBS_NonTFBS_March_27th_2024_03_15_31_logstep=...
# ...                                                 ...
# 3370  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...
# 3371  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...
# 3372  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...
# 3373  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...
# 3374  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...
#
#                              tags
# 0     [TFBS_NonTFBS, ZNF785, e-3]
# 1     [PHF21A, TFBS_NonTFBS, e-3]
# 2      [TFBS_NonTFBS, ZBED1, e-6]
# 3     [PHF21A, TFBS_NonTFBS, e-3]
# 4     [PHF21A, TFBS_NonTFBS, e-3]
# ...                           ...
# 3370   [SAP30, TFBS_NonTFBS, e-3]
# 3371   [SAP30, TFBS_NonTFBS, e-6]
# 3372   [SAP30, TFBS_NonTFBS, e-5]
# 3373   [SAP30, TFBS_NonTFBS, e-4]
# 3374   [SAP30, TFBS_NonTFBS, e-3]
#
# [3375 rows x 4 columns]

# %%
# Define a function to filter tags
def filter_tags(tags):
    return [tag for tag in tags if '-' not in tag and 'TFBS' not in tag]

# %%
runs_df['tags'] = runs_df['tags'].apply(filter_tags)

# %%
runs_df
# Out:
#                                                 summary  \
# 0                           {'_wandb': {'runtime': 63}}
# 1     {'_step': 126, 'train_loss': 0.701253188507897...
# 2     {'eval_f1': 0.6248965880072537, 'eval_auc': 0....
# 3     {'eval_acc': 0.8145533532446375, 'train_loss':...
# 4     {'eval_auc': 0.3969597065276369, 'eval_recall'...
# ...                                                 ...
# 3370  {'eval_Validation loss': 0.6931307792663575, '...
# 3371  {'eval_auc': 0.8798126755400077, 'eval_Validat...
# 3372  {'Confusion Matrix': {'size': 59356, '_type': ...
# 3373  {'_runtime': 604.1279644966125, 'train_loss': ...
# 3374  {'_step': 327, '_runtime': 602.4626541137695, ...
#
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...                                                 ...
# 3370  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3371  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3372  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3373  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3374  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name      tags
# 0     TFBS_NonTFBS_March_27th_2024_03_29_55_logstep=...  [ZNF785]
# 1     TFBS_NonTFBS_March_27th_2024_03_25_06_logstep=...  [PHF21A]
# 2     TFBS_NonTFBS_March_27th_2024_03_20_46_logstep=...   [ZBED1]
# 3     TFBS_NonTFBS_March_27th_2024_03_20_18_logstep=...  [PHF21A]
# 4     TFBS_NonTFBS_March_27th_2024_03_15_31_logstep=...  [PHF21A]
# ...                                                 ...       ...
# 3370  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...   [SAP30]
# 3371  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...   [SAP30]
# 3372  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...   [SAP30]
# 3373  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...   [SAP30]
# 3374  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...   [SAP30]
#
# [3375 rows x 4 columns]

# %%
# Normalize the summary column to create a DataFrame of summaries
summaries_df = pd.json_normalize(runs_df['summary'])

# Concatenate the new summary columns with the original DataFrame (minus the old 'summary' column)
expanded_runs_df = pd.concat([runs_df.drop('summary', axis=1), summaries_df], axis=1)
# Assuming expanded_runs_df is your DataFrame
expanded_runs_df['tags'] = expanded_runs_df['tags'].apply(lambda x: x[0] if x else None)

# %%
expanded_runs_df
# Out:
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...                                                 ...
# 3370  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3371  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3372  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3373  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3374  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name    tags  \
# 0     TFBS_NonTFBS_March_27th_2024_03_29_55_logstep=...  ZNF785
# 1     TFBS_NonTFBS_March_27th_2024_03_25_06_logstep=...  PHF21A
# 2     TFBS_NonTFBS_March_27th_2024_03_20_46_logstep=...   ZBED1
# 3     TFBS_NonTFBS_March_27th_2024_03_20_18_logstep=...  PHF21A
# 4     TFBS_NonTFBS_March_27th_2024_03_15_31_logstep=...  PHF21A
# ...                                                 ...     ...
# 3370  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...   SAP30
# 3371  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...   SAP30
# 3372  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...   SAP30
# 3373  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...   SAP30
# 3374  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...   SAP30
#
#       _wandb.runtime  _step  train_loss  eval_recall  learning_rate  \
# 0                 63    NaN         NaN          NaN            NaN
# 1                278  126.0    0.701253     0.500000   5.333333e-04
# 2                591  282.0    0.654189     0.625171   1.319444e-07
# 3                278  126.0    0.341377     0.814529   1.777778e-04
# 4                276  126.0    0.696598     0.500000   5.333333e-04
# ...              ...    ...         ...          ...            ...
# 3370             692  327.0    0.697234     0.500000   3.873874e-04
# 3371             693  324.0    0.547333     0.798311   1.381381e-07
# 3372             700  324.0    0.242748     0.899412   1.381381e-06
# 3373             696  324.0    0.171405     0.887280   1.381381e-05
# 3374             689  327.0    0.095667     0.883309   1.291291e-04
#
#       eval_precision    _timestamp  ...  eval_auc  eval_mcc  \
# 0                NaN           NaN  ...       NaN       NaN
# 1           0.250204  1.711525e+09  ...  0.447602  0.000000
# 2           0.625522  1.711525e+09  ...  0.683296  0.250692
# 3           0.815707  1.711524e+09  ...  0.897842  0.630234
# 4           0.250204  1.711524e+09  ...  0.396960  0.000000
# ...              ...           ...  ...       ...       ...
# 3370        0.251934  1.709079e+09  ...  0.505400  0.000000
# 3371        0.799096  1.709079e+09  ...  0.879813  0.597406
# 3372        0.899874  1.709079e+09  ...  0.962615  0.799286
# 3373        0.889443  1.709079e+09  ...  0.951327  0.776720
# 3374        0.883297  1.709079e+09  ...  0.935315  0.766606
#
#       eval_Validation loss  Confusion Matrix.width  Confusion Matrix.format  \
# 0                      NaN                     NaN                      NaN
# 1                 0.693607                  1200.0                      png
# 2                 0.649277                  1200.0                      png
# 3                 0.461001                  1200.0                      png
# 4                 0.701757                  1200.0                      png
# ...                    ...                     ...                      ...
# 3370              0.693131                  1200.0                      png
# 3371              0.537199                  1200.0                      png
# 3372              0.245715                  1200.0                      png
# 3373              0.341513                  1200.0                      png
# 3374              0.485489                  1200.0                      png
#
#       Confusion Matrix.height  \
# 0                         NaN
# 1                      1200.0
# 2                      1200.0
# 3                      1200.0
# 4                      1200.0
# ...                       ...
# 3370                   1200.0
# 3371                   1200.0
# 3372                   1200.0
# 3373                   1200.0
# 3374                   1200.0
#
#                                 Confusion Matrix.sha256  \
# 0                                                   NaN
# 1     9588f8f016a2943f043f3d407aae6d2d72d871dbde408f...
# 2     6991426f0b9205b465cc644ad1c78d4efc619fb9758700...
# 3     47fb48fea6738c4408c4904d877c20acb32664b5446f97...
# 4     9588f8f016a2943f043f3d407aae6d2d72d871dbde408f...
# ...                                                 ...
# 3370  8bb7708fa5de7feeb1d06e439d1d08483f9f17af9479c6...
# 3371  5a78816cab0e1fa1c6a6f02ac5e67d8fb0dd137cfec7c4...
# 3372  265f5743eafafb5593d85b3f5b25a8bde9f25d156c0678...
# 3373  7375fb8417576ec4fc3d46996dd222308076be3b318ac5...
# 3374  9c25be08f0448a8369b8ab35a1cfd22c3a92ae50e8f279...
#
#                                   Confusion Matrix.path  \
# 0                                                   NaN
# 1     media/images/Confusion Matrix_84_9588f8f016a29...
# 2     media/images/Confusion Matrix_188_6991426f0b92...
# 3     media/images/Confusion Matrix_84_47fb48fea6738...
# 4     media/images/Confusion Matrix_84_9588f8f016a29...
# ...                                                 ...
# 3370  media/images/Confusion Matrix_218_8bb7708fa5de...
# 3371  media/images/Confusion Matrix_216_5a78816cab0e...
# 3372  media/images/Confusion Matrix_216_265f5743eafa...
# 3373  media/images/Confusion Matrix_216_7375fb841757...
# 3374  media/images/Confusion Matrix_218_9c25be08f044...
#
#       Confusion Matrix.size Confusion Matrix._type
# 0                       NaN                    NaN
# 1                   51357.0             image-file
# 2                   57489.0             image-file
# 3                   55686.0             image-file
# 4                   51357.0             image-file
# ...                     ...                    ...
# 3370                49619.0             image-file
# 3371                57947.0             image-file
# 3372                59356.0             image-file
# 3373                58933.0             image-file
# 3374                56420.0             image-file
#
# [3375 rows x 23 columns]

# %%
# Remove rows with any NaN values and keep the original index
expanded_runs_df = expanded_runs_df.dropna().reset_index()
expanded_runs_df
# Out:
#       index                                             config  \
# 0         1  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1         2  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2         3  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3         4  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4         5  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...     ...                                                ...
# 3286   3370  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3287   3371  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3288   3372  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3289   3373  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3290   3374  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name    tags  \
# 0     TFBS_NonTFBS_March_27th_2024_03_25_06_logstep=...  PHF21A
# 1     TFBS_NonTFBS_March_27th_2024_03_20_46_logstep=...   ZBED1
# 2     TFBS_NonTFBS_March_27th_2024_03_20_18_logstep=...  PHF21A
# 3     TFBS_NonTFBS_March_27th_2024_03_15_31_logstep=...  PHF21A
# 4     TFBS_NonTFBS_March_27th_2024_03_13_00_logstep=...  ZNF579
# ...                                                 ...     ...
# 3286  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...   SAP30
# 3287  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...   SAP30
# 3288  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...   SAP30
# 3289  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...   SAP30
# 3290  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...   SAP30
#
#       _wandb.runtime  _step  train_loss  eval_recall  learning_rate  \
# 0                278  126.0    0.701253     0.500000   5.333333e-04
# 1                591  282.0    0.654189     0.625171   1.319444e-07
# 2                278  126.0    0.341377     0.814529   1.777778e-04
# 3                276  126.0    0.696598     0.500000   5.333333e-04
# 4                454  210.0    0.568148     0.712468   4.166667e-07
# ...              ...    ...         ...          ...            ...
# 3286             692  327.0    0.697234     0.500000   3.873874e-04
# 3287             693  324.0    0.547333     0.798311   1.381381e-07
# 3288             700  324.0    0.242748     0.899412   1.381381e-06
# 3289             696  324.0    0.171405     0.887280   1.381381e-05
# 3290             689  327.0    0.095667     0.883309   1.291291e-04
#
#       eval_precision  ...  eval_auc  eval_mcc  eval_Validation loss  \
# 0           0.250204  ...  0.447602  0.000000              0.693607
# 1           0.625522  ...  0.683296  0.250692              0.649277
# 2           0.815707  ...  0.897842  0.630234              0.461001
# 3           0.250204  ...  0.396960  0.000000              0.701757
# 4           0.714082  ...  0.791798  0.426546              0.566603
# ...              ...  ...       ...       ...                   ...
# 3286        0.251934  ...  0.505400  0.000000              0.693131
# 3287        0.799096  ...  0.879813  0.597406              0.537199
# 3288        0.899874  ...  0.962615  0.799286              0.245715
# 3289        0.889443  ...  0.951327  0.776720              0.341513
# 3290        0.883297  ...  0.935315  0.766606              0.485489
#
#       Confusion Matrix.width  Confusion Matrix.format  \
# 0                     1200.0                      png
# 1                     1200.0                      png
# 2                     1200.0                      png
# 3                     1200.0                      png
# 4                     1200.0                      png
# ...                      ...                      ...
# 3286                  1200.0                      png
# 3287                  1200.0                      png
# 3288                  1200.0                      png
# 3289                  1200.0                      png
# 3290                  1200.0                      png
#
#       Confusion Matrix.height  \
# 0                      1200.0
# 1                      1200.0
# 2                      1200.0
# 3                      1200.0
# 4                      1200.0
# ...                       ...
# 3286                   1200.0
# 3287                   1200.0
# 3288                   1200.0
# 3289                   1200.0
# 3290                   1200.0
#
#                                 Confusion Matrix.sha256  \
# 0     9588f8f016a2943f043f3d407aae6d2d72d871dbde408f...
# 1     6991426f0b9205b465cc644ad1c78d4efc619fb9758700...
# 2     47fb48fea6738c4408c4904d877c20acb32664b5446f97...
# 3     9588f8f016a2943f043f3d407aae6d2d72d871dbde408f...
# 4     ff2ba4e07c917facd2715b83969450a6a1912a513c8244...
# ...                                                 ...
# 3286  8bb7708fa5de7feeb1d06e439d1d08483f9f17af9479c6...
# 3287  5a78816cab0e1fa1c6a6f02ac5e67d8fb0dd137cfec7c4...
# 3288  265f5743eafafb5593d85b3f5b25a8bde9f25d156c0678...
# 3289  7375fb8417576ec4fc3d46996dd222308076be3b318ac5...
# 3290  9c25be08f0448a8369b8ab35a1cfd22c3a92ae50e8f279...
#
#                                   Confusion Matrix.path Confusion Matrix.size  \
# 0     media/images/Confusion Matrix_84_9588f8f016a29...               51357.0
# 1     media/images/Confusion Matrix_188_6991426f0b92...               57489.0
# 2     media/images/Confusion Matrix_84_47fb48fea6738...               55686.0
# 3     media/images/Confusion Matrix_84_9588f8f016a29...               51357.0
# 4     media/images/Confusion Matrix_140_ff2ba4e07c91...               58748.0
# ...                                                 ...                   ...
# 3286  media/images/Confusion Matrix_218_8bb7708fa5de...               49619.0
# 3287  media/images/Confusion Matrix_216_5a78816cab0e...               57947.0
# 3288  media/images/Confusion Matrix_216_265f5743eafa...               59356.0
# 3289  media/images/Confusion Matrix_216_7375fb841757...               58933.0
# 3290  media/images/Confusion Matrix_218_9c25be08f044...               56420.0
#
#       Confusion Matrix._type
# 0                 image-file
# 1                 image-file
# 2                 image-file
# 3                 image-file
# 4                 image-file
# ...                      ...
# 3286              image-file
# 3287              image-file
# 3288              image-file
# 3289              image-file
# 3290              image-file
#
# [3291 rows x 24 columns]

# %%
# Group by 'tags' and find the index of the max 'eval_acc' for each group
idx = expanded_runs_df.groupby('tags')['eval_acc'].idxmax()

# Use the indices to select rows from the original DataFrame
best_acc_df = expanded_runs_df.loc[idx].reset_index(drop=True)
best_acc_df
# Out:
#      index                                             config  \
# 0     1134  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1      498  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     2085  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3     1322  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     2735  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ..     ...                                                ...
# 146    352  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 147   1636  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 148    246  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 149   2708  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 150   1659  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                   name      tags  \
# 0    TFBS_NonTFBS_March_11th_2024_07_48_56_logstep=...      AGO2
# 1    TFBS_NonTFBS_March_22th_2024_03_02_22_logstep=...  ARHGAP35
# 2    TFBS_NonTFBS_March_03th_2024_07_58_34_logstep=...    ARID3A
# 3    TFBS_NonTFBS_March_10th_2024_18_51_55_logstep=...      ARNT
# 4    TFBS_NonTFBS_February_29th_2024_20_07_02_logst...      BLC3
# ..                                                 ...       ...
# 146  TFBS_NonTFBS_March_22th_2024_16_27_48_logstep=...    ZNF785
# 147  TFBS_NonTFBS_March_09th_2024_03_13_54_logstep=...    ZNF792
# 148  TFBS_NonTFBS_March_24th_2024_11_52_13_logstep=...   ZSCAN23
# 149  TFBS_NonTFBS_March_01th_2024_02_09_02_logstep=...    ZSCAN9
# 150  TFBS_NonTFBS_March_09th_2024_01_32_17_logstep=...      ZXDB
#
#      _wandb.runtime   _step  train_loss  eval_recall  learning_rate  \
# 0              1362   633.0    0.264199     0.895822       0.000004
# 1               154    66.0    0.333016     0.821965       0.000019
# 2              1699   795.0    0.256148     0.764785       0.000036
# 3              1831   873.0    0.404111     0.750620       0.000121
# 4              7580  3555.0    0.111454     0.908947       0.000034
# ..              ...     ...         ...          ...            ...
# 146             219    99.0    0.223840     0.875766       0.000019
# 147             862   408.0    0.263192     0.808337       0.000126
# 148             275   126.0    0.371474     0.776157       0.000018
# 149             601   282.0    0.307224     0.812420       0.000132
# 150            1083   513.0    0.271421     0.813148       0.000128
#
#      eval_precision  ...  eval_auc  eval_mcc  eval_Validation loss  \
# 0          0.898803  ...  0.936196  0.794619              0.298919
# 1          0.823799  ...  0.901186  0.645762              0.402552
# 2          0.768812  ...  0.837500  0.533582              0.765750
# 3          0.750809  ...  0.826269  0.501429              0.593425
# 4          0.909569  ...  0.960377  0.818516              0.361423
# ..              ...  ...       ...       ...                   ...
# 146        0.875901  ...  0.949737  0.751668              0.293426
# 147        0.812972  ...  0.887947  0.621292              0.530071
# 148        0.781929  ...  0.858684  0.558057              0.493020
# 149        0.812749  ...  0.890887  0.625169              0.483263
# 150        0.813921  ...  0.886258  0.627069              0.535345
#
#      Confusion Matrix.width  Confusion Matrix.format  Confusion Matrix.height  \
# 0                    1200.0                      png                   1200.0
# 1                    1200.0                      png                   1200.0
# 2                    1200.0                      png                   1200.0
# 3                    1200.0                      png                   1200.0
# 4                    1200.0                      png                   1200.0
# ..                      ...                      ...                      ...
# 146                  1200.0                      png                   1200.0
# 147                  1200.0                      png                   1200.0
# 148                  1200.0                      png                   1200.0
# 149                  1200.0                      png                   1200.0
# 150                  1200.0                      png                   1200.0
#
#                                Confusion Matrix.sha256  \
# 0    958cd42b536bc3994165310ae2cbd90fbd514c41e93d89...
# 1    05bda9ec50bc339493dca11b5d394511f04b407205e0ee...
# 2    9790b8d093b46b5410432abe0ae5c05698c8f6338f0c86...
# 3    4654e6e9f4b65a33e5232fe1c4e4f3ad0d152246fc91aa...
# 4    62feb30361869d99e534374c07accb544ecca05e54c11e...
# ..                                                 ...
# 146  774761deed86c76bcda8a44b4a3b2a90bb747b702d742e...
# 147  0a705a0c192a9c707044695c28c4b400f4158812f32126...
# 148  f1f3edfd44a11d0b78090ba0a1cd55c3cd31b4e702be1c...
# 149  e5c3db86ea9e90d0c522f3bbd8795316ce7d735f6f33ba...
# 150  7bebe030ee27cf12dc17f4e6d3e64b82faa375bcb2e99b...
#
#                                  Confusion Matrix.path Confusion Matrix.size  \
# 0    media/images/Confusion Matrix_422_958cd42b536b...               60413.0
# 1    media/images/Confusion Matrix_44_05bda9ec50bc3...               57200.0
# 2    media/images/Confusion Matrix_530_9790b8d093b4...               59950.0
# 3    media/images/Confusion Matrix_582_4654e6e9f4b6...               58394.0
# 4    media/images/Confusion Matrix_2370_62feb303618...               62161.0
# ..                                                 ...                   ...
# 146  media/images/Confusion Matrix_66_774761deed86c...               56456.0
# 147  media/images/Confusion Matrix_272_0a705a0c192a...               59776.0
# 148  media/images/Confusion Matrix_84_f1f3edfd44a11...               56203.0
# 149  media/images/Confusion Matrix_188_e5c3db86ea9e...               54036.0
# 150  media/images/Confusion Matrix_342_7bebe030ee27...               56804.0
#
#      Confusion Matrix._type
# 0                image-file
# 1                image-file
# 2                image-file
# 3                image-file
# 4                image-file
# ..                      ...
# 146              image-file
# 147              image-file
# 148              image-file
# 149              image-file
# 150              image-file
#
# [151 rows x 24 columns]

# %%
best_acc_df.iloc[1]['config']
# Out:
# {'epochs': 10,
#  'Dropout': 0.1,
#  'batch_size': 1040,
#  'Weight Decay': 0.005,
#  'architecture': 'TFBS_Finetuned_Models',
#  'learning_rate': 0.0001,
#  'warm up percentage': 0.1,
#  'Maximum sequence length': 100}

# %%
base_path= "/data/private/pdutta/DNABERT_output/TFBS/Finetuned_models"

# %%
for index, row in best_acc_df.iterrows():
    config = row['config']
    
    # Format the learning rate string for the folder name
    learning_rate_str = format(config['learning_rate'], '.1e').split('e-')[-1].lstrip('0')
    learning_rate_folder = f"e-{learning_rate_str}"

    tag = row['tags']
    
    # Construct the pattern to match the best model directory
    best_model_dir_pattern = f"_bs={config['batch_size']}_lr={config['learning_rate']}_wp={config['warm up percentage']}_dp={config['Dropout']}_wd={config['Weight Decay']}_len={config['Maximum sequence length']}_epoch={config['epochs']}.0"

    tag_directory = os.path.join(base_path, tag)
    learning_rate_directory = os.path.join(tag_directory, learning_rate_folder)
    
    if os.path.exists(learning_rate_directory):
        # Find the best model in the learning rate directory
        best_model_path = ""
        for model_dir in os.listdir(learning_rate_directory):
            if best_model_dir_pattern in model_dir:
                best_model_path = os.path.join(learning_rate_directory, model_dir)
                break

        # Delete other models in the learning rate directory
        if best_model_path:
            for model_dir in os.listdir(learning_rate_directory):
                full_model_dir = os.path.join(learning_rate_directory, model_dir)
                if full_model_dir != best_model_path:
                    print(f"Deleting model: {full_model_dir}")
                    shutil.rmtree(full_model_dir)
        else:
            print("No best model match found in the learning rate directory.")

        # Now, delete other learning rate directories under the tag
        for lr_dir in os.listdir(tag_directory):
            full_lr_dir_path = os.path.join(tag_directory, lr_dir)
            if full_lr_dir_path != learning_rate_directory:
                print(f"Deleting learning rate directory: {full_lr_dir_path}")
                shutil.rmtree(full_lr_dir_path)
    else:
        #print(f"Learning rate directory does not exist: {learning_rate_directory}")
        continue
# Out:
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-5/logstep=211_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-5/logstep=211_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-5/logstep=211_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-5/logstep=211_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-5/logstep=211_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/AGO2/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-4/logstep=22_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-4/logstep=22_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-4/logstep=22_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-4/logstep=22_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-4/logstep=22_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARHGAP35/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-4/logstep=265_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-4/logstep=265_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-4/logstep=265_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-4/logstep=265_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-4/logstep=265_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARID3A/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-3/logstep=291_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-3/logstep=291_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-3/logstep=291_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-3/logstep=291_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-3/logstep=291_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ARNT/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-4/logstep=1185_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-4/logstep=1185_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-4/logstep=1185_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-4/logstep=1185_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-4/logstep=1185_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BLC3/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-5/logstep=81_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-5/logstep=81_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-5/logstep=81_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-5/logstep=81_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-5/logstep=81_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/BRD9/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-4/logstep=246_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-4/logstep=246_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-4/logstep=246_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-4/logstep=246_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-4/logstep=246_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFA2T3/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-4/logstep=99_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-4/logstep=99_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-4/logstep=99_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-4/logstep=99_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-4/logstep=99_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBFB/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-5/logstep=69_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-5/logstep=69_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-5/logstep=69_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-5/logstep=69_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-5/logstep=69_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-4/logstep=13_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-4/logstep=13_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CBX2/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPB/e-4/logstep=2325_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPB/e-4/logstep=2325_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPB/e-4/logstep=2325_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPB/e-4/logstep=2325_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPB/e-4/logstep=2325_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPB/e-5
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-4/logstep=13_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-4/logstep=13_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-4/logstep=13_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CEBPZ/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-3/logstep=31_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-3/logstep=31_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-3/logstep=31_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-3/logstep=31_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-3/logstep=31_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CHD7/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-5/logstep=813_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-5/logstep=813_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-5/logstep=813_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-5/logstep=813_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-5/logstep=813_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CREB1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-5/logstep=420_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-5/logstep=420_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-5/logstep=420_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-5/logstep=420_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-5/logstep=420_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/CTBP1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DDX20/e-4/logstep=85_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DDX20/e-4/logstep=85_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DDX20/e-4/logstep=85_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DDX20/e-4/logstep=85_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DDX20/e-4/logstep=85_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DDX20/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DDX20/e-3
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-3/logstep=43_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-3/logstep=43_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-3/logstep=43_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-3/logstep=43_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-3/logstep=43_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/DEK/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-5/logstep=72_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-5/logstep=72_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-5/logstep=72_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-5/logstep=72_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-5/logstep=72_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F4/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-4/logstep=13_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-4/logstep=13_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-4/logstep=13_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E2F7/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-4/logstep=181_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-4/logstep=181_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-4/logstep=181_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-4/logstep=181_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-4/logstep=181_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/E4F1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP300/e-5/logstep=4381_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP300/e-5/logstep=4381_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP300/e-5/logstep=4381_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-3/logstep=156_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-3/logstep=156_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-3/logstep=156_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-3/logstep=156_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-3/logstep=156_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EP400/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-4/logstep=7_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-4/logstep=7_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-4/logstep=7_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-4/logstep=7_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-4/logstep=7_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/EWSR1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-3/logstep=157_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-3/logstep=157_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-3/logstep=157_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-3/logstep=157_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-3/logstep=157_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FEZF1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOSL2/e-4/logstep=993_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOSL2/e-4/logstep=993_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOSL2/e-4/logstep=993_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOSL2/e-4/logstep=993_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOSL2/e-4/logstep=993_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOSL2/e-5
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-4/logstep=802_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-4/logstep=802_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-4/logstep=802_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-4/logstep=802_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-4/logstep=802_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXA2/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-5/logstep=309_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-5/logstep=309_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-5/logstep=309_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-5/logstep=309_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-5/logstep=309_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXK2/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXM1/e-4/logstep=108_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXM1/e-4/logstep=108_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXM1/e-4/logstep=108_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXM1/e-4/logstep=108_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXM1/e-4/logstep=108_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXM1/e-5
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-3/logstep=135_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-3/logstep=135_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-3/logstep=135_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-3/logstep=135_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-3/logstep=135_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/FOXP2/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-3/logstep=64_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-3/logstep=64_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-3/logstep=64_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-3/logstep=64_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-3/logstep=64_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GATA4/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-3/logstep=51_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-3/logstep=51_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-3/logstep=51_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-3/logstep=51_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-3/logstep=51_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/GFI1B/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-5/logstep=603_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-5/logstep=603_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-5/logstep=603_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-5/logstep=603_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-5/logstep=603_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H2AK9ac/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-5/logstep=2335_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-5/logstep=2335_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-5/logstep=2335_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-5/logstep=2335_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-5/logstep=2335_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K14ac/e-6
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K27me3/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K27me3/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K27me3/e-4
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-6/logstep=5443_bs=1040_lr=1e-06_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-6/logstep=5443_bs=1040_lr=3e-06_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-6/logstep=5443_bs=1040_lr=1e-06_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-6/logstep=5443_bs=1040_lr=3e-06_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-6/logstep=5443_bs=1040_lr=1e-06_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K79me1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K9ac/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K9me3/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K9me3/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H3K9me3/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-5/logstep=3741_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-5/logstep=3741_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-5/logstep=3741_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-5/logstep=3741_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-5/logstep=3741_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/H4K8ac/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-5/logstep=600_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-5/logstep=600_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-5/logstep=600_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-5/logstep=600_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-5/logstep=600_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-5/logstep=718_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-5/logstep=718_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-5/logstep=718_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-5/logstep=718_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-5/logstep=718_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HDAC2/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-3/logstep=75_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-3/logstep=75_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-3/logstep=75_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-3/logstep=75_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-3/logstep=75_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HES1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-5/logstep=135_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-5/logstep=135_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-5/logstep=135_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-5/logstep=135_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-5/logstep=135_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HMBOX1/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HNF1A/e-4/logstep=66_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HNF1A/e-4/logstep=66_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HNF1A/e-4/logstep=66_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HNF1A/e-4/logstep=66_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HNF1A/e-4/logstep=66_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/HNF1A/e-5
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-5/logstep=139_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-5/logstep=139_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-5/logstep=139_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-5/logstep=139_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-5/logstep=139_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IKZF52/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-5/logstep=21_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-5/logstep=21_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-5/logstep=21_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-5/logstep=21_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-5/logstep=21_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILF3/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-4/logstep=9_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-4/logstep=9_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-4/logstep=9_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-4/logstep=9_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-4/logstep=9_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ILK/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-3/logstep=12_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-3/logstep=12_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-3/logstep=12_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-3/logstep=12_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-3/logstep=12_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/IRF5/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-4/logstep=1611_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-4/logstep=1611_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-4/logstep=1611_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-4/logstep=1611_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-4/logstep=1611_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/JUND/e-6
# ...
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF544/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF544/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF558/e-3/logstep=70_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF558/e-3/logstep=70_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF558/e-3/logstep=70_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF558/e-3/logstep=70_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF558/e-3/logstep=70_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF558/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF558/e-4
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-4/logstep=15_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-4/logstep=15_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-4/logstep=15_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-4/logstep=15_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-4/logstep=15_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF560/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-4/logstep=70_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-4/logstep=70_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-4/logstep=70_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-4/logstep=70_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-4/logstep=70_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF579/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-3/logstep=34_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-3/logstep=34_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-3/logstep=34_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-3/logstep=34_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-3/logstep=34_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF585B/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-4/logstep=66_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-4/logstep=66_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-4/logstep=66_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-4/logstep=66_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-4/logstep=66_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF596/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF600/e-4/logstep=232_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF600/e-4/logstep=232_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF600/e-4/logstep=232_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF600/e-4/logstep=232_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF600/e-4/logstep=232_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF600/e-5
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-3/logstep=69_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-3/logstep=69_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-3/logstep=69_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-3/logstep=69_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-3/logstep=69_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF610/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-3/logstep=76_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-3/logstep=76_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-3/logstep=76_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-3/logstep=76_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-3/logstep=76_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF652/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-3/logstep=162_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-3/logstep=162_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-3/logstep=162_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-3/logstep=162_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-3/logstep=162_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF692/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-5/logstep=34_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-5/logstep=34_bs=1040_lr=3e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-5/logstep=34_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-5/logstep=34_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-5/logstep=34_bs=1040_lr=1e-05_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-3
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF777/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF785/e-4/logstep=33_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF785/e-4/logstep=33_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF785/e-4/logstep=33_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF785/e-4/logstep=33_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF785/e-4/logstep=33_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF785/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF785/e-3
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-3/logstep=136_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-3/logstep=136_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-3/logstep=136_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-3/logstep=136_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-3/logstep=136_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZNF792/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN23/e-4/logstep=42_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN23/e-4/logstep=42_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN23/e-4/logstep=42_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN23/e-4/logstep=42_bs=1040_lr=0.0001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN23/e-4/logstep=42_bs=1040_lr=0.0003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN23/e-5
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-3/logstep=94_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-3/logstep=94_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-3/logstep=94_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-3/logstep=94_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-3/logstep=94_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZSCAN9/e-6
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-3/logstep=171_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-3/logstep=171_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-3/logstep=171_bs=1024_lr=0.003_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-3/logstep=171_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.001_len=100_epoch=10.0
# Deleting model: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-3/logstep=171_bs=1024_lr=0.001_wp=0.1_dp=0.1_wd=0.0005_len=100_epoch=10.0
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-5
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-4
# Deleting learning rate directory: /data/private/pdutta/DNABERT_output/TFBS/Finetuned_models/ZXDB/e-6

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False)[['tags','eval_acc']]
# Out:
#       tags  eval_acc
# 62   RBM14  0.968908
# 72    SPI1  0.957358
# 42    MAFF  0.939551
# 78   THAP1  0.937964
# 14    E2F4  0.918800
# ..     ...       ...
# 35    ILF3  0.715873
# 10    CHD7  0.709527
# 58    PTRF  0.705040
# 79  THRAP3  0.683565
# 18   EWSR1  0.605755
#
# [118 rows x 2 columns]

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False)[['tags','eval_acc']].to_csv("TFBS_accuracy_Stat.tsv", sep="\t")

# %%
best_acc_df
