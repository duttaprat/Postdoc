# %%
import pandas as pd
import wandb

# %%
api = wandb.Api()
entity, project = "pratik24111991", "TFBS_Finetuned_Models_300bp_balanced_Work"
runs = api.runs(entity + "/" + project)

# %%
summary_list, config_list, name_list, tag_list = [], [], [], []
for run in runs:
    # .summary contains output keys/values for
    # metrics such as accuracy.
    #  We call ._json_dict to omit large files
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append({k: v for k, v in run.config.items() if not k.startswith("_")})

    # .name is the human-readable name of the run.
    name_list.append(run.name)
    tag_list.append(run.tags)

runs_df = pd.DataFrame(
    {"summary": summary_list, "config": config_list, "name": name_list, "tags":tag_list}
)

# %%
runs_df
# Out:
#                                                summary  \
# 0    {'train_loss': 0.6270707417125544, 'eval_preci...
# 1    {'eval_mcc': 0.1820258751685492, '_wandb': {'r...
# 2    {'learning_rate': 5.4200542005420054e-08, 'Con...
# 3    {'_step': 10620, 'eval_mcc': 0, 'train_loss': ...
# 4    {'train_loss': 0.6949255400233798, 'eval_preci...
# ..                                                 ...
# 903                        {'_wandb': {'runtime': 32}}
# 904  {'train_loss': 0.00918852477642315, 'eval_prec...
# 905  {'eval_mcc': 0.8233823837004726, '_wandb': {'r...
# 906  {'_step': 1210, '_wandb': {'runtime': 2349}, '...
# 907  {'eval_Validation loss': 0.35719382564226787, ...
#
#                                                 config  \
# 0    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 1    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 2    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 3    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 4    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# ..                                                 ...
# 903  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 904  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 905  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 906  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 907  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                   name  \
# 0    TFBS_NonTFBS_June_05th_2024_23_55_10_logstep=1...
# 1    TFBS_NonTFBS_June_05th_2024_23_16_16_logstep=1...
# 2    TFBS_NonTFBS_June_05th_2024_22_37_33_logstep=1...
# 3    TFBS_NonTFBS_June_05th_2024_22_14_07_logstep=2...
# 4    TFBS_NonTFBS_June_05th_2024_22_05_03_logstep=2...
# ..                                                 ...
# 903  TFBS_NonTFBS_May_23th_2024_15_17_30_logstep=12...
# 904  TFBS_NonTFBS_May_23th_2024_14_25_44_logstep=12...
# 905  TFBS_NonTFBS_May_23th_2024_13_41_27_logstep=12...
# 906  TFBS_NonTFBS_May_23th_2024_13_02_04_logstep=12...
# 907  TFBS_NonTFBS_May_23th_2024_12_23_11_logstep=12...
#
#                               tags
# 0    [H3K36me3, TFBS_NonTFBS, e-6]
# 1    [H3K36me3, TFBS_NonTFBS, e-6]
# 2    [H3K36me3, TFBS_NonTFBS, e-6]
# 3       [RAD21, TFBS_NonTFBS, e-3]
# 4     [H3K9me3, TFBS_NonTFBS, e-3]
# ..                             ...
# 903     [CEBPA, TFBS_NonTFBS, e-4]
# 904     [CEBPA, TFBS_NonTFBS, e-4]
# 905     [CEBPA, TFBS_NonTFBS, e-4]
# 906     [CEBPA, TFBS_NonTFBS, e-4]
# 907     [CEBPA, TFBS_NonTFBS, e-4]
#
# [908 rows x 4 columns]

# %%
# Define a function to filter tags
def filter_tags(tags):
    return [tag for tag in tags if '-' not in tag and 'TFBS' not in tag]

# %%
runs_df['tags'] = runs_df['tags'].apply(filter_tags)

# %%
runs_df
# Out:
#                                                summary  \
# 0    {'train_loss': 0.6270707417125544, 'eval_preci...
# 1    {'eval_mcc': 0.1820258751685492, '_wandb': {'r...
# 2    {'learning_rate': 5.4200542005420054e-08, 'Con...
# 3    {'_step': 10620, 'eval_mcc': 0, 'train_loss': ...
# 4    {'train_loss': 0.6949255400233798, 'eval_preci...
# ..                                                 ...
# 903                        {'_wandb': {'runtime': 32}}
# 904  {'train_loss': 0.00918852477642315, 'eval_prec...
# 905  {'eval_mcc': 0.8233823837004726, '_wandb': {'r...
# 906  {'_step': 1210, '_wandb': {'runtime': 2349}, '...
# 907  {'eval_Validation loss': 0.35719382564226787, ...
#
#                                                 config  \
# 0    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 1    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 2    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 3    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 4    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# ..                                                 ...
# 903  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 904  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 905  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 906  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 907  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                   name        tags
# 0    TFBS_NonTFBS_June_05th_2024_23_55_10_logstep=1...  [H3K36me3]
# 1    TFBS_NonTFBS_June_05th_2024_23_16_16_logstep=1...  [H3K36me3]
# 2    TFBS_NonTFBS_June_05th_2024_22_37_33_logstep=1...  [H3K36me3]
# 3    TFBS_NonTFBS_June_05th_2024_22_14_07_logstep=2...     [RAD21]
# 4    TFBS_NonTFBS_June_05th_2024_22_05_03_logstep=2...   [H3K9me3]
# ..                                                 ...         ...
# 903  TFBS_NonTFBS_May_23th_2024_15_17_30_logstep=12...     [CEBPA]
# 904  TFBS_NonTFBS_May_23th_2024_14_25_44_logstep=12...     [CEBPA]
# 905  TFBS_NonTFBS_May_23th_2024_13_41_27_logstep=12...     [CEBPA]
# 906  TFBS_NonTFBS_May_23th_2024_13_02_04_logstep=12...     [CEBPA]
# 907  TFBS_NonTFBS_May_23th_2024_12_23_11_logstep=12...     [CEBPA]
#
# [908 rows x 4 columns]

# %%
# Normalize the summary column to create a DataFrame of summaries
summaries_df = pd.json_normalize(runs_df['summary'])

# Concatenate the new summary columns with the original DataFrame (minus the old 'summary' column)
expanded_runs_df = pd.concat([runs_df.drop('summary', axis=1), summaries_df], axis=1)
# Assuming expanded_runs_df is your DataFrame
expanded_runs_df['tags'] = expanded_runs_df['tags'].apply(lambda x: x[0] if x else None)

# %%
expanded_runs_df
# Out:
#                                                 config  \
# 0    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 1    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 2    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 3    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 4    {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# ..                                                 ...
# 903  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 904  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 905  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 906  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 907  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                   name      tags  train_loss  \
# 0    TFBS_NonTFBS_June_05th_2024_23_55_10_logstep=1...  H3K36me3    0.627071
# 1    TFBS_NonTFBS_June_05th_2024_23_16_16_logstep=1...  H3K36me3    0.662153
# 2    TFBS_NonTFBS_June_05th_2024_22_37_33_logstep=1...  H3K36me3    0.625209
# 3    TFBS_NonTFBS_June_05th_2024_22_14_07_logstep=2...     RAD21    0.694753
# 4    TFBS_NonTFBS_June_05th_2024_22_05_03_logstep=2...   H3K9me3    0.694926
# ..                                                 ...       ...         ...
# 903  TFBS_NonTFBS_May_23th_2024_15_17_30_logstep=12...     CEBPA         NaN
# 904  TFBS_NonTFBS_May_23th_2024_14_25_44_logstep=12...     CEBPA    0.009189
# 905  TFBS_NonTFBS_May_23th_2024_13_41_27_logstep=12...     CEBPA    0.054939
# 906  TFBS_NonTFBS_May_23th_2024_13_02_04_logstep=12...     CEBPA    0.009411
# 907  TFBS_NonTFBS_May_23th_2024_12_23_11_logstep=12...     CEBPA    0.053269
#
#      eval_precision  eval_Validation loss    _step     _runtime  eval_mcc  \
# 0          0.640725              0.624322    968.0  1808.485339  0.278635
# 1          0.592252              0.664515   1210.0  2267.969909  0.182026
# 2          0.642480              0.623269   1210.0  2261.715991  0.282269
# 3          0.249767              0.694093  10620.0  6614.299117  0.000000
# 4          0.249933              0.695659  10620.0  6605.493064  0.000000
# ..              ...                   ...      ...          ...       ...
# 903             NaN                   NaN      NaN          NaN       NaN
# 904        0.919998              0.472767   1210.0  3042.108180  0.839686
# 905        0.912503              0.354305   1210.0  2593.578342  0.823382
# 906        0.919642              0.472342   1210.0  2300.019405  0.838657
# 907        0.911977              0.357194   1210.0  2271.259037  0.822202
#
#        _timestamp  ...  eval_acc  eval_auc  \
# 0    1.717648e+09  ...  0.638333  0.698923
# 1    1.717646e+09  ...  0.590267  0.629178
# 2    1.717644e+09  ...  0.640200  0.700248
# 3    1.717647e+09  ...  0.499533       NaN
# 4    1.717646e+09  ...  0.499867       NaN
# ..            ...  ...       ...       ...
# 903           NaN  ...       NaN       NaN
# 904  1.716492e+09  ...  0.919467  0.970946
# 905  1.716489e+09  ...  0.910467  0.971116
# 906  1.716486e+09  ...  0.918733  0.970520
# 907  1.716484e+09  ...  0.909800  0.970636
#
#                                  Confusion Matrix.path  Confusion Matrix.size  \
# 0    media/images/Confusion Matrix_847_a4c3c1db8bcd...                57708.0
# 1    media/images/Confusion Matrix_1089_177ac8b8f72...                58537.0
# 2    media/images/Confusion Matrix_1089_e7f89ed1d5d...                57685.0
# 3    media/images/Confusion Matrix_8496_4be120346ff...                49731.0
# 4    media/images/Confusion Matrix_8496_7e23f820ece...                49818.0
# ..                                                 ...                    ...
# 903                                                NaN                    NaN
# 904  media/images/Confusion Matrix_1089_75b86fca852...                56594.0
# 905  media/images/Confusion Matrix_1089_f6bb2fbf43e...                57386.0
# 906  media/images/Confusion Matrix_1089_58f1d4377b2...                56913.0
# 907  media/images/Confusion Matrix_1089_fb13f17c69c...                57884.0
#
#      Confusion Matrix._type Confusion Matrix.width  Confusion Matrix.format  \
# 0                image-file                 1200.0                      png
# 1                image-file                 1200.0                      png
# 2                image-file                 1200.0                      png
# 3                image-file                 1200.0                      png
# 4                image-file                 1200.0                      png
# ..                      ...                    ...                      ...
# 903                     NaN                    NaN                      NaN
# 904              image-file                 1200.0                      png
# 905              image-file                 1200.0                      png
# 906              image-file                 1200.0                      png
# 907              image-file                 1200.0                      png
#
#     Confusion Matrix.height  \
# 0                    1200.0
# 1                    1200.0
# 2                    1200.0
# 3                    1200.0
# 4                    1200.0
# ..                      ...
# 903                     NaN
# 904                  1200.0
# 905                  1200.0
# 906                  1200.0
# 907                  1200.0
#
#                                Confusion Matrix.sha256 _wandb.runtime
# 0    a4c3c1db8bcd6fac12f7a87bb9e7db091e7ec783b18c9f...            NaN
# 1    177ac8b8f72f4afbc1bdf7fb875881b835621b6441e295...         2318.0
# 2    e7f89ed1d5df6c51249da093ff5f564761f0b36db02ec0...         2312.0
# 3    4be120346ff340d4ff2ee35c5773eb89746a06f15acd5b...            NaN
# 4    7e23f820eceecdddea4ede69e17e24ed7876eeee61425b...            NaN
# ..                                                 ...            ...
# 903                                                NaN           32.0
# 904  75b86fca852c54fef06a8df9ab8ebd1b4491d9b20d2a1c...         3092.0
# 905  f6bb2fbf43edc55602f863f690a0207d203b13ae6c95eb...         2643.0
# 906  58f1d4377b2d3356df720b6e18140f5c4068c5642edb66...         2349.0
# 907  fb13f17c69c1108dd7652fced42e5b0e67e1e775666ea8...         2320.0
#
# [908 rows x 23 columns]

# %%
# # Remove rows with any NaN values and keep the original index
# expanded_runs_df = expanded_runs_df.dropna().reset_index()
# expanded_runs_df

# %%
# Group by 'tags' and find the index of the max 'eval_acc' for each group
idx = expanded_runs_df.groupby('tags')['eval_acc'].idxmax()

# Use the indices to select rows from the original DataFrame
best_acc_df = expanded_runs_df.loc[idx].reset_index(drop=True)
best_acc_df
# Out:
#                                                config  \
# 0   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 1   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 2   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 3   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 4   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 5   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 6   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 7   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 8   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 9   {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 10  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 11  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 12  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 13  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 1...
# 14  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 15  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 16  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 17  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 18  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 19  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 20  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 21  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 22  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 23  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 24  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 25  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 26  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 27  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 28  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
# 29  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 8...
# 30  {'epochs': 15, 'Dropout': 0.1, 'batch_size': 6...
#
#                                                  name      tags  train_loss  \
# 0   TFBS_NonTFBS_May_23th_2024_15_18_16_logstep=12...     CEBPA    0.008737
# 1   TFBS_NonTFBS_May_24th_2024_00_13_39_logstep=15...     CEBPB    0.006428
# 2   TFBS_NonTFBS_May_24th_2024_18_45_40_logstep=12...      CTCF    0.352588
# 3   TFBS_NonTFBS_May_29th_2024_17_51_42_logstep=15...      EGR2    0.003934
# 4   TFBS_NonTFBS_May_25th_2024_06_21_28_logstep=12...       FOS    0.010088
# 5   TFBS_NonTFBS_May_26th_2024_21_20_26_logstep=12...     H2AFZ    0.534687
# 6   TFBS_NonTFBS_May_27th_2024_20_33_10_logstep=12...   H2AK5ac    0.329701
# 7   TFBS_NonTFBS_May_28th_2024_16_03_05_logstep=12...  H2BK12ac    0.391510
# 8   TFBS_NonTFBS_May_30th_2024_09_30_41_logstep=12...   H2BK5ac    0.456696
# 9   TFBS_NonTFBS_May_31th_2024_09_33_20_logstep=12...     H3F3A    0.612258
# 10  TFBS_NonTFBS_June_01th_2024_09_46_03_logstep=1...   H3K14ac    0.373052
# 11  TFBS_NonTFBS_June_02th_2024_06_47_26_logstep=1...   H3K27ac    0.588260
# 12  TFBS_NonTFBS_June_03th_2024_08_27_04_logstep=1...  H3K27me3    0.577114
# 13  TFBS_NonTFBS_June_05th_2024_12_54_52_logstep=1...  H3K36me3    0.606918
# 14  TFBS_NonTFBS_May_31th_2024_21_26_53_logstep=15...   H3K4me2    0.573895
# 15  TFBS_NonTFBS_May_27th_2024_17_39_09_logstep=15...  H3K79me1    0.427213
# 16  TFBS_NonTFBS_June_05th_2024_01_22_08_logstep=1...  H3K79me2    0.613519
# 17  TFBS_NonTFBS_May_28th_2024_07_37_18_logstep=21...    H3K9ac    0.552593
# 18  TFBS_NonTFBS_June_02th_2024_09_15_45_logstep=2...   H3K9me1    0.293759
# 19  TFBS_NonTFBS_June_04th_2024_09_10_00_logstep=2...   H3K9me3    0.520060
# 20  TFBS_NonTFBS_May_28th_2024_03_51_12_logstep=21...    H4K8ac    0.373610
# 21  TFBS_NonTFBS_May_29th_2024_05_43_09_logstep=21...     IKZF1    0.037250
# 22  TFBS_NonTFBS_June_04th_2024_01_10_50_logstep=1...      NFE2    0.004650
# 23  TFBS_NonTFBS_June_02th_2024_20_21_52_logstep=2...     RAD21    0.019260
# 24  TFBS_NonTFBS_May_23th_2024_22_49_54_logstep=15...     RUNX3    0.009189
# 25  TFBS_NonTFBS_May_27th_2024_20_34_30_logstep=15...    TRIM22    0.021520
# 26  TFBS_NonTFBS_June_02th_2024_19_11_41_logstep=1...    ZBTB33    0.224846
# 27  TFBS_NonTFBS_May_23th_2024_16_00_45_logstep=21...     ZFHX2    0.005909
# 28  TFBS_NonTFBS_May_29th_2024_07_24_15_logstep=15...    ZNF121    0.011563
# 29  TFBS_NonTFBS_June_05th_2024_09_09_13_logstep=1...    ZNF143    0.011386
# 30  TFBS_NonTFBS_June_01th_2024_06_10_19_logstep=2...    ZNF366    0.013803
#
#     eval_precision  eval_Validation loss    _step      _runtime  eval_mcc  \
# 0         0.921079              0.449242   1210.0   2570.453699  0.841326
# 1         0.917596              0.644254  15930.0  14336.096091  0.834459
# 2         0.818927              0.431534   1210.0   2258.373427  0.636641
# 3         0.957355              0.321884  15930.0  14154.192645  0.914148
# 4         0.914536              0.478346   1210.0   2260.462936  0.829075
# 5         0.715204              0.558386   1210.0   2253.556387  0.430295
# 6         0.849114              0.354976   1210.0   2258.157024  0.697268
# 7         0.821331              0.409370   1210.0   2253.843985  0.642041
# 8         0.783676              0.477877   1210.0   5748.704899  0.567118
# 9         0.638490              0.626708   1210.0   2256.423315  0.276894
# 10        0.821002              0.391538   1210.0   2306.241226  0.641477
# 11        0.675038              0.598102   1210.0   2295.949471  0.349624
# 12        0.687373              0.581065   1210.0   2990.141407  0.374298
# 13        0.647786              0.616810   1210.0   2271.836351  0.293651
# 14        0.674728              0.601461  15930.0  11128.471020  0.349464
# 15        0.771687              0.491079  15930.0  11137.070772  0.542020
# 16        0.628471              0.639483  15930.0  11114.075613  0.255228
# 17        0.709500              0.556632  21240.0  13152.902779  0.418105
# 18        0.854651              0.354348  21240.0  13126.245556  0.708895
# 19        0.637735              0.708299  21240.0  13162.063925  0.275469
# 20        0.820088              0.415390  21240.0  13192.746089  0.640123
# 21        0.824918              0.976665  21240.0  13169.007059  0.649484
# 22        0.942206              0.434656  15930.0  14233.020961  0.884409
# 23        0.863029              0.916762  21240.0  13185.086129  0.726033
# 24        0.915423              0.574536  15930.0  11047.748491  0.830895
# 25        0.878079              0.839814  15930.0  11116.180341  0.755700
# 26        0.867836              0.352302  15930.0  11043.519444  0.735658
# 27        0.947619              0.403763  21240.0  13256.623403  0.895039
# 28        0.936368              0.458477  15730.0   9830.167193  0.872733
# 29        0.898855              0.693737  15930.0  11084.959015  0.797394
# 30        0.877331              0.859174  20070.0  12504.718454  0.752723
#
#       _timestamp  ...  eval_acc  eval_auc  \
# 0   1.716494e+09  ...  0.919933  0.971719
# 1   1.716538e+09  ...  0.916867       NaN
# 2   1.716593e+09  ...  0.817600  0.891568
# 3   1.717034e+09  ...  0.956800       NaN
# 4   1.716635e+09  ...  0.914533  0.967287
# 5   1.716775e+09  ...  0.715067  0.788969
# 6   1.716859e+09  ...  0.847467  0.917015
# 7   1.716929e+09  ...  0.820533  0.893559
# 8   1.717082e+09  ...  0.783400  0.856095
# 9   1.717165e+09  ...  0.638467  0.696395
# 10  1.717252e+09  ...  0.820600  0.903441
# 11  1.717328e+09  ...  0.674600  0.735749
# 12  1.717421e+09  ...  0.687067  0.756084
# 13  1.717609e+09  ...  0.646200  0.709212
# 14  1.717216e+09  ...  0.674733       NaN
# 15  1.716857e+09  ...  0.770733       NaN
# 16  1.717576e+09  ...  0.625933       NaN
# 17  1.716909e+09  ...  0.708667       NaN
# 18  1.717347e+09  ...  0.854267       NaN
# 19  1.717520e+09  ...  0.637733       NaN
# 20  1.716896e+09  ...  0.820000       NaN
# 21  1.716989e+09  ...  0.824400       NaN
# 22  1.717492e+09  ...  0.942200       NaN
# 23  1.717387e+09  ...  0.863000       NaN
# 24  1.716530e+09  ...  0.915267       NaN
# 25  1.716868e+09  ...  0.877667       NaN
# 26  1.717381e+09  ...  0.867800       NaN
# 27  1.716508e+09  ...  0.947333       NaN
# 28  1.716992e+09  ...  0.936398       NaN
# 29  1.717604e+09  ...  0.898400       NaN
# 30  1.717249e+09  ...  0.876905       NaN
#
#                                 Confusion Matrix.path  Confusion Matrix.size  \
# 0   media/images/Confusion Matrix_1089_df9d1926090...                58399.0
# 1   media/images/Confusion Matrix_14337_666c48561c...                55775.0
# 2   media/images/Confusion Matrix_1089_2bd8a632194...                55737.0
# 3   media/images/Confusion Matrix_14337_323246492d...                55531.0
# 4   media/images/Confusion Matrix_1089_7fe13c815e4...                57062.0
# 5   media/images/Confusion Matrix_1089_71ee44a3767...                56301.0
# 6   media/images/Confusion Matrix_1089_a12145b661e...                57890.0
# 7   media/images/Confusion Matrix_1089_6f49a1ca92a...                55287.0
# 8   media/images/Confusion Matrix_1089_829b457bd29...                59924.0
# 9   media/images/Confusion Matrix_1089_7d836b9e8b2...                55122.0
# 10  media/images/Confusion Matrix_1089_46d833cefd0...                55902.0
# 11  media/images/Confusion Matrix_1089_f23f2532c8f...                57182.0
# 12  media/images/Confusion Matrix_1089_7dc9dda3353...                57585.0
# 13  media/images/Confusion Matrix_1089_0bda59e1b0a...                57289.0
# 14  media/images/Confusion Matrix_14337_e1f16ab5f8...                54943.0
# 15  media/images/Confusion Matrix_14337_06808379c3...                54050.0
# 16  media/images/Confusion Matrix_14337_a6136f3284...                55195.0
# 17  media/images/Confusion Matrix_19116_520d23ee27...                57916.0
# 18  media/images/Confusion Matrix_19116_826437ebf3...                54503.0
# 19  media/images/Confusion Matrix_19116_2f7efcb2fa...                59118.0
# 20  media/images/Confusion Matrix_19116_59744b1a41...                53790.0
# 21  media/images/Confusion Matrix_19116_024568e18b...                54860.0
# 22  media/images/Confusion Matrix_14337_5480286b06...                56197.0
# 23  media/images/Confusion Matrix_19116_1a3497d608...                56488.0
# 24  media/images/Confusion Matrix_14337_ea1aeb6408...                55424.0
# 25  media/images/Confusion Matrix_14337_cf4ef060a1...                55529.0
# 26  media/images/Confusion Matrix_14337_bee908af82...                55731.0
# 27  media/images/Confusion Matrix_19116_f5a5fd7540...                56187.0
# 28  media/images/Confusion Matrix_14157_ef30ffe68c...                55446.0
# 29  media/images/Confusion Matrix_14337_420da4d648...                56187.0
# 30  media/images/Confusion Matrix_18063_2cc067fa80...                55667.0
#
#     Confusion Matrix._type Confusion Matrix.width  Confusion Matrix.format  \
# 0               image-file                 1200.0                      png
# 1               image-file                 1200.0                      png
# 2               image-file                 1200.0                      png
# 3               image-file                 1200.0                      png
# 4               image-file                 1200.0                      png
# 5               image-file                 1200.0                      png
# 6               image-file                 1200.0                      png
# 7               image-file                 1200.0                      png
# 8               image-file                 1200.0                      png
# 9               image-file                 1200.0                      png
# 10              image-file                 1200.0                      png
# 11              image-file                 1200.0                      png
# 12              image-file                 1200.0                      png
# 13              image-file                 1200.0                      png
# 14              image-file                 1200.0                      png
# 15              image-file                 1200.0                      png
# 16              image-file                 1200.0                      png
# 17              image-file                 1200.0                      png
# 18              image-file                 1200.0                      png
# 19              image-file                 1200.0                      png
# 20              image-file                 1200.0                      png
# 21              image-file                 1200.0                      png
# 22              image-file                 1200.0                      png
# 23              image-file                 1200.0                      png
# 24              image-file                 1200.0                      png
# 25              image-file                 1200.0                      png
# 26              image-file                 1200.0                      png
# 27              image-file                 1200.0                      png
# 28              image-file                 1200.0                      png
# 29              image-file                 1200.0                      png
# 30              image-file                 1200.0                      png
#
#    Confusion Matrix.height                            Confusion Matrix.sha256  \
# 0                   1200.0  df9d19260906878f257e28ae35dc418f57d5c808230699...
# 1                   1200.0  666c48561c8add0cc86e4b7a20d8d7540d7fe207fb8b54...
# 2                   1200.0  2bd8a6321949b95609b06ccf683718b02d70ffd08ebc9d...
# 3                   1200.0  323246492de768ce518270c7e3dddfe6ff1aa29bf35441...
# 4                   1200.0  7fe13c815e46b28953e37ea7141e4f192bc63ae6174076...
# 5                   1200.0  71ee44a376744cfef29b53679c34e7d96713c4733b1a28...
# 6                   1200.0  a12145b661e67115163861a58bf769050626f4236683b3...
# 7                   1200.0  6f49a1ca92ab7c374b1d74e06c80b67899e1c73f8eba8f...
# 8                   1200.0  829b457bd294de6a7e6b96b7c4d74c951be8a032750c8a...
# 9                   1200.0  7d836b9e8b220ddf93a1eeac62d2b7511bee3fddd80ce8...
# 10                  1200.0  46d833cefd0680d02b5679bd6abd705d55d3c97b3af932...
# 11                  1200.0  f23f2532c8f291485e7c60b4a3a9c2580563c547a0a63c...
# 12                  1200.0  7dc9dda33534487e0eba8e17a1b853738b711a2414a384...
# 13                  1200.0  0bda59e1b0a4b4a03fbc4f846b74b9618160b696d07627...
# 14                  1200.0  e1f16ab5f81c92d0895fe57c1b7cc487abd65da5273d58...
# 15                  1200.0  06808379c3007304b8fd75b0654bbd6c5b6b6fc7ad8a6c...
# 16                  1200.0  a6136f3284861fef7f98144a4e30681236d235a1d95ea5...
# 17                  1200.0  520d23ee27e0ba7e7588192644a1393f47a8eb8e150af5...
# 18                  1200.0  826437ebf334f977bb78bb144e918a8eb37bb1a9abde5c...
# 19                  1200.0  2f7efcb2fab993dcad72d8db05ca198ac76045d60cf245...
# 20                  1200.0  59744b1a416bea7dcaadd375fac6dd3451b52f946ee91f...
# 21                  1200.0  024568e18b243dfaca6c7f8949d3294cdad45f810b3766...
# 22                  1200.0  5480286b06edfd0147bbcd7cd43ea5fda48fa02ef503b4...
# 23                  1200.0  1a3497d608496128a45bdceceb0087dfdc245235b0c708...
# 24                  1200.0  ea1aeb64087cc6ff075fbbff44cfa7d9fd1c92da96dfc9...
# 25                  1200.0  cf4ef060a1acb9f183a91b206b45810e2b2a8d61db5046...
# 26                  1200.0  bee908af8231f5d28410c1cb9ab0898563fdc4f6672736...
# 27                  1200.0  f5a5fd75400ae1315e71a86be33f82ecd6fd806660ef17...
# 28                  1200.0  ef30ffe68cd06d4c74a6d5b2a445da17d7c77f54ea4363...
# 29                  1200.0  420da4d6489a6db8d28d33472f1e3fee2a9206c2593f15...
# 30                  1200.0  2cc067fa8004b063f3b7b33bc58e9f2738f122ac1c7dfa...
#
#    _wandb.runtime
# 0          2620.0
# 1         14435.0
# 2          2308.0
# 3         14254.0
# 4          2310.0
# 5          2303.0
# 6          2308.0
# 7          2303.0
# 8          5898.0
# 9          2306.0
# 10         2357.0
# 11         2347.0
# 12         3115.0
# 13         2321.0
# 14        11223.0
# 15        11227.0
# 16        11207.0
# 17        13248.0
# 18        13228.0
# 19        13260.0
# 20        13288.0
# 21        13268.0
# 22        14336.0
# 23        13282.0
# 24        11139.0
# 25        11211.0
# 26        11133.0
# 27        13350.0
# 28         9908.0
# 29        11178.0
# 30        12594.0
#
# [31 rows x 23 columns]

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False).to_csv("300BP_TFBS_Models_stat.tsv", sep="\t")

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False)[['tags','eval_acc']]
# Out:
#         tags  eval_acc
# 3       EGR2  0.956800
# 27     ZFHX2  0.947333
# 22      NFE2  0.942200
# 28    ZNF121  0.936398
# 0      CEBPA  0.919933
# 1      CEBPB  0.916867
# 24     RUNX3  0.915267
# 4        FOS  0.914533
# 29    ZNF143  0.898400
# 25    TRIM22  0.877667
# 30    ZNF366  0.876905
# 26    ZBTB33  0.867800
# 23     RAD21  0.863000
# 18   H3K9me1  0.854267
# 6    H2AK5ac  0.847467
# 21     IKZF1  0.824400
# 10   H3K14ac  0.820600
# 7   H2BK12ac  0.820533
# 20    H4K8ac  0.820000
# 2       CTCF  0.817600
# 8    H2BK5ac  0.783400
# 15  H3K79me1  0.770733
# 5      H2AFZ  0.715067
# 17    H3K9ac  0.708667
# 12  H3K27me3  0.687067
# 14   H3K4me2  0.674733
# 11   H3K27ac  0.674600
# 13  H3K36me3  0.646200
# 9      H3F3A  0.638467
# 19   H3K9me3  0.637733
# 16  H3K79me2  0.625933

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False)[['tags','eval_acc']].to_csv("300bp_TFBS_accuracy_Stat.tsv", sep="\t")

# %%
best_acc_df[best_acc_df['eval_acc']>=0.85][['tags', 'config', 'eval_acc']].sort_values(by="eval_acc", ascending=False).to_csv("top_300BP_TFBS_models.tsv", sep="\t", index=False)
