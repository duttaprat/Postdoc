# %%
import pandas as pd
import wandb

# %%
api = wandb.Api()
entity, project = "pratik24111991", "TFBS_Finetuned_Models_Work"
runs = api.runs(entity + "/" + project)

# %%
summary_list, config_list, name_list, tag_list = [], [], [], []
for run in runs:
    # .summary contains output keys/values for
    # metrics such as accuracy.
    #  We call ._json_dict to omit large files
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append({k: v for k, v in run.config.items() if not k.startswith("_")})

    # .name is the human-readable name of the run.
    name_list.append(run.name)
    tag_list.append(run.tags)

runs_df = pd.DataFrame(
    {"summary": summary_list, "config": config_list, "name": name_list, "tags":tag_list}
)

# %%
runs_df
# Out:
#                                                 summary  \
# 0     {'_step': 2151, 'eval_f1': 0.33346292593170573...
# 1     {'_runtime': 41269.81987476349, '_timestamp': ...
# 2     {'eval_acc': 0.5002916400379234, 'eval_auc': 0...
# 3     {'eval_Validation loss': 0.6931685654233757, '...
# 4     {'_wandb': {'runtime': 72}, '_runtime': 68.505...
# ...                                                 ...
# 5346  {'eval_f1': 0.33504827683416727, '_timestamp':...
# 5347  {'_wandb': {'runtime': 693}, '_timestamp': 170...
# 5348  {'_step': 324, 'train_loss': 0.242748406336263...
# 5349  {'_step': 324, 'eval_recall': 0.88727966698592...
# 5350  {'_step': 327, 'eval_mcc': 0.7666059955114591,...
#
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# ...                                                 ...
# 5346  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5347  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5348  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5349  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5350  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name  \
# 0     TFBS_NonTFBS_April_10th_2024_21_32_52_logstep=...
# 1     TFBS_NonTFBS_April_10th_2024_08_31_51_logstep=...
# 2     TFBS_NonTFBS_April_09th_2024_20_13_20_logstep=...
# 3     TFBS_NonTFBS_April_09th_2024_07_06_31_logstep=...
# 4     TFBS_NonTFBS_April_09th_2024_07_05_07_logstep=...
# ...                                                 ...
# 5346  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...
# 5347  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...
# 5348  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...
# 5349  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...
# 5350  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...
#
#                              tags
# 0      [H2AFZ, TFBS_NonTFBS, e-3]
# 1      [H2AFZ, TFBS_NonTFBS, e-3]
# 2      [H2AFZ, TFBS_NonTFBS, e-3]
# 3      [H2AFZ, TFBS_NonTFBS, e-3]
# 4     [TFBS_NonTFBS, ZNF830, e-3]
# ...                           ...
# 5346   [SAP30, TFBS_NonTFBS, e-3]
# 5347   [SAP30, TFBS_NonTFBS, e-6]
# 5348   [SAP30, TFBS_NonTFBS, e-5]
# 5349   [SAP30, TFBS_NonTFBS, e-4]
# 5350   [SAP30, TFBS_NonTFBS, e-3]
#
# [5351 rows x 4 columns]

# %%
# Define a function to filter tags
def filter_tags(tags):
    return [tag for tag in tags if '-' not in tag and 'TFBS' not in tag]

# %%
runs_df['tags'] = runs_df['tags'].apply(filter_tags)

# %%
runs_df
# Out:
#                                                 summary  \
# 0     {'_step': 2151, 'eval_f1': 0.33346292593170573...
# 1     {'_runtime': 41269.81987476349, '_timestamp': ...
# 2     {'eval_acc': 0.5002916400379234, 'eval_auc': 0...
# 3     {'eval_Validation loss': 0.6931685654233757, '...
# 4     {'_wandb': {'runtime': 72}, '_runtime': 68.505...
# ...                                                 ...
# 5346  {'eval_f1': 0.33504827683416727, '_timestamp':...
# 5347  {'_wandb': {'runtime': 693}, '_timestamp': 170...
# 5348  {'_step': 324, 'train_loss': 0.242748406336263...
# 5349  {'_step': 324, 'eval_recall': 0.88727966698592...
# 5350  {'_step': 327, 'eval_mcc': 0.7666059955114591,...
#
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# ...                                                 ...
# 5346  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5347  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5348  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5349  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5350  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name      tags
# 0     TFBS_NonTFBS_April_10th_2024_21_32_52_logstep=...   [H2AFZ]
# 1     TFBS_NonTFBS_April_10th_2024_08_31_51_logstep=...   [H2AFZ]
# 2     TFBS_NonTFBS_April_09th_2024_20_13_20_logstep=...   [H2AFZ]
# 3     TFBS_NonTFBS_April_09th_2024_07_06_31_logstep=...   [H2AFZ]
# 4     TFBS_NonTFBS_April_09th_2024_07_05_07_logstep=...  [ZNF830]
# ...                                                 ...       ...
# 5346  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...   [SAP30]
# 5347  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...   [SAP30]
# 5348  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...   [SAP30]
# 5349  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...   [SAP30]
# 5350  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...   [SAP30]
#
# [5351 rows x 4 columns]

# %%
# Normalize the summary column to create a DataFrame of summaries
summaries_df = pd.json_normalize(runs_df['summary'])

# Concatenate the new summary columns with the original DataFrame (minus the old 'summary' column)
expanded_runs_df = pd.concat([runs_df.drop('summary', axis=1), summaries_df], axis=1)
# Assuming expanded_runs_df is your DataFrame
expanded_runs_df['tags'] = expanded_runs_df['tags'].apply(lambda x: x[0] if x else None)

# %%
expanded_runs_df
# Out:
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# ...                                                 ...
# 5346  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5347  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5348  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5349  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 5350  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name    tags    _step  \
# 0     TFBS_NonTFBS_April_10th_2024_21_32_52_logstep=...   H2AFZ   2151.0
# 1     TFBS_NonTFBS_April_10th_2024_08_31_51_logstep=...   H2AFZ  12906.0
# 2     TFBS_NonTFBS_April_09th_2024_20_13_20_logstep=...   H2AFZ  12906.0
# 3     TFBS_NonTFBS_April_09th_2024_07_06_31_logstep=...   H2AFZ  12906.0
# 4     TFBS_NonTFBS_April_09th_2024_07_05_07_logstep=...  ZNF830     20.0
# ...                                                 ...     ...      ...
# 5346  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...   SAP30    327.0
# 5347  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...   SAP30    324.0
# 5348  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...   SAP30    324.0
# 5349  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...   SAP30    324.0
# 5350  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...   SAP30    327.0
#
#        eval_f1      _runtime  eval_acc  train_loss  eval_precision  eval_auc  \
# 0     0.333463   8522.936523  0.500292    0.633849        0.250146  0.500162
# 1     0.333463  41269.819875  0.500292    0.693174        0.250146  0.499568
# 2     0.333463  41078.283773  0.500292    0.693245        0.250146  0.499269
# 3     0.333463  41565.112284  0.500292    0.693176        0.250146  0.500000
# 4     0.338577     68.505405  0.511892    1.507313        0.255946  0.541137
# ...        ...           ...       ...         ...             ...       ...
# 5346  0.335048    606.565690  0.503869    0.697234        0.251934  0.505400
# 5347  0.797994    603.007237  0.798092    0.547333        0.799096  0.879813
# 5348  0.899477    608.870517  0.899523    0.242748        0.899874  0.962615
# 5349  0.887354    604.127964  0.887546    0.171405        0.889443  0.951327
# 5350  0.883302    602.462654  0.883307    0.095667        0.883297  0.935315
#
#       ...  learning_rate  eval_Validation loss  Confusion Matrix.size  \
# 0     ...   2.833682e-03              0.693147                54721.0
# 1     ...   1.118080e-04              0.693166                54721.0
# 2     ...   3.354239e-04              0.693165                54721.0
# 3     ...   1.118080e-04              0.693169                54721.0
# 4     ...   0.000000e+00              1.382536                49393.0
# ...   ...            ...                   ...                    ...
# 5346  ...   3.873874e-04              0.693131                49619.0
# 5347  ...   1.381381e-07              0.537199                57947.0
# 5348  ...   1.381381e-06              0.245715                59356.0
# 5349  ...   1.381381e-05              0.341513                58933.0
# 5350  ...   1.291291e-04              0.485489                56420.0
#
#       Confusion Matrix._type  Confusion Matrix.width  Confusion Matrix.format  \
# 0                 image-file                  1200.0                      png
# 1                 image-file                  1200.0                      png
# 2                 image-file                  1200.0                      png
# 3                 image-file                  1200.0                      png
# 4                 image-file                  1200.0                      png
# ...                      ...                     ...                      ...
# 5346              image-file                  1200.0                      png
# 5347              image-file                  1200.0                      png
# 5348              image-file                  1200.0                      png
# 5349              image-file                  1200.0                      png
# 5350              image-file                  1200.0                      png
#
#      Confusion Matrix.height  \
# 0                     1200.0
# 1                     1200.0
# 2                     1200.0
# 3                     1200.0
# 4                     1200.0
# ...                      ...
# 5346                  1200.0
# 5347                  1200.0
# 5348                  1200.0
# 5349                  1200.0
# 5350                  1200.0
#
#                                 Confusion Matrix.sha256  \
# 0     736401ff65e7992b9d14637f01dd77c572e67e0f28a9ca...
# 1     736401ff65e7992b9d14637f01dd77c572e67e0f28a9ca...
# 2     736401ff65e7992b9d14637f01dd77c572e67e0f28a9ca...
# 3     736401ff65e7992b9d14637f01dd77c572e67e0f28a9ca...
# 4     af24858423cc896b0236c1ba6394a82524545e7a9f73d6...
# ...                                                 ...
# 5346  8bb7708fa5de7feeb1d06e439d1d08483f9f17af9479c6...
# 5347  5a78816cab0e1fa1c6a6f02ac5e67d8fb0dd137cfec7c4...
# 5348  265f5743eafafb5593d85b3f5b25a8bde9f25d156c0678...
# 5349  7375fb8417576ec4fc3d46996dd222308076be3b318ac5...
# 5350  9c25be08f0448a8369b8ab35a1cfd22c3a92ae50e8f279...
#
#                                   Confusion Matrix.path  _wandb.runtime
# 0     media/images/Confusion Matrix_0_736401ff65e799...             NaN
# 1     media/images/Confusion Matrix_10755_736401ff65...         46848.0
# 2     media/images/Confusion Matrix_10755_736401ff65...         44296.0
# 3     media/images/Confusion Matrix_10755_736401ff65...         47193.0
# 4     media/images/Confusion Matrix_19_af24858423cc8...            72.0
# ...                                                 ...             ...
# 5346  media/images/Confusion Matrix_218_8bb7708fa5de...           692.0
# 5347  media/images/Confusion Matrix_216_5a78816cab0e...           693.0
# 5348  media/images/Confusion Matrix_216_265f5743eafa...           700.0
# 5349  media/images/Confusion Matrix_216_7375fb841757...           696.0
# 5350  media/images/Confusion Matrix_218_9c25be08f044...           689.0
#
# [5351 rows x 23 columns]

# %%
# Remove rows with any NaN values and keep the original index
expanded_runs_df = expanded_runs_df.dropna().reset_index()
expanded_runs_df
# Out:
#       index                                             config  \
# 0         1  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 1         2  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 2         3  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 3         4  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 4         5  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# ...     ...                                                ...
# 4901   5346  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4902   5347  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4903   5348  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4904   5349  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4905   5350  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name    tags    _step  \
# 0     TFBS_NonTFBS_April_10th_2024_08_31_51_logstep=...   H2AFZ  12906.0
# 1     TFBS_NonTFBS_April_09th_2024_20_13_20_logstep=...   H2AFZ  12906.0
# 2     TFBS_NonTFBS_April_09th_2024_07_06_31_logstep=...   H2AFZ  12906.0
# 3     TFBS_NonTFBS_April_09th_2024_07_05_07_logstep=...  ZNF830     20.0
# 4     TFBS_NonTFBS_April_09th_2024_07_03_43_logstep=...  ZNF830     20.0
# ...                                                 ...     ...      ...
# 4901  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...   SAP30    327.0
# 4902  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...   SAP30    324.0
# 4903  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...   SAP30    324.0
# 4904  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...   SAP30    324.0
# 4905  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...   SAP30    327.0
#
#        eval_f1      _runtime  eval_acc  train_loss  eval_precision  ...  \
# 0     0.333463  41269.819875  0.500292    0.693174        0.250146  ...
# 1     0.333463  41078.283773  0.500292    0.693245        0.250146  ...
# 2     0.333463  41565.112284  0.500292    0.693176        0.250146  ...
# 3     0.338577     68.505405  0.511892    1.507313        0.255946  ...
# 4     0.338577     68.498296  0.511892    0.697799        0.255946  ...
# ...        ...           ...       ...         ...             ...  ...
# 4901  0.335048    606.565690  0.503869    0.697234        0.251934  ...
# 4902  0.797994    603.007237  0.798092    0.547333        0.799096  ...
# 4903  0.899477    608.870517  0.899523    0.242748        0.899874  ...
# 4904  0.887354    604.127964  0.887546    0.171405        0.889443  ...
# 4905  0.883302    602.462654  0.883307    0.095667        0.883297  ...
#
#       learning_rate  eval_Validation loss  Confusion Matrix.size  \
# 0      1.118080e-04              0.693166                54721.0
# 1      3.354239e-04              0.693165                54721.0
# 2      1.118080e-04              0.693169                54721.0
# 3      0.000000e+00              1.382536                49393.0
# 4      0.000000e+00              0.693117                49393.0
# ...             ...                   ...                    ...
# 4901   3.873874e-04              0.693131                49619.0
# 4902   1.381381e-07              0.537199                57947.0
# 4903   1.381381e-06              0.245715                59356.0
# 4904   1.381381e-05              0.341513                58933.0
# 4905   1.291291e-04              0.485489                56420.0
#
#       Confusion Matrix._type  Confusion Matrix.width  Confusion Matrix.format  \
# 0                 image-file                  1200.0                      png
# 1                 image-file                  1200.0                      png
# 2                 image-file                  1200.0                      png
# 3                 image-file                  1200.0                      png
# 4                 image-file                  1200.0                      png
# ...                      ...                     ...                      ...
# 4901              image-file                  1200.0                      png
# 4902              image-file                  1200.0                      png
# 4903              image-file                  1200.0                      png
# 4904              image-file                  1200.0                      png
# 4905              image-file                  1200.0                      png
#
#       Confusion Matrix.height  \
# 0                      1200.0
# 1                      1200.0
# 2                      1200.0
# 3                      1200.0
# 4                      1200.0
# ...                       ...
# 4901                   1200.0
# 4902                   1200.0
# 4903                   1200.0
# 4904                   1200.0
# 4905                   1200.0
#
#                                 Confusion Matrix.sha256  \
# 0     736401ff65e7992b9d14637f01dd77c572e67e0f28a9ca...
# 1     736401ff65e7992b9d14637f01dd77c572e67e0f28a9ca...
# 2     736401ff65e7992b9d14637f01dd77c572e67e0f28a9ca...
# 3     af24858423cc896b0236c1ba6394a82524545e7a9f73d6...
# 4     af24858423cc896b0236c1ba6394a82524545e7a9f73d6...
# ...                                                 ...
# 4901  8bb7708fa5de7feeb1d06e439d1d08483f9f17af9479c6...
# 4902  5a78816cab0e1fa1c6a6f02ac5e67d8fb0dd137cfec7c4...
# 4903  265f5743eafafb5593d85b3f5b25a8bde9f25d156c0678...
# 4904  7375fb8417576ec4fc3d46996dd222308076be3b318ac5...
# 4905  9c25be08f0448a8369b8ab35a1cfd22c3a92ae50e8f279...
#
#                                   Confusion Matrix.path _wandb.runtime
# 0     media/images/Confusion Matrix_10755_736401ff65...        46848.0
# 1     media/images/Confusion Matrix_10755_736401ff65...        44296.0
# 2     media/images/Confusion Matrix_10755_736401ff65...        47193.0
# 3     media/images/Confusion Matrix_19_af24858423cc8...           72.0
# 4     media/images/Confusion Matrix_19_af24858423cc8...           72.0
# ...                                                 ...            ...
# 4901  media/images/Confusion Matrix_218_8bb7708fa5de...          692.0
# 4902  media/images/Confusion Matrix_216_5a78816cab0e...          693.0
# 4903  media/images/Confusion Matrix_216_265f5743eafa...          700.0
# 4904  media/images/Confusion Matrix_216_7375fb841757...          696.0
# 4905  media/images/Confusion Matrix_218_9c25be08f044...          689.0
#
# [4906 rows x 24 columns]

# %%
# Group by 'tags' and find the index of the max 'eval_acc' for each group
idx = expanded_runs_df.groupby('tags')['eval_acc'].idxmax()

# Use the indices to select rows from the original DataFrame
best_acc_df = expanded_runs_df.loc[idx].reset_index(drop=True)
best_acc_df
# Out:
#      index                                             config  \
# 0     1290  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 1     1510  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 2      166  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 3     3110  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     2474  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ..     ...                                                ...
# 419   1554  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 420   1496  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 421   1862  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 4...
# 422   4684  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 423   3635  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                   name      tags  _step  \
# 0    TFBS_NonTFBS_April_02th_2024_01_59_24_logstep=...      ADNP   84.0
# 1    TFBS_NonTFBS_April_01th_2024_00_56_04_logstep=...      AFF1  112.0
# 2    TFBS_NonTFBS_April_08th_2024_09_51_03_logstep=...      AGO1   91.0
# 3    TFBS_NonTFBS_March_11th_2024_07_48_56_logstep=...      AGO2  633.0
# 4    TFBS_NonTFBS_March_22th_2024_03_02_22_logstep=...  ARHGAP35   66.0
# ..                                                 ...       ...    ...
# 419  TFBS_NonTFBS_March_29th_2024_22_13_39_logstep=...    ZSCAN4  105.0
# 420  TFBS_NonTFBS_April_01th_2024_01_31_02_logstep=...   ZSCAN5A   40.0
# 421  TFBS_NonTFBS_March_28th_2024_00_35_12_logstep=...   ZSCAN5C   80.0
# 422  TFBS_NonTFBS_March_01th_2024_02_09_02_logstep=...    ZSCAN9  282.0
# 423  TFBS_NonTFBS_March_09th_2024_01_32_17_logstep=...      ZXDB  513.0
#
#       eval_f1     _runtime  eval_acc  train_loss  eval_precision  ...  \
# 0    0.697605   195.097749  0.697791    0.491164        0.698848  ...
# 1    0.771229   252.408261  0.771503    0.412298        0.772159  ...
# 2    0.934558   214.870189  0.934578    0.173443        0.934964  ...
# 3    0.895784  1204.465479  0.895999    0.264199        0.898803  ...
# 4    0.821313   125.135130  0.821501    0.333016        0.823799  ...
# ..        ...          ...       ...         ...             ...  ...
# 419  0.872177   241.394078  0.872801    0.235353        0.879305  ...
# 420  0.868224    94.731095  0.868922    0.300181        0.874865  ...
# 421  0.781919   187.623710  0.781928    0.422188        0.782058  ...
# 422  0.812409   525.080328  0.812469    0.307224        0.812749  ...
# 423  0.813028   951.873121  0.813143    0.271421        0.813921  ...
#
#      learning_rate  eval_Validation loss  Confusion Matrix.size  \
# 0         0.000074              0.556304                59260.0
# 1         0.000074              0.489762                56987.0
# 2         0.000100              0.217270                54813.0
# 3         0.000004              0.298919                60413.0
# 4         0.000019              0.402552                57200.0
# ..             ...                   ...                    ...
# 419       0.000051              0.378305                55101.0
# 420       0.000000              0.311428                58513.0
# 421       0.000000              0.471170                55333.0
# 422       0.000132              0.483263                54036.0
# 423       0.000128              0.535345                56804.0
#
#      Confusion Matrix._type  Confusion Matrix.width  Confusion Matrix.format  \
# 0                image-file                  1200.0                      png
# 1                image-file                  1200.0                      png
# 2                image-file                  1200.0                      png
# 3                image-file                  1200.0                      png
# 4                image-file                  1200.0                      png
# ..                      ...                     ...                      ...
# 419              image-file                  1200.0                      png
# 420              image-file                  1200.0                      png
# 421              image-file                  1200.0                      png
# 422              image-file                  1200.0                      png
# 423              image-file                  1200.0                      png
#
#      Confusion Matrix.height  \
# 0                     1200.0
# 1                     1200.0
# 2                     1200.0
# 3                     1200.0
# 4                     1200.0
# ..                       ...
# 419                   1200.0
# 420                   1200.0
# 421                   1200.0
# 422                   1200.0
# 423                   1200.0
#
#                                Confusion Matrix.sha256  \
# 0    4cd68014477cf9a253946fb3a8e5731064dca356908b5e...
# 1    57538da06cb056c9ea737cee9856bb0904daea3344d1ba...
# 2    eb9f9661213cd7aa22f6c54b1df7910ca13684deb9f6da...
# 3    958cd42b536bc3994165310ae2cbd90fbd514c41e93d89...
# 4    05bda9ec50bc339493dca11b5d394511f04b407205e0ee...
# ..                                                 ...
# 419  8c84502b2c48ab7e127586b4b2de9ef4de9a25c6b57cda...
# 420  15e3928e27a81126a8756b7a2874f005f41fb2d662555a...
# 421  93e14e1228775373425ea1ed716add7bee037c49401919...
# 422  e5c3db86ea9e90d0c522f3bbd8795316ce7d735f6f33ba...
# 423  7bebe030ee27cf12dc17f4e6d3e64b82faa375bcb2e99b...
#
#                                  Confusion Matrix.path _wandb.runtime
# 0    media/images/Confusion Matrix_72_4cd68014477cf...          210.0
# 1    media/images/Confusion Matrix_96_57538da06cb05...          272.0
# 2    media/images/Confusion Matrix_78_eb9f9661213cd...          237.0
# 3    media/images/Confusion Matrix_422_958cd42b536b...         1362.0
# 4    media/images/Confusion Matrix_44_05bda9ec50bc3...          154.0
# ..                                                 ...            ...
# 419  media/images/Confusion Matrix_90_8c84502b2c48a...          255.0
# 420  media/images/Confusion Matrix_36_15e3928e27a81...           98.0
# 421  media/images/Confusion Matrix_70_93e14e1228775...          192.0
# 422  media/images/Confusion Matrix_188_e5c3db86ea9e...          601.0
# 423  media/images/Confusion Matrix_342_7bebe030ee27...         1083.0
#
# [424 rows x 24 columns]

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False).to_csv("All_TFBS_Models_stat.tsv", sep="\t")

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False)[['tags','eval_acc']]
# Out:
#         tags  eval_acc
# 218    RBM14  0.968908
# 231     SAFB  0.968090
# 266    TAF15  0.959936
# 255     SPI1  0.957358
# 291     USF1  0.951848
# ..       ...       ...
# 82     H2AFZ  0.500292
# 95   H3K9me3  0.499966
# 89   H3K27ac  0.499856
# 86     H3F3A  0.499651
# 416  ZSCAN26  0.495783
#
# [424 rows x 2 columns]

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False)[['tags','eval_acc']].to_csv("TFBS_accuracy_Stat.tsv", sep="\t")

# %%
best_acc_df[best_acc_df['eval_acc']>=0.85][['tags', 'config', 'eval_acc']].sort_values(by="eval_acc", ascending=False).to_csv("top_TFBS_models.tsv", sep="\t", index=False)
