# %%
import pandas as pd
import wandb

# %%
api = wandb.Api()
entity, project = "pratik24111991", "TFBS_Finetuned_Models_Work"
runs = api.runs(entity + "/" + project)

# %%
summary_list, config_list, name_list, tag_list = [], [], [], []
for run in runs:
    # .summary contains output keys/values for
    # metrics such as accuracy.
    #  We call ._json_dict to omit large files
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append({k: v for k, v in run.config.items() if not k.startswith("_")})

    # .name is the human-readable name of the run.
    name_list.append(run.name)
    tag_list.append(run.tags)

runs_df = pd.DataFrame(
    {"summary": summary_list, "config": config_list, "name": name_list, "tags":tag_list}
)

# %%
runs_df
# Out:
#                                                 summary  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'_wandb': {'runtime': 35114}, 'eval_f1': 0.76...
# ...                                                 ...
# 2355  {'eval_f1': 0.33504827683416727, 'eval_precisi...
# 2356  {'_step': 324, '_wandb': {'runtime': 693}, 'ev...
# 2357  {'_timestamp': 1709078760.263911, 'train_loss'...
# 2358  {'eval_mcc': 0.7767198869762932, 'eval_precisi...
# 2359  {'eval_Validation loss': 0.48548863530159, '_s...
#
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...                                                 ...
# 2355  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2356  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2357  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2358  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2359  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name  \
# 0     TFBS_NonTFBS_March_12th_2024_00_02_05_logstep=...
# 1     TFBS_NonTFBS_March_11th_2024_22_12_45_logstep=...
# 2     TFBS_NonTFBS_March_11th_2024_20_39_45_logstep=...
# 3     TFBS_NonTFBS_March_11th_2024_18_52_35_logstep=...
# 4     TFBS_NonTFBS_March_11th_2024_14_16_40_logstep=...
# ...                                                 ...
# 2355  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...
# 2356  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...
# 2357  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...
# 2358  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...
# 2359  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...
#
#                                tags
# 0     [H3K79me1, TFBS_NonTFBS, e-5]
# 1     [H3K79me1, TFBS_NonTFBS, e-4]
# 2     [H3K79me1, TFBS_NonTFBS, e-3]
# 3     [H3K79me1, TFBS_NonTFBS, e-6]
# 4     [H3K79me1, TFBS_NonTFBS, e-5]
# ...                             ...
# 2355     [SAP30, TFBS_NonTFBS, e-3]
# 2356     [SAP30, TFBS_NonTFBS, e-6]
# 2357     [SAP30, TFBS_NonTFBS, e-5]
# 2358     [SAP30, TFBS_NonTFBS, e-4]
# 2359     [SAP30, TFBS_NonTFBS, e-3]
#
# [2360 rows x 4 columns]

# %%
# Define a function to filter tags
def filter_tags(tags):
    return [tag for tag in tags if '-' not in tag and 'TFBS' not in tag]

# %%
runs_df['tags'] = runs_df['tags'].apply(filter_tags)

# %%
runs_df
# Out:
#                                                 summary  \
# 0                                                    {}
# 1                                                    {}
# 2                                                    {}
# 3                                                    {}
# 4     {'_wandb': {'runtime': 35114}, 'eval_f1': 0.76...
# ...                                                 ...
# 2355  {'eval_f1': 0.33504827683416727, 'eval_precisi...
# 2356  {'_step': 324, '_wandb': {'runtime': 693}, 'ev...
# 2357  {'_timestamp': 1709078760.263911, 'train_loss'...
# 2358  {'eval_mcc': 0.7767198869762932, 'eval_precisi...
# 2359  {'eval_Validation loss': 0.48548863530159, '_s...
#
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...                                                 ...
# 2355  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2356  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2357  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2358  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2359  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name        tags
# 0     TFBS_NonTFBS_March_12th_2024_00_02_05_logstep=...  [H3K79me1]
# 1     TFBS_NonTFBS_March_11th_2024_22_12_45_logstep=...  [H3K79me1]
# 2     TFBS_NonTFBS_March_11th_2024_20_39_45_logstep=...  [H3K79me1]
# 3     TFBS_NonTFBS_March_11th_2024_18_52_35_logstep=...  [H3K79me1]
# 4     TFBS_NonTFBS_March_11th_2024_14_16_40_logstep=...  [H3K79me1]
# ...                                                 ...         ...
# 2355  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...     [SAP30]
# 2356  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...     [SAP30]
# 2357  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...     [SAP30]
# 2358  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...     [SAP30]
# 2359  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...     [SAP30]
#
# [2360 rows x 4 columns]

# %%
# Normalize the summary column to create a DataFrame of summaries
summaries_df = pd.json_normalize(runs_df['summary'])

# Concatenate the new summary columns with the original DataFrame (minus the old 'summary' column)
expanded_runs_df = pd.concat([runs_df.drop('summary', axis=1), summaries_df], axis=1)
# Assuming expanded_runs_df is your DataFrame
expanded_runs_df['tags'] = expanded_runs_df['tags'].apply(lambda x: x[0] if x else None)

# %%
expanded_runs_df
# Out:
#                                                  config  \
# 0     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4     {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...                                                 ...
# 2355  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2356  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2357  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2358  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2359  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name      tags   eval_f1  \
# 0     TFBS_NonTFBS_March_12th_2024_00_02_05_logstep=...  H3K79me1       NaN
# 1     TFBS_NonTFBS_March_11th_2024_22_12_45_logstep=...  H3K79me1       NaN
# 2     TFBS_NonTFBS_March_11th_2024_20_39_45_logstep=...  H3K79me1       NaN
# 3     TFBS_NonTFBS_March_11th_2024_18_52_35_logstep=...  H3K79me1       NaN
# 4     TFBS_NonTFBS_March_11th_2024_14_16_40_logstep=...  H3K79me1  0.763926
# ...                                                 ...       ...       ...
# 2355  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...     SAP30  0.335048
# 2356  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...     SAP30  0.797994
# 2357  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...     SAP30  0.899477
# 2358  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...     SAP30  0.887354
# 2359  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...     SAP30  0.883302
#
#       eval_mcc  eval_recall  learning_rate    _step  eval_precision  eval_auc  \
# 0          NaN          NaN            NaN      NaN             NaN       NaN
# 1          NaN          NaN            NaN      NaN             NaN       NaN
# 2          NaN          NaN            NaN      NaN             NaN       NaN
# 3          NaN          NaN            NaN      NaN             NaN       NaN
# 4     0.532850     0.764757   1.114784e-06  16329.0        0.768103  0.834585
# ...        ...          ...            ...      ...             ...       ...
# 2355  0.000000     0.500000   3.873874e-04    327.0        0.251934  0.505400
# 2356  0.597406     0.798311   1.381381e-07    324.0        0.799096  0.879813
# 2357  0.799286     0.899412   1.381381e-06    324.0        0.899874  0.962615
# 2358  0.776720     0.887280   1.381381e-05    324.0        0.889443  0.951327
# 2359  0.766606     0.883309   1.291291e-04    327.0        0.883297  0.935315
#
#       ...  eval_Validation loss  eval_acc  _wandb.runtime  \
# 0     ...                   NaN       NaN             NaN
# 1     ...                   NaN       NaN             NaN
# 2     ...                   NaN       NaN             NaN
# 3     ...                   NaN       NaN             NaN
# 4     ...              0.488250  0.764634         35114.0
# ...   ...                   ...       ...             ...
# 2355  ...              0.693131  0.503869           692.0
# 2356  ...              0.537199  0.798092           693.0
# 2357  ...              0.245715  0.899523           700.0
# 2358  ...              0.341513  0.887546           696.0
# 2359  ...              0.485489  0.883307           689.0
#
#       Confusion Matrix._type  Confusion Matrix.width  Confusion Matrix.format  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                 image-file                  1200.0                      png
# ...                      ...                     ...                      ...
# 2355              image-file                  1200.0                      png
# 2356              image-file                  1200.0                      png
# 2357              image-file                  1200.0                      png
# 2358              image-file                  1200.0                      png
# 2359              image-file                  1200.0                      png
#
#      Confusion Matrix.height  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                     1200.0
# ...                      ...
# 2355                  1200.0
# 2356                  1200.0
# 2357                  1200.0
# 2358                  1200.0
# 2359                  1200.0
#
#                                 Confusion Matrix.sha256  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     581d69cdd53dde6db39ee0b73f5649cdabc20e61220942...
# ...                                                 ...
# 2355  8bb7708fa5de7feeb1d06e439d1d08483f9f17af9479c6...
# 2356  5a78816cab0e1fa1c6a6f02ac5e67d8fb0dd137cfec7c4...
# 2357  265f5743eafafb5593d85b3f5b25a8bde9f25d156c0678...
# 2358  7375fb8417576ec4fc3d46996dd222308076be3b318ac5...
# 2359  9c25be08f0448a8369b8ab35a1cfd22c3a92ae50e8f279...
#
#                                   Confusion Matrix.path  Confusion Matrix.size
# 0                                                   NaN                    NaN
# 1                                                   NaN                    NaN
# 2                                                   NaN                    NaN
# 3                                                   NaN                    NaN
# 4     media/images/Confusion Matrix_10886_581d69cdd5...                61277.0
# ...                                                 ...                    ...
# 2355  media/images/Confusion Matrix_218_8bb7708fa5de...                49619.0
# 2356  media/images/Confusion Matrix_216_5a78816cab0e...                57947.0
# 2357  media/images/Confusion Matrix_216_265f5743eafa...                59356.0
# 2358  media/images/Confusion Matrix_216_7375fb841757...                58933.0
# 2359  media/images/Confusion Matrix_218_9c25be08f044...                56420.0
#
# [2360 rows x 23 columns]

# %%
# Remove rows with any NaN values and keep the original index
expanded_runs_df = expanded_runs_df.dropna().reset_index()
expanded_runs_df
# Out:
#       index                                             config  \
# 0         4  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1         5  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2         6  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3         7  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4         8  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ...     ...                                                ...
# 2350   2355  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2351   2356  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2352   2357  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2353   2358  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2354   2359  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                    name      tags   eval_f1  \
# 0     TFBS_NonTFBS_March_11th_2024_14_16_40_logstep=...  H3K79me1  0.763926
# 1     TFBS_NonTFBS_March_11th_2024_14_02_14_logstep=...      ZEB1  0.834396
# 2     TFBS_NonTFBS_March_11th_2024_13_47_46_logstep=...      ZEB1  0.830014
# 3     TFBS_NonTFBS_March_11th_2024_13_33_19_logstep=...      ZEB1  0.833570
# 4     TFBS_NonTFBS_March_11th_2024_13_18_53_logstep=...      ZEB1  0.829924
# ...                                                 ...       ...       ...
# 2350  TFBS_NonTFBS_February_27th_2024_19_05_22_logst...     SAP30  0.335048
# 2351  TFBS_NonTFBS_February_27th_2024_18_56_57_logst...     SAP30  0.797994
# 2352  TFBS_NonTFBS_February_27th_2024_18_55_50_logst...     SAP30  0.899477
# 2353  TFBS_NonTFBS_February_27th_2024_18_55_00_logst...     SAP30  0.887354
# 2354  TFBS_NonTFBS_February_27th_2024_18_53_42_logst...     SAP30  0.883302
#
#       eval_mcc  eval_recall  learning_rate    _step  eval_precision  ...  \
# 0     0.532850     0.764757   1.114784e-06  16329.0        0.768103  ...
# 1     0.674062     0.834274   3.787879e-06    390.0        0.839811  ...
# 2     0.663142     0.829843   1.262626e-06    390.0        0.833308  ...
# 3     0.672659     0.833462   3.787879e-06    390.0        0.839222  ...
# 4     0.662975     0.829754   1.262626e-06    390.0        0.833230  ...
# ...        ...          ...            ...      ...             ...  ...
# 2350  0.000000     0.500000   3.873874e-04    327.0        0.251934  ...
# 2351  0.597406     0.798311   1.381381e-07    324.0        0.799096  ...
# 2352  0.799286     0.899412   1.381381e-06    324.0        0.899874  ...
# 2353  0.776720     0.887280   1.381381e-05    324.0        0.889443  ...
# 2354  0.766606     0.883309   1.291291e-04    327.0        0.883297  ...
#
#       eval_Validation loss  eval_acc  _wandb.runtime  Confusion Matrix._type  \
# 0                 0.488250  0.764634         35114.0              image-file
# 1                 0.383239  0.835277           856.0              image-file
# 2                 0.389353  0.830630           855.0              image-file
# 3                 0.384626  0.834488           854.0              image-file
# 4                 0.389356  0.830543           856.0              image-file
# ...                    ...       ...             ...                     ...
# 2350              0.693131  0.503869           692.0              image-file
# 2351              0.537199  0.798092           693.0              image-file
# 2352              0.245715  0.899523           700.0              image-file
# 2353              0.341513  0.887546           696.0              image-file
# 2354              0.485489  0.883307           689.0              image-file
#
#       Confusion Matrix.width  Confusion Matrix.format  \
# 0                     1200.0                      png
# 1                     1200.0                      png
# 2                     1200.0                      png
# 3                     1200.0                      png
# 4                     1200.0                      png
# ...                      ...                      ...
# 2350                  1200.0                      png
# 2351                  1200.0                      png
# 2352                  1200.0                      png
# 2353                  1200.0                      png
# 2354                  1200.0                      png
#
#       Confusion Matrix.height  \
# 0                      1200.0
# 1                      1200.0
# 2                      1200.0
# 3                      1200.0
# 4                      1200.0
# ...                       ...
# 2350                   1200.0
# 2351                   1200.0
# 2352                   1200.0
# 2353                   1200.0
# 2354                   1200.0
#
#                                 Confusion Matrix.sha256  \
# 0     581d69cdd53dde6db39ee0b73f5649cdabc20e61220942...
# 1     feb43d53ed3ba438f719cd1cb72616505e348922b9a060...
# 2     741d5e1c7589a93cfc1cdbafbd42cc5ad60c64a834096d...
# 3     8c4c8962d28f9d8b77e05b0483b0b5026bba83e93398cf...
# 4     7ce8762ff6041058de4616b26a350952983759cf1e667d...
# ...                                                 ...
# 2350  8bb7708fa5de7feeb1d06e439d1d08483f9f17af9479c6...
# 2351  5a78816cab0e1fa1c6a6f02ac5e67d8fb0dd137cfec7c4...
# 2352  265f5743eafafb5593d85b3f5b25a8bde9f25d156c0678...
# 2353  7375fb8417576ec4fc3d46996dd222308076be3b318ac5...
# 2354  9c25be08f0448a8369b8ab35a1cfd22c3a92ae50e8f279...
#
#                                   Confusion Matrix.path Confusion Matrix.size
# 0     media/images/Confusion Matrix_10886_581d69cdd5...               61277.0
# 1     media/images/Confusion Matrix_260_feb43d53ed3b...               55995.0
# 2     media/images/Confusion Matrix_260_741d5e1c7589...               59693.0
# 3     media/images/Confusion Matrix_260_8c4c8962d28f...               56735.0
# 4     media/images/Confusion Matrix_260_7ce8762ff604...               59942.0
# ...                                                 ...                   ...
# 2350  media/images/Confusion Matrix_218_8bb7708fa5de...               49619.0
# 2351  media/images/Confusion Matrix_216_5a78816cab0e...               57947.0
# 2352  media/images/Confusion Matrix_216_265f5743eafa...               59356.0
# 2353  media/images/Confusion Matrix_216_7375fb841757...               58933.0
# 2354  media/images/Confusion Matrix_218_9c25be08f044...               56420.0
#
# [2355 rows x 24 columns]

# %%
# Group by 'tags' and find the index of the max 'eval_acc' for each group
idx = expanded_runs_df.groupby('tags')['eval_acc'].idxmax()

# Use the indices to select rows from the original DataFrame
best_acc_df = expanded_runs_df.loc[idx].reset_index(drop=True)
best_acc_df
# Out:
#     index                                             config  \
# 0     119  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 1    1070  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 2     307  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 3    1720  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 4    1295  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# ..    ...                                                ...
# 94   2295  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 95    160  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 96    621  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 97   1693  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
# 98    644  {'epochs': 10, 'Dropout': 0.1, 'batch_size': 1...
#
#                                                  name    tags   eval_f1  \
# 0   TFBS_NonTFBS_March_11th_2024_07_48_56_logstep=...    AGO2  0.895784
# 1   TFBS_NonTFBS_March_03th_2024_07_58_34_logstep=...  ARID3A  0.763331
# 2   TFBS_NonTFBS_March_10th_2024_18_51_55_logstep=...    ARNT  0.750420
# 3   TFBS_NonTFBS_February_29th_2024_20_07_02_logst...    BLC3  0.908875
# 4   TFBS_NonTFBS_March_02th_2024_07_41_10_logstep=...    BRD9  0.738001
# ..                                                ...     ...       ...
# 94  TFBS_NonTFBS_February_27th_2024_22_06_01_logst...  ZNF652  0.851404
# 95  TFBS_NonTFBS_March_11th_2024_06_11_19_logstep=...  ZNF692  0.831956
# 96  TFBS_NonTFBS_March_09th_2024_03_13_54_logstep=...  ZNF792  0.808163
# 97  TFBS_NonTFBS_March_01th_2024_02_09_02_logstep=...  ZSCAN9  0.812409
# 98  TFBS_NonTFBS_March_09th_2024_01_32_17_logstep=...    ZXDB  0.813028
#
#     eval_mcc  eval_recall  learning_rate   _step  eval_precision  ...  \
# 0   0.794619     0.895822       0.000004   633.0        0.898803  ...
# 1   0.533582     0.764785       0.000036   795.0        0.768812  ...
# 2   0.501429     0.750620       0.000121   873.0        0.750809  ...
# 3   0.818516     0.908947       0.000034  3555.0        0.909569  ...
# 4   0.478249     0.738164       0.000004   243.0        0.740089  ...
# ..       ...          ...            ...     ...             ...  ...
# 94  0.702968     0.851480       0.000137   228.0        0.851488  ...
# 95  0.664753     0.831936       0.000129   486.0        0.832817  ...
# 96  0.621292     0.808337       0.000126   408.0        0.812972  ...
# 97  0.625169     0.812420       0.000132   282.0        0.812749  ...
# 98  0.627069     0.813148       0.000128   513.0        0.813921  ...
#
#     eval_Validation loss  eval_acc  _wandb.runtime  Confusion Matrix._type  \
# 0               0.298919  0.895999          1362.0              image-file
# 1               0.765750  0.764071          1699.0              image-file
# 2               0.593425  0.750443          1831.0              image-file
# 3               0.361423  0.908906          7580.0              image-file
# 4               0.512739  0.738697           534.0              image-file
# ..                   ...       ...             ...                     ...
# 94              0.373125  0.851404           490.0              image-file
# 95              0.425019  0.832101          1025.0              image-file
# 96              0.530071  0.809028           862.0              image-file
# 97              0.483263  0.812469           601.0              image-file
# 98              0.535345  0.813143          1083.0              image-file
#
#     Confusion Matrix.width  Confusion Matrix.format  Confusion Matrix.height  \
# 0                   1200.0                      png                   1200.0
# 1                   1200.0                      png                   1200.0
# 2                   1200.0                      png                   1200.0
# 3                   1200.0                      png                   1200.0
# 4                   1200.0                      png                   1200.0
# ..                     ...                      ...                      ...
# 94                  1200.0                      png                   1200.0
# 95                  1200.0                      png                   1200.0
# 96                  1200.0                      png                   1200.0
# 97                  1200.0                      png                   1200.0
# 98                  1200.0                      png                   1200.0
#
#                               Confusion Matrix.sha256  \
# 0   958cd42b536bc3994165310ae2cbd90fbd514c41e93d89...
# 1   9790b8d093b46b5410432abe0ae5c05698c8f6338f0c86...
# 2   4654e6e9f4b65a33e5232fe1c4e4f3ad0d152246fc91aa...
# 3   62feb30361869d99e534374c07accb544ecca05e54c11e...
# 4   0b36807bba0d5ceda023762edbaf45d0b463b29bbec878...
# ..                                                ...
# 94  1ac2070351ebd1bceb2e5d4f27380f1ea6667dc82f6400...
# 95  d0d6ce66dba2ae38fd584c6e040cfc876601c15f1f4a5a...
# 96  0a705a0c192a9c707044695c28c4b400f4158812f32126...
# 97  e5c3db86ea9e90d0c522f3bbd8795316ce7d735f6f33ba...
# 98  7bebe030ee27cf12dc17f4e6d3e64b82faa375bcb2e99b...
#
#                                 Confusion Matrix.path Confusion Matrix.size
# 0   media/images/Confusion Matrix_422_958cd42b536b...               60413.0
# 1   media/images/Confusion Matrix_530_9790b8d093b4...               59950.0
# 2   media/images/Confusion Matrix_582_4654e6e9f4b6...               58394.0
# 3   media/images/Confusion Matrix_2370_62feb303618...               62161.0
# 4   media/images/Confusion Matrix_162_0b36807bba0d...               58948.0
# ..                                                ...                   ...
# 94  media/images/Confusion Matrix_152_1ac2070351eb...               55152.0
# 95  media/images/Confusion Matrix_324_d0d6ce66dba2...               55171.0
# 96  media/images/Confusion Matrix_272_0a705a0c192a...               59776.0
# 97  media/images/Confusion Matrix_188_e5c3db86ea9e...               54036.0
# 98  media/images/Confusion Matrix_342_7bebe030ee27...               56804.0
#
# [99 rows x 24 columns]

# %%
best_acc_df.sort_values(by="eval_acc", ascending=False)[['tags','eval_acc']]
# Out:
#       tags  eval_acc
# 48   RBM14  0.968908
# 57    SPI1  0.957358
# 63   THAP1  0.937964
# 12    E2F4  0.918800
# 45  RAD212  0.915177
# ..     ...       ...
# 36   MYBL2  0.739527
# 4     BRD9  0.738697
# 80  ZNF318  0.731597
# 28    ILF3  0.715873
# 15   EWSR1  0.605755
#
# [99 rows x 2 columns]
