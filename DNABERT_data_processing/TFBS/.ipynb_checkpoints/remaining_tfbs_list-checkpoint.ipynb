# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
# Load the important TFBS files list
with open('/home/campus.stonybrook.edu/pdutta/Github/Postdoc/DNABERT_data_processing/TFBS/all_selected_tfbs.txt', 'r') as file:
    important_tfbs= file.read().splitlines()

# %%
important_tfbs
# Out:
# ['CEBPA ',
#  'CTCF ',
#  'FOS ',
#  'H2AFZ ',
#  'H2AK5ac ',
#  'H2BK12ac ',
#  'H2BK5ac ',
#  'H3F3A ',
#  'H3K14ac ',
#  'H3K27ac ',
#  'H3K27me3 ',
#  'H3K36me3 ',
#  'H3K4me1 ',
#  'H3K4me2 ',
#  'H3K79me1 ',
#  'H3K79me2 ',
#  'H3K9ac ',
#  'H3K9me1 ',
#  'H3K9me3 ',
#  'H4K20me1 ',
#  'H4K5ac ',
#  'H4K8ac ',
#  'IKZF1 ',
#  'RAD21 ',
#  'RBM22 ',
#  'RUNX3 ',
#  'TRIM22 ',
#  'ZBTB33 ',
#  'ZNF143 ',
#  'CEBPB ',
#  'EGR2 ',
#  'NFE2 ',
#  'PRDM1 ',
#  'SCRT2 ',
#  'ZFHX2 ',
#  'ZNF121 ',
#  'ZNF366 ',
#  'ZNF770 ']

# %%
def seq2kmer(seq, k=6):
    """
    Convert original sequence to kmers.
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def process_bed_file(file_path):
    df = pd.read_csv(file_path, sep="\t")
    df.rename(columns={'label': 'Label'}, inplace=True)
    print(df.groupby(['Label']).size())
    g = df.groupby('Label')
    df_balanced = g.apply(lambda x: x.sample(n=min(len(x), 50000), random_state=42)).reset_index(drop=True)
    
    # Save the balanced DataFrame to a new BED file
    balanced_bed_path = file_path.replace('.bed', '_balanced.bed')
    df_balanced.to_csv(balanced_bed_path, sep='\t', index=False)
    print(f"Balanced BED saved to {balanced_bed_path}")
    
    # Extract k-mers and save to a separate file
    df_balanced['Sequence'] = df_balanced['sequence'].apply(seq2kmer) 
    df_shuffle = shuffle(df_balanced[['Sequence','Label']]).reset_index(drop=True)
    
    train, test = train_test_split(df_shuffle, test_size=0.15)
    print (train.shape, test.shape)
    print(train.groupby(['Label']).size(), test.groupby(['Label']).size() )
    
    
    # Create a directory named after the bed file
    base_path = os.path.dirname(file_path)
    dir_path = os.path.join(base_path, '300bp_balanced')
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    
    # Save the train and dev files
    train.to_csv(os.path.join(dir_path, 'train.tsv'), sep='\t', index=False)
    test.to_csv(os.path.join(dir_path, 'dev.tsv'), sep='\t', index=False)

# %%
# def split_and_save(dataset, base_path, bed_file_name):
#     df = pd.DataFrame(dataset, columns=['Sequence', 'Label'])
#     print(df.groupby(['Label']).size())
#     df = df.groupby('Label').apply(lambda x: x.sample(n=min(len(x), 50000), random_state=42)).reset_index(drop=True)
#     print(df.groupby(['Label']).size())

#     # Split the dataset
#     X_train, X_test, y_train, y_test = train_test_split(df['Sequence'], df['Label'], test_size=0.2, random_state=42)
    
#     # Prepare train and dev (test) DataFrames
#     train_df = pd.DataFrame({'Sequence': X_train, 'Label': y_train})
#     dev_df = pd.DataFrame({'Sequence': X_test, 'Label': y_test})
    
#     # Create a directory named after the bed file
#     base_path = os.path.dirname(file_path)
#     dir_path = os.path.join(base_path, '300bp_balanced')
#     if not os.path.exists(dir_path):
#         os.makedirs(dir_path)
    
#     # Save the train and dev files
#     train_df.to_csv(os.path.join(dir_path, 'train.tsv'), sep='\t', index=False)
#     dev_df.to_csv(os.path.join(dir_path, 'dev.tsv'), sep='\t', index=False)

# %%
base_folder_path= "/data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg"
for tfbs in important_tfbs:
    tfbs= tfbs.strip()
    file_path = f"{base_folder_path}/{tfbs.strip()}/300bp_unique.bed"
    if os.path.isfile(file_path):
        print(f"300bp.bed of the folder {tfbs} is processing.")
        dataset = process_bed_file(file_path)
        #split_and_save(dataset, f"{base_folder_path}/{tfbs}", "300bp_unique.bed")
    else:
        print(f'300bp.bed file is not still generated in the folder {tfbs}.')

# for root, dirs, files in os.walk(folder_path):
#     # Skip .ipynb_checkpoints directories
#     if '.ipynb_checkpoints' in root:
#         continue
#     for file in files:
#         if file.endswith('.bed'):
#             file_path = os.path.join(root, file)
#             dataset = process_bed_file(file_path)
#             split_and_save(dataset, root, file)
# Out:
# 300bp.bed of the folder CEBPA is processing.
# Label
# 0    58877
# 1    57842
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/CEBPA/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42415
# 1    42585
# dtype: int64 Label
# 0    7585
# 1    7415
# dtype: int64
# 300bp.bed of the folder CTCF is processing.
# Label
# 0    9123823
# 1     249010
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/CTCF/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42527
# 1    42473
# dtype: int64 Label
# 0    7473
# 1    7527
# dtype: int64
# 300bp.bed of the folder FOS is processing.
# Label
# 0    503537
# 1    169317
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/FOS/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42478
# 1    42522
# dtype: int64 Label
# 0    7522
# 1    7478
# dtype: int64
# 300bp.bed of the folder H2AFZ is processing.
# Label
# 0    3673191
# 1     902296
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H2AFZ/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42485
# 1    42515
# dtype: int64 Label
# 0    7515
# 1    7485
# dtype: int64
# 300bp.bed of the folder H2AK5ac is processing.
# Label
# 0    756141
# 1    494461
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H2AK5ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42352
# 1    42648
# dtype: int64 Label
# 0    7648
# 1    7352
# dtype: int64
# 300bp.bed of the folder H2BK12ac is processing.
# Label
# 0    873334
# 1    500494
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H2BK12ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42446
# 1    42554
# dtype: int64 Label
# 0    7554
# 1    7446
# dtype: int64
# 300bp.bed of the folder H2BK5ac is processing.
# Label
# 0    605297
# 1    418512
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H2BK5ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42521
# 1    42479
# dtype: int64 Label
# 0    7479
# 1    7521
# dtype: int64
# 300bp.bed of the folder H3F3A is processing.
# Label
# 0    1093667
# 1     640371
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3F3A/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42539
# 1    42461
# dtype: int64 Label
# 0    7461
# 1    7539
# dtype: int64
# 300bp.bed of the folder H3K14ac is processing.
# Label
# 0    506209
# 1    348946
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K14ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42551
# 1    42449
# dtype: int64 Label
# 0    7449
# 1    7551
# dtype: int64
# 300bp.bed of the folder H3K27ac is processing.
# Label
# 0    6069787
# 1    1179753
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K27ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42504
# 1    42496
# dtype: int64 Label
# 0    7496
# 1    7504
# dtype: int64
# 300bp.bed of the folder H3K27me3 is processing.
# Label
# 0    5533769
# 1    1400874
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K27me3/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42545
# 1    42455
# dtype: int64 Label
# 0    7455
# 1    7545
# dtype: int64
# 300bp.bed of the folder H3K36me3 is processing.
# Label
# 0    6777247
# 1     801216
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K36me3/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42456
# 1    42544
# dtype: int64 Label
# 0    7544
# 1    7456
# dtype: int64
# 300bp.bed of the folder H3K4me1 is processing.
# Label
# 0    4835338
# 1    1342846
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K4me1/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42598
# 1    42402
# dtype: int64 Label
# 0    7402
# 1    7598
# dtype: int64
# 300bp.bed of the folder H3K4me2 is processing.
# Label
# 0    5253634
# 1     795739
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K4me2/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42551
# 1    42449
# dtype: int64 Label
# 0    7449
# 1    7551
# dtype: int64
# 300bp.bed of the folder H3K79me1 is processing.
# Label
# 0    1179748
# 1     565470
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K79me1/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42592
# 1    42408
# dtype: int64 Label
# 0    7408
# 1    7592
# dtype: int64
# 300bp.bed of the folder H3K79me2 is processing.
# Label
# 0    4198038
# 1     566725
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K79me2/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42604
# 1    42396
# dtype: int64 Label
# 0    7396
# 1    7604
# dtype: int64
# 300bp.bed of the folder H3K9ac is processing.
# Label
# 0    4734464
# 1     717785
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K9ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42486
# 1    42514
# dtype: int64 Label
# 0    7514
# 1    7486
# dtype: int64
# 300bp.bed of the folder H3K9me1 is processing.
# Label
# 0    203539
# 1    196657
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K9me1/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42510
# 1    42490
# dtype: int64 Label
# 0    7490
# 1    7510
# dtype: int64
# 300bp.bed of the folder H3K9me3 is processing.
# Label
# 0    5529310
# 1    1530154
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H3K9me3/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42502
# 1    42498
# dtype: int64 Label
# 0    7498
# 1    7502
# dtype: int64
# 300bp.bed of the folder H4K20me1 is processing.
# Label
# 0    2069875
# 1     563553
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H4K20me1/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42479
# 1    42521
# dtype: int64 Label
# 0    7521
# 1    7479
# dtype: int64
# 300bp.bed of the folder H4K5ac is processing.
# Label
# 0    233918
# 1    194004
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H4K5ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42542
# 1    42458
# dtype: int64 Label
# 0    7458
# 1    7542
# dtype: int64
# 300bp.bed of the folder H4K8ac is processing.
# Label
# 0    810558
# 1    433597
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/H4K8ac/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42532
# 1    42468
# dtype: int64 Label
# 0    7468
# 1    7532
# dtype: int64
# 300bp.bed of the folder IKZF1 is processing.
# Label
# 0    257195
# 1    120550
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/IKZF1/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42563
# 1    42437
# dtype: int64 Label
# 0    7437
# 1    7563
# dtype: int64
# 300bp.bed of the folder RAD21 is processing.
# Label
# 0    1615820
# 1     188052
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/RAD21/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42507
# 1    42493
# dtype: int64 Label
# 0    7493
# 1    7507
# dtype: int64
# 300bp.bed of the folder RBM22 is processing.
# Label
# 0    49033
# 1    38154
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/RBM22/300bp_unique_balanced.bed
# (74108, 2) (13079, 2)
# Label
# 0    41687
# 1    32421
# dtype: int64 Label
# 0    7346
# 1    5733
# dtype: int64
# 300bp.bed of the folder RUNX3 is processing.
# Label
# 0    74174
# 1    69903
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/RUNX3/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42379
# 1    42621
# dtype: int64 Label
# 0    7621
# 1    7379
# dtype: int64
# 300bp.bed of the folder TRIM22 is processing.
# Label
# 0    94475
# 1    55932
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/TRIM22/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42479
# 1    42521
# dtype: int64 Label
# 0    7521
# 1    7479
# dtype: int64
# 300bp.bed of the folder ZBTB33 is processing.
# Label
# 0    132156
# 1     96111
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/ZBTB33/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42531
# 1    42469
# dtype: int64 Label
# 0    7469
# 1    7531
# dtype: int64
# 300bp.bed of the folder ZNF143 is processing.
# Label
# 0    135856
# 1     66295
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/ZNF143/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42559
# 1    42441
# dtype: int64 Label
# 0    7441
# 1    7559
# dtype: int64
# 300bp.bed of the folder CEBPB is processing.
# Label
# 0    504060
# 1    148540
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/CEBPB/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42501
# 1    42499
# dtype: int64 Label
# 0    7499
# 1    7501
# dtype: int64
# 300bp.bed of the folder EGR2 is processing.
# Label
# 0    62404
# 1    57610
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/EGR2/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42503
# 1    42497
# dtype: int64 Label
# 0    7497
# 1    7503
# dtype: int64
# 300bp.bed of the folder NFE2 is processing.
# Label
# 0    75991
# 1    53717
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/NFE2/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42490
# 1    42510
# dtype: int64 Label
# 0    7510
# 1    7490
# dtype: int64
# 300bp.bed of the folder PRDM1 is processing.
# Label
# 0    52980
# 1    50489
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/PRDM1/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42492
# 1    42508
# dtype: int64 Label
# 0    7508
# 1    7492
# dtype: int64
# 300bp.bed of the folder SCRT2 is processing.
# Label
# 0    64935
# 1    59462
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/SCRT2/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42438
# 1    42562
# dtype: int64 Label
# 0    7562
# 1    7438
# dtype: int64
# 300bp.bed of the folder ZFHX2 is processing.
# Label
# 0    66445
# 1    61052
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/ZFHX2/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42453
# 1    42547
# dtype: int64 Label
# 0    7547
# 1    7453
# dtype: int64
# 300bp.bed of the folder ZNF121 is processing.
# Label
# 0    38296
# 1    35805
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/ZNF121/300bp_unique_balanced.bed
# (62985, 2) (11116, 2)
# Label
# 0    32615
# 1    30370
# dtype: int64 Label
# 0    5681
# 1    5435
# dtype: int64
# 300bp.bed of the folder ZNF366 is processing.
# Label
# 0    51940
# 1    44505
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/ZNF366/300bp_unique_balanced.bed
# (80329, 2) (14176, 2)
# Label
# 0    42466
# 1    37863
# dtype: int64 Label
# 0    7534
# 1    6642
# dtype: int64
# 300bp.bed of the folder ZNF770 is processing.
# Label
# 0    58883
# 1    57572
# dtype: int64
# Balanced BED saved to /data/projects/DNABERT_snv/Manuscript_11_2023/TFBS_fine_tune_data/Data_Jan_2024/cleaned_names_0524/1_1_pos_neg/ZNF770/300bp_unique_balanced.bed
# (85000, 2) (15000, 2)
# Label
# 0    42451
# 1    42549
# dtype: int64 Label
# 0    7549
# 1    7451
# dtype: int64
