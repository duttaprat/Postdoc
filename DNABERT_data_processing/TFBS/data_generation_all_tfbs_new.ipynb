# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
def seq2kmer(seq, k=6):
    """
    Convert original sequence to kmers.
    
    Arguments:
    seq -- str, original sequence.
    k -- int, kmer of length k specified.
    
    Returns:
    kmers -- str, kmers separated by space
    """
    kmer = [seq[x:x+k] for x in range(len(seq)+1-k)]
    kmers = " ".join(kmer)
    return kmers

# %%
def process_bed_file(file_path):
    df = pd.read_csv(file_path, sep="\t")
    #display(df)
    df.rename(columns={'label': 'Label'}, inplace=True)
    #print(df.groupby(['Label']).size())
    g = df.groupby('Label')
    df_balanced = g.apply(lambda x: x.sample(n=min(len(x), 50000), random_state=42)).reset_index(drop=True)
    
    # Save the balanced DataFrame to a new BED file
    balanced_bed_path = file_path.replace('.bed', '_balanced.bed')
    df_balanced.to_csv(balanced_bed_path, sep='\t', index=False)
    print(f"Balanced BED saved to {balanced_bed_path}")
    
    # Extract k-mers and save to a separate file
    df_balanced['Sequence'] = df_balanced['sequence'].apply(seq2kmer) 
    df_shuffle = shuffle(df_balanced[['Sequence','Label']]).reset_index(drop=True)
    
    train, test = train_test_split(df_shuffle, test_size=0.15)
    #print (train.shape, test.shape)
    #print(train.groupby(['Label']).size(), test.groupby(['Label']).size() )
    
    
    # Create a directory named after the bed file
    base_path = os.path.dirname(file_path)
    dir_path = os.path.join(base_path, '300bp_balanced')
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    
    # Save the train and dev files
    train.to_csv(os.path.join(dir_path, 'train.tsv'), sep='\t', index=False)
    test.to_csv(os.path.join(dir_path, 'dev.tsv'), sep='\t', index=False)

# %%
folder_path= "/home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg"
# List all subdirectories in the base path, excluding .ipynb_checkpoints
subfolders = [f.name for f in os.scandir(folder_path) if f.is_dir() and f.name != '.ipynb_checkpoints']


# Loop through each subfolder and read the 300bp_unique.bed file
for subfolder in subfolders:
    file_path = os.path.join(folder_path, subfolder, '300bp_unique.bed')
    if os.path.isfile(file_path):
        print(f"300bp.bed of the folder {subfolder} is processing.")
        dataset = process_bed_file(file_path)
        #split_and_save(dataset, f"{base_folder_path}/{tfbs}", "300bp_unique.bed")
    else:
        print(f'300bp.bed file is not still generated in the folder {subfolder}.')
# Out:
# 300bp.bed of the folder MEF2D is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MEF2D/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF132 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF132/300bp_unique_balanced.bed
# 300bp.bed of the folder NR3C1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NR3C1/300bp_unique_balanced.bed
# 300bp.bed of the folder SMARCA5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SMARCA5/300bp_unique_balanced.bed
# 300bp.bed of the folder H2AK9ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H2AK9ac/300bp_unique_balanced.bed
# 300bp.bed of the folder KDM5B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KDM5B/300bp_unique_balanced.bed
# 300bp.bed of the folder IRF5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/IRF5/300bp_unique_balanced.bed
# 300bp.bed of the folder ZSCAN29 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZSCAN29/300bp_unique_balanced.bed
# 300bp.bed of the folder MYNN is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MYNN/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF629 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF629/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB49 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB49/300bp_unique_balanced.bed
# 300bp.bed of the folder EWSR1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/EWSR1/300bp_unique_balanced.bed
# 300bp.bed of the folder SCRT1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SCRT1/300bp_unique_balanced.bed
# 300bp.bed of the folder IRF9 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/IRF9/300bp_unique_balanced.bed
# 300bp.bed of the folder MBD1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MBD1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF155 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF155/300bp_unique_balanced.bed
# 300bp.bed of the folder EBF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/EBF1/300bp_unique_balanced.bed
# 300bp.bed of the folder H2BK20ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H2BK20ac/300bp_unique_balanced.bed
# 300bp.bed of the folder SKIL is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SKIL/300bp_unique_balanced.bed
# 300bp.bed of the folder MIER1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MIER1/300bp_unique_balanced.bed
# 300bp.bed of the folder MTA2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MTA2/300bp_unique_balanced.bed
# 300bp.bed of the folder CDC5L is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CDC5L/300bp_unique_balanced.bed
# 300bp.bed of the folder DNMT1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/DNMT1/300bp_unique_balanced.bed
# 300bp.bed of the folder MYB is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MYB/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF512 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF512/300bp_unique_balanced.bed
# 300bp.bed of the folder IKZF5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/IKZF5/300bp_unique_balanced.bed
# 300bp.bed of the folder GMEB2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GMEB2/300bp_unique_balanced.bed
# 300bp.bed of the folder RBM25 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBM25/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF623 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF623/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF404 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF404/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF544 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF544/300bp_unique_balanced.bed
# 300bp.bed of the folder VEZF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/VEZF1/300bp_unique_balanced.bed
# 300bp.bed of the folder POLR2H is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/POLR2H/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB8A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB8A/300bp_unique_balanced.bed
# 300bp.bed of the folder THRAP3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/THRAP3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZXDB is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZXDB/300bp_unique_balanced.bed
# 300bp.bed of the folder NR2C2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NR2C2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZSCAN30 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZSCAN30/300bp_unique_balanced.bed
# 300bp.bed of the folder PYGO2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PYGO2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF614 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF614/300bp_unique_balanced.bed
# 300bp.bed of the folder HMG20B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HMG20B/300bp_unique_balanced.bed
# 300bp.bed of the folder CREB3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CREB3/300bp_unique_balanced.bed
# 300bp.bed of the folder PTTG1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PTTG1/300bp_unique_balanced.bed
# 300bp.bed of the folder H3K18ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H3K18ac/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF644 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF644/300bp_unique_balanced.bed
# 300bp.bed of the folder MTA1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MTA1/300bp_unique_balanced.bed
# 300bp.bed of the folder PAF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PAF1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF547 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF547/300bp_unique_balanced.bed
# 300bp.bed of the folder NFIL3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFIL3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF362 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF362/300bp_unique_balanced.bed
# 300bp.bed of the folder ZFP64 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZFP64/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF473 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF473/300bp_unique_balanced.bed
# 300bp.bed of the folder MCM7 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MCM7/300bp_unique_balanced.bed
# 300bp.bed of the folder SUZ12 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SUZ12/300bp_unique_balanced.bed
# 300bp.bed of the folder POLR2AphosphoS2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/POLR2AphosphoS2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF423 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF423/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF571 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF571/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF282 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF282/300bp_unique_balanced.bed
# 300bp.bed of the folder PRDM4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PRDM4/300bp_unique_balanced.bed
# 300bp.bed of the folder MZF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MZF1/300bp_unique_balanced.bed
# 300bp.bed of the folder IRF4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/IRF4/300bp_unique_balanced.bed
# 300bp.bed of the folder LCORL is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/LCORL/300bp_unique_balanced.bed
# 300bp.bed of the folder GATAD2A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GATAD2A/300bp_unique_balanced.bed
# 300bp.bed of the folder COPS2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/COPS2/300bp_unique_balanced.bed
# 300bp.bed of the folder PRDM1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PRDM1/300bp_unique_balanced.bed
# 300bp.bed of the folder HHEX is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HHEX/300bp_unique_balanced.bed
# 300bp.bed of the folder CEBPZ is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CEBPZ/300bp_unique_balanced.bed
# 300bp.bed of the folder ILF3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ILF3/300bp_unique_balanced.bed
# 300bp.bed of the folder NFE2L1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFE2L1/300bp_unique_balanced.bed
# 300bp.bed of the folder POLR2AphosphoS5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/POLR2AphosphoS5/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF507 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF507/300bp_unique_balanced.bed
# 300bp.bed of the folder MLX is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MLX/300bp_unique_balanced.bed
# 300bp.bed of the folder GTF2A2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GTF2A2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF16 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF16/300bp_unique_balanced.bed
# 300bp.bed of the folder ZEB2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZEB2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZMYM3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZMYM3/300bp_unique_balanced.bed
# 300bp.bed of the folder MAFG is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MAFG/300bp_unique_balanced.bed
# 300bp.bed of the folder YBX3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/YBX3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF444 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF444/300bp_unique_balanced.bed
# 300bp.bed of the folder SSRP1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SSRP1/300bp_unique_balanced.bed
# 300bp.bed of the folder SUPT20H is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SUPT20H/300bp_unique_balanced.bed
# 300bp.bed of the folder U2AF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/U2AF1/300bp_unique_balanced.bed
# 300bp.bed of the folder H4K8ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H4K8ac/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF354B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF354B/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB1/300bp_unique_balanced.bed
# 300bp.bed of the folder SIN3B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SIN3B/300bp_unique_balanced.bed
# 300bp.bed of the folder CHD1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CHD1/300bp_unique_balanced.bed
# 300bp.bed of the folder TRIM25 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TRIM25/300bp_unique_balanced.bed
# 300bp.bed of the folder GLI4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GLI4/300bp_unique_balanced.bed
# 300bp.bed of the folder HDAC8 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HDAC8/300bp_unique_balanced.bed
# 300bp.bed of the folder NFKBIZ is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFKBIZ/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF8 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF8/300bp_unique_balanced.bed
# 300bp.bed of the folder HSF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HSF1/300bp_unique_balanced.bed
# 300bp.bed of the folder HNRNPUL1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HNRNPUL1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF579 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF579/300bp_unique_balanced.bed
# 300bp.bed of the folder FOXA3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/FOXA3/300bp_unique_balanced.bed
# 300bp.bed of the folder C11orf30 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/C11orf30/300bp_unique_balanced.bed
# 300bp.bed of the folder BCL11A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/BCL11A/300bp_unique_balanced.bed
# 300bp.bed of the folder JUN is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/JUN/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF777 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF777/300bp_unique_balanced.bed
# 300bp.bed of the folder SRF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SRF/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF335 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF335/300bp_unique_balanced.bed
# 300bp.bed of the folder HDAC6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HDAC6/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF24 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF24/300bp_unique_balanced.bed
# 300bp.bed of the folder ARID2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ARID2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZFP37 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZFP37/300bp_unique_balanced.bed
# 300bp.bed of the folder EP300 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/EP300/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF549 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF549/300bp_unique_balanced.bed
# 300bp.bed of the folder SOX5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SOX5/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF217 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF217/300bp_unique_balanced.bed
# 300bp.bed of the folder ATM is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ATM/300bp_unique_balanced.bed
# 300bp.bed of the folder HLTF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HLTF/300bp_unique_balanced.bed
# 300bp.bed of the folder TAF7 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TAF7/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF560 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF560/300bp_unique_balanced.bed
# 300bp.bed of the folder POLR2G is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/POLR2G/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB2/300bp_unique_balanced.bed
# 300bp.bed of the folder TSHZ1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TSHZ1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB5/300bp_unique_balanced.bed
# 300bp.bed of the folder SIN3A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SIN3A/300bp_unique_balanced.bed
# 300bp.bed of the folder ZSCAN18 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZSCAN18/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF645 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF645/300bp_unique_balanced.bed
# 300bp.bed of the folder ZFP91 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZFP91/300bp_unique_balanced.bed
# 300bp.bed of the folder THAP11 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/THAP11/300bp_unique_balanced.bed
# 300bp.bed of the folder AEBP2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/AEBP2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF529 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF529/300bp_unique_balanced.bed
# 300bp.bed of the folder HCFC1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HCFC1/300bp_unique_balanced.bed
# 300bp.bed of the folder LARP7 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/LARP7/300bp_unique_balanced.bed
# 300bp.bed of the folder NR2C1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NR2C1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF740 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF740/300bp_unique_balanced.bed
# 300bp.bed of the folder BMI1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/BMI1/300bp_unique_balanced.bed
# 300bp.bed of the folder IRF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/IRF1/300bp_unique_balanced.bed
# 300bp.bed of the folder CREB1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CREB1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF175 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF175/300bp_unique_balanced.bed
# 300bp.bed of the folder RBM15 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBM15/300bp_unique_balanced.bed
# 300bp.bed of the folder SRSF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SRSF1/300bp_unique_balanced.bed
# 300bp.bed of the folder FEZF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/FEZF1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF407 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF407/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF311 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF311/300bp_unique_balanced.bed
# 300bp.bed of the folder ZZZ3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZZZ3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF280D is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF280D/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF11 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF11/300bp_unique_balanced.bed
# 300bp.bed of the folder RFX1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RFX1/300bp_unique_balanced.bed
# 300bp.bed of the folder ASH2L is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ASH2L/300bp_unique_balanced.bed
# 300bp.bed of the folder HNRNPH1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HNRNPH1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF395 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF395/300bp_unique_balanced.bed
# 300bp.bed of the folder MCM5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MCM5/300bp_unique_balanced.bed
# 300bp.bed of the folder SETDB1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SETDB1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF350 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF350/300bp_unique_balanced.bed
# 300bp.bed of the folder POU5F1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/POU5F1/300bp_unique_balanced.bed
# 300bp.bed of the folder NEUROD1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NEUROD1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF592 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF592/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF83 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF83/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF302 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF302/300bp_unique_balanced.bed
# 300bp.bed of the folder NFATC3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFATC3/300bp_unique_balanced.bed
# 300bp.bed of the folder H3K79me1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H3K79me1/300bp_unique_balanced.bed
# 300bp.bed of the folder ID3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ID3/300bp_unique_balanced.bed
# 300bp.bed of the folder AGO1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/AGO1/300bp_unique_balanced.bed
# 300bp.bed of the folder SMARCA4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SMARCA4/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF513 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF513/300bp_unique_balanced.bed
# 300bp.bed of the folder DPF2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/DPF2/300bp_unique_balanced.bed
# 300bp.bed of the folder MAFF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MAFF/300bp_unique_balanced.bed
# 300bp.bed of the folder TCF7 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TCF7/300bp_unique_balanced.bed
# 300bp.bed of the folder IRF3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/IRF3/300bp_unique_balanced.bed
# 300bp.bed of the folder TCF12 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TCF12/300bp_unique_balanced.bed
# 300bp.bed of the folder KDM3A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KDM3A/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF26 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF26/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF146 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF146/300bp_unique_balanced.bed
# 300bp.bed of the folder RLF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RLF/300bp_unique_balanced.bed
# 300bp.bed of the folder KAT2A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KAT2A/300bp_unique_balanced.bed
# 300bp.bed of the folder KAT7 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KAT7/300bp_unique_balanced.bed
# 300bp.bed of the folder RB1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RB1/300bp_unique_balanced.bed
# 300bp.bed of the folder E2F6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/E2F6/300bp_unique_balanced.bed
# 300bp.bed of the folder MITF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MITF/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF366 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF366/300bp_unique_balanced.bed
# 300bp.bed of the folder NCOA4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NCOA4/300bp_unique_balanced.bed
# 300bp.bed of the folder USF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/USF1/300bp_unique_balanced.bed
# 300bp.bed of the folder TEAD3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TEAD3/300bp_unique_balanced.bed
# 300bp.bed of the folder NFYC is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFYC/300bp_unique_balanced.bed
# 300bp.bed of the folder SOX13 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SOX13/300bp_unique_balanced.bed
# 300bp.bed of the folder SPI1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SPI1/300bp_unique_balanced.bed
# 300bp.bed of the folder CUX1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CUX1/300bp_unique_balanced.bed
# 300bp.bed of the folder KDM6A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KDM6A/300bp_unique_balanced.bed
# 300bp.bed of the folder ZIC2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZIC2/300bp_unique_balanced.bed
# 300bp.bed of the folder ADNP is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ADNP/300bp_unique_balanced.bed
# 300bp.bed of the folder GLIS2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GLIS2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF207 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF207/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF5/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF639 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF639/300bp_unique_balanced.bed
# 300bp.bed of the folder RBAK is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBAK/300bp_unique_balanced.bed
# 300bp.bed of the folder ESR1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ESR1/300bp_unique_balanced.bed
# 300bp.bed of the folder TRIM28 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TRIM28/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF6/300bp_unique_balanced.bed
# 300bp.bed of the folder H3T11ph is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H3T11ph/300bp_unique_balanced.bed
# 300bp.bed of the folder RBM39 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBM39/300bp_unique_balanced.bed
# 300bp.bed of the folder STAT1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/STAT1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF189 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF189/300bp_unique_balanced.bed
# 300bp.bed of the folder ATF3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ATF3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF205 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF205/300bp_unique_balanced.bed
# 300bp.bed of the folder TAF15 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TAF15/300bp_unique_balanced.bed
# 300bp.bed of the folder TEAD2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TEAD2/300bp_unique_balanced.bed
# 300bp.bed of the folder H4K5ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H4K5ac/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB48 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB48/300bp_unique_balanced.bed
# 300bp.bed of the folder NCOA6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NCOA6/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF510 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF510/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF48 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF48/300bp_unique_balanced.bed
# 300bp.bed of the folder H3K27me3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H3K27me3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF19 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF19/300bp_unique_balanced.bed
# 300bp.bed of the folder HMGXB4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HMGXB4/300bp_unique_balanced.bed
# 300bp.bed of the folder FOXP2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/FOXP2/300bp_unique_balanced.bed
# 300bp.bed of the folder ETV5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ETV5/300bp_unique_balanced.bed
# 300bp.bed of the folder PPP1R10 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PPP1R10/300bp_unique_balanced.bed
# 300bp.bed of the folder DEK is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/DEK/300bp_unique_balanced.bed
# 300bp.bed of the folder ATF2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ATF2/300bp_unique_balanced.bed
# 300bp.bed of the folder BACH1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/BACH1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF626 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF626/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF791 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF791/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF830 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF830/300bp_unique_balanced.bed
# 300bp.bed of the folder PCBP1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PCBP1/300bp_unique_balanced.bed
# 300bp.bed of the folder HNF1A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HNF1A/300bp_unique_balanced.bed
# 300bp.bed of the folder CBFA2T3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CBFA2T3/300bp_unique_balanced.bed
# 300bp.bed of the folder TCF7L2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TCF7L2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF558 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF558/300bp_unique_balanced.bed
# 300bp.bed of the folder AGO2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/AGO2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF354C is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF354C/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF112 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF112/300bp_unique_balanced.bed
# 300bp.bed of the folder SOX6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SOX6/300bp_unique_balanced.bed
# 300bp.bed of the folder ARHGAP35 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ARHGAP35/300bp_unique_balanced.bed
# 300bp.bed of the folder ELF4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ELF4/300bp_unique_balanced.bed
# 300bp.bed of the folder FOXP1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/FOXP1/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF9 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF9/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB17 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB17/300bp_unique_balanced.bed
# 300bp.bed of the folder BCOR is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/BCOR/300bp_unique_balanced.bed
# 300bp.bed of the folder KMT2B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KMT2B/300bp_unique_balanced.bed
# 300bp.bed of the folder INSM2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/INSM2/300bp_unique_balanced.bed
# 300bp.bed of the folder PAX8 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PAX8/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF157 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF157/300bp_unique_balanced.bed
# 300bp.bed of the folder YY1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/YY1/300bp_unique_balanced.bed
# 300bp.bed of the folder TRIP13 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TRIP13/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB7A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB7A/300bp_unique_balanced.bed
# 300bp.bed of the folder ZSCAN4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZSCAN4/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF384 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF384/300bp_unique_balanced.bed
# 300bp.bed of the folder CBX1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CBX1/300bp_unique_balanced.bed
# 300bp.bed of the folder MNT is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MNT/300bp_unique_balanced.bed
# 300bp.bed of the folder SMAD5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SMAD5/300bp_unique_balanced.bed
# 300bp.bed of the folder H2BK15ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H2BK15ac/300bp_unique_balanced.bed
# 300bp.bed of the folder HLF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HLF/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF18 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF18/300bp_unique_balanced.bed
# 300bp.bed of the folder CHD2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CHD2/300bp_unique_balanced.bed
# 300bp.bed of the folder MCM2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MCM2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF10 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF10/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF324 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF324/300bp_unique_balanced.bed
# 300bp.bed of the folder JUND is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/JUND/300bp_unique_balanced.bed
# 300bp.bed of the folder KAT2B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KAT2B/300bp_unique_balanced.bed
# 300bp.bed of the folder E2F5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/E2F5/300bp_unique_balanced.bed
# 300bp.bed of the folder ELF3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ELF3/300bp_unique_balanced.bed
# 300bp.bed of the folder GFI1B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GFI1B/300bp_unique_balanced.bed
# 300bp.bed of the folder BCL11B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/BCL11B/300bp_unique_balanced.bed
# 300bp.bed of the folder HNF4A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HNF4A/300bp_unique_balanced.bed
# 300bp.bed of the folder SCRT2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SCRT2/300bp_unique_balanced.bed
# 300bp.bed of the folder MIXL1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MIXL1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF449 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF449/300bp_unique_balanced.bed
# 300bp.bed of the folder PBX3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PBX3/300bp_unique_balanced.bed
# 300bp.bed of the folder RUNX1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RUNX1/300bp_unique_balanced.bed
# 300bp.bed of the folder PTRF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PTRF/300bp_unique_balanced.bed
# 300bp.bed of the folder XRCC5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/XRCC5/300bp_unique_balanced.bed
# 300bp.bed of the folder RBM17 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBM17/300bp_unique_balanced.bed
# 300bp.bed of the folder NR2F6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NR2F6/300bp_unique_balanced.bed
# 300bp.bed of the folder ATF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ATF1/300bp_unique_balanced.bed
# 300bp.bed of the folder NKRF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NKRF/300bp_unique_balanced.bed
# 300bp.bed of the folder ETV6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ETV6/300bp_unique_balanced.bed
# 300bp.bed of the folder KAT8 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KAT8/300bp_unique_balanced.bed
# 300bp.bed of the folder RBFOX2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBFOX2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZC3H8 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZC3H8/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF416 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF416/300bp_unique_balanced.bed
# 300bp.bed of the folder ZMIZ1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZMIZ1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF2/300bp_unique_balanced.bed
# 300bp.bed of the folder NFIB is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFIB/300bp_unique_balanced.bed
# 300bp.bed of the folder TBX3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TBX3/300bp_unique_balanced.bed
# 300bp.bed of the folder UBTF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/UBTF/300bp_unique_balanced.bed
# 300bp.bed of the folder CC2D1A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CC2D1A/300bp_unique_balanced.bed
# 300bp.bed of the folder NR2F1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NR2F1/300bp_unique_balanced.bed
# 300bp.bed of the folder EZH2phosphoT487 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/EZH2phosphoT487/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB44 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB44/300bp_unique_balanced.bed
# 300bp.bed of the folder ETS1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ETS1/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF17 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF17/300bp_unique_balanced.bed
# 300bp.bed of the folder ZSCAN5C is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZSCAN5C/300bp_unique_balanced.bed
# 300bp.bed of the folder STAT3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/STAT3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF707 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF707/300bp_unique_balanced.bed
# 300bp.bed of the folder PTBP1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PTBP1/300bp_unique_balanced.bed
# 300bp.bed of the folder ARID3A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ARID3A/300bp_unique_balanced.bed
# 300bp.bed of the folder MEF2A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MEF2A/300bp_unique_balanced.bed
# 300bp.bed of the folder SMARCE1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SMARCE1/300bp_unique_balanced.bed
# 300bp.bed of the folder TEAD4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TEAD4/300bp_unique_balanced.bed
# 300bp.bed of the folder NCOA1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NCOA1/300bp_unique_balanced.bed
# 300bp.bed of the folder PML is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PML/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF701 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF701/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF433 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF433/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF596 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF596/300bp_unique_balanced.bed
# ...
# 300bp.bed of the folder CLOCK is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CLOCK/300bp_unique_balanced.bed
# 300bp.bed of the folder JUNB is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/JUNB/300bp_unique_balanced.bed
# 300bp.bed of the folder HDAC2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HDAC2/300bp_unique_balanced.bed
# 300bp.bed of the folder BCL3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/BCL3/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF37A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF37A/300bp_unique_balanced.bed
# 300bp.bed of the folder MYRF is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MYRF/300bp_unique_balanced.bed
# 300bp.bed of the folder NFRKB is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFRKB/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF280A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF280A/300bp_unique_balanced.bed
# 300bp.bed of the folder CCAR2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CCAR2/300bp_unique_balanced.bed
# 300bp.bed of the folder HES2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HES2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZGPAT is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZGPAT/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF239 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF239/300bp_unique_balanced.bed
# 300bp.bed of the folder DEAF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/DEAF1/300bp_unique_balanced.bed
# 300bp.bed of the folder FOXA2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/FOXA2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF263 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF263/300bp_unique_balanced.bed
# 300bp.bed of the folder SRSF7 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SRSF7/300bp_unique_balanced.bed
# 300bp.bed of the folder GTF2F1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GTF2F1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB33 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB33/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF114 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF114/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF687 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF687/300bp_unique_balanced.bed
# 300bp.bed file is not still generated in the folder CTCF .
# 300bp.bed of the folder RBBP5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBBP5/300bp_unique_balanced.bed
# 300bp.bed of the folder RERE is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RERE/300bp_unique_balanced.bed
# 300bp.bed of the folder SALL2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SALL2/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF766 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF766/300bp_unique_balanced.bed
# 300bp.bed of the folder H3F3A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H3F3A/300bp_unique_balanced.bed
# 300bp.bed of the folder L3MBTL2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/L3MBTL2/300bp_unique_balanced.bed
# 300bp.bed of the folder GABPA is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GABPA/300bp_unique_balanced.bed
# 300bp.bed of the folder HES1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HES1/300bp_unique_balanced.bed
# 300bp.bed of the folder SREBF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SREBF1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB40 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB40/300bp_unique_balanced.bed
# 300bp.bed of the folder ARID4B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ARID4B/300bp_unique_balanced.bed
# 300bp.bed of the folder CREB3L1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CREB3L1/300bp_unique_balanced.bed
# 300bp.bed of the folder WT1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/WT1/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF4/300bp_unique_balanced.bed
# 300bp.bed of the folder TOE1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TOE1/300bp_unique_balanced.bed
# 300bp.bed of the folder MXI1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MXI1/300bp_unique_balanced.bed
# 300bp.bed of the folder HNF4G is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/HNF4G/300bp_unique_balanced.bed
# 300bp.bed of the folder DNMT3B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/DNMT3B/300bp_unique_balanced.bed
# 300bp.bed of the folder MCM3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MCM3/300bp_unique_balanced.bed
# 300bp.bed of the folder H2AK5ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H2AK5ac/300bp_unique_balanced.bed
# 300bp.bed of the folder CEBPG is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CEBPG/300bp_unique_balanced.bed
# 300bp.bed of the folder MAZ is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MAZ/300bp_unique_balanced.bed
# 300bp.bed of the folder ARID1B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ARID1B/300bp_unique_balanced.bed
# 300bp.bed of the folder SMAD4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SMAD4/300bp_unique_balanced.bed
# 300bp.bed of the folder ZFP69B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZFP69B/300bp_unique_balanced.bed
# 300bp.bed of the folder FOXK2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/FOXK2/300bp_unique_balanced.bed
# 300bp.bed of the folder EGR2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/EGR2/300bp_unique_balanced.bed
# 300bp.bed of the folder GATA4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GATA4/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF530 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF530/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF664 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF664/300bp_unique_balanced.bed
# 300bp.bed of the folder KLF16 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/KLF16/300bp_unique_balanced.bed
# 300bp.bed of the folder SP3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SP3/300bp_unique_balanced.bed
# 300bp.bed of the folder RCOR2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RCOR2/300bp_unique_balanced.bed
# 300bp.bed of the folder H3K27ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H3K27ac/300bp_unique_balanced.bed
# 300bp.bed of the folder GTF2B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GTF2B/300bp_unique_balanced.bed
# 300bp.bed of the folder PAX5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PAX5/300bp_unique_balanced.bed
# 300bp.bed of the folder GTF2E2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GTF2E2/300bp_unique_balanced.bed
# 300bp.bed of the folder RBPJ is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RBPJ/300bp_unique_balanced.bed
# 300bp.bed of the folder MEIS2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/MEIS2/300bp_unique_balanced.bed
# 300bp.bed of the folder ELF1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ELF1/300bp_unique_balanced.bed
# 300bp.bed of the folder E2F4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/E2F4/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF652 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF652/300bp_unique_balanced.bed
# 300bp.bed of the folder ASH1L is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ASH1L/300bp_unique_balanced.bed
# 300bp.bed of the folder SMC3 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SMC3/300bp_unique_balanced.bed
# 300bp.bed of the folder CTBP2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/CTBP2/300bp_unique_balanced.bed
# 300bp.bed of the folder H3K23ac is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/H3K23ac/300bp_unique_balanced.bed
# 300bp.bed of the folder SKI is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SKI/300bp_unique_balanced.bed
# 300bp.bed of the folder NR0B1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NR0B1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZSCAN21 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZSCAN21/300bp_unique_balanced.bed
# 300bp.bed of the folder PHF21A is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PHF21A/300bp_unique_balanced.bed
# 300bp.bed of the folder E4F1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/E4F1/300bp_unique_balanced.bed
# 300bp.bed of the folder FOSL1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/FOSL1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF792 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF792/300bp_unique_balanced.bed
# 300bp.bed of the folder ILK is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ILK/300bp_unique_balanced.bed
# 300bp.bed of the folder SNIP1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SNIP1/300bp_unique_balanced.bed
# 300bp.bed of the folder RFX5 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RFX5/300bp_unique_balanced.bed
# 300bp.bed of the folder RELA is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RELA/300bp_unique_balanced.bed
# 300bp.bed of the folder RELB is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RELB/300bp_unique_balanced.bed
# 300bp.bed of the folder BRD4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/BRD4/300bp_unique_balanced.bed
# 300bp.bed of the folder PRDM6 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/PRDM6/300bp_unique_balanced.bed
# 300bp.bed of the folder ETV4 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ETV4/300bp_unique_balanced.bed
# 300bp.bed of the folder TRIM22 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/TRIM22/300bp_unique_balanced.bed
# 300bp.bed of the folder GLIS1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GLIS1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB7B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB7B/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF680 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF680/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF148 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF148/300bp_unique_balanced.bed
# 300bp.bed of the folder YY2 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/YY2/300bp_unique_balanced.bed
# 300bp.bed of the folder DMAP1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/DMAP1/300bp_unique_balanced.bed
# 300bp.bed of the folder GATAD2B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/GATAD2B/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF512B is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF512B/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBED1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBED1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZBTB26 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZBTB26/300bp_unique_balanced.bed
# 300bp.bed of the folder ZFP41 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZFP41/300bp_unique_balanced.bed
# 300bp.bed of the folder NFATC1 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/NFATC1/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF174 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF174/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF7 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF7/300bp_unique_balanced.bed
# 300bp.bed of the folder ZNF221 is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/ZNF221/300bp_unique_balanced.bed
# 300bp.bed of the folder SFPQ is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/SFPQ/300bp_unique_balanced.bed
# 300bp.bed of the folder RFXANK is processing.
# Balanced BED saved to /home/shared/rdavuluri/TFBS_Pallavi/ramana.cewit/1_1_pos_neg/RFXANK/300bp_unique_balanced.bed
