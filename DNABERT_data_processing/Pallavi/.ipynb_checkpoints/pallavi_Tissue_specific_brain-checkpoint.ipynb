# %%
import os, tarfile
import re
import pandas as pd
import numpy as np
import zipfile, gzip
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
input_path = "/data/projects/Tissue_specific_data/TissueEnhanced/DNABERT_raw/"

# %%
tissue_name = "brain"

# %%
df_house = pd.read_csv(input_path+"HouseTrans.csv", sep=",")
df_other = pd.read_csv(input_path+"TspTrans_"+tissue_name+".csv", sep=",")

# %%
output_folder_path ="/data/projects/Tissue_specific_data/TissueEnhanced/DNABERT_Finetuned_Data/"+tissue_name
if not os.path.exists(output_folder_path + '/Evaluation_data'):
    os.makedirs(output_folder_path + '/Evaluation_data')

# %%
df_other
# Out:
#                                  name  \
# 0      chr16:24254335-24256834(brain)
# 1       chr6:83708629-83711128(brain)
# 2    chr13:111151714-111154213(brain)
# 3      chr17:28576396-28578895(brain)
# 4       chr9:36188921-36191420(brain)
# ..                                ...
# 605    chr11:31810645-31813144(brain)
# 606    chr16:56191622-56194121(brain)
# 607    chr11:31810832-31813331(brain)
# 608   chr1:210683430-210685929(brain)
# 609       chr1:2026919-2029418(brain)
#
#                                                   kmer  label
# 0    ATAGGT TAGGTA AGGTAT GGTATA GTATAC TATACA ATAC...      1
# 1    CTCTGC TCTGCG CTGCGG TGCGGA GCGGAG CGGAGG GGAG...      1
# 2    GTTAAG TTAAGA TAAGAC AAGACA AGACAC GACACA ACAC...      1
# 3    CTGAGG TGAGGG GAGGGG AGGGGA GGGGAG GGGAGC GGAG...      1
# 4    CCTCTG CTCTGC TCTGCC CTGCCC TGCCCC GCCCCA CCCC...      1
# ..                                                 ...    ...
# 605  CGCGGG GCGGGC CGGGCT GGGCTT GGCTTT GCTTTC CTTT...      1
# ...

# %%
df_merge = pd.concat([df_house, df_other]).reset_index(drop=True)
df_merge = df_merge.rename(columns={"kmer": "Sequence", "label": "Label"})
df_merge
# Out:
#                                  name  \
# 0        chr13:49792183-49794682(all)
# 1        chr13:41018817-41021316(all)
# 2        chr13:38347851-38350350(all)
# 3        chr13:97951675-97954174(all)
# 4        chr13:49245925-49248424(all)
# ...                               ...
# 4822   chr11:31810645-31813144(brain)
# 4823   chr16:56191622-56194121(brain)
# 4824   chr11:31810832-31813331(brain)
# 4825  chr1:210683430-210685929(brain)
# 4826      chr1:2026919-2029418(brain)
#
#                                                Sequence  Label
# 0     GCCGCG CCGCGC CGCGCC GCGCCC CGCCCG GCCCGC CCCG...      0
# 1     GATATT ATATTT TATTTA ATTTAA TTTAAC TTAACA TAAC...      0
# 2     AAACGT AACGTA ACGTAC CGTACT GTACTT TACTTC ACTT...      0
# 3     ATAAAA TAAAAT AAAATG AAATGT AATGTT ATGTTC TGTT...      0
# 4     GTGTCC TGTCCC GTCCCA TCCCAT CCCATG CCATGG CATG...      0
# ...                                                 ...    ...
# ...

# %%
train, test = train_test_split(df_merge, test_size=0.20)
test, val = train_test_split(test, test_size=0.5)
print (train.shape, test.shape, val.shape)
print(train.groupby(['Label']).size(), test.groupby(['Label']).size() , val.groupby(['Label']).size())
# Out:
# (3861, 3) (483, 3) (483, 3)
# Label
# 0    3369
# 1     492
# dtype: int64 Label
# 0    436
# 1     47
# dtype: int64 Label
# 0    412
# 1     71
# dtype: int64

# %%
train[['Sequence','Label']].to_csv(output_folder_path+"/train.tsv", sep="\t", index=False)
test[['Sequence','Label']].to_csv(output_folder_path+"/dev.tsv", sep="\t", index=False)
val[['Sequence','Label']].to_csv(output_folder_path+"/Evaluation_data/dev.tsv", sep="\t", index=False)

# %%
split_raw_folder = input_path + "/" + tissue_name
if not os.path.exists(split_raw_folder):
    os.makedirs(split_raw_folder)

# %%
train.to_csv(split_raw_folder+"/train_raw.tsv", sep="\t", index=False)
test.to_csv(split_raw_folder+"/dev_raw.tsv", sep="\t", index=False)
val.to_csv(split_raw_folder+"/test_raw.tsv", sep="\t", index=False)
