# %% [markdown]
# ### This is pipeline for `RNA-Seq` analysis. For this, I have used `interactive jupyter-notebook`, where I can run any `shell script`, `R` code or `python` code. For know more about `interactive jupyter-notebook` you can go through following links.
#
# * https://jakevdp.github.io/PythonDataScienceHandbook/01.05-ipython-and-shell-commands.html
# * https://stackoverflow.com/questions/53301306/access-variable-declared-in-a-bash-cell-from-another-jupyter-cell
# * https://www.linkedin.com/pulse/interfacing-r-from-python-3-jupyter-notebook-jared-stufft/
# * https://hbctraining.github.io/Intro-to-rnaseq-hpc-O2/lessons/02_assessing_quality.html
# * https://bioinformatics.uconn.edu/resources-and-events/tutorials-2/rna-seq-tutorial-with-reference-genome/#
# * https://towardsdatascience.com/guide-to-r-and-python-in-a-single-jupyter-notebook-ff12532eb3ba

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# library(edgeR)
# library(RColorBrewer)
# #library(pheatmap)
# #library(EnhancedVolcano)
# # library(goseq)
# # library(ggplot2)
# # library(dplyr)
# # library(biomaRt)
# # library(goseq)
# #library(sratoolkit)
# Out:
# R[write to console]: Loading required package: limma

# %% [markdown]
# #### For this work, we have used 6 samples(SRR) from the study [SRP103945](https://www.ncbi.nlm.nih.gov/Traces/study/?acc=PRJNA382981&o=acc_s%3Aa). The 6 RNA-seq samples are `SRR5448863`, `SRR5448864`, `SRR5448865`, `SRR5448866`,`SRR5448867`, and `SRR5448868` . To know about more about the samples and study please go through the [link1](https://www.refine.bio/experiments/SRP103945/rna-seq-and-chip-seq-analysis-of-bmi1-or-ring1b-silenced-prostate-cancer-cells-c4-2) and [link2](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE97831).
#
# * https://linsalrob.github.io/ComputationalGenomicsManual/Databases/SRA.html

# %% [markdown]
# ### Assign variables for the entire pipeline.

# %%
import rpy2.rinterface
import os
home_dir= os.path.expanduser('~')
SRA_List=[ "SRR5448863","SRR5448864", "SRR5448866", "SRR5448868"]
SRA_1="SRR5448863"
FASTQ_DIR = home_dir+ "/ncbi/fastq/"
FASTQC_DIR = home_dir+ "/ncbi/fastqc/"
BOWTIE_SAM_OUT_DIR  = home_dir+"/ncbi/bowtie_output"
BAM_DIR  = home_dir+"/ncbi/BAM_files/"
ANNOTATION_FILE = home_dir+"/ncbi/reference/gencode.v39.annotation.gtf"
HT_SEQ_OUT_DIR= home_dir+"/ncbi/HT_Seq_Count/"

# %%
HT_SEQ_OUT_DIR
# Out:
# '/home/pdutta/ncbi/HT_Seq_Count/'

# %% [markdown]
# ### `prefetch`: Download data from `NCBI Sequence Read Archive` in `.sra` format using FASP or HTTPS protocols

# %%
for sra in SRA_List:
    print("\nSRA: ",sra)
    ! prefetch $sra
# Out:
# SRA:  SRR5448863
#
# 2022-04-07T22:29:11 prefetch.2.8.0: 1) 'SRR5448863' is found locally
#
# SRA:  SRR5448864
#
# 2022-04-07T22:29:11 prefetch.2.8.0: 1) Downloading 'SRR5448864'...
# 2022-04-07T22:29:11 prefetch.2.8.0:  Downloading via http...
# 2022-04-07T22:30:52 prefetch.2.8.0: 1) 'SRR5448864' was downloaded successfully
#
# SRA:  SRR5448866
#
# 2022-04-07T22:30:53 prefetch.2.8.0: 1) Downloading 'SRR5448866'...
# 2022-04-07T22:30:53 prefetch.2.8.0:  Downloading via http...
# 2022-04-07T22:32:55 prefetch.2.8.0: 1) 'SRR5448866' was downloaded successfully
#
# SRA:  SRR5448868
#
# 2022-04-07T22:32:55 prefetch.2.8.0: 1) Downloading 'SRR5448868'...
# 2022-04-07T22:32:55 prefetch.2.8.0:  Downloading via http...
# 2022-04-07T22:34:42 prefetch.2.8.0: 1) 'SRR5448868' was downloaded successfully

# %% [markdown]
# #### `fastq-dump` is a tool for downloading sequencing reads from NCBI’s Sequence Read Archive (SRA). These sequence reads will be downloaded as `FASTQ` files.
# * https://rnnh.github.io/bioinfo-notebook/docs/fastq-dump.html
# * https://www.reneshbedre.com/blog/ncbi_sra_toolkit.html

# %%
! mkdir -p -- "$FASTQ_DIR"
for sra in SRA_List:
    print("\nSRA: ",sra)
    ! fastq-dump --skip-technical --readids --read-filter pass --dumpbase --outdir "$FASTQ_DIR" --split-files "$sra"
# Out:
# SRA:  SRR5448863
# Read 33558497 spots for SRR5448863
# Written 33558497 spots for SRR5448863
#
# SRA:  SRR5448864
# Read 29781556 spots for SRR5448864
# Written 29781556 spots for SRR5448864
#
# SRA:  SRR5448866
# Read 27465767 spots for SRR5448866
# Written 27465767 spots for SRR5448866
#
# SRA:  SRR5448868
# Read 29232809 spots for SRR5448868
# Written 29232809 spots for SRR5448868

# %% [markdown]
# #### `FastQC` provides a simple way to do some quality control checks on raw sequence data coming from high throughput sequencing pipelines.

# %%
! mkdir -p -- "$FASTQC_DIR"
! fastqc -t 30 --outdir "$FASTQC_DIR" $FASTQ_DIR*.fastq
# Out:
# Started analysis of SRR5448863_pass_1.fastq
# Started analysis of SRR5448863_pass_2.fastq
# Started analysis of SRR5448864_pass_1.fastq
# Started analysis of SRR5448864_pass_2.fastq
# Started analysis of SRR5448866_pass_1.fastq
# Started analysis of SRR5448866_pass_2.fastq
# Started analysis of SRR5448868_pass_1.fastq
# Started analysis of SRR5448868_pass_2.fastq
# Approx 5% complete for SRR5448864_pass_1.fastq
# Approx 5% complete for SRR5448863_pass_1.fastq
# Approx 5% complete for SRR5448866_pass_1.fastq
# Approx 5% complete for SRR5448864_pass_2.fastq
# Approx 5% complete for SRR5448863_pass_2.fastq
# Approx 5% complete for SRR5448866_pass_2.fastq
# Approx 5% complete for SRR5448868_pass_1.fastq
# Approx 5% complete for SRR5448868_pass_2.fastq
# Approx 10% complete for SRR5448866_pass_1.fastq
# Approx 10% complete for SRR5448864_pass_1.fastq
# Approx 10% complete for SRR5448866_pass_2.fastq
# Approx 10% complete for SRR5448868_pass_1.fastq
# Approx 10% complete for SRR5448864_pass_2.fastq
# Approx 10% complete for SRR5448863_pass_1.fastq
# Approx 10% complete for SRR5448863_pass_2.fastq
# Approx 10% complete for SRR5448868_pass_2.fastq
# Approx 15% complete for SRR5448866_pass_1.fastq
# Approx 15% complete for SRR5448866_pass_2.fastq
# Approx 15% complete for SRR5448864_pass_1.fastq
# Approx 15% complete for SRR5448868_pass_1.fastq
# Approx 15% complete for SRR5448864_pass_2.fastq
# Approx 15% complete for SRR5448868_pass_2.fastq
# Approx 15% complete for SRR5448863_pass_1.fastq
# Approx 15% complete for SRR5448863_pass_2.fastq
# Approx 20% complete for SRR5448866_pass_1.fastq
# Approx 20% complete for SRR5448866_pass_2.fastq
# Approx 20% complete for SRR5448868_pass_1.fastq
# Approx 20% complete for SRR5448864_pass_1.fastq
# Approx 20% complete for SRR5448864_pass_2.fastq
# Approx 20% complete for SRR5448868_pass_2.fastq
# Approx 20% complete for SRR5448863_pass_1.fastq
# Approx 20% complete for SRR5448863_pass_2.fastq
# Approx 25% complete for SRR5448866_pass_1.fastq
# Approx 25% complete for SRR5448866_pass_2.fastq
# Approx 25% complete for SRR5448868_pass_1.fastq
# Approx 25% complete for SRR5448864_pass_1.fastq
# Approx 25% complete for SRR5448868_pass_2.fastq
# Approx 25% complete for SRR5448864_pass_2.fastq
# Approx 25% complete for SRR5448863_pass_1.fastq
# Approx 30% complete for SRR5448866_pass_1.fastq
# Approx 30% complete for SRR5448866_pass_2.fastq
# Approx 25% complete for SRR5448863_pass_2.fastq
# Approx 30% complete for SRR5448868_pass_1.fastq
# Approx 30% complete for SRR5448864_pass_1.fastq
# Approx 30% complete for SRR5448868_pass_2.fastq
# Approx 30% complete for SRR5448864_pass_2.fastq
# Approx 35% complete for SRR5448866_pass_1.fastq
# Approx 30% complete for SRR5448863_pass_1.fastq
# Approx 35% complete for SRR5448866_pass_2.fastq
# Approx 35% complete for SRR5448868_pass_1.fastq
# Approx 30% complete for SRR5448863_pass_2.fastq
# Approx 35% complete for SRR5448864_pass_1.fastq
# Approx 35% complete for SRR5448868_pass_2.fastq
# Approx 35% complete for SRR5448864_pass_2.fastq
# Approx 40% complete for SRR5448866_pass_1.fastq
# Approx 40% complete for SRR5448866_pass_2.fastq
# Approx 40% complete for SRR5448868_pass_1.fastq
# Approx 35% complete for SRR5448863_pass_1.fastq
# Approx 35% complete for SRR5448863_pass_2.fastq
# Approx 40% complete for SRR5448864_pass_1.fastq
# Approx 40% complete for SRR5448868_pass_2.fastq
# Approx 40% complete for SRR5448864_pass_2.fastq
# Approx 45% complete for SRR5448866_pass_1.fastq
# Approx 45% complete for SRR5448866_pass_2.fastq
# Approx 45% complete for SRR5448868_pass_1.fastq
# Approx 40% complete for SRR5448863_pass_1.fastq
# Approx 45% complete for SRR5448864_pass_1.fastq
# Approx 40% complete for SRR5448863_pass_2.fastq
# Approx 45% complete for SRR5448868_pass_2.fastq
# Approx 50% complete for SRR5448866_pass_1.fastq
# Approx 45% complete for SRR5448864_pass_2.fastq
# Approx 50% complete for SRR5448866_pass_2.fastq
# Approx 50% complete for SRR5448868_pass_1.fastq
# Approx 50% complete for SRR5448864_pass_1.fastq
# Approx 45% complete for SRR5448863_pass_1.fastq
# Approx 50% complete for SRR5448868_pass_2.fastq
# Approx 55% complete for SRR5448866_pass_1.fastq
# Approx 50% complete for SRR5448864_pass_2.fastq
# Approx 45% complete for SRR5448863_pass_2.fastq
# Approx 55% complete for SRR5448866_pass_2.fastq
# Approx 55% complete for SRR5448868_pass_1.fastq
# Approx 55% complete for SRR5448864_pass_1.fastq
# Approx 60% complete for SRR5448866_pass_1.fastq
# Approx 55% complete for SRR5448868_pass_2.fastq
# Approx 50% complete for SRR5448863_pass_1.fastq
# Approx 55% complete for SRR5448864_pass_2.fastq
# Approx 60% complete for SRR5448866_pass_2.fastq
# Approx 50% complete for SRR5448863_pass_2.fastq
# Approx 60% complete for SRR5448868_pass_1.fastq
# Approx 65% complete for SRR5448866_pass_1.fastq
# Approx 60% complete for SRR5448864_pass_1.fastq
# Approx 60% complete for SRR5448868_pass_2.fastq
# Approx 65% complete for SRR5448866_pass_2.fastq
# Approx 60% complete for SRR5448864_pass_2.fastq
# Approx 55% complete for SRR5448863_pass_1.fastq
# Approx 55% complete for SRR5448863_pass_2.fastq
# Approx 65% complete for SRR5448868_pass_1.fastq
# Approx 70% complete for SRR5448866_pass_1.fastq
# Approx 65% complete for SRR5448864_pass_1.fastq
# Approx 65% complete for SRR5448868_pass_2.fastq
# Approx 70% complete for SRR5448866_pass_2.fastq
# Approx 65% complete for SRR5448864_pass_2.fastq
# Approx 60% complete for SRR5448863_pass_1.fastq
# Approx 70% complete for SRR5448868_pass_1.fastq
# Approx 60% complete for SRR5448863_pass_2.fastq
# Approx 75% complete for SRR5448866_pass_1.fastq
# Approx 70% complete for SRR5448868_pass_2.fastq
# Approx 75% complete for SRR5448866_pass_2.fastq
# Approx 70% complete for SRR5448864_pass_1.fastq
# Approx 70% complete for SRR5448864_pass_2.fastq
# Approx 75% complete for SRR5448868_pass_1.fastq
# Approx 65% complete for SRR5448863_pass_1.fastq
# Approx 80% complete for SRR5448866_pass_1.fastq
# Approx 65% complete for SRR5448863_pass_2.fastq
# Approx 80% complete for SRR5448866_pass_2.fastq
# Approx 75% complete for SRR5448868_pass_2.fastq
# Approx 75% complete for SRR5448864_pass_1.fastq
# Approx 75% complete for SRR5448864_pass_2.fastq
# Approx 80% complete for SRR5448868_pass_1.fastq
# Approx 85% complete for SRR5448866_pass_1.fastq
# Approx 70% complete for SRR5448863_pass_1.fastq
# Approx 85% complete for SRR5448866_pass_2.fastq
# Approx 80% complete for SRR5448868_pass_2.fastq
# Approx 70% complete for SRR5448863_pass_2.fastq
# Approx 80% complete for SRR5448864_pass_1.fastq
# Approx 80% complete for SRR5448864_pass_2.fastq
# Approx 85% complete for SRR5448868_pass_1.fastq
# Approx 90% complete for SRR5448866_pass_1.fastq
# Approx 90% complete for SRR5448866_pass_2.fastq
# Approx 75% complete for SRR5448863_pass_1.fastq
# Approx 85% complete for SRR5448868_pass_2.fastq
# Approx 75% complete for SRR5448863_pass_2.fastq
# Approx 85% complete for SRR5448864_pass_1.fastq
# Approx 90% complete for SRR5448868_pass_1.fastq
# Approx 85% complete for SRR5448864_pass_2.fastq
# Approx 95% complete for SRR5448866_pass_1.fastq
# Approx 95% complete for SRR5448866_pass_2.fastq
# Approx 90% complete for SRR5448868_pass_2.fastq
# Approx 80% complete for SRR5448863_pass_1.fastq
# Approx 90% complete for SRR5448864_pass_1.fastq
# Approx 80% complete for SRR5448863_pass_2.fastq
# Approx 95% complete for SRR5448868_pass_1.fastq
# Approx 90% complete for SRR5448864_pass_2.fastq
# Analysis complete for SRR5448866_pass_1.fastq
# Analysis complete for SRR5448866_pass_2.fastq
# Approx 95% complete for SRR5448868_pass_2.fastq
# Approx 95% complete for SRR5448864_pass_1.fastq
# Approx 85% complete for SRR5448863_pass_1.fastq
# Analysis complete for SRR5448868_pass_1.fastq
# Approx 85% complete for SRR5448863_pass_2.fastq
# Approx 95% complete for SRR5448864_pass_2.fastq
# Analysis complete for SRR5448868_pass_2.fastq
# Analysis complete for SRR5448864_pass_1.fastq
# Approx 90% complete for SRR5448863_pass_1.fastq
# Analysis complete for SRR5448864_pass_2.fastq
# Approx 90% complete for SRR5448863_pass_2.fastq
# Approx 95% complete for SRR5448863_pass_1.fastq
# Approx 95% complete for SRR5448863_pass_2.fastq
# Analysis complete for SRR5448863_pass_1.fastq
# Analysis complete for SRR5448863_pass_2.fastq

# %% [markdown]
# ## Alignment using `bowtie2`.
# * https://rnnh.github.io/bioinfo-notebook/docs/bowtie2.html
# ## To install `bowtie2` you can use any of two approaches
#  * For installing using conda, try ```conda install -c bioconda/label/broken bowtie2```
#  * For manual installation, please follow the link https://www.metagenomics.wiki/tools/bowtie2/install

# %% [markdown]
# ### Run the `script` file named `bowtie2.sh`. The file generats `.SAM` file.

# %%
! head "$BOWTIE_SAM_OUT_DIR/output.sam"
# Out:
# @HD	VN:1.0	SO:unsorted
# @SQ	SN:chr1	LN:248956422
# @SQ	SN:chr2	LN:242193529
# @SQ	SN:chr3	LN:198295559
# @SQ	SN:chr4	LN:190214555
# @SQ	SN:chr5	LN:181538259
# @SQ	SN:chr6	LN:170805979
# @SQ	SN:chr7	LN:159345973
# @SQ	SN:chr8	LN:145138636
# @SQ	SN:chr9	LN:138394717

# %% [markdown]
# ### Now we will use `samtools` to generate `.bam` file from the generated `.sam` file
# * For install samtools, use the following conda command <br>
#   `conda install -c bioconda samtools==1.15`
#
# * https://rnnh.github.io/bioinfo-notebook/docs/samtools.html
# * http://quinlanlab.org/tutorials/samtools/samtools.html

# %%
! mkdir -p -- "$BAM_DIR"
for sra in SRA_List:
    print("Using SAMTOOLS for" , sra )
    # !samtools view -@ n -Sb -o "$BAM_DIR$sra".bam "$BOWTIE_SAM_OUT_DIR/$sra"_SAM.sam
    # !samtools sort -O bam -o "$BAM_DIR"sorted_"$sra".bam "$BAM_DIR$sra".bam
    # !samtools index "$BAM_DIR"sorted_"$sra".bam
#! samtools view sample.bam | head
# Out:
# Using SAMTOOLS for SRR5448863
# [bam_sort_core] merging from 20 files and 1 in-memory blocks...
# Using SAMTOOLS for SRR5448864
# [main_samview] fail to read the header from "/home/pdutta/ncbi/bowtie_output/SRR5448864_SAM.sam".
# [E::hts_open_format] Failed to open file "/home/pdutta/ncbi/BAM_files/SRR5448864.bam" : No such file or directory
# samtools sort: can't open "/home/pdutta/ncbi/BAM_files/SRR5448864.bam": No such file or directory
# [E::hts_open_format] Failed to open file "/home/pdutta/ncbi/BAM_files/sorted_SRR5448864.bam" : No such file or directory
# samtools index: failed to open "/home/pdutta/ncbi/BAM_files/sorted_SRR5448864.bam": No such file or directory
# Using SAMTOOLS for SRR5448866
# [bam_sort_core] merging from 16 files and 1 in-memory blocks...
# Using SAMTOOLS for SRR5448868
# [bam_sort_core] merging from 17 files and 1 in-memory blocks...

# %% [markdown]
# ### We have used `HtSeq` to count how many reads map for each feature.
# https://rnnh.github.io/bioinfo-notebook/docs/htseq-count.html

# %%
! mkdir -p -- "$HT_SEQ_OUT_DIR"
for sra in SRA_List:
    ! htseq-count --format bam "$BAM_DIR"sorted_"$sra".bam "$ANNOTATION_FILE" > "$HT_SEQ_OUT_DIR$sra"Htseq_count.txt
# Out:
# 100000 GFF lines processed.
# 200000 GFF lines processed.
# 300000 GFF lines processed.
# 400000 GFF lines processed.
# 500000 GFF lines processed.
# 600000 GFF lines processed.
# 700000 GFF lines processed.
# 800000 GFF lines processed.
# 900000 GFF lines processed.
# 1000000 GFF lines processed.
# 1100000 GFF lines processed.
# 1200000 GFF lines processed.
# 1300000 GFF lines processed.
# 1400000 GFF lines processed.
# 1500000 GFF lines processed.
# 1600000 GFF lines processed.
# 1700000 GFF lines processed.
# 1800000 GFF lines processed.
# 1900000 GFF lines processed.
# 2000000 GFF lines processed.
# 2100000 GFF lines processed.
# 2200000 GFF lines processed.
# 2300000 GFF lines processed.
# 2400000 GFF lines processed.
# 2500000 GFF lines processed.
# 2600000 GFF lines processed.
# 2700000 GFF lines processed.
# 2800000 GFF lines processed.
# 2900000 GFF lines processed.
# 3000000 GFF lines processed.
# 3100000 GFF lines processed.
# 3200000 GFF lines processed.
# 3241002 GFF lines processed.
# Warning: Read SRR5448863.23471568.1 claims to have an aligned mate which could not be found in an adjacent line.
# 100000 alignment record pairs processed.
# 200000 alignment record pairs processed.
# 300000 alignment record pairs processed.
# 400000 alignment record pairs processed.
# 500000 alignment record pairs processed.
# 600000 alignment record pairs processed.
# 700000 alignment record pairs processed.
# 800000 alignment record pairs processed.
# 900000 alignment record pairs processed.
# 1000000 alignment record pairs processed.
# 1100000 alignment record pairs processed.
# 1200000 alignment record pairs processed.
# 1300000 alignment record pairs processed.
# 1400000 alignment record pairs processed.
# 1500000 alignment record pairs processed.
# 1600000 alignment record pairs processed.
# 1700000 alignment record pairs processed.
# 1800000 alignment record pairs processed.
# 1900000 alignment record pairs processed.
# 2000000 alignment record pairs processed.
# 2100000 alignment record pairs processed.
# 2200000 alignment record pairs processed.
# 2300000 alignment record pairs processed.
# 2400000 alignment record pairs processed.
# 2500000 alignment record pairs processed.
# 2600000 alignment record pairs processed.
# 2700000 alignment record pairs processed.
# 2800000 alignment record pairs processed.
# 2900000 alignment record pairs processed.
# 3000000 alignment record pairs processed.
# 3100000 alignment record pairs processed.
# 3200000 alignment record pairs processed.
# 3300000 alignment record pairs processed.
# 3400000 alignment record pairs processed.
# 3500000 alignment record pairs processed.
# 3600000 alignment record pairs processed.
# 3700000 alignment record pairs processed.
# 3800000 alignment record pairs processed.
# 3900000 alignment record pairs processed.
# 4000000 alignment record pairs processed.
# 4100000 alignment record pairs processed.
# 4200000 alignment record pairs processed.
# 4300000 alignment record pairs processed.
# 4400000 alignment record pairs processed.
# 4500000 alignment record pairs processed.
# 4600000 alignment record pairs processed.
# 4700000 alignment record pairs processed.
# 4800000 alignment record pairs processed.
# 4900000 alignment record pairs processed.
# 5000000 alignment record pairs processed.
# 5100000 alignment record pairs processed.
# 5200000 alignment record pairs processed.
# 5300000 alignment record pairs processed.
# 5400000 alignment record pairs processed.
# 5500000 alignment record pairs processed.
# 5600000 alignment record pairs processed.
# 5700000 alignment record pairs processed.
# 5800000 alignment record pairs processed.
# 5900000 alignment record pairs processed.
# 6000000 alignment record pairs processed.
# 6100000 alignment record pairs processed.
# 6200000 alignment record pairs processed.
# 6300000 alignment record pairs processed.
# 6400000 alignment record pairs processed.
# 6500000 alignment record pairs processed.
# 6600000 alignment record pairs processed.
# 6700000 alignment record pairs processed.
# 6800000 alignment record pairs processed.
# 6900000 alignment record pairs processed.
# 7000000 alignment record pairs processed.
# 7100000 alignment record pairs processed.
# 7200000 alignment record pairs processed.
# 7300000 alignment record pairs processed.
# 7400000 alignment record pairs processed.
# 7500000 alignment record pairs processed.
# 7600000 alignment record pairs processed.
# 7700000 alignment record pairs processed.
# 7800000 alignment record pairs processed.
# 7900000 alignment record pairs processed.
# 8000000 alignment record pairs processed.
# 8100000 alignment record pairs processed.
# 8200000 alignment record pairs processed.
# 8300000 alignment record pairs processed.
# 8400000 alignment record pairs processed.
# 8500000 alignment record pairs processed.
# 8600000 alignment record pairs processed.
# 8700000 alignment record pairs processed.
# 8800000 alignment record pairs processed.
# 8900000 alignment record pairs processed.
# 9000000 alignment record pairs processed.
# 9100000 alignment record pairs processed.
# 9200000 alignment record pairs processed.
# 9300000 alignment record pairs processed.
# 9400000 alignment record pairs processed.
# 9500000 alignment record pairs processed.
# 9600000 alignment record pairs processed.
# 9700000 alignment record pairs processed.
# 9800000 alignment record pairs processed.
# 9900000 alignment record pairs processed.
# 10000000 alignment record pairs processed.
# 10100000 alignment record pairs processed.
# 10200000 alignment record pairs processed.
# 10300000 alignment record pairs processed.
# 10400000 alignment record pairs processed.
# 10500000 alignment record pairs processed.
# 10600000 alignment record pairs processed.
# 10700000 alignment record pairs processed.
# 10800000 alignment record pairs processed.
# 10900000 alignment record pairs processed.
# 11000000 alignment record pairs processed.
# 11100000 alignment record pairs processed.
# 11200000 alignment record pairs processed.
# 11300000 alignment record pairs processed.
# 11400000 alignment record pairs processed.
# 11500000 alignment record pairs processed.
# 11600000 alignment record pairs processed.
# 11700000 alignment record pairs processed.
# 11800000 alignment record pairs processed.
# 11900000 alignment record pairs processed.
# 12000000 alignment record pairs processed.
# 12100000 alignment record pairs processed.
# 12200000 alignment record pairs processed.
# 12300000 alignment record pairs processed.
# 12400000 alignment record pairs processed.
# 12500000 alignment record pairs processed.
# 12600000 alignment record pairs processed.
# 12700000 alignment record pairs processed.
# 12800000 alignment record pairs processed.
# 12900000 alignment record pairs processed.
# 13000000 alignment record pairs processed.
# 13100000 alignment record pairs processed.
# 13200000 alignment record pairs processed.
# 13300000 alignment record pairs processed.
# 13400000 alignment record pairs processed.
# 13500000 alignment record pairs processed.
# 13600000 alignment record pairs processed.
# 13700000 alignment record pairs processed.
# 13800000 alignment record pairs processed.
# 13900000 alignment record pairs processed.
# 14000000 alignment record pairs processed.
# 14100000 alignment record pairs processed.
# 14200000 alignment record pairs processed.
# 14300000 alignment record pairs processed.
# 14400000 alignment record pairs processed.
# 14500000 alignment record pairs processed.
# 14600000 alignment record pairs processed.
# 14700000 alignment record pairs processed.
# 14800000 alignment record pairs processed.
# 14900000 alignment record pairs processed.
# 15000000 alignment record pairs processed.
# 15100000 alignment record pairs processed.
# 15200000 alignment record pairs processed.
# 15300000 alignment record pairs processed.
# 15400000 alignment record pairs processed.
# 15500000 alignment record pairs processed.
# 15600000 alignment record pairs processed.
# 15700000 alignment record pairs processed.
# 15800000 alignment record pairs processed.
# 15900000 alignment record pairs processed.
# 16000000 alignment record pairs processed.
# 16100000 alignment record pairs processed.
# 16200000 alignment record pairs processed.
# 16300000 alignment record pairs processed.
# 16400000 alignment record pairs processed.
# 16500000 alignment record pairs processed.
# 16600000 alignment record pairs processed.
# 16700000 alignment record pairs processed.
# 16800000 alignment record pairs processed.
# 16900000 alignment record pairs processed.
# 17000000 alignment record pairs processed.
# 17100000 alignment record pairs processed.
# 17200000 alignment record pairs processed.
# 17300000 alignment record pairs processed.
# 17400000 alignment record pairs processed.
# 17500000 alignment record pairs processed.
# 17600000 alignment record pairs processed.
# 17700000 alignment record pairs processed.
# 17800000 alignment record pairs processed.
# 17900000 alignment record pairs processed.
# 18000000 alignment record pairs processed.
# 18100000 alignment record pairs processed.
# 18200000 alignment record pairs processed.
# 18300000 alignment record pairs processed.
# 18400000 alignment record pairs processed.
# 18500000 alignment record pairs processed.
# 18600000 alignment record pairs processed.
# 18700000 alignment record pairs processed.
# 18800000 alignment record pairs processed.
# 18900000 alignment record pairs processed.
# 19000000 alignment record pairs processed.
# 19100000 alignment record pairs processed.
# 19200000 alignment record pairs processed.
# 19300000 alignment record pairs processed.
# 19400000 alignment record pairs processed.
# 19500000 alignment record pairs processed.
# 19600000 alignment record pairs processed.
# 19700000 alignment record pairs processed.
# 19800000 alignment record pairs processed.
# 19900000 alignment record pairs processed.
# 20000000 alignment record pairs processed.
# 20100000 alignment record pairs processed.
# 20200000 alignment record pairs processed.
# 20300000 alignment record pairs processed.
# 20400000 alignment record pairs processed.
# 20500000 alignment record pairs processed.
# 20600000 alignment record pairs processed.
# 20700000 alignment record pairs processed.
# 20800000 alignment record pairs processed.
# 20900000 alignment record pairs processed.
# 21000000 alignment record pairs processed.
# 21100000 alignment record pairs processed.
# 21200000 alignment record pairs processed.
# 21300000 alignment record pairs processed.
# 21400000 alignment record pairs processed.
# 21500000 alignment record pairs processed.
# 21600000 alignment record pairs processed.
# 21700000 alignment record pairs processed.
# 21800000 alignment record pairs processed.
# 21900000 alignment record pairs processed.
# 22000000 alignment record pairs processed.
# 22100000 alignment record pairs processed.
# 22200000 alignment record pairs processed.
# 22300000 alignment record pairs processed.
# 22400000 alignment record pairs processed.
# 22500000 alignment record pairs processed.
# 22600000 alignment record pairs processed.
# 22700000 alignment record pairs processed.
# 22800000 alignment record pairs processed.
# 22900000 alignment record pairs processed.
# 23000000 alignment record pairs processed.
# 23100000 alignment record pairs processed.
# 23200000 alignment record pairs processed.
# 23300000 alignment record pairs processed.
# 23400000 alignment record pairs processed.
# 23500000 alignment record pairs processed.
# 23600000 alignment record pairs processed.
# 23700000 alignment record pairs processed.
# 23800000 alignment record pairs processed.
# 23900000 alignment record pairs processed.
# 24000000 alignment record pairs processed.
# 24100000 alignment record pairs processed.
# 24200000 alignment record pairs processed.
# 24300000 alignment record pairs processed.
# 24400000 alignment record pairs processed.
# 24500000 alignment record pairs processed.
# 24600000 alignment record pairs processed.
# 24700000 alignment record pairs processed.
# 24800000 alignment record pairs processed.
# 24900000 alignment record pairs processed.
# 25000000 alignment record pairs processed.
# 25100000 alignment record pairs processed.
# 25200000 alignment record pairs processed.
# 25300000 alignment record pairs processed.
# 25400000 alignment record pairs processed.
# 25500000 alignment record pairs processed.
# 25600000 alignment record pairs processed.
# 25700000 alignment record pairs processed.
# 25800000 alignment record pairs processed.
# 25900000 alignment record pairs processed.
# 26000000 alignment record pairs processed.
# 26100000 alignment record pairs processed.
# 26200000 alignment record pairs processed.
# 26300000 alignment record pairs processed.
# 26400000 alignment record pairs processed.
# 26500000 alignment record pairs processed.
# 26600000 alignment record pairs processed.
# 26700000 alignment record pairs processed.
# 26800000 alignment record pairs processed.
# 26900000 alignment record pairs processed.
# 27000000 alignment record pairs processed.
# 27100000 alignment record pairs processed.
# 27200000 alignment record pairs processed.
# 27300000 alignment record pairs processed.
# 27400000 alignment record pairs processed.
# 27500000 alignment record pairs processed.
# 27600000 alignment record pairs processed.
# 27700000 alignment record pairs processed.
# 27800000 alignment record pairs processed.
# 27900000 alignment record pairs processed.
# 28000000 alignment record pairs processed.
# 28100000 alignment record pairs processed.
# 28200000 alignment record pairs processed.
# 28300000 alignment record pairs processed.
# 28400000 alignment record pairs processed.
# 28500000 alignment record pairs processed.
# 28600000 alignment record pairs processed.
# 28700000 alignment record pairs processed.
# 28800000 alignment record pairs processed.
# 28900000 alignment record pairs processed.
# 29000000 alignment record pairs processed.
# 29100000 alignment record pairs processed.
# 29200000 alignment record pairs processed.
# 29300000 alignment record pairs processed.
# 29400000 alignment record pairs processed.
# 29500000 alignment record pairs processed.
# 29600000 alignment record pairs processed.
# 29700000 alignment record pairs processed.
# 29800000 alignment record pairs processed.
# 29900000 alignment record pairs processed.
# 30000000 alignment record pairs processed.
# 30100000 alignment record pairs processed.
# 30200000 alignment record pairs processed.
# 30300000 alignment record pairs processed.
# 30400000 alignment record pairs processed.
# 30500000 alignment record pairs processed.
# 30600000 alignment record pairs processed.
# 30700000 alignment record pairs processed.
# 30800000 alignment record pairs processed.
# 30900000 alignment record pairs processed.
# 31000000 alignment record pairs processed.
# 31100000 alignment record pairs processed.
# 31200000 alignment record pairs processed.
# 31300000 alignment record pairs processed.
# 31400000 alignment record pairs processed.
# 31500000 alignment record pairs processed.
# 31600000 alignment record pairs processed.
# 31700000 alignment record pairs processed.
# 31800000 alignment record pairs processed.
# 31900000 alignment record pairs processed.
# 32000000 alignment record pairs processed.
# 32100000 alignment record pairs processed.
# 32200000 alignment record pairs processed.
# 32300000 alignment record pairs processed.
# 32400000 alignment record pairs processed.
# 32500000 alignment record pairs processed.
# 32600000 alignment record pairs processed.
# 32700000 alignment record pairs processed.
# 32800000 alignment record pairs processed.
# 32900000 alignment record pairs processed.
# 33000000 alignment record pairs processed.
# 33100000 alignment record pairs processed.
# 33200000 alignment record pairs processed.
# 33300000 alignment record pairs processed.
# 33400000 alignment record pairs processed.
# 33500000 alignment record pairs processed.
# 33600000 alignment record pairs processed.
# 33700000 alignment record pairs processed.
# 33800000 alignment record pairs processed.
# 33900000 alignment record pairs processed.
# 34000000 alignment record pairs processed.
# 34100000 alignment record pairs processed.
# 34200000 alignment record pairs processed.
# 34300000 alignment record pairs processed.
# 34400000 alignment record pairs processed.
# 34500000 alignment record pairs processed.
# 34600000 alignment record pairs processed.
# 34700000 alignment record pairs processed.
# 34800000 alignment record pairs processed.
# 34900000 alignment record pairs processed.
# 35000000 alignment record pairs processed.
# 35100000 alignment record pairs processed.
# 35200000 alignment record pairs processed.
# 35300000 alignment record pairs processed.
# 35400000 alignment record pairs processed.
# 35500000 alignment record pairs processed.
# 35600000 alignment record pairs processed.
# 35700000 alignment record pairs processed.
# 35800000 alignment record pairs processed.
# 35900000 alignment record pairs processed.
# 36000000 alignment record pairs processed.
# 36100000 alignment record pairs processed.
# 36200000 alignment record pairs processed.
# 36300000 alignment record pairs processed.
# 36400000 alignment record pairs processed.
# 36500000 alignment record pairs processed.
# 36600000 alignment record pairs processed.
# 36700000 alignment record pairs processed.
# 36800000 alignment record pairs processed.
# 36900000 alignment record pairs processed.
# 37000000 alignment record pairs processed.
# 37100000 alignment record pairs processed.
# 37200000 alignment record pairs processed.
# 37300000 alignment record pairs processed.
# 37400000 alignment record pairs processed.
# 37500000 alignment record pairs processed.
# 37600000 alignment record pairs processed.
# 37700000 alignment record pairs processed.
# 37800000 alignment record pairs processed.
# 37900000 alignment record pairs processed.
# 38000000 alignment record pairs processed.
# 38100000 alignment record pairs processed.
# 38200000 alignment record pairs processed.
# 38300000 alignment record pairs processed.
# 38400000 alignment record pairs processed.
# 38500000 alignment record pairs processed.
# 38600000 alignment record pairs processed.
# 38700000 alignment record pairs processed.
# 38800000 alignment record pairs processed.
# 38900000 alignment record pairs processed.
# 39000000 alignment record pairs processed.
# 39100000 alignment record pairs processed.
# 39200000 alignment record pairs processed.
# 39300000 alignment record pairs processed.
# 39400000 alignment record pairs processed.
# 39500000 alignment record pairs processed.
# 39600000 alignment record pairs processed.
# 39700000 alignment record pairs processed.
# 39800000 alignment record pairs processed.
# 39900000 alignment record pairs processed.
# 40000000 alignment record pairs processed.
# 40100000 alignment record pairs processed.
# 40200000 alignment record pairs processed.
# 40300000 alignment record pairs processed.
# 40400000 alignment record pairs processed.
# 40500000 alignment record pairs processed.
# 40600000 alignment record pairs processed.
# 40700000 alignment record pairs processed.
# 40800000 alignment record pairs processed.
# 40900000 alignment record pairs processed.
# 41000000 alignment record pairs processed.
# 41100000 alignment record pairs processed.
# 41200000 alignment record pairs processed.
# 41300000 alignment record pairs processed.
# 41400000 alignment record pairs processed.
# 41500000 alignment record pairs processed.
# 41600000 alignment record pairs processed.
# 41700000 alignment record pairs processed.
# 41800000 alignment record pairs processed.
# 41900000 alignment record pairs processed.
# 42000000 alignment record pairs processed.
# 42100000 alignment record pairs processed.
# 42200000 alignment record pairs processed.
# 42300000 alignment record pairs processed.
# 42400000 alignment record pairs processed.
# 42500000 alignment record pairs processed.
# 42600000 alignment record pairs processed.
# 42700000 alignment record pairs processed.
# 42800000 alignment record pairs processed.
# 42900000 alignment record pairs processed.
# 43000000 alignment record pairs processed.
# 43100000 alignment record pairs processed.
# 43200000 alignment record pairs processed.
# 43300000 alignment record pairs processed.
# 43400000 alignment record pairs processed.
# 43500000 alignment record pairs processed.
# 43600000 alignment record pairs processed.
# 43700000 alignment record pairs processed.
# 43800000 alignment record pairs processed.
# 43900000 alignment record pairs processed.
# 44000000 alignment record pairs processed.
# 44100000 alignment record pairs processed.
# 44200000 alignment record pairs processed.
# 44300000 alignment record pairs processed.
# 44400000 alignment record pairs processed.
# 44500000 alignment record pairs processed.
# 44600000 alignment record pairs processed.
# 44700000 alignment record pairs processed.
# 44800000 alignment record pairs processed.
# 44900000 alignment record pairs processed.
# 45000000 alignment record pairs processed.
# 45100000 alignment record pairs processed.
# 45200000 alignment record pairs processed.
# 45300000 alignment record pairs processed.
# 45400000 alignment record pairs processed.
# 45500000 alignment record pairs processed.
# 45600000 alignment record pairs processed.
# 45700000 alignment record pairs processed.
# 45800000 alignment record pairs processed.
# 45900000 alignment record pairs processed.
# 46000000 alignment record pairs processed.
# 46100000 alignment record pairs processed.
# 46200000 alignment record pairs processed.
# 46300000 alignment record pairs processed.
# 46400000 alignment record pairs processed.
# 46500000 alignment record pairs processed.
# 46600000 alignment record pairs processed.
# 46700000 alignment record pairs processed.
# 46800000 alignment record pairs processed.
# 46900000 alignment record pairs processed.
# 47000000 alignment record pairs processed.
# 47100000 alignment record pairs processed.
# 47200000 alignment record pairs processed.
# 47300000 alignment record pairs processed.
# 47400000 alignment record pairs processed.
# 47500000 alignment record pairs processed.
# 47600000 alignment record pairs processed.
# 47700000 alignment record pairs processed.
# 47800000 alignment record pairs processed.
# 47900000 alignment record pairs processed.
# 48000000 alignment record pairs processed.
# 48100000 alignment record pairs processed.
# 48200000 alignment record pairs processed.
# 48300000 alignment record pairs processed.
# 48400000 alignment record pairs processed.
# 48500000 alignment record pairs processed.
# 48600000 alignment record pairs processed.
# 48700000 alignment record pairs processed.
# 48800000 alignment record pairs processed.
# 48900000 alignment record pairs processed.
# 49000000 alignment record pairs processed.
# 49100000 alignment record pairs processed.
# 49200000 alignment record pairs processed.
# 49300000 alignment record pairs processed.
# 49400000 alignment record pairs processed.
# 49500000 alignment record pairs processed.
# 49600000 alignment record pairs processed.
# 49700000 alignment record pairs processed.
# 49800000 alignment record pairs processed.
# 49900000 alignment record pairs processed.
# 50000000 alignment record pairs processed.
# 50100000 alignment record pairs processed.
# 50200000 alignment record pairs processed.
# 50300000 alignment record pairs processed.
# 50400000 alignment record pairs processed.
# 50500000 alignment record pairs processed.
# 50600000 alignment record pairs processed.
# 50700000 alignment record pairs processed.
# 50800000 alignment record pairs processed.
# 50900000 alignment record pairs processed.
# 51000000 alignment record pairs processed.
# 51100000 alignment record pairs processed.
# 51200000 alignment record pairs processed.
# 51300000 alignment record pairs processed.
# 51400000 alignment record pairs processed.
# 51500000 alignment record pairs processed.
# 51600000 alignment record pairs processed.
# 51700000 alignment record pairs processed.
# 51800000 alignment record pairs processed.
# 51900000 alignment record pairs processed.
# 52000000 alignment record pairs processed.
# 52100000 alignment record pairs processed.
# 52200000 alignment record pairs processed.
# 52300000 alignment record pairs processed.
# 52400000 alignment record pairs processed.
# 52500000 alignment record pairs processed.
# 52600000 alignment record pairs processed.
# 52700000 alignment record pairs processed.
# 52800000 alignment record pairs processed.
# 52900000 alignment record pairs processed.
# 53000000 alignment record pairs processed.
# 53100000 alignment record pairs processed.
# 53200000 alignment record pairs processed.
# 53300000 alignment record pairs processed.
# 53400000 alignment record pairs processed.
# 53500000 alignment record pairs processed.
# 53600000 alignment record pairs processed.
# 53700000 alignment record pairs processed.
# 53800000 alignment record pairs processed.
# 53900000 alignment record pairs processed.
# 54000000 alignment record pairs processed.
# 54100000 alignment record pairs processed.
# 54200000 alignment record pairs processed.
# 54300000 alignment record pairs processed.
# 54400000 alignment record pairs processed.
# 54500000 alignment record pairs processed.
# 54600000 alignment record pairs processed.
# 54700000 alignment record pairs processed.
# 54800000 alignment record pairs processed.
# 54900000 alignment record pairs processed.
# 55000000 alignment record pairs processed.
# 55100000 alignment record pairs processed.
# 55200000 alignment record pairs processed.
# 55300000 alignment record pairs processed.
# 55400000 alignment record pairs processed.
# 55500000 alignment record pairs processed.
# 55600000 alignment record pairs processed.
# 55700000 alignment record pairs processed.
# 55800000 alignment record pairs processed.
# 55900000 alignment record pairs processed.
# 56000000 alignment record pairs processed.
# 56100000 alignment record pairs processed.
# 56200000 alignment record pairs processed.
# 56300000 alignment record pairs processed.
# 56400000 alignment record pairs processed.
# 56500000 alignment record pairs processed.
# 56600000 alignment record pairs processed.
# 56700000 alignment record pairs processed.
# 56800000 alignment record pairs processed.
# 56900000 alignment record pairs processed.
# 57000000 alignment record pairs processed.
# 57100000 alignment record pairs processed.
# 57200000 alignment record pairs processed.
# 57300000 alignment record pairs processed.
# 57400000 alignment record pairs processed.
# 57500000 alignment record pairs processed.
# 57600000 alignment record pairs processed.
# 57700000 alignment record pairs processed.
# 57800000 alignment record pairs processed.
# 57900000 alignment record pairs processed.
# 58000000 alignment record pairs processed.
# 58100000 alignment record pairs processed.
# 58200000 alignment record pairs processed.
# 58300000 alignment record pairs processed.
# 58400000 alignment record pairs processed.
# 58500000 alignment record pairs processed.
# 58600000 alignment record pairs processed.
# 58700000 alignment record pairs processed.
# 58800000 alignment record pairs processed.
# 58900000 alignment record pairs processed.
# 59000000 alignment record pairs processed.
# 59100000 alignment record pairs processed.
# 59200000 alignment record pairs processed.
# 59300000 alignment record pairs processed.
# 59400000 alignment record pairs processed.
# 59500000 alignment record pairs processed.
# 59600000 alignment record pairs processed.
# 59700000 alignment record pairs processed.
# 59800000 alignment record pairs processed.
# 59900000 alignment record pairs processed.
# 60000000 alignment record pairs processed.
# 60100000 alignment record pairs processed.
# 60200000 alignment record pairs processed.
# 60300000 alignment record pairs processed.
# 60400000 alignment record pairs processed.
# 60500000 alignment record pairs processed.
# 60600000 alignment record pairs processed.
# 60700000 alignment record pairs processed.
# 60800000 alignment record pairs processed.
# 60900000 alignment record pairs processed.
# 61000000 alignment record pairs processed.
# 61100000 alignment record pairs processed.
# 61200000 alignment record pairs processed.
# 61300000 alignment record pairs processed.
# Warning: 57409446 reads with missing mate encountered.
# 61374574 alignment record pairs processed.
# [E::hts_open_format] Failed to open file "/home/pdutta/ncbi/BAM_files/sorted_SRR5448864.bam" : No such file or directory
# Traceback (most recent call last):
#   File "/home/pdutta/anaconda3/envs/r_env/bin/htseq-count", line 5, in <module>
#     HTSeq.scripts.count.main()
#   File "/home/pdutta/anaconda3/envs/r_env/lib/python3.10/site-packages/HTSeq/scripts/count.py", line 473, in main
#     args = _parse_sanitize_cmdline_arguments()
#   File "/home/pdutta/anaconda3/envs/r_env/lib/python3.10/site-packages/HTSeq/scripts/count.py", line 465, in _parse_sanitize_cmdline_arguments
#     _check_sam_files(args.samfilenames)
#   File "/home/pdutta/anaconda3/envs/r_env/lib/python3.10/site-packages/HTSeq/scripts/count.py", line 158, in _check_sam_files
#     with pysam.AlignmentFile(sam_filename, "r") as sf:
#   File "pysam/libcalignmentfile.pyx", line 751, in pysam.libcalignmentfile.AlignmentFile.__cinit__
#   File "pysam/libcalignmentfile.pyx", line 950, in pysam.libcalignmentfile.AlignmentFile._open
# FileNotFoundError: [Errno 2] could not open alignment file `/home/pdutta/ncbi/BAM_files/sorted_SRR5448864.bam`: No such file or directory
# 100000 GFF lines processed.
# 200000 GFF lines processed.
# 300000 GFF lines processed.
# 400000 GFF lines processed.
# 500000 GFF lines processed.
# 600000 GFF lines processed.
# 700000 GFF lines processed.
# 800000 GFF lines processed.
# 900000 GFF lines processed.
# 1000000 GFF lines processed.
# 1100000 GFF lines processed.
# 1200000 GFF lines processed.
# 1300000 GFF lines processed.
# 1400000 GFF lines processed.
# 1500000 GFF lines processed.
# 1600000 GFF lines processed.
# 1700000 GFF lines processed.
# 1800000 GFF lines processed.
# 1900000 GFF lines processed.
# 2000000 GFF lines processed.
# 2100000 GFF lines processed.
# 2200000 GFF lines processed.
# 2300000 GFF lines processed.
# 2400000 GFF lines processed.
# 2500000 GFF lines processed.
# 2600000 GFF lines processed.
# 2700000 GFF lines processed.
# 2800000 GFF lines processed.
# 2900000 GFF lines processed.
# 3000000 GFF lines processed.
# 3100000 GFF lines processed.
# 3200000 GFF lines processed.
# 3241002 GFF lines processed.
# Warning: Read SRR5448866.6894255.1 claims to have an aligned mate which could not be found in an adjacent line.
# 100000 alignment record pairs processed.
# 200000 alignment record pairs processed.
# 300000 alignment record pairs processed.
# 400000 alignment record pairs processed.
# 500000 alignment record pairs processed.
# 600000 alignment record pairs processed.
# 700000 alignment record pairs processed.
# 800000 alignment record pairs processed.
# 900000 alignment record pairs processed.
# 1000000 alignment record pairs processed.
# 1100000 alignment record pairs processed.
# 1200000 alignment record pairs processed.
# 1300000 alignment record pairs processed.
# 1400000 alignment record pairs processed.
# 1500000 alignment record pairs processed.
# 1600000 alignment record pairs processed.
# 1700000 alignment record pairs processed.
# 1800000 alignment record pairs processed.
# 1900000 alignment record pairs processed.
# 2000000 alignment record pairs processed.
# 2100000 alignment record pairs processed.
# 2200000 alignment record pairs processed.
# 2300000 alignment record pairs processed.
# 2400000 alignment record pairs processed.
# 2500000 alignment record pairs processed.
# 2600000 alignment record pairs processed.
# 2700000 alignment record pairs processed.
# 2800000 alignment record pairs processed.
# 2900000 alignment record pairs processed.
# 3000000 alignment record pairs processed.
# 3100000 alignment record pairs processed.
# 3200000 alignment record pairs processed.
# 3300000 alignment record pairs processed.
# 3400000 alignment record pairs processed.
# 3500000 alignment record pairs processed.
# 3600000 alignment record pairs processed.
# 3700000 alignment record pairs processed.
# 3800000 alignment record pairs processed.
# 3900000 alignment record pairs processed.
# 4000000 alignment record pairs processed.
# 4100000 alignment record pairs processed.
# 4200000 alignment record pairs processed.
# 4300000 alignment record pairs processed.
# 4400000 alignment record pairs processed.
# 4500000 alignment record pairs processed.
# 4600000 alignment record pairs processed.
# 4700000 alignment record pairs processed.
# 4800000 alignment record pairs processed.
# 4900000 alignment record pairs processed.
# 5000000 alignment record pairs processed.
# 5100000 alignment record pairs processed.
# 5200000 alignment record pairs processed.
# 5300000 alignment record pairs processed.
# 5400000 alignment record pairs processed.
# 5500000 alignment record pairs processed.
# 5600000 alignment record pairs processed.
# 5700000 alignment record pairs processed.
# 5800000 alignment record pairs processed.
# 5900000 alignment record pairs processed.
# 6000000 alignment record pairs processed.
# 6100000 alignment record pairs processed.
# 6200000 alignment record pairs processed.
# 6300000 alignment record pairs processed.
# 6400000 alignment record pairs processed.
# 6500000 alignment record pairs processed.
# 6600000 alignment record pairs processed.
# 6700000 alignment record pairs processed.
# 6800000 alignment record pairs processed.
# 6900000 alignment record pairs processed.
# 7000000 alignment record pairs processed.
# 7100000 alignment record pairs processed.
# 7200000 alignment record pairs processed.
# 7300000 alignment record pairs processed.
# 7400000 alignment record pairs processed.
# 7500000 alignment record pairs processed.
# 7600000 alignment record pairs processed.
# 7700000 alignment record pairs processed.
# 7800000 alignment record pairs processed.
# 7900000 alignment record pairs processed.
# 8000000 alignment record pairs processed.
# 8100000 alignment record pairs processed.
# 8200000 alignment record pairs processed.
# 8300000 alignment record pairs processed.
# 8400000 alignment record pairs processed.
# 8500000 alignment record pairs processed.
# 8600000 alignment record pairs processed.
# 8700000 alignment record pairs processed.
# 8800000 alignment record pairs processed.
# 8900000 alignment record pairs processed.
# 9000000 alignment record pairs processed.
# 9100000 alignment record pairs processed.
# 9200000 alignment record pairs processed.
# 9300000 alignment record pairs processed.
# 9400000 alignment record pairs processed.
# 9500000 alignment record pairs processed.
# 9600000 alignment record pairs processed.
# 9700000 alignment record pairs processed.
# 9800000 alignment record pairs processed.
# 9900000 alignment record pairs processed.
# 10000000 alignment record pairs processed.
# 10100000 alignment record pairs processed.
# 10200000 alignment record pairs processed.
# 10300000 alignment record pairs processed.
# 10400000 alignment record pairs processed.
# 10500000 alignment record pairs processed.
# 10600000 alignment record pairs processed.
# 10700000 alignment record pairs processed.
# 10800000 alignment record pairs processed.
# 10900000 alignment record pairs processed.
# 11000000 alignment record pairs processed.
# 11100000 alignment record pairs processed.
# 11200000 alignment record pairs processed.
# 11300000 alignment record pairs processed.
# 11400000 alignment record pairs processed.
# 11500000 alignment record pairs processed.
# 11600000 alignment record pairs processed.
# 11700000 alignment record pairs processed.
# 11800000 alignment record pairs processed.
# 11900000 alignment record pairs processed.
# 12000000 alignment record pairs processed.
# 12100000 alignment record pairs processed.
# 12200000 alignment record pairs processed.
# 12300000 alignment record pairs processed.
# 12400000 alignment record pairs processed.
# 12500000 alignment record pairs processed.
# 12600000 alignment record pairs processed.
# 12700000 alignment record pairs processed.
# 12800000 alignment record pairs processed.
# 12900000 alignment record pairs processed.
# 13000000 alignment record pairs processed.
# 13100000 alignment record pairs processed.
# 13200000 alignment record pairs processed.
# 13300000 alignment record pairs processed.
# 13400000 alignment record pairs processed.
# 13500000 alignment record pairs processed.
# 13600000 alignment record pairs processed.
# 13700000 alignment record pairs processed.
# 13800000 alignment record pairs processed.
# 13900000 alignment record pairs processed.
# 14000000 alignment record pairs processed.
# 14100000 alignment record pairs processed.
# 14200000 alignment record pairs processed.
# 14300000 alignment record pairs processed.
# 14400000 alignment record pairs processed.
# 14500000 alignment record pairs processed.
# 14600000 alignment record pairs processed.
# 14700000 alignment record pairs processed.
# 14800000 alignment record pairs processed.
# 14900000 alignment record pairs processed.
# 15000000 alignment record pairs processed.
# 15100000 alignment record pairs processed.
# 15200000 alignment record pairs processed.
# 15300000 alignment record pairs processed.
# 15400000 alignment record pairs processed.
# 15500000 alignment record pairs processed.
# 15600000 alignment record pairs processed.
# 15700000 alignment record pairs processed.
# 15800000 alignment record pairs processed.
# 15900000 alignment record pairs processed.
# 16000000 alignment record pairs processed.
# 16100000 alignment record pairs processed.
# 16200000 alignment record pairs processed.
# 16300000 alignment record pairs processed.
# 16400000 alignment record pairs processed.
# 16500000 alignment record pairs processed.
# 16600000 alignment record pairs processed.
# 16700000 alignment record pairs processed.
# 16800000 alignment record pairs processed.
# 16900000 alignment record pairs processed.
# 17000000 alignment record pairs processed.
# 17100000 alignment record pairs processed.
# 17200000 alignment record pairs processed.
# 17300000 alignment record pairs processed.
# 17400000 alignment record pairs processed.
# 17500000 alignment record pairs processed.
# 17600000 alignment record pairs processed.
# 17700000 alignment record pairs processed.
# 17800000 alignment record pairs processed.
# 17900000 alignment record pairs processed.
# 18000000 alignment record pairs processed.
# 18100000 alignment record pairs processed.
# 18200000 alignment record pairs processed.
# 18300000 alignment record pairs processed.
# 18400000 alignment record pairs processed.
# 18500000 alignment record pairs processed.
# 18600000 alignment record pairs processed.
# 18700000 alignment record pairs processed.
# 18800000 alignment record pairs processed.
# 18900000 alignment record pairs processed.
# 19000000 alignment record pairs processed.
# 19100000 alignment record pairs processed.
# 19200000 alignment record pairs processed.
# 19300000 alignment record pairs processed.
# 19400000 alignment record pairs processed.
# 19500000 alignment record pairs processed.
# 19600000 alignment record pairs processed.
# 19700000 alignment record pairs processed.
# 19800000 alignment record pairs processed.
# 19900000 alignment record pairs processed.
# 20000000 alignment record pairs processed.
# 20100000 alignment record pairs processed.
# 20200000 alignment record pairs processed.
# 20300000 alignment record pairs processed.
# 20400000 alignment record pairs processed.
# 20500000 alignment record pairs processed.
# 20600000 alignment record pairs processed.
# 20700000 alignment record pairs processed.
# 20800000 alignment record pairs processed.
# 20900000 alignment record pairs processed.
# 21000000 alignment record pairs processed.
# 21100000 alignment record pairs processed.
# 21200000 alignment record pairs processed.
# 21300000 alignment record pairs processed.
# 21400000 alignment record pairs processed.
# 21500000 alignment record pairs processed.
# 21600000 alignment record pairs processed.
# 21700000 alignment record pairs processed.
# 21800000 alignment record pairs processed.
# 21900000 alignment record pairs processed.
# 22000000 alignment record pairs processed.
# 22100000 alignment record pairs processed.
# 22200000 alignment record pairs processed.
# 22300000 alignment record pairs processed.
# 22400000 alignment record pairs processed.
# 22500000 alignment record pairs processed.
# 22600000 alignment record pairs processed.
# 22700000 alignment record pairs processed.
# 22800000 alignment record pairs processed.
# 22900000 alignment record pairs processed.
# 23000000 alignment record pairs processed.
# 23100000 alignment record pairs processed.
# 23200000 alignment record pairs processed.
# 23300000 alignment record pairs processed.
# 23400000 alignment record pairs processed.
# 23500000 alignment record pairs processed.
# 23600000 alignment record pairs processed.
# 23700000 alignment record pairs processed.
# 23800000 alignment record pairs processed.
# 23900000 alignment record pairs processed.
# 24000000 alignment record pairs processed.
# 24100000 alignment record pairs processed.
# 24200000 alignment record pairs processed.
# 24300000 alignment record pairs processed.
# 24400000 alignment record pairs processed.
# 24500000 alignment record pairs processed.
# 24600000 alignment record pairs processed.
# 24700000 alignment record pairs processed.
# 24800000 alignment record pairs processed.
# 24900000 alignment record pairs processed.
# 25000000 alignment record pairs processed.
# 25100000 alignment record pairs processed.
# 25200000 alignment record pairs processed.
# 25300000 alignment record pairs processed.
# 25400000 alignment record pairs processed.
# 25500000 alignment record pairs processed.
# 25600000 alignment record pairs processed.
# 25700000 alignment record pairs processed.
# 25800000 alignment record pairs processed.
# 25900000 alignment record pairs processed.
# 26000000 alignment record pairs processed.
# 26100000 alignment record pairs processed.
# 26200000 alignment record pairs processed.
# 26300000 alignment record pairs processed.
# 26400000 alignment record pairs processed.
# 26500000 alignment record pairs processed.
# 26600000 alignment record pairs processed.
# 26700000 alignment record pairs processed.
# 26800000 alignment record pairs processed.
# 26900000 alignment record pairs processed.
# 27000000 alignment record pairs processed.
# 27100000 alignment record pairs processed.
# 27200000 alignment record pairs processed.
# 27300000 alignment record pairs processed.
# 27400000 alignment record pairs processed.
# 27500000 alignment record pairs processed.
# 27600000 alignment record pairs processed.
# 27700000 alignment record pairs processed.
# 27800000 alignment record pairs processed.
# 27900000 alignment record pairs processed.
# 28000000 alignment record pairs processed.
# 28100000 alignment record pairs processed.
# 28200000 alignment record pairs processed.
# 28300000 alignment record pairs processed.
# 28400000 alignment record pairs processed.
# 28500000 alignment record pairs processed.
# 28600000 alignment record pairs processed.
# 28700000 alignment record pairs processed.
# 28800000 alignment record pairs processed.
# 28900000 alignment record pairs processed.
# 29000000 alignment record pairs processed.
# 29100000 alignment record pairs processed.
# 29200000 alignment record pairs processed.
# 29300000 alignment record pairs processed.
# 29400000 alignment record pairs processed.
# 29500000 alignment record pairs processed.
# 29600000 alignment record pairs processed.
# 29700000 alignment record pairs processed.
# 29800000 alignment record pairs processed.
# 29900000 alignment record pairs processed.
# 30000000 alignment record pairs processed.
# 30100000 alignment record pairs processed.
# 30200000 alignment record pairs processed.
# 30300000 alignment record pairs processed.
# 30400000 alignment record pairs processed.
# 30500000 alignment record pairs processed.
# 30600000 alignment record pairs processed.
# 30700000 alignment record pairs processed.
# 30800000 alignment record pairs processed.
# 30900000 alignment record pairs processed.
# 31000000 alignment record pairs processed.
# 31100000 alignment record pairs processed.
# 31200000 alignment record pairs processed.
# 31300000 alignment record pairs processed.
# 31400000 alignment record pairs processed.
# 31500000 alignment record pairs processed.
# 31600000 alignment record pairs processed.
# 31700000 alignment record pairs processed.
# 31800000 alignment record pairs processed.
# 31900000 alignment record pairs processed.
# 32000000 alignment record pairs processed.
# 32100000 alignment record pairs processed.
# 32200000 alignment record pairs processed.
# 32300000 alignment record pairs processed.
# 32400000 alignment record pairs processed.
# 32500000 alignment record pairs processed.
# 32600000 alignment record pairs processed.
# 32700000 alignment record pairs processed.
# 32800000 alignment record pairs processed.
# 32900000 alignment record pairs processed.
# 33000000 alignment record pairs processed.
# 33100000 alignment record pairs processed.
# 33200000 alignment record pairs processed.
# 33300000 alignment record pairs processed.
# 33400000 alignment record pairs processed.
# 33500000 alignment record pairs processed.
# 33600000 alignment record pairs processed.
# 33700000 alignment record pairs processed.
# 33800000 alignment record pairs processed.
# 33900000 alignment record pairs processed.
# 34000000 alignment record pairs processed.
# 34100000 alignment record pairs processed.
# 34200000 alignment record pairs processed.
# 34300000 alignment record pairs processed.
# 34400000 alignment record pairs processed.
# 34500000 alignment record pairs processed.
# 34600000 alignment record pairs processed.
# 34700000 alignment record pairs processed.
# 34800000 alignment record pairs processed.
# 34900000 alignment record pairs processed.
# 35000000 alignment record pairs processed.
# 35100000 alignment record pairs processed.
# 35200000 alignment record pairs processed.
# 35300000 alignment record pairs processed.
# 35400000 alignment record pairs processed.
# 35500000 alignment record pairs processed.
# 35600000 alignment record pairs processed.
# 35700000 alignment record pairs processed.
# 35800000 alignment record pairs processed.
# 35900000 alignment record pairs processed.
# 36000000 alignment record pairs processed.
# 36100000 alignment record pairs processed.
# 36200000 alignment record pairs processed.
# 36300000 alignment record pairs processed.
# 36400000 alignment record pairs processed.
# 36500000 alignment record pairs processed.
# 36600000 alignment record pairs processed.
# 36700000 alignment record pairs processed.
# 36800000 alignment record pairs processed.
# 36900000 alignment record pairs processed.
# 37000000 alignment record pairs processed.
# 37100000 alignment record pairs processed.
# 37200000 alignment record pairs processed.
# 37300000 alignment record pairs processed.
# 37400000 alignment record pairs processed.
# 37500000 alignment record pairs processed.
# 37600000 alignment record pairs processed.
# 37700000 alignment record pairs processed.
# 37800000 alignment record pairs processed.
# 37900000 alignment record pairs processed.
# 38000000 alignment record pairs processed.
# 38100000 alignment record pairs processed.
# 38200000 alignment record pairs processed.
# 38300000 alignment record pairs processed.
# 38400000 alignment record pairs processed.
# 38500000 alignment record pairs processed.
# 38600000 alignment record pairs processed.
# 38700000 alignment record pairs processed.
# 38800000 alignment record pairs processed.
# 38900000 alignment record pairs processed.
# 39000000 alignment record pairs processed.
# 39100000 alignment record pairs processed.
# 39200000 alignment record pairs processed.
# 39300000 alignment record pairs processed.
# 39400000 alignment record pairs processed.
# 39500000 alignment record pairs processed.
# 39600000 alignment record pairs processed.
# 39700000 alignment record pairs processed.
# 39800000 alignment record pairs processed.
# 39900000 alignment record pairs processed.
# 40000000 alignment record pairs processed.
# 40100000 alignment record pairs processed.
# 40200000 alignment record pairs processed.
# 40300000 alignment record pairs processed.
# 40400000 alignment record pairs processed.
# 40500000 alignment record pairs processed.
# 40600000 alignment record pairs processed.
# 40700000 alignment record pairs processed.
# 40800000 alignment record pairs processed.
# 40900000 alignment record pairs processed.
# 41000000 alignment record pairs processed.
# 41100000 alignment record pairs processed.
# 41200000 alignment record pairs processed.
# 41300000 alignment record pairs processed.
# 41400000 alignment record pairs processed.
# 41500000 alignment record pairs processed.
# 41600000 alignment record pairs processed.
# 41700000 alignment record pairs processed.
# 41800000 alignment record pairs processed.
# 41900000 alignment record pairs processed.
# 42000000 alignment record pairs processed.
# 42100000 alignment record pairs processed.
# 42200000 alignment record pairs processed.
# 42300000 alignment record pairs processed.
# 42400000 alignment record pairs processed.
# 42500000 alignment record pairs processed.
# 42600000 alignment record pairs processed.
# 42700000 alignment record pairs processed.
# 42800000 alignment record pairs processed.
# 42900000 alignment record pairs processed.
# 43000000 alignment record pairs processed.
# ...
# 16700000 alignment record pairs processed.
# 16800000 alignment record pairs processed.
# 16900000 alignment record pairs processed.
# 17000000 alignment record pairs processed.
# 17100000 alignment record pairs processed.
# 17200000 alignment record pairs processed.
# 17300000 alignment record pairs processed.
# 17400000 alignment record pairs processed.
# 17500000 alignment record pairs processed.
# 17600000 alignment record pairs processed.
# 17700000 alignment record pairs processed.
# 17800000 alignment record pairs processed.
# 17900000 alignment record pairs processed.
# 18000000 alignment record pairs processed.
# 18100000 alignment record pairs processed.
# 18200000 alignment record pairs processed.
# 18300000 alignment record pairs processed.
# 18400000 alignment record pairs processed.
# 18500000 alignment record pairs processed.
# 18600000 alignment record pairs processed.
# 18700000 alignment record pairs processed.
# 18800000 alignment record pairs processed.
# 18900000 alignment record pairs processed.
# 19000000 alignment record pairs processed.
# 19100000 alignment record pairs processed.
# 19200000 alignment record pairs processed.
# 19300000 alignment record pairs processed.
# 19400000 alignment record pairs processed.
# 19500000 alignment record pairs processed.
# 19600000 alignment record pairs processed.
# 19700000 alignment record pairs processed.
# 19800000 alignment record pairs processed.
# 19900000 alignment record pairs processed.
# 20000000 alignment record pairs processed.
# 20100000 alignment record pairs processed.
# 20200000 alignment record pairs processed.
# 20300000 alignment record pairs processed.
# 20400000 alignment record pairs processed.
# 20500000 alignment record pairs processed.
# 20600000 alignment record pairs processed.
# 20700000 alignment record pairs processed.
# 20800000 alignment record pairs processed.
# 20900000 alignment record pairs processed.
# 21000000 alignment record pairs processed.
# 21100000 alignment record pairs processed.
# 21200000 alignment record pairs processed.
# 21300000 alignment record pairs processed.
# 21400000 alignment record pairs processed.
# 21500000 alignment record pairs processed.
# 21600000 alignment record pairs processed.
# 21700000 alignment record pairs processed.
# 21800000 alignment record pairs processed.
# 21900000 alignment record pairs processed.
# 22000000 alignment record pairs processed.
# 22100000 alignment record pairs processed.
# 22200000 alignment record pairs processed.
# 22300000 alignment record pairs processed.
# 22400000 alignment record pairs processed.
# 22500000 alignment record pairs processed.
# 22600000 alignment record pairs processed.
# 22700000 alignment record pairs processed.
# 22800000 alignment record pairs processed.
# 22900000 alignment record pairs processed.
# 23000000 alignment record pairs processed.
# 23100000 alignment record pairs processed.
# 23200000 alignment record pairs processed.
# 23300000 alignment record pairs processed.
# 23400000 alignment record pairs processed.
# 23500000 alignment record pairs processed.
# 23600000 alignment record pairs processed.
# 23700000 alignment record pairs processed.
# 23800000 alignment record pairs processed.
# 23900000 alignment record pairs processed.
# 24000000 alignment record pairs processed.
# 24100000 alignment record pairs processed.
# 24200000 alignment record pairs processed.
# 24300000 alignment record pairs processed.
# 24400000 alignment record pairs processed.
# 24500000 alignment record pairs processed.
# 24600000 alignment record pairs processed.
# 24700000 alignment record pairs processed.
# 24800000 alignment record pairs processed.
# 24900000 alignment record pairs processed.
# 25000000 alignment record pairs processed.
# 25100000 alignment record pairs processed.
# 25200000 alignment record pairs processed.
# 25300000 alignment record pairs processed.
# 25400000 alignment record pairs processed.
# 25500000 alignment record pairs processed.
# 25600000 alignment record pairs processed.
# 25700000 alignment record pairs processed.
# 25800000 alignment record pairs processed.
# 25900000 alignment record pairs processed.
# 26000000 alignment record pairs processed.
# 26100000 alignment record pairs processed.
# 26200000 alignment record pairs processed.
# 26300000 alignment record pairs processed.
# 26400000 alignment record pairs processed.
# 26500000 alignment record pairs processed.
# 26600000 alignment record pairs processed.
# 26700000 alignment record pairs processed.
# 26800000 alignment record pairs processed.
# 26900000 alignment record pairs processed.
# 27000000 alignment record pairs processed.
# 27100000 alignment record pairs processed.
# 27200000 alignment record pairs processed.
# 27300000 alignment record pairs processed.
# 27400000 alignment record pairs processed.
# 27500000 alignment record pairs processed.
# 27600000 alignment record pairs processed.
# 27700000 alignment record pairs processed.
# 27800000 alignment record pairs processed.
# 27900000 alignment record pairs processed.
# 28000000 alignment record pairs processed.
# 28100000 alignment record pairs processed.
# 28200000 alignment record pairs processed.
# 28300000 alignment record pairs processed.
# 28400000 alignment record pairs processed.
# 28500000 alignment record pairs processed.
# 28600000 alignment record pairs processed.
# 28700000 alignment record pairs processed.
# 28800000 alignment record pairs processed.
# 28900000 alignment record pairs processed.
# 29000000 alignment record pairs processed.
# 29100000 alignment record pairs processed.
# 29200000 alignment record pairs processed.
# 29300000 alignment record pairs processed.
# 29400000 alignment record pairs processed.
# 29500000 alignment record pairs processed.
# 29600000 alignment record pairs processed.
# 29700000 alignment record pairs processed.
# 29800000 alignment record pairs processed.
# 29900000 alignment record pairs processed.
# 30000000 alignment record pairs processed.
# 30100000 alignment record pairs processed.
# 30200000 alignment record pairs processed.
# 30300000 alignment record pairs processed.
# 30400000 alignment record pairs processed.
# 30500000 alignment record pairs processed.
# 30600000 alignment record pairs processed.
# 30700000 alignment record pairs processed.
# 30800000 alignment record pairs processed.
# 30900000 alignment record pairs processed.
# 31000000 alignment record pairs processed.
# 31100000 alignment record pairs processed.
# 31200000 alignment record pairs processed.
# 31300000 alignment record pairs processed.
# 31400000 alignment record pairs processed.
# 31500000 alignment record pairs processed.
# 31600000 alignment record pairs processed.
# 31700000 alignment record pairs processed.
# 31800000 alignment record pairs processed.
# 31900000 alignment record pairs processed.
# 32000000 alignment record pairs processed.
# 32100000 alignment record pairs processed.
# 32200000 alignment record pairs processed.
# 32300000 alignment record pairs processed.
# 32400000 alignment record pairs processed.
# 32500000 alignment record pairs processed.
# 32600000 alignment record pairs processed.
# 32700000 alignment record pairs processed.
# 32800000 alignment record pairs processed.
# 32900000 alignment record pairs processed.
# 33000000 alignment record pairs processed.
# 33100000 alignment record pairs processed.
# 33200000 alignment record pairs processed.
# 33300000 alignment record pairs processed.
# 33400000 alignment record pairs processed.
# 33500000 alignment record pairs processed.
# 33600000 alignment record pairs processed.
# 33700000 alignment record pairs processed.
# 33800000 alignment record pairs processed.
# 33900000 alignment record pairs processed.
# 34000000 alignment record pairs processed.
# 34100000 alignment record pairs processed.
# 34200000 alignment record pairs processed.
# 34300000 alignment record pairs processed.
# 34400000 alignment record pairs processed.
# 34500000 alignment record pairs processed.
# 34600000 alignment record pairs processed.
# 34700000 alignment record pairs processed.
# 34800000 alignment record pairs processed.
# 34900000 alignment record pairs processed.
# 35000000 alignment record pairs processed.
# 35100000 alignment record pairs processed.
# 35200000 alignment record pairs processed.
# 35300000 alignment record pairs processed.
# 35400000 alignment record pairs processed.
# 35500000 alignment record pairs processed.
# 35600000 alignment record pairs processed.
# 35700000 alignment record pairs processed.
# 35800000 alignment record pairs processed.
# 35900000 alignment record pairs processed.
# 36000000 alignment record pairs processed.
# 36100000 alignment record pairs processed.
# 36200000 alignment record pairs processed.
# 36300000 alignment record pairs processed.
# 36400000 alignment record pairs processed.
# 36500000 alignment record pairs processed.
# 36600000 alignment record pairs processed.
# 36700000 alignment record pairs processed.
# 36800000 alignment record pairs processed.
# 36900000 alignment record pairs processed.
# 37000000 alignment record pairs processed.
# 37100000 alignment record pairs processed.
# 37200000 alignment record pairs processed.
# 37300000 alignment record pairs processed.
# 37400000 alignment record pairs processed.
# 37500000 alignment record pairs processed.
# 37600000 alignment record pairs processed.
# 37700000 alignment record pairs processed.
# 37800000 alignment record pairs processed.
# 37900000 alignment record pairs processed.
# 38000000 alignment record pairs processed.
# 38100000 alignment record pairs processed.
# 38200000 alignment record pairs processed.
# 38300000 alignment record pairs processed.
# 38400000 alignment record pairs processed.
# 38500000 alignment record pairs processed.
# 38600000 alignment record pairs processed.
# 38700000 alignment record pairs processed.
# 38800000 alignment record pairs processed.
# 38900000 alignment record pairs processed.
# 39000000 alignment record pairs processed.
# 39100000 alignment record pairs processed.
# 39200000 alignment record pairs processed.
# 39300000 alignment record pairs processed.
# 39400000 alignment record pairs processed.
# 39500000 alignment record pairs processed.
# 39600000 alignment record pairs processed.
# 39700000 alignment record pairs processed.
# 39800000 alignment record pairs processed.
# 39900000 alignment record pairs processed.
# 40000000 alignment record pairs processed.
# 40100000 alignment record pairs processed.
# 40200000 alignment record pairs processed.
# 40300000 alignment record pairs processed.
# 40400000 alignment record pairs processed.
# 40500000 alignment record pairs processed.
# 40600000 alignment record pairs processed.
# 40700000 alignment record pairs processed.
# 40800000 alignment record pairs processed.
# 40900000 alignment record pairs processed.
# 41000000 alignment record pairs processed.
# 41100000 alignment record pairs processed.
# 41200000 alignment record pairs processed.
# 41300000 alignment record pairs processed.
# 41400000 alignment record pairs processed.
# 41500000 alignment record pairs processed.
# 41600000 alignment record pairs processed.
# 41700000 alignment record pairs processed.
# 41800000 alignment record pairs processed.
# 41900000 alignment record pairs processed.
# 42000000 alignment record pairs processed.
# 42100000 alignment record pairs processed.
# 42200000 alignment record pairs processed.
# 42300000 alignment record pairs processed.
# 42400000 alignment record pairs processed.
# 42500000 alignment record pairs processed.
# 42600000 alignment record pairs processed.
# 42700000 alignment record pairs processed.
# 42800000 alignment record pairs processed.
# 42900000 alignment record pairs processed.
# 43000000 alignment record pairs processed.
# 43100000 alignment record pairs processed.
# 43200000 alignment record pairs processed.
# 43300000 alignment record pairs processed.
# 43400000 alignment record pairs processed.
# 43500000 alignment record pairs processed.
# 43600000 alignment record pairs processed.
# 43700000 alignment record pairs processed.
# 43800000 alignment record pairs processed.
# 43900000 alignment record pairs processed.
# 44000000 alignment record pairs processed.
# 44100000 alignment record pairs processed.
# 44200000 alignment record pairs processed.
# 44300000 alignment record pairs processed.
# 44400000 alignment record pairs processed.
# 44500000 alignment record pairs processed.
# 44600000 alignment record pairs processed.
# 44700000 alignment record pairs processed.
# 44800000 alignment record pairs processed.
# 44900000 alignment record pairs processed.
# 45000000 alignment record pairs processed.
# 45100000 alignment record pairs processed.
# 45200000 alignment record pairs processed.
# 45300000 alignment record pairs processed.
# 45400000 alignment record pairs processed.
# 45500000 alignment record pairs processed.
# 45600000 alignment record pairs processed.
# 45700000 alignment record pairs processed.
# 45800000 alignment record pairs processed.
# 45900000 alignment record pairs processed.
# 46000000 alignment record pairs processed.
# 46100000 alignment record pairs processed.
# 46200000 alignment record pairs processed.
# 46300000 alignment record pairs processed.
# 46400000 alignment record pairs processed.
# 46500000 alignment record pairs processed.
# 46600000 alignment record pairs processed.
# 46700000 alignment record pairs processed.
# 46800000 alignment record pairs processed.
# 46900000 alignment record pairs processed.
# 47000000 alignment record pairs processed.
# 47100000 alignment record pairs processed.
# 47200000 alignment record pairs processed.
# 47300000 alignment record pairs processed.
# 47400000 alignment record pairs processed.
# 47500000 alignment record pairs processed.
# 47600000 alignment record pairs processed.
# 47700000 alignment record pairs processed.
# 47800000 alignment record pairs processed.
# 47900000 alignment record pairs processed.
# 48000000 alignment record pairs processed.
# 48100000 alignment record pairs processed.
# 48200000 alignment record pairs processed.
# 48300000 alignment record pairs processed.
# 48400000 alignment record pairs processed.
# 48500000 alignment record pairs processed.
# 48600000 alignment record pairs processed.
# 48700000 alignment record pairs processed.
# 48800000 alignment record pairs processed.
# 48900000 alignment record pairs processed.
# 49000000 alignment record pairs processed.
# 49100000 alignment record pairs processed.
# 49200000 alignment record pairs processed.
# 49300000 alignment record pairs processed.
# 49400000 alignment record pairs processed.
# 49500000 alignment record pairs processed.
# 49600000 alignment record pairs processed.
# 49700000 alignment record pairs processed.
# 49800000 alignment record pairs processed.
# 49900000 alignment record pairs processed.
# 50000000 alignment record pairs processed.
# 50100000 alignment record pairs processed.
# 50200000 alignment record pairs processed.
# 50300000 alignment record pairs processed.
# 50400000 alignment record pairs processed.
# 50500000 alignment record pairs processed.
# 50600000 alignment record pairs processed.
# 50700000 alignment record pairs processed.
# 50800000 alignment record pairs processed.
# 50900000 alignment record pairs processed.
# 51000000 alignment record pairs processed.
# 51100000 alignment record pairs processed.
# 51200000 alignment record pairs processed.
# 51300000 alignment record pairs processed.
# 51400000 alignment record pairs processed.
# 51500000 alignment record pairs processed.
# 51600000 alignment record pairs processed.
# 51700000 alignment record pairs processed.
# 51800000 alignment record pairs processed.
# 51900000 alignment record pairs processed.
# 52000000 alignment record pairs processed.
# 52100000 alignment record pairs processed.
# 52200000 alignment record pairs processed.
# 52300000 alignment record pairs processed.
# 52400000 alignment record pairs processed.
# 52500000 alignment record pairs processed.
# 52600000 alignment record pairs processed.
# 52700000 alignment record pairs processed.
# 52800000 alignment record pairs processed.
# 52900000 alignment record pairs processed.
# 53000000 alignment record pairs processed.
# 53100000 alignment record pairs processed.
# 53200000 alignment record pairs processed.
# 53300000 alignment record pairs processed.
# 53400000 alignment record pairs processed.
# 53500000 alignment record pairs processed.
# Warning: 50090536 reads with missing mate encountered.
# 53585950 alignment record pairs processed.

# %% [markdown]
# ### `DESeq2` using `R`
#
# For Python, you can follow this [link](https://github.com/wckdouglas/diffexpr)

# %%
# %%R
# library("DESeq2")

# %%
# %%R -i home_dir
# # Set the working directory
# directory <- paste(home_dir,"/ncbi/count_temp", sep="")
# print(directory)
# setwd(directory)
# Out:
# [1] "/home/pdutta/ncbi/count_temp"

# %%
# %%R
# outputPrefix <- "Gmax_DESeq2"
#
# sampleFiles<- c("SRR5448863Htseq_count.txt",
#                 "SRR5448866Htseq_count.txt")
# sampleNames <- c("Leaf tissue 1","Leaf tissue 2")
# sampleCondition <- c("ambient","elevated")
# sampleTable <- data.frame(sampleName = sampleNames, fileName = sampleFiles, condition = sampleCondition)
#
# treatments = c("ambient","elevated")
# print(sampleTable)
# Out:
#      sampleName                  fileName condition
# 1 Leaf tissue 1 SRR5448863Htseq_count.txt   ambient
# 2 Leaf tissue 2 SRR5448866Htseq_count.txt  elevated

# %%
# %%R
# library("DESeq2")
# library("S4Vectors")
# ddsHTSeq <- DESeqDataSetFromHTSeqCount(sampleTable = sampleTable,
#                                        directory = directory,
#                                        design = ~ condition)
# colData(ddsHTSeq)$condition <- factor(colData(ddsHTSeq)$condition,
#                                       levels = treatments)

# %%
# %%R
# ddsHTSeq
# Out:
# class: DESeqDataSet
# dim: 61533 2
# metadata(1): version
# assays(1): counts
# rownames(61533): ENSG00000000003.15 ENSG00000000005.6 ...
#   ENSG00000289643.1 ENSG00000289644.1
# rowData names(0):
# colnames(2): SRR5448863Htseq_count.txt SRR5448866Htseq_count.txt
# colData names(1): condition

# %%
# %%R
# dds <- DESeq(ddsHTSeq)
# #res <- results(dds)
# #print(dds)
# Out:
# R[write to console]: estimating size factors
#
# R[write to console]: estimating dispersions
#
# R[write to console]: Error in checkForExperimentalReplicates(object, modelMatrix) :
#
#   The design matrix has the same number of samples and coefficients to fit,
#   so estimation of dispersion is not possible. Treating samples
#   as replicates was deprecated in v1.20 and no longer supported since v1.22.
# Error in checkForExperimentalReplicates(object, modelMatrix) :
#
#   The design matrix has the same number of samples and coefficients to fit,
#   so estimation of dispersion is not possible. Treating samples
#   as replicates was deprecated in v1.20 and no longer supported since v1.22.
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:272, in RMagics.eval(self, code)
#     270 try:
#     271     # Need the newline in case the last line in code is a comment.
# --> 272     value, visible = ro.r("withVisible({%s\n})" % code)
#     273 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     274     # Otherwise next return seems to have copy of error.
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/robjects/__init__.py:451, in R.__call__(self, string)
#     450 p = rinterface.parse(string)
# --> 451 res = self.eval(p)
#     452 return conversion.rpy2py(res)
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/robjects/functions.py:201, in SignatureTranslatedFunction.__call__(self, *args, **kwargs)
#     200         kwargs[r_k] = v
# --> 201 return (super(SignatureTranslatedFunction, self)
#     202         .__call__(*args, **kwargs))
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/robjects/functions.py:124, in Function.__call__(self, *args, **kwargs)
#     123         new_kwargs[k] = conversion.py2rpy(v)
# --> 124 res = super(Function, self).__call__(*new_args, **new_kwargs)
#     125 res = conversion.rpy2py(res)
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/rinterface_lib/conversion.py:45, in _cdata_res_to_rinterface.<locals>._(*args, **kwargs)
#      44 def _(*args, **kwargs):
# ---> 45     cdata = function(*args, **kwargs)
#      46     # TODO: test cdata is of the expected CType
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/rinterface.py:810, in SexpClosure.__call__(self, *args, **kwargs)
#     809     if error_occured[0]:
# --> 810         raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     811 return res
#
# RRuntimeError: Error in checkForExperimentalReplicates(object, modelMatrix) :
#
#   The design matrix has the same number of samples and coefficients to fit,
#   so estimation of dispersion is not possible. Treating samples
#   as replicates was deprecated in v1.20 and no longer supported since v1.22.
#
#
#
# During handling of the above exception, another exception occurred:
#
# RInterpreterError                         Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('R', '', 'dds <- DESeq(ddsHTSeq)\n#res <- results(dds)\n#print(dds)\n')
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2347, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2345 with self.builtin_trap:
#    2346     args = (magic_arg_s, cell)
# -> 2347     result = fn(*args, **kwargs)
#    2348 return result
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:787, in RMagics.R(self, line, cell, local_ns)
#     785     if not e.stdout.endswith(e.err):
#     786         print(e.err)
# --> 787     raise e
#     788 finally:
#     789     if self.device in ['png', 'svg']:
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:767, in RMagics.R(self, line, cell, local_ns)
#     765         return_output = False
#     766 else:
# --> 767     text_result, result, visible = self.eval(code)
#     768     text_output += text_result
#     769     if visible:
#
# File ~/anaconda3/envs/r_env/lib/python3.10/site-packages/rpy2/ipython/rmagic.py:276, in RMagics.eval(self, code)
#     273 except (ri.embedded.RRuntimeError, ValueError) as exception:
#     274     # Otherwise next return seems to have copy of error.
#     275     warning_or_other_msg = self.flush()
# --> 276     raise RInterpreterError(code, str(exception),
#     277                             warning_or_other_msg)
#     278 text_output = self.flush()
#     279 return text_output, value, visible[0]
#
# RInterpreterError: Failed to parse and evaluate line 'dds <- DESeq(ddsHTSeq)\n#res <- results(dds)\n#print(dds)\n'.
# R error message: 'Error in checkForExperimentalReplicates(object, modelMatrix) : \n\n  The design matrix has the same number of samples and coefficients to fit,\n  so estimation of dispersion is not possible. Treating samples\n  as replicates was deprecated in v1.20 and no longer supported since v1.22.'

# %%
# %%R -i home_dir
# # Set the working directory
# directory <- paste(home_dir,"/ncbi/count_temp", sep="")

# %%
# %%R
# sampleFiles <- grep("txt",list.files(directory),value=TRUE)
# sampleCondition <- sub("(.*txt).*","\\1",sampleFiles)
# sampleTable <- data.frame(sampleName = sampleFiles,
#                           fileName = sampleFiles,
#                           condition = sampleCondition)
# sampleTable$condition <- factor(sampleTable$condition)

# %%
# %%R
# sampleTable
# Out:
#                  sampleName                  fileName                 condition
# 1 SRR5448863Htseq_count.txt SRR5448863Htseq_count.txt SRR5448863Htseq_count.txt
# 2 SRR5448866Htseq_count.txt SRR5448866Htseq_count.txt SRR5448866Htseq_count.txt

# %%
# %%R
# library("DESeq2")
# ddsHTSeq <- DESeqDataSetFromHTSeqCount(sampleTable = sampleTable,
#                                        directory = directory,
#                                        design= ~ condition)
# ddsHTSeq
# Out:
# class: DESeqDataSet
# dim: 61533 2
# metadata(1): version
# assays(1): counts
# rownames(61533): ENSG00000000003.15 ENSG00000000005.6 ...
#   ENSG00000289643.1 ENSG00000289644.1
# rowData names(0):
# colnames(2): SRR5448863Htseq_count.txt SRR5448866Htseq_count.txt
# colData names(1): condition
