# %%
import pandas as pd
import glob

# %%
df_acceptor_DBSNP= pd.read_csv("/data/private/pdutta/PSB_Data_2024/Acceptor/combined_file.tsv", sep="\t", header=None)

# %%
df_acceptor_DBSNP
# Out:
#               0         1         2                  3  4      5         6   \
# 0          chr10  99729695  99729774  ENST00000016171.6  -  chr10  99710868
# 1          chr10  99729695  99729774  ENST00000016171.6  -  chr10  99710868
# 2          chr10  99729695  99729774  ENST00000016171.6  -  chr10  99710868
# 3          chr10  99729695  99729774  ENST00000016171.6  -  chr10  99710868
# 4          chr10  99729695  99729774  ENST00000016171.6  -  chr10  99710868
# ...          ...       ...       ...                ... ..    ...       ...
# 577264345   chrY  13234787  13234866  ENST00000684326.1  -   chrY  13234599
# 577264346   chrY  13234787  13234866  ENST00000684326.1  -   chrY  13234599
# 577264347   chrY  13234787  13234866  ENST00000684326.1  -   chrY  13234599
# 577264348   chrY  13234787  13234866  ENST00000684326.1  -   chrY  13234599
# 577264349   chrY  13234787  13234866  ENST00000684326.1  -   chrY  13234599
#
# ...

# %%
unique_df_acceptor = df_acceptor_DBSNP.drop_duplicates(subset=[0, 1, 2])
unique_df_acceptor
# Out:
#               0         1         2                  3  4      5         6   \
# 0          chr10  99729695  99729774  ENST00000016171.6  -  chr10  99710868
# 128        chr10  99727524  99727603  ENST00000016171.6  -  chr10  99710868
# 252        chr10  99727115  99727194  ENST00000016171.6  -  chr10  99710868
# 400        chr10  99724084  99724163  ENST00000016171.6  -  chr10  99710868
# 484        chr10  99721029  99721108  ENST00000016171.6  -  chr10  99710868
# ...          ...       ...       ...                ... ..    ...       ...
# 577248556   chrY   2789708   2789787  ENST00000680285.1  +   chrY   2752083
# 577249089   chrY   2787439   2787518  ENST00000680845.1  +   chrY   2786855
# 577249600   chrY   2840987   2841066  ENST00000681787.1  +   chrY   2752296
# 577252102   chrY  13334301  13334380  ENST00000682112.1  -   chrY  13248379
# 577253561   chrY  13234787  13234866  ENST00000682112.1  -   chrY  13234577
#
# ...
