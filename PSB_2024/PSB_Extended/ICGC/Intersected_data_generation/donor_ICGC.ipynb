# %%
import os
import pandas as pd
import numpy as np
import pybedtools 
from Bio import SeqIO
from io import StringIO
pybedtools.helpers.set_tempdir("/data/projects/temp")
from tqdm import tqdm

# %%
ICGC_bed_file = "/data/projects/DNABERT_snv/Manuscript_11_2023/bed/ICGC/ICGC_hg38_combined_final.bed"

# %%
# Define a function to read large file in chunks and show progress
def read_large_file(file_path, chunk_size=100000):
    # Determine the total size of the file
    total_size = os.path.getsize(file_path)
    print("Total Size :", total_size)
    # Iterator to read file in chunks
    iterator = pd.read_csv(file_path, chunksize=chunk_size, sep="\t", header=None, names=["Chromosome", "Start", "End", "Mutation_ID","T1","Reference_Allele", "Alternative_Allele","T2", "Info"])

    # Use tqdm to show progress, using file size as a proxy
    chunks = []
    # Initialize tqdm with the total number of chunks (estimated)
    with tqdm(total=os.path.getsize(file_path) // (chunk_size * 1024), desc="Reading file") as pbar:
        for chunk in iterator:
            # Process each chunk
            chunks.append(chunk)

            # Update the progress bar by one chunk
            pbar.update(1)

    print("Reading done....")
    # Concatenate chunks into a single DataFrame
    df = pd.concat(chunks, ignore_index=True)

    return df

# %%
df = read_large_file(ICGC_bed_file)
# Out:
# Total Size : 30209257697
# Reading file: 818it [03:01,  4.52it/s]
# Reading done....

# %%
df['Chromosome'] = 'chr' + df['Chromosome'].astype(str)
df
# Out:
#          Chromosome     Start       End  Mutation_ID T1 Reference_Allele  \
# 0              chr1     10001     10002   MU43280717  .                A
# 1              chr1     10025     10026   MU75019506  .                A
# 2              chr1     10071     10072   MU40549878  .                C
# 3              chr1     10073     10074  MU121369972  .                A
# 4              chr1     10079     10080  MU121498435  .                A
# ...             ...       ...       ...          ... ..              ...
# 81714693       chrY  57206259  57206260   MU81205562  .                G
# 81714694       chrY  57208638  57208639   MU81205574  .                C
# 81714695       chrY  57209763  57209764   MU81205598  .                C
# 81714696       chrY  57211399  57211400   MU81205605  .                C
# 81714697       chrY  57212412  57212413   MU81205614  .                T
#
#          Alternative_Allele T2  \
# 0                         T  .
# 1                         G  .
# 2                        CA  .
# 3                         G  .
# 4                         G  .
# ...                     ... ..
# 81714693                  A  .
# 81714694                  T  .
# 81714695                  T  .
# 81714696                  T  .
# 81714697                  C  .
#
#                                                        Info
# 0         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 1         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 2         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 3         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 4         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# ...                                                     ...
# 81714693  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714694  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714695  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714696  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714697  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
#
# [81714698 rows x 9 columns]

# %%
df_donor = pd.read_csv("/data/projects/DNABERT_snv/Manuscript_11_2023/bed/DNABERT_run_data/donor.bed", sep="\t", header=None)
df_donor[2] = df_donor[2].round().astype(int)
df_donor
# Out:
#             0          1          2                3                4  5   \
# 0         chr7  127589124  127589203  ENST00000000233  ENSG00000004059  +
# 1         chr7  127588526  127588605  ENST00000000233  ENSG00000004059  +
# 2         chr7  127589555  127589634  ENST00000000233  ENSG00000004059  +
# 3         chr7  127591049  127591128  ENST00000000233  ENSG00000004059  +
# 4         chr7  127591661  127591740  ENST00000000233  ENSG00000004059  +
# ...        ...        ...        ...              ...              ... ..
# 1175762  chr17   63706595   63706674  ENST00000640999  ENSG00000266173  -
# 1175763  chr17   63707207   63707286  ENST00000640999  ENSG00000266173  -
# 1175764  chr17   63710451   63710530  ENST00000640999  ENSG00000266173  -
# 1175765  chr17   63710688   63710767  ENST00000640999  ENSG00000266173  -
# 1175766  chr17   63713366   63713445  ENST00000640999  ENSG00000266173  -
#
#                 6     7               8      9       10          11  \
# 0        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 1        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 2        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 3        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 4        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# ...            ...   ...             ...    ...     ...         ...
# 1175762   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175763   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175764   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175765   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175766   63741796  2336  protein_coding  48.88  STRADA   NullTrans
#
#                                                         12
# 0        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 1        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 2        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 3        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 4        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# ...                                                    ...
# 1175762                                                NaN
# 1175763                                                NaN
# 1175764                                                NaN
# 1175765                                                NaN
# 1175766                                                NaN
#
# [1175767 rows x 13 columns]

# %%
icgc_bed = pybedtools.BedTool.from_dataframe(df.iloc[1:])

# %%
donor_bed = pybedtools.BedTool.from_dataframe(df_donor)

# %%
intersect_bed = donor_bed.intersect(icgc_bed, wa=True, wb=True)

# %%
intersect_df = intersect_bed.to_dataframe()
new_columns = ['chr_name', 'Donor_start', 'Donor_end', "ENSEMBL_Transcript_ID","ENSEMBL_Gene ID", "strand","TSS","Transcript_length","Transcript_type","Gene_CG_content","GENE_symbol","Category","Tissue", "Chromosome", "Start",	"End", "Mutation_ID", "T1", "Reference_Allele", "Alternative_Allele", "T2","Info"]
intersect_df.columns = new_columns
intersect_df
# Out:
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 22 fields; you can supply custom names with the `names` kwarg
#   warn(
#         chr_name  Donor_start  Donor_end ENSEMBL_Transcript_ID  \
# 0           chr7    127588526  127588605       ENST00000000233
# 1           chr7    127588526  127588605       ENST00000000233
# 2           chr7    127588526  127588605       ENST00000000233
# 3           chr7    127588526  127588605       ENST00000000233
# 4           chr7    127588526  127588605       ENST00000000233
# ...          ...          ...        ...                   ...
# 5792687    chr17     63710688   63710767       ENST00000640999
# 5792688    chr17     63710688   63710767       ENST00000640999
# 5792689    chr17     63710688   63710767       ENST00000640999
# 5792690    chr17     63713366   63713445       ENST00000640999
# 5792691    chr17     63713366   63713445       ENST00000640999
#
#          ENSEMBL_Gene ID strand        TSS  Transcript_length Transcript_type  \
# 0        ENSG00000004059      +  127588411               1032  protein_coding
# 1        ENSG00000004059      +  127588411               1032  protein_coding
# 2        ENSG00000004059      +  127588411               1032  protein_coding
# 3        ENSG00000004059      +  127588411               1032  protein_coding
# 4        ENSG00000004059      +  127588411               1032  protein_coding
# ...                  ...    ...        ...                ...             ...
# 5792687  ENSG00000266173      -   63741796               2336  protein_coding
# 5792688  ENSG00000266173      -   63741796               2336  protein_coding
# 5792689  ENSG00000266173      -   63741796               2336  protein_coding
# 5792690  ENSG00000266173      -   63741796               2336  protein_coding
# 5792691  ENSG00000266173      -   63741796               2336  protein_coding
#
#          Gene_CG_content  ...  \
# 0                  56.14  ...
# 1                  56.14  ...
# 2                  56.14  ...
# 3                  56.14  ...
# 4                  56.14  ...
# ...                  ...  ...
# 5792687            48.88  ...
# 5792688            48.88  ...
# 5792689            48.88  ...
# 5792690            48.88  ...
# 5792691            48.88  ...
#
#                                                     Tissue Chromosome  \
# 0        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 1        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 2        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 3        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 4        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# ...                                                    ...        ...
# 5792687                                                  .      chr17
# 5792688                                                  .      chr17
# 5792689                                                  .      chr17
# 5792690                                                  .      chr17
# 5792691                                                  .      chr17
#
#              Start        End  Mutation_ID  T1 Reference_Allele  \
# 0        127588529  127588530   MU80692579   .                G
# 1        127588553  127588554   MU90753368   .                G
# 2        127588569  127588570  MU115107606   .                G
# 3        127588581  127588582   MU84868698   .                G
# 4        127588591  127588592   MU83704948   .                G
# ...            ...        ...          ...  ..              ...
# 5792687   63710752   63710753   MU28664773   .                C
# 5792688   63710760   63710761   MU29299841   .                C
# 5792689   63710765   63710766  MU129502912   .                T
# 5792690   63713396   63713397   MU84546198   .                G
# 5792691   63713425   63713426  MU130439032   .                C
#
#         Alternative_Allele T2  \
# 0                        T  .
# 1                        A  .
# 2                        T  .
# 3                        T  .
# 4                        T  .
# ...                    ... ..
# 5792687                  A  .
# 5792688                  T  .
# 5792689                  C  .
# 5792690                  T  .
# 5792691                  G  .
#
#                                                       Info
# 0        CONSEQUENCE=ARF5|ENSG00000004059|+|ARF5-001|EN...
# 1        CONSEQUENCE=ARF5|ENSG00000004059|+|ARF5-001|EN...
# 2        CONSEQUENCE=ARF5|ENSG00000004059|+|ARF5-001|EN...
# 3        CONSEQUENCE=ARF5|ENSG00000004059|+|ARF5-001|EN...
# 4        CONSEQUENCE=ARF5|ENSG00000004059|+|ARF5-001|EN...
# ...                                                    ...
# 5792687  CONSEQUENCE=STRADA|ENSG00000266173|1|STRADA-00...
# 5792688  CONSEQUENCE=STRADA|ENSG00000266173|1|STRADA-00...
# 5792689  CONSEQUENCE=STRADA|ENSG00000266173|1|STRADA-00...
# 5792690  CONSEQUENCE=STRADA|ENSG00000266173|1|STRADA-00...
# 5792691  CONSEQUENCE=STRADA|ENSG00000266173|1|STRADA-00...
#
# [5792692 rows x 22 columns]

# %%
intersect_df[intersect_df['Reference_Allele'].str.len()==3]
# Out:
#         chr_name  Donor_start  Donor_end ENSEMBL_Transcript_ID  \
# 169         chr2     37242654   37242733       ENST00000002125
# 282         chr3     50159695   50159774       ENST00000002829
# 476         chr7    117480108  117480187       ENST00000003084
# 891         chr8     17554660   17554739       ENST00000004531
# 899         chr8     17548804   17548883       ENST00000004531
# ...          ...          ...        ...                   ...
# 5790762     chrX     56269450   56269529       ENST00000640927
# 5790816    chr18     70135144   70135223       ENST00000640931
# 5790927    chr10     77110133   77110212       ENST00000640934
# 5791749    chr10     77110133   77110212       ENST00000640969
# 5792166    chr14     94003315   94003394       ENST00000640978
#
#          ENSEMBL_Gene ID strand        TSS  Transcript_length  \
# 169      ENSG00000003509      +   37231658               2184
# 282      ENSG00000001617      +   50155324               3607
# 476      ENSG00000001626      +  117480025               6070
# 891      ENSG00000003989      +   17538777               7560
# 899      ENSG00000003989      +   17538777               7560
# ...                  ...    ...        ...                ...
# 5790762  ENSG00000102349      +   56233212               1150
# 5790816  ENSG00000176225      -   70139607               2065
# 5790927  ENSG00000156113      -   77637447               3528
# 5791749  ENSG00000156113      -   77637806               5789
# 5792166  ENSG00000175699      +   93987225               1429
#
#                  Transcript_type  Gene_CG_content  ...  \
# 169               protein_coding            38.97  ...
# 282               protein_coding            57.74  ...
# 476               protein_coding            36.90  ...
# 891               protein_coding            40.13  ...
# 899               protein_coding            40.13  ...
# ...                          ...              ...  ...
# 5790762           protein_coding            38.82  ...
# 5790816  nonsense_mediated_decay            36.76  ...
# 5790927           protein_coding            43.94  ...
# 5791749           protein_coding            43.94  ...
# 5792166           protein_coding            53.16  ...
#
#                                                     Tissue Chromosome  \
# 169      Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr2
# 282      Adipose_Tissue, Bladder, Blood_Vessel, Breast,...       chr3
# 476                                                      .       chr7
# 891                                                      .       chr8
# 899                                                      .       chr8
# ...                                                    ...        ...
# 5790762                                                  .       chrX
# 5790816                                                  .      chr18
# 5790927                                                  .      chr10
# 5791749                                                  .      chr10
# 5792166                                                  .      chr14
#
#              Start        End  Mutation_ID  T1 Reference_Allele  \
# 169       37242704   37242707  MU113949942   .              GGA
# 282       50159773   50159776   MU40919316   .              CTT
# 476      117480177  117480180  MU128922383   .              GAC
# 891       17554700   17554703    MU4308423   .              TGA
# 899       17548857   17548860  MU112574363   .              GTT
# ...            ...        ...          ...  ..              ...
# 5790762   56269524   56269527   MU67798354   .              ATG
# 5790816   70135193   70135196       MU2853   .              TTC
# 5790927   77110160   77110163  MU128767388   .              ATT
# 5791749   77110160   77110163  MU128767388   .              ATT
# 5792166   94003327   94003330  MU121132011   .              GAC
#
#         Alternative_Allele T2  \
# 169                      G  .
# 282                      C  .
# 476                      G  .
# 891                      T  .
# 899                      G  .
# ...                    ... ..
# 5790762                  A  .
# 5790816                  T  .
# 5790927                  A  .
# 5791749                  A  .
# 5792166                  G  .
#
#                                                       Info
# 169      CONSEQUENCE=NDUFAF7|ENSG00000003509|+|NDUFAF7-...
# 282      CONSEQUENCE=SEMA3F|ENSG00000001617|+|SEMA3F-00...
# 476      CONSEQUENCE=CFTR|ENSG00000001626|+|CFTR-001|EN...
# 891      CONSEQUENCE=SLC7A2|ENSG00000003989|+|SLC7A2-20...
# 899      CONSEQUENCE=SLC7A2|ENSG00000003989|+|SLC7A2-20...
# ...                                                    ...
# 5790762  CONSEQUENCE=KLF8|ENSG00000102349|+|KLF8-002|EN...
# 5790816  CONSEQUENCE=RTTN|ENSG00000176225|1|RTTN-001|EN...
# 5790927  CONSEQUENCE=KCNMA1|ENSG00000156113|1|KCNMA1-00...
# 5791749  CONSEQUENCE=KCNMA1|ENSG00000156113|1|KCNMA1-00...
# 5792166  CONSEQUENCE=LINC00521|ENSG00000175699|+|LINC00...
#
# [14377 rows x 22 columns]

# %%
intersect_df.to_csv("/data/projects/DNABERT_snv/Manuscript_11_2023/Intersected_data/donor_ICGC_intersected.tsv", sep="\t", index=False)
