# %%
import os
import pandas as pd
import numpy as np
import pybedtools 
from Bio import SeqIO
from io import StringIO
pybedtools.helpers.set_tempdir("/data/projects/temp")
from tqdm import tqdm

# %%
ICGC_bed_file = "/data/projects/DNABERT_snv/Manuscript_11_2023/bed/ICGC/ICGC_hg38_combined_final.bed"

# %%
# Define a function to read large file in chunks and show progress
def read_large_file(file_path, chunk_size=100000):
    # Determine the total size of the file
    total_size = os.path.getsize(file_path)
    print("Total Size :", total_size)
    # Iterator to read file in chunks
    iterator = pd.read_csv(file_path, chunksize=chunk_size, sep="\t", header=None, names=["Chromosome", "Start", "End", "Mutation_ID","T1","Reference_Allele", "Alternative_Allele","T2", "Info"])

    # Use tqdm to show progress, using file size as a proxy
    chunks = []
    # Initialize tqdm with the total number of chunks (estimated)
    with tqdm(total=os.path.getsize(file_path) // (chunk_size * 1024), desc="Reading file") as pbar:
        for chunk in iterator:
            # Process each chunk
            chunks.append(chunk)

            # Update the progress bar by one chunk
            pbar.update(1)

    print("Reading done....")
    # Concatenate chunks into a single DataFrame
    df = pd.concat(chunks, ignore_index=True)

    return df

# %%
df = read_large_file(ICGC_bed_file)
# Out:
# Total Size : 30209257697
# Reading file: 818it [03:01,  4.50it/s]
# Reading done....

# %%
df['Chromosome'] = 'chr' + df['Chromosome'].astype(str)
df
# Out:
#          Chromosome     Start       End  Mutation_ID T1 Reference_Allele  \
# 0              chr1     10001     10002   MU43280717  .                A
# 1              chr1     10025     10026   MU75019506  .                A
# 2              chr1     10071     10072   MU40549878  .                C
# 3              chr1     10073     10074  MU121369972  .                A
# 4              chr1     10079     10080  MU121498435  .                A
# ...             ...       ...       ...          ... ..              ...
# 81714693       chrY  57206259  57206260   MU81205562  .                G
# 81714694       chrY  57208638  57208639   MU81205574  .                C
# 81714695       chrY  57209763  57209764   MU81205598  .                C
# 81714696       chrY  57211399  57211400   MU81205605  .                C
# 81714697       chrY  57212412  57212413   MU81205614  .                T
#
#          Alternative_Allele T2  \
# 0                         T  .
# 1                         G  .
# 2                        CA  .
# 3                         G  .
# 4                         G  .
# ...                     ... ..
# 81714693                  A  .
# 81714694                  T  .
# 81714695                  T  .
# 81714696                  T  .
# 81714697                  C  .
#
#                                                        Info
# 0         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 1         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 2         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 3         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 4         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# ...                                                     ...
# 81714693  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714694  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714695  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714696  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81714697  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
#
# [81714698 rows x 9 columns]

# %%
df_core_prom = pd.read_csv("/data/projects/DNABERT_snv/Manuscript_11_2023/bed/DNABERT_run_data/core_prom.bed", sep="\t", header=None)
df_core_prom[2] = df_core_prom[2].round().astype(int)
df_core_prom
# Out:
#            0          1          2                3                4  5   \
# 0        chr7  127588366  127588455  ENST00000000233  ENSG00000004059  +
# 1       chr12    8949601    8949690  ENST00000000412  ENSG00000003056  -
# 2       chr11   64305479   64305568  ENST00000000442  ENSG00000173153  +
# 3       chr12    2794925    2795014  ENST00000001008  ENSG00000004478  +
# 4        chr2   72147818   72147907  ENST00000001146  ENSG00000003137  -
# ...       ...        ...        ...              ...              ... ..
# 194768  chr20   45416096   45416185  ENST00000640986  ENSG00000124155  +
# 194769   chr6  160510972  160511061  ENST00000640989  ENSG00000290613  -
# 194770   chr2   85888732   85888821  ENST00000640992  ENSG00000115525  -
# 194771  chr20   45416088   45416177  ENST00000640996  ENSG00000124155  +
# 194772  chr17   63741752   63741841  ENST00000640999  ENSG00000266173  -
#
#                6     7                        8      9        10          11  \
# 0       127588411  1032           protein_coding  56.14     ARF5  HouseTrans
# 1         8949645  2450           protein_coding  42.37     M6PR  HouseTrans
# 2        64305524  2274           protein_coding  57.13    ESRRA  HouseTrans
# 3         2794970  3715           protein_coding  51.53    FKBP4  HouseTrans
# 4        72147862  4556           protein_coding  59.85  CYP26B1   NullTrans
# ...           ...   ...                      ...    ...      ...         ...
# 194768   45416141  2187  nonsense_mediated_decay  45.91     PIGT   NullTrans
# 194769  160511016   807                   lncRNA  40.95    LPAL2   NullTrans
# 194770   85888776  2292           protein_coding  45.07  ST3GAL5   NullTrans
# 194771   45416133  2219  nonsense_mediated_decay  45.91     PIGT   NullTrans
# 194772   63741796  2336           protein_coding  48.88   STRADA   NullTrans
#
#                                                        12
# 0       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 1       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 2       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 3       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 4                                                     NaN
# ...                                                   ...
# 194768                                                NaN
# 194769                                                NaN
# 194770                                                NaN
# 194771                                                NaN
# 194772                                                NaN
#
# [194773 rows x 13 columns]

# %%
icgc_bed = pybedtools.BedTool.from_dataframe(df.iloc[1:])

# %%
core_prom_bed = pybedtools.BedTool.from_dataframe(df_core_prom)

# %%
intersect_bed = core_prom_bed.intersect(icgc_bed, wa=True, wb=True)

# %%
intersect_df = intersect_bed.to_dataframe()
new_columns = ['chr_name', 'Core_prom_start', 'Core_prom_end', "ENSEMBL_Transcript_ID","ENSEMBL_Gene ID", "strand","TSS","Transcript_length","Transcript_type","Gene_CG_content","GENE_symbol","Category","Tissue", "Chromosome", "Start",	"End", "Mutation_ID", "T1", "Reference_Allele", "Alternative_Allele", "T2","Info"]
intersect_df.columns = new_columns
intersect_df
# Out:
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 22 fields; you can supply custom names with the `names` kwarg
#   warn(
#        chr_name  Core_prom_start  Core_prom_end ENSEMBL_Transcript_ID  \
# 0          chr7        127588366      127588455       ENST00000000233
# 1          chr7        127588366      127588455       ENST00000000233
# 2         chr12          8949601        8949690       ENST00000000412
# 3         chr12          8949601        8949690       ENST00000000412
# 4         chr11         64305479       64305568       ENST00000000442
# ...         ...              ...            ...                   ...
# 746359    chr20         45416088       45416177       ENST00000640996
# 746360    chr20         45416088       45416177       ENST00000640996
# 746361    chr20         45416088       45416177       ENST00000640996
# 746362    chr20         45416088       45416177       ENST00000640996
# 746363    chr20         45416088       45416177       ENST00000640996
#
#         ENSEMBL_Gene ID strand        TSS  Transcript_length  \
# 0       ENSG00000004059      +  127588411               1032
# 1       ENSG00000004059      +  127588411               1032
# 2       ENSG00000003056      -    8949645               2450
# 3       ENSG00000003056      -    8949645               2450
# 4       ENSG00000173153      +   64305524               2274
# ...                 ...    ...        ...                ...
# 746359  ENSG00000124155      +   45416133               2219
# 746360  ENSG00000124155      +   45416133               2219
# 746361  ENSG00000124155      +   45416133               2219
# 746362  ENSG00000124155      +   45416133               2219
# 746363  ENSG00000124155      +   45416133               2219
#
#                 Transcript_type  Gene_CG_content  ...  \
# 0                protein_coding            56.14  ...
# 1                protein_coding            56.14  ...
# 2                protein_coding            42.37  ...
# 3                protein_coding            42.37  ...
# 4                protein_coding            57.13  ...
# ...                         ...              ...  ...
# 746359  nonsense_mediated_decay            45.91  ...
# 746360  nonsense_mediated_decay            45.91  ...
# 746361  nonsense_mediated_decay            45.91  ...
# 746362  nonsense_mediated_decay            45.91  ...
# 746363  nonsense_mediated_decay            45.91  ...
#
#                                                    Tissue Chromosome  \
# 0       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 1       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 2       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...      chr12
# 3       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...      chr12
# 4       Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...      chr11
# ...                                                   ...        ...
# 746359                                                  .      chr20
# 746360                                                  .      chr20
# 746361                                                  .      chr20
# 746362                                                  .      chr20
# 746363                                                  .      chr20
#
#             Start        End  Mutation_ID  T1 Reference_Allele  \
# 0       127588387  127588388  MU133392649   .                G
# 1       127588429  127588430   MU39478069   .                T
# 2         8949659    8949660   MU49180650   .                G
# 3         8949660    8949661   MU37117518   .                G
# 4        64305485   64305486   MU46907284   .                C
# ...           ...        ...          ...  ..              ...
# 746359   45416128   45416129   MU66504628   .                C
# 746360   45416129   45416130  MU128987750   .                G
# 746361   45416141   45416142  MU120160683   .                G
# 746362   45416144   45416145   MU93024897   .                G
# 746363   45416172   45416173     MU633820   .                C
#
#        Alternative_Allele T2  \
# 0                       A  .
# 1                       C  .
# 2                       A  .
# 3                       A  .
# 4                       T  .
# ...                   ... ..
# 746359                  G  .
# 746360                  A  .
# 746361                  A  .
# 746362                  T  .
# 746363                  T  .
#
#                                                      Info
# 0       CONSEQUENCE=ARF5|ENSG00000004059|+|ARF5-001|EN...
# 1       CONSEQUENCE=ARF5|ENSG00000004059|+|ARF5-001|EN...
# 2       CONSEQUENCE=M6PR|ENSG00000003056|1|M6PR-001|EN...
# 3       CONSEQUENCE=M6PR|ENSG00000003056|1|M6PR-001|EN...
# 4       CONSEQUENCE=||||||intergenic_region||,ESRRA|EN...
# ...                                                   ...
# 746359  CONSEQUENCE=PIGT|ENSG00000124155|+|PIGT-004|EN...
# 746360  CONSEQUENCE=PIGT|ENSG00000124155|+|PIGT-004|EN...
# 746361  CONSEQUENCE=PIGT|ENSG00000124155|+|PIGT-004|EN...
# 746362  CONSEQUENCE=PIGT|ENSG00000124155|+|PIGT-004|EN...
# 746363  CONSEQUENCE=PIGT|ENSG00000124155|+|PIGT-004|EN...
#
# [746364 rows x 22 columns]

# %%
intersect_df.to_csv("/data/projects/DNABERT_snv/Manuscript_11_2023/Intersected_data/core_prom_ICGC_intersected.tsv", sep="\t", index=False)
