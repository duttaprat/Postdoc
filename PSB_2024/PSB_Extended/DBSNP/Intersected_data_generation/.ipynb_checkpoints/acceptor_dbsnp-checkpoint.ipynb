# %%
import os
import pandas as pd
import numpy as np
import pybedtools 
from Bio import SeqIO
from io import StringIO
pybedtools.helpers.set_tempdir("/data/projects/temp")
from tqdm import tqdm

# %%
ICGC_bed_file = "/data/projects/DNABERT_snv/Manuscript_11_2023/bed/ICGC/ICGC.bed"

# %%
# Define a function to read large file in chunks and show progress
def read_large_file(file_path, chunk_size=100000):
    # Determine the total size of the file
    total_size = os.path.getsize(file_path)
    print("Total Size :", total_size)
    # Iterator to read file in chunks
    iterator = pd.read_csv(file_path, chunksize=chunk_size, sep="\t", header=None, names=["Chromosome", "Start", "End", "Mutation_ID","T1","Reference_Allele", "Alternative_Allele","T2", "Info"])

    # Use tqdm to show progress, using file size as a proxy
    chunks = []
    # Initialize tqdm with the total number of chunks (estimated)
    with tqdm(total=os.path.getsize(file_path) // (chunk_size * 1024), desc="Reading file") as pbar:
        for chunk in iterator:
            # Process each chunk
            chunks.append(chunk)

            # Update the progress bar by one chunk
            pbar.update(1)

    print("Reading done....")
    # Concatenate chunks into a single DataFrame
    df = pd.concat(chunks, ignore_index=True)

    return df

# %%
df = read_large_file(ICGC_bed_file)
# Out:
# Total Size : 30241674872
# Reading file: 818it [02:59,  4.56it/s]
# Reading done....

# %%
df['Chromosome'] = 'chr' + df['Chromosome'].astype(str)
df
# Out:
#          Chromosome     Start       End  Mutation_ID T1 Reference_Allele  \
# 0              chr1     10001     10002   MU43280717  .                A
# 1              chr1     10025     10026   MU75019506  .                A
# 2              chr1     10071     10072   MU40549878  .                C
# 3              chr1     10073     10074  MU121369972  .                A
# 4              chr1     10079     10080  MU121498435  .                A
# ...             ...       ...       ...          ... ..              ...
# 81782583       chrY  59352410  59352411   MU81205562  .                G
# 81782584       chrY  59354789  59354790   MU81205574  .                C
# 81782585       chrY  59355914  59355915   MU81205598  .                C
# 81782586       chrY  59357550  59357551   MU81205605  .                C
# 81782587       chrY  59358563  59358564   MU81205614  .                T
#
#          Alternative_Allele T2  \
# 0                         T  .
# 1                         G  .
# 2                        CA  .
# 3                         G  .
# 4                         G  .
# ...                     ... ..
# 81782583                  A  .
# 81782584                  T  .
# 81782585                  T  .
# 81782586                  T  .
# 81782587                  C  .
#
#                                                        Info
# 0         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 1         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 2         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 3         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# 4         CONSEQUENCE=||||||intergenic_region||,WASH7P|E...
# ...                                                     ...
# 81782583  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81782584  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81782585  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81782586  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
# 81782587  CONSEQUENCE=||||||intergenic_region||;OCCURREN...
#
# [81782588 rows x 9 columns]

# %%
def expand_info(info):
    # Split the info field into its components
    fields = info.split(';')
    consequence = fields[0].split('=')[1] if len(fields) > 0 else ''
    occurrence = fields[1].split('=')[1] if len(fields) > 1 else ''
    affected_donors = fields[2].split('=')[1] if len(fields) > 2 else ''
    mutation = fields[3].split('=')[1] if len(fields) > 3 else ''
    project_count = fields[4].split('=')[1] if len(fields) > 4 else ''
    studies = fields[5].split('=')[1] if len(fields) > 5 else ''
    tested_donors = fields[6].split('=')[1] if len(fields) > 6 else ''
    return pd.Series([consequence, occurrence, affected_donors, mutation, project_count, studies, tested_donors])

# %%
# Apply the expansion function to each row
expanded_df = df['Info'].apply(expand_info)
expanded_df.columns = ["Consequedf_accepter","Occurrence", "Affected_Donors", "Mutation", "Project_Count", "Studies", "Tested_Donors"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5914, in NDFrame.__setattr__(self, name, value)
#    5913 try:
# -> 5914     object.__getattribute__(self, name)
#    5915     return object.__setattr__(self, name, value)
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:659, in Series.name(self)
#     613 """
#     614 Return the name of the Series.
#     615
#    (...)
#     657 'Even Numbers'
#     658 """
# --> 659 return self._name
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute '_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Apply the expansion function to each row
# ----> 2 expanded_df = df['Info'].apply(expand_info)
#       3 expanded_df.columns = ["Consequence", "Occurrence", "Affected_Donors", "Mutation", "Project_Count", "Studies", "Tested_Donors"]
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[8], line 11, in expand_info(info)
#       9 studies = fields[5].split('=')[1] if len(fields) > 5 else ''
#      10 tested_donors = fields[6].split('=')[1] if len(fields) > 6 else ''
# ---> 11 return pd.Series([consequence, occurrence, affected_donors, mutation, project_count, studies, tested_donors])
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:483, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     481     object.__setattr__(self, "_name", name)
#     482 else:
# --> 483     self.name = name
#     484     self._set_axis(0, index)
#
# File /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5914, in NDFrame.__setattr__(self, name, value)
#    5909 # first try regular attribute access via __getattribute__, so that
#    5910 # e.g. ``obj.x`` and ``obj.x = 4`` will always reference/modify
#    5911 # the same attribute.
#    5913 try:
# -> 5914     object.__getattribute__(self, name)
#    5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#
# KeyboardInterrupt:

# %%
result_df = pd.concat([df[["Chromosome", "Start", "End", "Mutation_ID","T1","Reference_Allele", "Alternative_Allele","T2"]], expanded_df], axis=1)

# %%
df_acceptor = pd.read_csv("/data/projects/DNABERT_snv/Manuscript_11_2023/bed/DNABERT_run_data/acceptor.bed", sep="\t", header=None)
df_acceptor[2] = df_acceptor[2].round().astype(int)
df_acceptor
# Out:
#             0          1          2                3                4  5   \
# 0         chr7  127589043  127589122  ENST00000000233  ENSG00000004059  +
# 1         chr7  127588371  127588450  ENST00000000233  ENSG00000004059  +
# 2         chr7  127589445  127589524  ENST00000000233  ENSG00000004059  +
# 3         chr7  127590923  127591002  ENST00000000233  ENSG00000004059  +
# 4         chr7  127591173  127591252  ENST00000000233  ENSG00000004059  +
# ...        ...        ...        ...              ...              ... ..
# 1175762  chr17   63706700   63706779  ENST00000640999  ENSG00000266173  -
# 1175763  chr17   63707379   63707458  ENST00000640999  ENSG00000266173  -
# 1175764  chr17   63710575   63710654  ENST00000640999  ENSG00000266173  -
# 1175765  chr17   63710797   63710876  ENST00000640999  ENSG00000266173  -
# 1175766  chr17   63713488   63713567  ENST00000640999  ENSG00000266173  -
#
#                 6     7               8      9       10          11  \
# 0        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 1        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 2        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 3        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# 4        127588411  1032  protein_coding  56.14    ARF5  HouseTrans
# ...            ...   ...             ...    ...     ...         ...
# 1175762   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175763   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175764   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175765   63741796  2336  protein_coding  48.88  STRADA   NullTrans
# 1175766   63741796  2336  protein_coding  48.88  STRADA   NullTrans
#
#                                                         12
# 0        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 1        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 2        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 3        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# 4        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...
# ...                                                    ...
# 1175762                                                NaN
# 1175763                                                NaN
# 1175764                                                NaN
# 1175765                                                NaN
# 1175766                                                NaN
#
# [1175767 rows x 13 columns]

# %%
icgc_bed = pybedtools.BedTool.from_dataframe(df.iloc[1:])

# %%
acceptor_bed = pybedtools.BedTool.from_dataframe(df_acceptor)

# %%
intersect_bed = acceptor_bed.intersect(icgc_bed, wa=True, wb=True)

# %%
intersect_df = intersect_bed.to_dataframe()
new_columns = ['chr_name', 'Acceptor_start', 'Acceptor_end', "Transcript_ID","Gene ID", "strand","TSS","ID","tag","value","GENE","Transcript_type","Tissue", "Chromosome", "Start",	"End", "Mutation_ID", "T1", "Reference_Allele", "Alternative_Allele", "T2","Info"]
intersect_df.columns = new_columns
intersect_df
# Out:
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 22 fields; you can supply custom names with the `names` kwarg
#   warn(
#         chr_name  Acceptor_start  Acceptor_end    Transcript_ID  \
# 0           chr7       127589043     127589122  ENST00000000233
# 1           chr7       127589043     127589122  ENST00000000233
# 2           chr7       127588371     127588450  ENST00000000233
# 3           chr7       127588371     127588450  ENST00000000233
# 4           chr7       127589445     127589524  ENST00000000233
# ...          ...             ...           ...              ...
# 2375836    chr17        63704008      63704087  ENST00000640999
# 2375837    chr17        63704008      63704087  ENST00000640999
# 2375838    chr17        63704543      63704622  ENST00000640999
# 2375839    chr17        63707379      63707458  ENST00000640999
# 2375840    chr17        63713488      63713567  ENST00000640999
#
#                  Gene ID strand        TSS    ID             tag  value  ...  \
# 0        ENSG00000004059      +  127588411  1032  protein_coding  56.14  ...
# 1        ENSG00000004059      +  127588411  1032  protein_coding  56.14  ...
# 2        ENSG00000004059      +  127588411  1032  protein_coding  56.14  ...
# 3        ENSG00000004059      +  127588411  1032  protein_coding  56.14  ...
# 4        ENSG00000004059      +  127588411  1032  protein_coding  56.14  ...
# ...                  ...    ...        ...   ...             ...    ...  ...
# 2375836  ENSG00000266173      -   63741796  2336  protein_coding  48.88  ...
# 2375837  ENSG00000266173      -   63741796  2336  protein_coding  48.88  ...
# 2375838  ENSG00000266173      -   63741796  2336  protein_coding  48.88  ...
# 2375839  ENSG00000266173      -   63741796  2336  protein_coding  48.88  ...
# 2375840  ENSG00000266173      -   63741796  2336  protein_coding  48.88  ...
#
#                                                     Tissue Chromosome  \
# 0        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 1        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 2        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 3        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# 4        Adipose_Tissue, Adrenal_Gland, Bladder, Blood,...       chr7
# ...                                                    ...        ...
# 2375836                                                  .      chr17
# 2375837                                                  .      chr17
# 2375838                                                  .      chr17
# 2375839                                                  .      chr17
# 2375840                                                  .      chr17
#
#              Start        End  Mutation_ID  T1 Reference_Allele  \
# 0        127589068  127589069   MU35907306   .                T
# 1        127589109  127589110  MU133330136   .                C
# 2        127588377  127588378    MU2774305   .                G
# 3        127588412  127588413  MU117944068   .                G
# 4        127589453  127589454   MU86144404   .                G
# ...            ...        ...          ...  ..              ...
# 2375836   63704071   63704072   MU65877200   .                T
# 2375837   63704075   63704076  MU131889209   .                G
# 2375838   63704608   63704609   MU68047245   .                G
# 2375839   63707400   63707401    MU9270347   .                G
# 2375840   63713492   63713493   MU91553898   .                G
#
#         Alternative_Allele T2  \
# 0                        G  .
# 1                        G  .
# 2                        A  .
# 3                        A  .
# 4                        A  .
# ...                    ... ..
# 2375836                  C  .
# 2375837                  A  .
# 2375838                  A  .
# 2375839                  A  .
# 2375840                  A  .
#
#                                                       Info
# 0        CONSEQUENCE=SND1|ENSG00000197157|+|SND1-001|EN...
# 1        CONSEQUENCE=SND1|ENSG00000197157|+|SND1-001|EN...
# 2        CONSEQUENCE=SND1|ENSG00000197157|+|SND1-001|EN...
# 3        CONSEQUENCE=SND1|ENSG00000197157|+|SND1-001|EN...
# 4        CONSEQUENCE=SND1|ENSG00000197157|+|SND1-001|EN...
# ...                                                    ...
# 2375836  CONSEQUENCE=CEP112|ENSG00000154240|1|CEP112-00...
# 2375837  CONSEQUENCE=CEP112|ENSG00000154240|1|CEP112-00...
# 2375838  CONSEQUENCE=CEP112|ENSG00000154240|1|CEP112-00...
# 2375839  CONSEQUENCE=CEP112|ENSG00000154240|1|CEP112-00...
# 2375840  CONSEQUENCE=CEP112|ENSG00000154240|1|CEP112-00...
#
# [2375841 rows x 22 columns]

# %%
intersect_df.to_csv("/data/projects/DNABERT_snv/Manuscript_11_2023/Intersected_data/acceptor_ICGC_intersected.tsv", sep="\t", index=False)
