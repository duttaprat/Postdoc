# %%
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go
from dash import Dash, dcc, html, Input, Output

# %%
INPUT_PATH= "/data/projects/shared_data/collab_data/10_transcripts/Data"
INPUT_FOLDERNAME = "tpm"
INPUT_FILENAME = "gbm_gtex.csv"
INPUT_FILENAME1 = "lgg_gtex.csv"
OUTPUT_PATH = "/data/projects/shared_data/collab_data/10_transcripts/Results"
OUTPUT_FILE_NAME = INPUT_FILENAME.split('.')[0]+"_box_plots.png"

# %%
df = pd.read_csv(INPUT_PATH+"/"+INPUT_FOLDERNAME+"/"+INPUT_FILENAME, sep= " ")
#df = df.T
df
# Out:
#           status                    sample  ENST00000461347.5  \
# 1     gtex_brain  GTEX-1117F-3226-SM-5N9CT           3.030013
# 2     gtex_brain  GTEX-111FC-3126-SM-5GZZ2           6.400012
# 3     gtex_brain  GTEX-111FC-3326-SM-5GZYV          13.230457
# 4     gtex_brain  GTEX-1128S-2726-SM-5H12C           4.580119
# 5     gtex_brain  GTEX-1128S-2826-SM-5N9DI           9.870026
# ...          ...                       ...                ...
# 1297         gbm           TCGA-76-4927-01           1.099989
# 1298         gbm           TCGA-76-4928-01           2.230015
# 1299         gbm           TCGA-76-4929-01           3.530057
# 1300         gbm           TCGA-76-4931-01           8.330060
# 1301         gbm           TCGA-76-4932-01           2.040034
#
#       ENST00000322723.8  ENST00000484328.1  ENST00000454824.5  \
# 1             37.190473      -1.089298e-08       2.099978e-01
# 2             64.430756      -1.089298e-08       7.299781e-01
# ...

# %%
df1 = pd.read_csv(INPUT_PATH+"/"+INPUT_FOLDERNAME+"/"+INPUT_FILENAME1, sep= " ")
df1
# Out:
#           status                    sample  ENST00000461347.5  \
# 1     gtex_brain  GTEX-1117F-3226-SM-5N9CT           3.030013
# 2     gtex_brain  GTEX-111FC-3126-SM-5GZZ2           6.400012
# 3     gtex_brain  GTEX-111FC-3326-SM-5GZYV          13.230457
# 4     gtex_brain  GTEX-1128S-2726-SM-5H12C           4.580119
# 5     gtex_brain  GTEX-1128S-2826-SM-5N9DI           9.870026
# ...          ...                       ...                ...
# 1653         lgg           TCGA-WY-A85A-01           3.340046
# 1654         lgg           TCGA-WY-A85B-01           3.650021
# 1655         lgg           TCGA-WY-A85C-01           5.050108
# 1656         lgg           TCGA-WY-A85D-01           3.389975
# 1657         lgg           TCGA-WY-A85E-01           3.610004
#
#       ENST00000322723.8  ENST00000484328.1  ENST00000454824.5  \
# 1             37.190473      -1.089298e-08       2.099978e-01
# 2             64.430756      -1.089298e-08       7.299781e-01
# ...

# %%
print(df.groupby(['status']).size())
print(df1.groupby(['status']).size())
# Out:
# status
# gbm            153
# gtex_brain    1148
# dtype: int64
# status
# gtex_brain    1148
# lgg            509
# dtype: int64

# %%
df_merge = pd.concat([df,df1]).drop_duplicates().reset_index(drop=True)
df_merge.rename(columns={'status': 'sample_group'}, inplace=True)
df_merge
# Out:
#      sample_group                    sample  ENST00000461347.5  \
# 0      gtex_brain  GTEX-1117F-3226-SM-5N9CT           3.030013
# 1      gtex_brain  GTEX-111FC-3126-SM-5GZZ2           6.400012
# 2      gtex_brain  GTEX-111FC-3326-SM-5GZYV          13.230457
# 3      gtex_brain  GTEX-1128S-2726-SM-5H12C           4.580119
# 4      gtex_brain  GTEX-1128S-2826-SM-5N9DI           9.870026
# ...           ...                       ...                ...
# 1805          lgg           TCGA-WY-A85A-01           3.340046
# 1806          lgg           TCGA-WY-A85B-01           3.650021
# 1807          lgg           TCGA-WY-A85C-01           5.050108
# 1808          lgg           TCGA-WY-A85D-01           3.389975
# 1809          lgg           TCGA-WY-A85E-01           3.610004
#
#       ENST00000322723.8  ENST00000484328.1  ENST00000454824.5  \
# 0             37.190473      -1.089298e-08       2.099978e-01
# 1             64.430756      -1.089298e-08       7.299781e-01
# ...

# %%
# df = df.astype({'Fee':'float','Discount':'float'})
#df = df.astype(float)
df_merge.dtypes
# Out:
# sample_group          object
# sample                object
# ENST00000461347.5    float64
# ENST00000322723.8    float64
# ENST00000484328.1    float64
# ENST00000454824.5    float64
# ENST00000417652.5    float64
# ENST00000453992.5    float64
# ENST00000436894.1    float64
# ENST00000494618.1    float64
# ENST00000356936.5    float64
# ENST00000466274.1    float64
# dtype: object

# %%
df_merge.groupby(['sample_group']).size()
# Out:
# sample_group
# gbm            153
# gtex_brain    1148
# lgg            509
# dtype: int64

# %%
df_merge.columns
# Out:
# Index(['sample_group', 'sample', 'ENST00000461347.5', 'ENST00000322723.8',
#        'ENST00000484328.1', 'ENST00000454824.5', 'ENST00000417652.5',
#        'ENST00000453992.5', 'ENST00000436894.1', 'ENST00000494618.1',
#        'ENST00000356936.5', 'ENST00000466274.1'],
#       dtype='object')

# %%
for column in df_merge.iloc[:,2:].columns:
    print(column)
    min_val = min([float(a) for a in df[column].values.tolist()] )
    fig = px.box(df_merge, x="sample_group", y=column, color= "sample_group")
    #fig.update_traces(quartilemethod="exclusive")
    #fig.update_layout(yaxis_tickformat = '%{y:.2f}')
    #fig.update_layout(yaxis = dict(tickmode = 'linear',tick0 = 5,dtick = 0.25))
    fig.update_yaxes(nticks=10, tickformat=".%2f")
    #fig.update_yaxes(tick0=min_val, dtick=1.50, tickformat='.%2f')
    #fig.update_layout(yaxis_tickformat = '%.2f')
    fig.show()
# Out:
# ENST00000461347.5
# ...

# %%
app = Dash(__name__)


app.layout = html.Div([
    html.H4("Analysis of the restaurant's revenue"),
    html.P("x-axis:"),
    dcc.Checklist(
        id='x-axis', 
        options=['status'],
        value=['time'], 
        inline=True
    ),
    html.P("y-axis:"),
    dcc.RadioItems(
        id='y-axis', 
        options=['ENST00000461347.5','ENST00000322723.8','ENST00000484328.1'],
        value='total_bill', 
        inline=True
    ),
    dcc.Graph(id="graph"),
])


@app.callback(
    Output("graph", "figure"), 
    Input("x-axis", "value"), 
    Input("y-axis", "value"))
def generate_chart(x, y):
    df = px.data.tips() # replace with your own data source
    fig = px.box(df, x=x, y=y)
    return fig


app.run_server(debug=True, port=8051)
# Out:
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
# Dash is running on http://127.0.0.1:8051/
#
#  * Serving Flask app '__main__'
#  * Debug mode: on
# /home/campus.stonybrook.edu/pdutta/anaconda3/envs/stratified_subsampling/lib/python3.8/site-packages/traitlets/traitlets.py:2202: FutureWarning: Supporting extra quotes around strings is deprecated in traitlets 5.0. You can use 'hmac-sha256' instead of '"hmac-sha256"' if you require traitlets >=5.
#   warn(
# /home/campus.stonybrook.edu/pdutta/anaconda3/envs/stratified_subsampling/lib/python3.8/site-packages/traitlets/traitlets.py:2157: FutureWarning: Supporting extra quotes around Bytes is deprecated in traitlets 5.0. Use '1cd74b43-ee38-43c2-9377-832d904e443d' instead of 'b"1cd74b43-ee38-43c2-9377-832d904e443d"'.
#   warn(
# Traceback (most recent call last):
# ...

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/campus.stonybrook.edu/pdutta/Github/Postdoc/Collab_code/boxplot.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bisoformer/home/campus.stonybrook.edu/pdutta/Github/Postdoc/Collab_code/boxplot.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> x
#
# NameError: name 'x' is not defined

# %%
! pwd
# Out:
# /home/campus.stonybrook.edu/pdutta/Github/Postdoc/Collab_code
