# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import pybedtools
import numpy as np
import os
pybedtools.helpers.set_tempdir('/data/projects/temp')
from IPython.display import display

# %%
df_gtf= pd.read_csv("/data/private/pdutta/Collab_data/Jim_work/mouse_gencode_annotation/gencode_gtf_annotation.tsv", sep="\t")

# %%
df_gtf
# Out:
#         seqname   source     feature      start        end score strand frame  \
# 0          chr1   HAVANA        gene    3143476    3144545     .      +     .
# 1          chr1   HAVANA  transcript    3143476    3144545     .      +     .
# 2          chr1   HAVANA        exon    3143476    3144545     .      +     .
# 3          chr1  ENSEMBL        gene    3172239    3172348     .      +     .
# 4          chr1  ENSEMBL  transcript    3172239    3172348     .      +     .
# ...         ...      ...         ...        ...        ...   ...    ...   ...
# 1032379    chr9   HAVANA         CDS  108691464  108691550     .      +     0
# 1032380    chr9   HAVANA        exon  108691629  108691767     .      +     .
# 1032381    chr9   HAVANA         CDS  108691629  108691767     .      +     0
# 1032382    chr9   HAVANA        exon  108691866  108691946     .      +     .
# 1032383    chr9   HAVANA         CDS  108691866  108691946     .      +     2
#
#                       gene_id       gene_type  ... transcript_type  \
# 0        ENSMUSG00000102693.2             TEC  ...             NaN
# 1        ENSMUSG00000102693.2             TEC  ...             TEC
# 2        ENSMUSG00000102693.2             TEC  ...             TEC
# 3        ENSMUSG00000064842.3           snRNA  ...             NaN
# 4        ENSMUSG00000064842.3           snRNA  ...           snRNA
# ...                       ...             ...  ...             ...
# 1032379  ENSMUSG00000032598.9  protein_coding  ...  protein_coding
# 1032380  ENSMUSG00000032598.9  protein_coding  ...  protein_coding
# 1032381  ENSMUSG00000032598.9  protein_coding  ...  protein_coding
# 1032382  ENSMUSG00000032598.9  protein_coding  ...  protein_coding
# 1032383  ENSMUSG00000032598.9  protein_coding  ...  protein_coding
#
#            transcript_name transcript_support_level                tag  \
# 0                      NaN                      NaN                NaN
# 1        4933401J01Rik-201                      NaN  Ensembl_canonical
# 2        4933401J01Rik-201                      NaN  Ensembl_canonical
# 3                      NaN                      NaN                NaN
# 4              Gm26206-201                      NaN  Ensembl_canonical
# ...                    ...                      ...                ...
# 1032379        Nckipsd-201                      1.0               CCDS
# 1032380        Nckipsd-201                      1.0               CCDS
# 1032381        Nckipsd-201                      1.0               CCDS
# 1032382        Nckipsd-201                      1.0               CCDS
# 1032383        Nckipsd-201                      NaN                NaN
#
#             havana_transcript exon_number               exon_id  \
# 0                         NaN         NaN                   NaN
# 1        OTTMUST00000127109.1         NaN                   NaN
# 2        OTTMUST00000127109.1         1.0  ENSMUSE00001343744.2
# 3                         NaN         NaN                   NaN
# 4                         NaN         NaN                   NaN
# ...                       ...         ...                   ...
# 1032379  OTTMUST00000128467.1         7.0  ENSMUSE00000221318.4
# 1032380  OTTMUST00000128467.1         8.0  ENSMUSE00000221321.4
# 1032381  OTTMUST00000128467.1         8.0  ENSMUSE00000221321.4
# 1032382  OTTMUST00000128467.1         9.0  ENSMUSE00000221323.4
# 1032383                   NaN         9.0                   NaN
#
#                    protein_id       ccdsid  ont
# 0                         NaN          NaN  NaN
# 1                         NaN          NaN  NaN
# 2                         NaN          NaN  NaN
# 3                         NaN          NaN  NaN
# 4                         NaN          NaN  NaN
# ...                       ...          ...  ...
# 1032379  ENSMUSP00000035218.8  CCDS23538.1  NaN
# 1032380  ENSMUSP00000035218.8  CCDS23538.1  NaN
# 1032381  ENSMUSP00000035218.8  CCDS23538.1  NaN
# 1032382  ENSMUSP00000035218.8  CCDS23538.1  NaN
# 1032383                   NaN          NaN  NaN
#
# [1032384 rows x 25 columns]

# %%
df_gtf.groupby('feature').size()
# Out:
# feature
# CDS               288589
# Selenocysteine        18
# UTR               101311
# exon              469432
# gene               29795
# start_codon        32674
# stop_codon         30315
# transcript         80250
# dtype: int64

# %%
df_exon = df_gtf[df_gtf['feature']=="exon"]
df_exon
# Out:
#         seqname   source feature      start        end score strand frame  \
# 2          chr1   HAVANA    exon    3143476    3144545     .      +     .
# 5          chr1  ENSEMBL    exon    3172239    3172348     .      +     .
# 8          chr1   HAVANA    exon    3283832    3286567     .      -     .
# 9          chr1   HAVANA    exon    3276124    3277540     .      -     .
# 11         chr1   HAVANA    exon    3283662    3285855     .      -     .
# ...         ...      ...     ...        ...        ...   ...    ...   ...
# 1032374    chr9   HAVANA    exon  108689418  108689908     .      +     .
# 1032376    chr9   HAVANA    exon  108691148  108691318     .      +     .
# 1032378    chr9   HAVANA    exon  108691464  108691550     .      +     .
# 1032380    chr9   HAVANA    exon  108691629  108691767     .      +     .
# 1032382    chr9   HAVANA    exon  108691866  108691946     .      +     .
#
#                       gene_id       gene_type      gene_name  level  \
# 2        ENSMUSG00000102693.2             TEC  4933401J01Rik    2.0
# 5        ENSMUSG00000064842.3           snRNA        Gm26206    3.0
# 8        ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# 9        ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# 11       ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# ...                       ...             ...            ...    ...
# 1032374  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032376  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032378  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032380  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032382  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
#
#               mgi_id           havana_gene         transcript_id  \
# 2        MGI:1918292  OTTMUSG00000049935.1  ENSMUST00000193812.2
# 5        MGI:5455983                   NaN  ENSMUST00000082908.3
# 8        MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000162897.2
# 9        MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000162897.2
# 11       MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000159265.2
# ...              ...                   ...                   ...
# 1032374  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032376  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032378  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032380  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032382  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
#
#                         transcript_type    transcript_name  \
# 2                                   TEC  4933401J01Rik-201
# 5                                 snRNA        Gm26206-201
# 8        protein_coding_CDS_not_defined           Xkr4-203
# 9        protein_coding_CDS_not_defined           Xkr4-203
# 11       protein_coding_CDS_not_defined           Xkr4-202
# ...                                 ...                ...
# 1032374                  protein_coding        Nckipsd-201
# 1032376                  protein_coding        Nckipsd-201
# 1032378                  protein_coding        Nckipsd-201
# 1032380                  protein_coding        Nckipsd-201
# 1032382                  protein_coding        Nckipsd-201
#
#          transcript_support_level                tag     havana_transcript  \
# 2                             NaN  Ensembl_canonical  OTTMUST00000127109.1
# 5                             NaN  Ensembl_canonical                   NaN
# 8                             1.0                NaN  OTTMUST00000086625.1
# 9                             1.0                NaN  OTTMUST00000086625.1
# 11                            1.0                NaN  OTTMUST00000086624.1
# ...                           ...                ...                   ...
# 1032374                       1.0               CCDS  OTTMUST00000128467.1
# 1032376                       1.0               CCDS  OTTMUST00000128467.1
# 1032378                       1.0               CCDS  OTTMUST00000128467.1
# 1032380                       1.0               CCDS  OTTMUST00000128467.1
# 1032382                       1.0               CCDS  OTTMUST00000128467.1
#
#          exon_number               exon_id            protein_id       ccdsid  \
# 2                1.0  ENSMUSE00001343744.2                   NaN          NaN
# 5                1.0  ENSMUSE00000522066.2                   NaN          NaN
# 8                1.0  ENSMUSE00000858910.2                   NaN          NaN
# 9                2.0  ENSMUSE00000866652.2                   NaN          NaN
# 11               1.0  ENSMUSE00000863980.2                   NaN          NaN
# ...              ...                   ...                   ...          ...
# 1032374          5.0  ENSMUSE00000472692.3  ENSMUSP00000035218.8  CCDS23538.1
# 1032376          6.0  ENSMUSE00000515905.3  ENSMUSP00000035218.8  CCDS23538.1
# 1032378          7.0  ENSMUSE00000221318.4  ENSMUSP00000035218.8  CCDS23538.1
# 1032380          8.0  ENSMUSE00000221321.4  ENSMUSP00000035218.8  CCDS23538.1
# 1032382          9.0  ENSMUSE00000221323.4  ENSMUSP00000035218.8  CCDS23538.1
#
#          ont
# 2        NaN
# 5        NaN
# 8        NaN
# 9        NaN
# 11       NaN
# ...      ...
# 1032374  NaN
# 1032376  NaN
# 1032378  NaN
# 1032380  NaN
# 1032382  NaN
#
# [469432 rows x 25 columns]

# %%
df_gtf.groupby('source').size()
# Out:
# source
# ENSEMBL     71786
# HAVANA     960598
# dtype: int64

# %%
df_exon.drop_duplicates(['start','end'])
# Out:
#         seqname   source feature      start        end score strand frame  \
# 2          chr1   HAVANA    exon    3143476    3144545     .      +     .
# 5          chr1  ENSEMBL    exon    3172239    3172348     .      +     .
# 8          chr1   HAVANA    exon    3283832    3286567     .      -     .
# 9          chr1   HAVANA    exon    3276124    3277540     .      -     .
# 11         chr1   HAVANA    exon    3283662    3285855     .      -     .
# ...         ...      ...     ...        ...        ...   ...    ...   ...
# 1032374    chr9   HAVANA    exon  108689418  108689908     .      +     .
# 1032376    chr9   HAVANA    exon  108691148  108691318     .      +     .
# 1032378    chr9   HAVANA    exon  108691464  108691550     .      +     .
# 1032380    chr9   HAVANA    exon  108691629  108691767     .      +     .
# 1032382    chr9   HAVANA    exon  108691866  108691946     .      +     .
#
#                       gene_id       gene_type      gene_name  level  \
# 2        ENSMUSG00000102693.2             TEC  4933401J01Rik    2.0
# 5        ENSMUSG00000064842.3           snRNA        Gm26206    3.0
# 8        ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# 9        ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# 11       ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# ...                       ...             ...            ...    ...
# 1032374  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032376  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032378  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032380  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032382  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
#
#               mgi_id           havana_gene         transcript_id  \
# 2        MGI:1918292  OTTMUSG00000049935.1  ENSMUST00000193812.2
# 5        MGI:5455983                   NaN  ENSMUST00000082908.3
# 8        MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000162897.2
# 9        MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000162897.2
# 11       MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000159265.2
# ...              ...                   ...                   ...
# 1032374  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032376  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032378  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032380  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032382  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
#
#                         transcript_type    transcript_name  \
# 2                                   TEC  4933401J01Rik-201
# 5                                 snRNA        Gm26206-201
# 8        protein_coding_CDS_not_defined           Xkr4-203
# 9        protein_coding_CDS_not_defined           Xkr4-203
# 11       protein_coding_CDS_not_defined           Xkr4-202
# ...                                 ...                ...
# 1032374                  protein_coding        Nckipsd-201
# 1032376                  protein_coding        Nckipsd-201
# 1032378                  protein_coding        Nckipsd-201
# 1032380                  protein_coding        Nckipsd-201
# 1032382                  protein_coding        Nckipsd-201
#
#          transcript_support_level                tag     havana_transcript  \
# 2                             NaN  Ensembl_canonical  OTTMUST00000127109.1
# 5                             NaN  Ensembl_canonical                   NaN
# 8                             1.0                NaN  OTTMUST00000086625.1
# 9                             1.0                NaN  OTTMUST00000086625.1
# 11                            1.0                NaN  OTTMUST00000086624.1
# ...                           ...                ...                   ...
# 1032374                       1.0               CCDS  OTTMUST00000128467.1
# 1032376                       1.0               CCDS  OTTMUST00000128467.1
# 1032378                       1.0               CCDS  OTTMUST00000128467.1
# 1032380                       1.0               CCDS  OTTMUST00000128467.1
# 1032382                       1.0               CCDS  OTTMUST00000128467.1
#
#          exon_number               exon_id            protein_id       ccdsid  \
# 2                1.0  ENSMUSE00001343744.2                   NaN          NaN
# 5                1.0  ENSMUSE00000522066.2                   NaN          NaN
# 8                1.0  ENSMUSE00000858910.2                   NaN          NaN
# 9                2.0  ENSMUSE00000866652.2                   NaN          NaN
# 11               1.0  ENSMUSE00000863980.2                   NaN          NaN
# ...              ...                   ...                   ...          ...
# 1032374          5.0  ENSMUSE00000472692.3  ENSMUSP00000035218.8  CCDS23538.1
# 1032376          6.0  ENSMUSE00000515905.3  ENSMUSP00000035218.8  CCDS23538.1
# 1032378          7.0  ENSMUSE00000221318.4  ENSMUSP00000035218.8  CCDS23538.1
# 1032380          8.0  ENSMUSE00000221321.4  ENSMUSP00000035218.8  CCDS23538.1
# 1032382          9.0  ENSMUSE00000221323.4  ENSMUSP00000035218.8  CCDS23538.1
#
#          ont
# 2        NaN
# 5        NaN
# 8        NaN
# 9        NaN
# 11       NaN
# ...      ...
# 1032374  NaN
# 1032376  NaN
# 1032378  NaN
# 1032380  NaN
# 1032382  NaN
#
# [245964 rows x 25 columns]

# %%
df_exon['unique_id'] = df_exon['gene_id'] + '_' + df_exon['start'].astype(str) + '_' + df_exon['end'].astype(str)
# Out:
# /tmp/ipykernel_3503301/1634419950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_exon['unique_id'] = df_exon['gene_id'] + '_' + df_exon['start'].astype(str) + '_' + df_exon['end'].astype(str)

# %%
# Get a list of the existing column names
cols = df_exon.columns.tolist()

# Remove 'start' and 'end' from their current positions in the list
cols.remove('start')
cols.remove('end')

# Insert 'start' and 'end' at the 2nd and 3rd positions
cols.insert(1, 'start')
cols.insert(2, 'end')

# Reorder the DataFrame columns using the modified list of column names
df_exon = df_exon[cols]

# %%
df_exon
# Out:
#         seqname      start        end   source feature score strand frame  \
# 2          chr1    3143476    3144545   HAVANA    exon     .      +     .
# 5          chr1    3172239    3172348  ENSEMBL    exon     .      +     .
# 8          chr1    3283832    3286567   HAVANA    exon     .      -     .
# 9          chr1    3276124    3277540   HAVANA    exon     .      -     .
# 11         chr1    3283662    3285855   HAVANA    exon     .      -     .
# ...         ...        ...        ...      ...     ...   ...    ...   ...
# 1032374    chr9  108689418  108689908   HAVANA    exon     .      +     .
# 1032376    chr9  108691148  108691318   HAVANA    exon     .      +     .
# 1032378    chr9  108691464  108691550   HAVANA    exon     .      +     .
# 1032380    chr9  108691629  108691767   HAVANA    exon     .      +     .
# 1032382    chr9  108691866  108691946   HAVANA    exon     .      +     .
#
#                       gene_id       gene_type      gene_name  level  \
# 2        ENSMUSG00000102693.2             TEC  4933401J01Rik    2.0
# 5        ENSMUSG00000064842.3           snRNA        Gm26206    3.0
# 8        ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# 9        ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# 11       ENSMUSG00000051951.6  protein_coding           Xkr4    2.0
# ...                       ...             ...            ...    ...
# 1032374  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032376  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032378  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032380  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
# 1032382  ENSMUSG00000032598.9  protein_coding        Nckipsd    2.0
#
#               mgi_id           havana_gene         transcript_id  \
# 2        MGI:1918292  OTTMUSG00000049935.1  ENSMUST00000193812.2
# 5        MGI:5455983                   NaN  ENSMUST00000082908.3
# 8        MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000162897.2
# 9        MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000162897.2
# 11       MGI:3528744  OTTMUSG00000026353.2  ENSMUST00000159265.2
# ...              ...                   ...                   ...
# 1032374  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032376  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032378  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032380  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
# 1032382  MGI:1931834  OTTMUSG00000050675.2  ENSMUST00000035218.9
#
#                         transcript_type    transcript_name  \
# 2                                   TEC  4933401J01Rik-201
# 5                                 snRNA        Gm26206-201
# 8        protein_coding_CDS_not_defined           Xkr4-203
# 9        protein_coding_CDS_not_defined           Xkr4-203
# 11       protein_coding_CDS_not_defined           Xkr4-202
# ...                                 ...                ...
# 1032374                  protein_coding        Nckipsd-201
# 1032376                  protein_coding        Nckipsd-201
# 1032378                  protein_coding        Nckipsd-201
# 1032380                  protein_coding        Nckipsd-201
# 1032382                  protein_coding        Nckipsd-201
#
#          transcript_support_level                tag     havana_transcript  \
# 2                             NaN  Ensembl_canonical  OTTMUST00000127109.1
# 5                             NaN  Ensembl_canonical                   NaN
# 8                             1.0                NaN  OTTMUST00000086625.1
# 9                             1.0                NaN  OTTMUST00000086625.1
# 11                            1.0                NaN  OTTMUST00000086624.1
# ...                           ...                ...                   ...
# 1032374                       1.0               CCDS  OTTMUST00000128467.1
# 1032376                       1.0               CCDS  OTTMUST00000128467.1
# 1032378                       1.0               CCDS  OTTMUST00000128467.1
# 1032380                       1.0               CCDS  OTTMUST00000128467.1
# 1032382                       1.0               CCDS  OTTMUST00000128467.1
#
#          exon_number               exon_id            protein_id       ccdsid  \
# 2                1.0  ENSMUSE00001343744.2                   NaN          NaN
# 5                1.0  ENSMUSE00000522066.2                   NaN          NaN
# 8                1.0  ENSMUSE00000858910.2                   NaN          NaN
# 9                2.0  ENSMUSE00000866652.2                   NaN          NaN
# 11               1.0  ENSMUSE00000863980.2                   NaN          NaN
# ...              ...                   ...                   ...          ...
# 1032374          5.0  ENSMUSE00000472692.3  ENSMUSP00000035218.8  CCDS23538.1
# 1032376          6.0  ENSMUSE00000515905.3  ENSMUSP00000035218.8  CCDS23538.1
# 1032378          7.0  ENSMUSE00000221318.4  ENSMUSP00000035218.8  CCDS23538.1
# 1032380          8.0  ENSMUSE00000221321.4  ENSMUSP00000035218.8  CCDS23538.1
# 1032382          9.0  ENSMUSE00000221323.4  ENSMUSP00000035218.8  CCDS23538.1
#
#          ont                                 unique_id
# 2        NaN      ENSMUSG00000102693.2_3143476_3144545
# 5        NaN      ENSMUSG00000064842.3_3172239_3172348
# 8        NaN      ENSMUSG00000051951.6_3283832_3286567
# 9        NaN      ENSMUSG00000051951.6_3276124_3277540
# 11       NaN      ENSMUSG00000051951.6_3283662_3285855
# ...      ...                                       ...
# 1032374  NaN  ENSMUSG00000032598.9_108689418_108689908
# 1032376  NaN  ENSMUSG00000032598.9_108691148_108691318
# 1032378  NaN  ENSMUSG00000032598.9_108691464_108691550
# 1032380  NaN  ENSMUSG00000032598.9_108691629_108691767
# 1032382  NaN  ENSMUSG00000032598.9_108691866_108691946
#
# [469432 rows x 26 columns]

# %%
df_exon.to_csv("/data/private/pdutta/Collab_data/Jim_work/mouse_gencode_annotation/exon_bed.tsv", sep="\t", index=False)

# %%
df_intersected_CPD_SNV = pd.read_csv("/data/private/pdutta/Collab_data/Jim_work/Output/UV_intersected_combined_CPD_SNV.tsv", sep= "\t")
df_intersected_CPD_SNV
# Out:
#        chr_name  CPD_start    CPD_end chr_name_SNV  SNV_start    SNV_end   ID  \
# 0          chr1    3610212    3610271         chr1    3610212    3610213  334
# 1          chr1    4020737    4020796         chr1    4020795    4020796  344
# 2          chr1    4252174    4252233         chr1    4252232    4252233  334
# 3          chr1    5725397    5725456         chr1    5725397    5725398  341
# 4          chr1    5779579    5779638         chr1    5779579    5779580  334
# ...         ...        ...        ...          ...        ...        ...  ...
# 288593     chrX  166005063  166005072         chrX  166005063  166005064  334
# 288594     chrX  166026319  166026328         chrX  166026319  166026320  334
# 288595     chrX  166581272  166581281         chrX  166581272  166581273  341
# 288596     chrX  167351471  167351480         chrX  167351471  167351472  341
# 288597     chrX  168363280  168363289         chrX  168363280  168363281  341
#
#            SNV_Info  CPD_original_start  CPD_original_end  distance
# 0       N:AG[T>G]TT             3610241           3610242        29
# 1       N:TT[C>T]GT             4020766           4020767       -29
# 2       T:TC[C>T]CC             4252203           4252204       -29
# 3       N:TT[C>T]TG             5725426           5725427        29
# 4       N:TT[T>C]TT             5779608           5779609        29
# ...             ...                 ...               ...       ...
# 288593  N:TT[C>T]AC           166005067         166005068         4
# 288594  U:TT[T>A]TA           166026323         166026324         4
# 288595  U:TT[C>T]CT           166581276         166581277         4
# 288596  N:AG[T>A]AA           167351475         167351476         4
# 288597  N:GT[C>T]TC           168363284         168363285         4
#
# [288598 rows x 11 columns]

# %%
df_exon_bed = pybedtools.BedTool.from_dataframe(df_exon)

# %%
df_statistics_intersect = pd.DataFrame(columns=['Distance of SNVs from CPDs', 'unique_CPDs','unique_SNVs', 'unique_EXON', 'unique_Intersected_data'])
for i in range(5):
    df_temp_CPD_SNV = df_intersected_CPD_SNV[abs(df_intersected_CPD_SNV["distance"])==i]
    temp_CPD_SNV_bed = pybedtools.BedTool.from_dataframe(df_temp_CPD_SNV)
    # Perform the intersection
    intersect_CPD_SNV_exon_bed = temp_CPD_SNV_bed.intersect(df_exon_bed, wa=True, wb=True)
    df_intersect_CPD_SNV_exon = intersect_CPD_SNV_exon_bed.to_dataframe()
    df_intersect_CPD_SNV_exon.columns = df_temp_CPD_SNV.columns.to_list() +  ['exon_' + str(x) for x in df_exon.columns.to_list()]
    display(df_intersect_CPD_SNV_exon)
    print(df_intersect_CPD_SNV_exon.shape)
    print("Unique CPDs :", df_intersect_CPD_SNV_exon.drop_duplicates(['CPD_start','CPD_end']).shape)
    print("Unique SNVs :", df_intersect_CPD_SNV_exon.drop_duplicates(['SNV_start','SNV_end','ID',	'SNV_Info']).shape)
    print("Unique exons :", df_intersect_CPD_SNV_exon.drop_duplicates(['exon_start', 'exon_end','exon_gene_id','exon_transcript_id']).shape)
    df_statistics_intersect.loc[i, ['Distance of SNVs from CPDs']] = i
    df_statistics_intersect.loc[i, ['unique_CPDs']] = len(df_intersect_CPD_SNV_exon.drop_duplicates(['CPD_start','CPD_end']))
    df_statistics_intersect.loc[i, ['unique_SNVs']] = len(df_intersect_CPD_SNV_exon.drop_duplicates(['SNV_start','SNV_end','ID',	'SNV_Info']))
    df_statistics_intersect.loc[i, ['unique_EXON']] = len(df_intersect_CPD_SNV_exon.drop_duplicates(['exon_start', 'exon_end','exon_gene_id','exon_transcript_id']))
    df_statistics_intersect.loc[i, ['unique_Intersected_data']] = len(df_intersect_CPD_SNV_exon)
    input()
# Out:
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 37 fields; you can supply custom names with the `names` kwarg
#   warn(
#      chr_name  CPD_start    CPD_end chr_name_SNV  SNV_start    SNV_end   ID  \
# 0        chr1    5346484    5346485         chr1    5346484    5346485  334
# 1        chr1    5378238    5378239         chr1    5378238    5378239  335
# 2        chr1    7586433    7586434         chr1    7586433    7586434  334
# 3        chr1   10522032   10522033         chr1   10522032   10522033  335
# 4        chr1   10853212   10853213         chr1   10853212   10853213  338
# ...       ...        ...        ...          ...        ...        ...  ...
# 1496     chr9  104059792  104059793         chr9  104059792  104059793  346
# 1497     chr9  104910835  104910836         chr9  104910835  104910836  334
# 1498     chr9  104910835  104910836         chr9  104910835  104910836  334
# 1499     chr9  106528324  106528325         chr9  106528324  106528325  334
# 1500     chr9  106528324  106528325         chr9  106528324  106528325  334
#
#          SNV_Info  CPD_original_start  CPD_original_end  distance  \
# 0     N:TC[C>G]TA             5346484           5346485         0
# 1     N:AT[C>T]CA             5378238           5378239         0
# 2     N:CC[T>A]CC             7586433           7586434         0
# 3     U:TT[C>T]CC            10522032          10522033         0
# 4     N:CT[C>T]TT            10853212          10853213         0
# ...           ...                 ...               ...       ...
# 1496  U:CA[C>T]TG           104059792         104059793         0
# 1497  T:CT[C>T]AA           104910835         104910836         0
# 1498  T:CT[C>T]AA           104910835         104910836         0
# 1499  U:CC[C>T]CC           106528324         106528325         0
# 1500  U:CC[C>T]CC           106528324         106528325         0
#
#      exon_seqname  exon_start   exon_end exon_source exon_feature exon_score  \
# 0            chr1     5346329    5346985      HAVANA         exon          .
# 1            chr1     5377962    5380240      HAVANA         exon          .
# 2            chr1     7586398    7588373      HAVANA         exon          .
# 3            chr1    10519470   10522214      HAVANA         exon          .
# 4            chr1    10852681   10854602      HAVANA         exon          .
# ...           ...         ...        ...         ...          ...        ...
# 1496         chr9   104059704  104059888      HAVANA         exon          .
# 1497         chr9   104909944  104911743      HAVANA         exon          .
# 1498         chr9   104909944  104911743      HAVANA         exon          .
# 1499         chr9   106527595  106528432      HAVANA         exon          .
# 1500         chr9   106527595  106528432      HAVANA         exon          .
#
#      exon_strand exon_frame           exon_gene_id        exon_gene_type  \
# 0              -          .   ENSMUSG00000104352.2  processed_pseudogene
# 1              +          .   ENSMUSG00000104046.2                   TEC
# 2              +          .   ENSMUSG00000103067.2                lncRNA
# 3              -          .   ENSMUSG00000103810.2                   TEC
# 4              -          .   ENSMUSG00000103448.2                   TEC
# ...          ...        ...                    ...                   ...
# 1496           -          .  ENSMUSG00000032560.15        protein_coding
# 1497           +          .  ENSMUSG00000032564.17        protein_coding
# 1498           +          .  ENSMUSG00000032564.17        protein_coding
# 1499           -          .  ENSMUSG00000023192.13        protein_coding
# 1500           -          .  ENSMUSG00000023192.13        protein_coding
#
#      exon_gene_name  exon_level  exon_mgi_id      exon_havana_gene  \
# 0            Gm7182         2.0  MGI:3644877  OTTMUSG00000050143.1
# 1           Gm37567         2.0  MGI:5610795  OTTMUSG00000050142.1
# 2           Gm30414         2.0  MGI:5589573  OTTMUSG00000050304.1
# 3           Gm38005         2.0  MGI:5611233  OTTMUSG00000047883.1
# 4           Gm37133         2.0  MGI:5610361  OTTMUSG00000047884.1
# ...             ...         ...          ...                   ...
# 1496        Dnajc13         2.0  MGI:2676368  OTTMUSG00000049291.7
# 1497          Cpne4         2.0  MGI:1921270  OTTMUSG00000023466.6
# 1498          Cpne4         2.0  MGI:1921270  OTTMUSG00000023466.6
# 1499           Grm2         2.0  MGI:1351339  OTTMUSG00000049456.2
# 1500           Grm2         2.0  MGI:1351339  OTTMUSG00000049456.2
#
#          exon_transcript_id  exon_transcript_type exon_transcript_name  \
# 0      ENSMUST00000193351.2  processed_pseudogene           Gm7182-201
# 1      ENSMUST00000193241.2                   TEC          Gm37567-201
# 2      ENSMUST00000194886.2                lncRNA          Gm30414-201
# 3      ENSMUST00000194845.2                   TEC          Gm38005-201
# 4      ENSMUST00000192705.2                   TEC          Gm37133-201
# ...                     ...                   ...                  ...
# 1496   ENSMUST00000191199.2       retained_intron          Dnajc13-214
# 1497  ENSMUST00000057742.15        protein_coding            Cpne4-201
# 1498   ENSMUST00000077190.7        protein_coding            Cpne4-202
# 1499  ENSMUST00000023959.13        protein_coding             Grm2-201
# 1500   ENSMUST00000201681.2        protein_coding             Grm2-203
#
#      exon_transcript_support_level           exon_tag exon_havana_transcript  \
# 0                                .  Ensembl_canonical   OTTMUST00000127487.1
# 1                                .  Ensembl_canonical   OTTMUST00000127486.1
# 2                              1.0  Ensembl_canonical   OTTMUST00000127738.1
# 3                                .  Ensembl_canonical   OTTMUST00000123156.1
# 4                                .  Ensembl_canonical   OTTMUST00000123157.1
# ...                            ...                ...                    ...
# 1496                           5.0                  .   OTTMUST00000125944.1
# 1497                           1.0               CCDS   OTTMUST00000057072.2
# 1498                           1.0              basic   OTTMUST00000057073.1
# 1499                           5.0               CCDS   OTTMUST00000126077.2
# 1500                           1.0              basic   OTTMUST00000126078.1
#
#       exon_exon_number          exon_exon_id       exon_protein_id  \
# 0                  2.0  ENSMUSE00001338734.2                     .
# 1                  1.0  ENSMUSE00001341804.2                     .
# 2                  3.0  ENSMUSE00001339812.2                     .
# 3                  1.0  ENSMUSE00001341523.2                     .
# 4                  1.0  ENSMUSE00001346299.2                     .
# ...                ...                   ...                   ...
# 1496               3.0  ENSMUSE00001328598.2                     .
# 1497              16.0  ENSMUSE00000692322.4  ENSMUSP00000049663.9
# 1498              13.0  ENSMUSE00000692322.4  ENSMUSP00000076432.7
# 1499               3.0  ENSMUSE00000260244.6  ENSMUSP00000023959.8
# 1500               3.0  ENSMUSE00000260244.6  ENSMUSP00000144631.2
#
#       exon_ccdsid     exon_ont                             exon_unique_id
# 0               .  PGO:0000004       ENSMUSG00000104352.2_5346329_5346985
# 1               .            .       ENSMUSG00000104046.2_5377962_5380240
# 2               .            .       ENSMUSG00000103067.2_7586398_7588373
# 3               .            .     ENSMUSG00000103810.2_10519470_10522214
# 4               .            .     ENSMUSG00000103448.2_10852681_10854602
# ...           ...          ...                                        ...
# 1496            .            .  ENSMUSG00000032560.15_104059704_104059888
# 1497  CCDS23461.1            .  ENSMUSG00000032564.17_104909944_104911743
# 1498            .            .  ENSMUSG00000032564.17_104909944_104911743
# 1499  CCDS52914.1            .  ENSMUSG00000023192.13_106527595_106528432
# 1500            .            .  ENSMUSG00000023192.13_106527595_106528432
#
# [1501 rows x 37 columns]
# (1501, 37)
# Unique CPDs : (728, 37)
# Unique SNVs : (728, 37)
# Unique exons : (1337, 37)
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 37 fields; you can supply custom names with the `names` kwarg
#   warn(
#     chr_name  CPD_start    CPD_end chr_name_SNV  SNV_start    SNV_end   ID  \
# 0       chr1    6509974    6509977         chr1    6509976    6509977  334
# 1       chr1   11678490   11678493         chr1   11678490   11678491  334
# 2       chr1   12743279   12743282         chr1   12743281   12743282  334
# 3       chr1   14182895   14182898         chr1   14182895   14182896  334
# 4       chr1   18066522   18066525         chr1   18066522   18066523  346
# ..       ...        ...        ...          ...        ...        ...  ...
# 911     chr9  107860536  107860539         chr9  107860538  107860539  334
# 912     chr9  107860536  107860539         chr9  107860538  107860539  334
# 913     chr9  107968597  107968600         chr9  107968599  107968600  334
# 914     chr9  107994490  107994493         chr9  107994492  107994493  334
# 915     chr9  108186456  108186459         chr9  108186456  108186457  346
#
#         SNV_Info  CPD_original_start  CPD_original_end  distance exon_seqname  \
# 0    N:GT[C>T]TC             6509975           6509976        -1         chr1
# 1    T:CT[C>T]CA            11678491          11678492         1         chr1
# 2    N:TT[C>T]TT            12743280          12743281        -1         chr1
# 3    N:TT[C>T]AA            14182896          14182897         1         chr1
# 4    N:TC[C>T]TC            18066523          18066524         1         chr1
# ..           ...                 ...               ...       ...          ...
# 911  T:TG[C>T]TT           107860537         107860538        -1         chr9
# 912  T:TG[C>T]TT           107860537         107860538        -1         chr9
# 913  U:CC[C>T]CC           107968598         107968599        -1         chr9
# 914  U:CC[C>T]TC           107994491         107994492        -1         chr9
# 915  U:AC[C>T]AG           108186457         108186458         1         chr9
#
#      exon_start   exon_end exon_source exon_feature exon_score exon_strand  \
# 0       6507711    6511520      HAVANA         exon          .           -
# 1      11678363   11678624      HAVANA         exon          .           -
# 2      12741685   12743314      HAVANA         exon          .           +
# 3      14179439   14183043      HAVANA         exon          .           -
# 4      18065794   18067707      HAVANA         exon          .           +
# ..          ...        ...         ...          ...        ...         ...
# 911   107860462  107860562      HAVANA         exon          .           +
# 912   107860486  107860562      HAVANA         exon          .           +
# 913   107968442  107969088      HAVANA         exon          .           -
# 914   107994249  107994758      HAVANA         exon          .           -
# 915   108183638  108188738      HAVANA         exon          .           +
#
#     exon_frame           exon_gene_id        exon_gene_type exon_gene_name  \
# 0            .   ENSMUSG00000103845.2  processed_pseudogene        Gm19026
# 1            .   ENSMUSG00000099845.2  processed_pseudogene        Gm29273
# 2            .   ENSMUSG00000097171.2                lncRNA        Gm17644
# 3            .   ENSMUSG00000104209.2                   TEC        Gm37400
# 4            .   ENSMUSG00000099591.2  processed_pseudogene        Gm17969
# ..         ...                    ...                   ...            ...
# 911          .  ENSMUSG00000079323.10        protein_coding        Gm20661
# 912          .  ENSMUSG00000079323.10        protein_coding        Gm20661
# 913          .  ENSMUSG00000032590.15        protein_coding           Apeh
# 914          .  ENSMUSG00000032589.15        protein_coding            Bsn
# 915          .  ENSMUSG00000007815.14        protein_coding           Rhoa
#
#      exon_level  exon_mgi_id      exon_havana_gene     exon_transcript_id  \
# 0           2.0  MGI:5011211  OTTMUSG00000050243.1   ENSMUST00000194240.2
# 1           2.0  MGI:5579979  OTTMUSG00000047936.1   ENSMUST00000188880.2
# 2           2.0  MGI:4937278  OTTMUSG00000047994.1   ENSMUST00000181272.2
# 3           2.0  MGI:5610628  OTTMUSG00000049161.1   ENSMUST00000193148.2
# 4           2.0  MGI:5010154  OTTMUSG00000048211.1   ENSMUST00000185706.2
# ..          ...          ...                   ...                    ...
# 911         2.0  MGI:5313108  OTTMUSG00000042094.1   ENSMUST00000176166.8
# 912         2.0  MGI:5313108  OTTMUSG00000042094.1   ENSMUST00000177368.2
# 913         2.0    MGI:88041  OTTMUSG00000050818.4   ENSMUST00000194083.6
# 914         2.0  MGI:1277955  OTTMUSG00000016899.2  ENSMUST00000035208.14
# 915         2.0  MGI:1096342  OTTMUSG00000050752.2   ENSMUST00000193619.2
#
#         exon_transcript_type exon_transcript_name  \
# 0       processed_pseudogene          Gm19026-201
# 1       processed_pseudogene          Gm29273-201
# 2                     lncRNA          Gm17644-201
# 3                        TEC          Gm37400-201
# 4       processed_pseudogene          Gm17969-201
# ..                       ...                  ...
# 911          retained_intron          Gm20661-201
# 912  nonsense_mediated_decay          Gm20661-203
# 913          retained_intron             Apeh-208
# 914           protein_coding              Bsn-201
# 915          retained_intron             Rhoa-204
#
#     exon_transcript_support_level                exon_tag  \
# 0                               .       Ensembl_canonical
# 1                               .       Ensembl_canonical
# 2                             1.0       Ensembl_canonical
# 3                               .       Ensembl_canonical
# 4                               .       Ensembl_canonical
# ..                            ...                     ...
# 911                           2.0  readthrough_transcript
# 912                           2.0  readthrough_transcript
# 913                           2.0                       .
# 914                           5.0                    CCDS
# 915                             .                       .
#
#     exon_havana_transcript  exon_exon_number          exon_exon_id  \
# 0     OTTMUST00000127629.1               1.0  ENSMUSE00001345117.2
# 1     OTTMUST00000123267.1               1.0  ENSMUSE00001320137.2
# 2     OTTMUST00000123375.1               3.0  ENSMUSE00001129524.2
# 3     OTTMUST00000125453.1               1.0  ENSMUSE00001337866.2
# 4     OTTMUST00000123776.1               2.0  ENSMUSE00001325976.2
# ..                     ...               ...                   ...
# 911   OTTMUST00000110399.1               2.0  ENSMUSE00001307229.2
# 912   OTTMUST00000110400.1               1.0  ENSMUSE00001307702.2
# 913   OTTMUST00000128773.1               8.0  ENSMUSE00001343386.2
# 914   OTTMUST00000041006.2               4.0  ENSMUSE00000221212.4
# 915   OTTMUST00000128627.1               1.0  ENSMUSE00001339798.2
#
#           exon_protein_id  exon_ccdsid     exon_ont  \
# 0                       .            .  PGO:0000004
# 1                       .            .  PGO:0000004
# 2                       .            .            .
# 3                       .            .            .
# 4                       .            .  PGO:0000004
# ..                    ...          ...          ...
# 911                     .            .            .
# 912  ENSMUSP00000135553.2            .            .
# 913                     .            .            .
# 914  ENSMUSP00000035208.7  CCDS23517.1            .
# 915                     .            .            .
#
#                                 exon_unique_id
# 0         ENSMUSG00000103845.2_6507711_6511520
# 1       ENSMUSG00000099845.2_11678363_11678624
# 2       ENSMUSG00000097171.2_12741685_12743314
# 3       ENSMUSG00000104209.2_14179439_14183043
# 4       ENSMUSG00000099591.2_18065794_18067707
# ..                                         ...
# 911  ENSMUSG00000079323.10_107860462_107860562
# 912  ENSMUSG00000079323.10_107860486_107860562
# 913  ENSMUSG00000032590.15_107968442_107969088
# 914  ENSMUSG00000032589.15_107994249_107994758
# 915  ENSMUSG00000007815.14_108183638_108188738
#
# [916 rows x 37 columns]
# (916, 37)
# Unique CPDs : (437, 37)
# Unique SNVs : (428, 37)
# Unique exons : (888, 37)
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 37 fields; you can supply custom names with the `names` kwarg
#   warn(
#     chr_name  CPD_start    CPD_end chr_name_SNV  SNV_start    SNV_end   ID  \
# 0       chr1   14861824   14861829         chr1   14861828   14861829  334
# 1       chr1   36360538   36360543         chr1   36360542   36360543  334
# 2       chr1   36360538   36360543         chr1   36360542   36360543  334
# 3       chr1   36360538   36360543         chr1   36360542   36360543  334
# 4       chr1   39121057   39121062         chr1   39121061   39121062  334
# ..       ...        ...        ...          ...        ...        ...  ...
# 596     chr9  103205613  103205618         chr9  103205613  103205614  334
# 597     chr9  103205613  103205618         chr9  103205613  103205614  334
# 598     chr9  104446799  104446804         chr9  104446803  104446804  335
# 599     chr9  106402592  106402597         chr9  106402596  106402597  334
# 600     chr9  108274648  108274653         chr9  108274648  108274649  335
#
#         SNV_Info  CPD_original_start  CPD_original_end  distance exon_seqname  \
# 0    N:AC[C>A]TT            14861826          14861827        -2         chr1
# 1    U:GC[C>T]CC            36360540          36360541        -2         chr1
# 2    U:GC[C>T]CC            36360540          36360541        -2         chr1
# 3    U:GC[C>T]CC            36360540          36360541        -2         chr1
# 4    N:CC[T>C]TC            39121059          39121060        -2         chr1
# ..           ...                 ...               ...       ...          ...
# 596  U:TT[T>A]TA           103205615         103205616         2         chr9
# 597  U:TT[T>A]TA           103205615         103205616         2         chr9
# 598  T:CC[T>C]CT           104446801         104446802        -2         chr9
# 599  T:AT[C>T]CT           106402594         106402595        -2         chr9
# 600  T:TA[T>A]TT           108274650         108274651         2         chr9
#
#      exon_start   exon_end exon_source exon_feature exon_score exon_strand  \
# 0      14858869   14863189      HAVANA         exon          .           +
# 1      36358073   36362072      HAVANA         exon          .           +
# 2      36358073   36363110      HAVANA         exon          .           +
# 3      36358073   36362069      HAVANA         exon          .           +
# 4      39120333   39122419      HAVANA         exon          .           -
# ..          ...        ...         ...          ...        ...         ...
# 596   103205009  103205892      HAVANA         exon          .           +
# 597   103205035  103206840      HAVANA         exon          .           +
# 598   104446682  104447300      HAVANA         exon          .           +
# 599   106402291  106402737      HAVANA         exon          .           -
# 600   108274392  108274969      HAVANA         exon          .           +
#
#     exon_frame           exon_gene_id  exon_gene_type exon_gene_name  \
# 0            .   ENSMUSG00000103492.2             TEC        Gm37412
# 1            .  ENSMUSG00000037447.17  protein_coding         Arid5a
# 2            .  ENSMUSG00000037447.17  protein_coding         Arid5a
# 3            .  ENSMUSG00000037447.17  protein_coding         Arid5a
# 4            .   ENSMUSG00000103182.2             TEC        Gm37091
# ..         ...                    ...             ...            ...
# 596          .  ENSMUSG00000032555.11  protein_coding         Topbp1
# 597          .  ENSMUSG00000032555.11  protein_coding         Topbp1
# 598          .  ENSMUSG00000032564.17  protein_coding          Cpne4
# 599          .   ENSMUSG00000118396.3  protein_coding  4930517N10Rik
# 600          .  ENSMUSG00000032611.10  protein_coding  1700102P08Rik
#
#      exon_level  exon_mgi_id      exon_havana_gene     exon_transcript_id  \
# 0           2.0  MGI:5610640  OTTMUSG00000049206.1   ENSMUST00000194866.2
# 1           2.0  MGI:2443039  OTTMUSG00000021515.5   ENSMUST00000115032.8
# 2           2.0  MGI:2443039  OTTMUSG00000021515.5   ENSMUST00000137906.2
# 3           1.0  MGI:2443039  OTTMUSG00000021515.5   ENSMUST00000115029.2
# 4           2.0  MGI:5610319  OTTMUSG00000050564.1   ENSMUST00000195455.2
# ..          ...          ...                   ...                    ...
# 596         2.0  MGI:1920018  OTTMUSG00000048444.7   ENSMUST00000186897.2
# 597         2.0  MGI:1920018  OTTMUSG00000048444.7   ENSMUST00000188840.2
# 598         2.0  MGI:1921270  OTTMUSG00000023466.6  ENSMUST00000057742.15
# 599         2.0  MGI:1922299  OTTMUSG00000049442.6   ENSMUST00000215525.2
# 600         2.0  MGI:2148248  OTTMUSG00000050821.3   ENSMUST00000035234.6
#
#     exon_transcript_type exon_transcript_name exon_transcript_support_level  \
# 0                    TEC          Gm37412-201                             .
# 1         protein_coding           Arid5a-204                           1.0
# 2         protein_coding           Arid5a-208                           1.0
# 3         protein_coding           Arid5a-202                           3.0
# 4                    TEC          Gm37091-201                             .
# ..                   ...                  ...                           ...
# 596      retained_intron           Topbp1-205                           1.0
# 597      retained_intron           Topbp1-207                             .
# 598       protein_coding            Cpne4-201                           1.0
# 599       protein_coding    4930517N10Rik-203                           2.0
# 600       protein_coding    1700102P08Rik-201                           1.0
#
#                exon_tag exon_havana_transcript  exon_exon_number  \
# 0     Ensembl_canonical   OTTMUST00000125544.1               1.0
# 1                  CCDS   OTTMUST00000051015.2               7.0
# 2                  CCDS   OTTMUST00000051014.1               5.0
# 3                  CCDS   OTTMUST00000051024.2               4.0
# 4     Ensembl_canonical   OTTMUST00000128220.1               1.0
# ..                  ...                    ...               ...
# 596  NAGNAG_splice_site   OTTMUST00000124256.1               1.0
# 597                   .   OTTMUST00000124257.1               1.0
# 598                CCDS   OTTMUST00000057072.2               1.0
# 599               basic   OTTMUST00000181658.1               4.0
# 600                CCDS   OTTMUST00000128781.3               4.0
#
#              exon_exon_id       exon_protein_id  exon_ccdsid exon_ont  \
# 0    ENSMUSE00001343997.2                     .            .        .
# 1    ENSMUSE00001339799.2  ENSMUSP00000110684.2  CCDS48239.1        .
# 2    ENSMUSE00000805304.2  ENSMUSP00000117810.2  CCDS14876.1        .
# 3    ENSMUSE00000630260.3  ENSMUSP00000110681.2  CCDS69878.1        .
# 4    ENSMUSE00001342135.2                     .            .        .
# ..                    ...                   ...          ...      ...
# 596  ENSMUSE00001333525.2                     .            .        .
# 597  ENSMUSE00001329778.2                     .            .        .
# 598  ENSMUSE00000794016.3  ENSMUSP00000049663.9  CCDS23461.1        .
# 599  ENSMUSE00001402417.2  ENSMUSP00000158670.2            .        .
# 600  ENSMUSE00000221540.6  ENSMUSP00000035234.5  CCDS23524.1        .
#
#                                 exon_unique_id
# 0       ENSMUSG00000103492.2_14858869_14863189
# 1      ENSMUSG00000037447.17_36358073_36362072
# 2      ENSMUSG00000037447.17_36358073_36363110
# 3      ENSMUSG00000037447.17_36358073_36362069
# 4       ENSMUSG00000103182.2_39120333_39122419
# ..                                         ...
# 596  ENSMUSG00000032555.11_103205009_103205892
# 597  ENSMUSG00000032555.11_103205035_103206840
# 598  ENSMUSG00000032564.17_104446682_104447300
# 599   ENSMUSG00000118396.3_106402291_106402737
# 600  ENSMUSG00000032611.10_108274392_108274969
#
# [601 rows x 37 columns]
# (601, 37)
# Unique CPDs : (324, 37)
# Unique SNVs : (318, 37)
# Unique exons : (587, 37)
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 37 fields; you can supply custom names with the `names` kwarg
#   warn(
#     chr_name  CPD_start    CPD_end chr_name_SNV  SNV_start    SNV_end   ID  \
# 0       chr1   36350119   36350126         chr1   36350125   36350126  334
# 1       chr1   37044601   37044608         chr1   37044607   37044608  334
# 2       chr1   39660470   39660477         chr1   39660470   39660471  335
# 3       chr1   51977805   51977812         chr1   51977811   51977812  334
# 4       chr1   52826985   52826992         chr1   52826985   52826986  334
# ..       ...        ...        ...          ...        ...        ...  ...
# 534     chr9  104079107  104079114         chr9  104079107  104079108  334
# 535     chr9  104079107  104079114         chr9  104079107  104079108  334
# 536     chr9  104079107  104079114         chr9  104079107  104079108  334
# 537     chr9  104079107  104079114         chr9  104079107  104079108  334
# 538     chr9  107736480  107736487         chr9  107736480  107736481  341
#
#         SNV_Info  CPD_original_start  CPD_original_end  distance exon_seqname  \
# 0    U:TT[C>T]AG            36350122          36350123        -3         chr1
# 1    N:GT[C>T]TC            37044604          37044605        -3         chr1
# 2    T:TC[T>A]TC            39660473          39660474         3         chr1
# 3    N:TC[C>T]GG            51977808          51977809        -3         chr1
# 4    U:CC[C>T]TC            52826988          52826989         3         chr1
# ..           ...                 ...               ...       ...          ...
# 534  U:CT[C>T]AA           104079110         104079111         3         chr9
# 535  U:CT[C>T]AA           104079110         104079111         3         chr9
# 536  U:CT[C>T]AA           104079110         104079111         3         chr9
# 537  U:CT[C>T]AA           104079110         104079111         3         chr9
# 538  U:GT[C>T]TT           107736483         107736484         3         chr9
#
#      exon_start   exon_end exon_source exon_feature exon_score exon_strand  \
# 0      36346839   36351852      HAVANA         exon          .           +
# 1      37044520   37044638     ENSEMBL         exon          .           +
# 2      39657574   39662411      HAVANA         exon          .           -
# 3      51977413   51977824      HAVANA         exon          .           -
# 4      52824586   52829376      HAVANA         exon          .           -
# ..          ...        ...         ...          ...        ...         ...
# 534   104079087  104079149      HAVANA         exon          .           -
# 535   104079087  104079149      HAVANA         exon          .           -
# 536   104079087  104079150      HAVANA         exon          .           -
# 537   104079087  104079149      HAVANA         exon          .           -
# 538   107735451  107737658      HAVANA         exon          .           -
#
#     exon_frame           exon_gene_id        exon_gene_type exon_gene_name  \
# 0            .  ENSMUSG00000037447.17        protein_coding         Arid5a
# 1            .   ENSMUSG00000119706.1                  rRNA       n-R5s210
# 2            .   ENSMUSG00000050967.6        protein_coding          Creg2
# 3            .   ENSMUSG00000100696.2  processed_pseudogene         Gm8419
# 4            .  ENSMUSG00000026102.10        protein_coding          Inpp1
# ..         ...                    ...                   ...            ...
# 534          .  ENSMUSG00000032560.15        protein_coding        Dnajc13
# 535          .  ENSMUSG00000032560.15        protein_coding        Dnajc13
# 536          .  ENSMUSG00000032560.15        protein_coding        Dnajc13
# 537          .  ENSMUSG00000032560.15        protein_coding        Dnajc13
# 538          .  ENSMUSG00000032582.15        protein_coding           Rbm6
#
#      exon_level  exon_mgi_id       exon_havana_gene     exon_transcript_id  \
# 0           2.0  MGI:2443039   OTTMUSG00000021515.5   ENSMUST00000192874.2
# 1           3.0  MGI:4422075                      .   ENSMUST00000177688.3
# 2           2.0  MGI:1928333   OTTMUSG00000049490.1   ENSMUST00000053355.6
# 3           2.0  MGI:3645596   OTTMUSG00000046701.1   ENSMUST00000189886.2
# 4           2.0   MGI:104848   OTTMUSG00000026596.5   ENSMUST00000027271.9
# ..          ...          ...                    ...                    ...
# 534         2.0  MGI:2676368   OTTMUSG00000049291.7  ENSMUST00000035170.13
# 535         2.0  MGI:2676368   OTTMUSG00000049291.7   ENSMUST00000186788.7
# 536         2.0  MGI:2676368   OTTMUSG00000049291.7   ENSMUST00000185503.7
# 537         2.0  MGI:2676368   OTTMUSG00000049291.7   ENSMUST00000188592.2
# 538         2.0  MGI:1338037  OTTMUSG00000043552.16   ENSMUST00000182242.2
#
#         exon_transcript_type exon_transcript_name  \
# 0            retained_intron           Arid5a-215
# 1                       rRNA         n-R5s210-201
# 2             protein_coding            Creg2-201
# 3       processed_pseudogene           Gm8419-201
# 4             protein_coding            Inpp1-201
# ..                       ...                  ...
# 534           protein_coding          Dnajc13-201
# 535           protein_coding          Dnajc13-203
# 536  nonsense_mediated_decay          Dnajc13-202
# 537          retained_intron          Dnajc13-206
# 538          retained_intron             Rbm6-204
#
#     exon_transcript_support_level              exon_tag  \
# 0                               .                     .
# 1                               .     Ensembl_canonical
# 2                             1.0                  CCDS
# 3                               .     Ensembl_canonical
# 4                             1.0                  CCDS
# ..                            ...                   ...
# 534                           5.0                  CCDS
# 535                           1.0  appris_alternative_1
# 536                           5.0          cds_start_NF
# 537                           5.0                     .
# 538                           1.0                     .
#
#     exon_havana_transcript  exon_exon_number          exon_exon_id  \
# 0     OTTMUST00000127040.1               1.0  ENSMUSE00001339647.2
# 1                        .               1.0  ENSMUSE00001080802.2
# 2     OTTMUST00000126186.1               4.0  ENSMUSE00000443601.3
# 3     OTTMUST00000121308.1               1.0  ENSMUSE00001321568.2
# 4     OTTMUST00000065807.2               6.0  ENSMUSE00000155737.4
# ..                     ...               ...                   ...
# 534   OTTMUST00000125683.3              25.0  ENSMUSE00000692356.2
# 535   OTTMUST00000125941.2              25.0  ENSMUSE00000692356.2
# 536   OTTMUST00000125945.1               1.0  ENSMUSE00001324000.2
# 537   OTTMUST00000125946.1               2.0  ENSMUSE00001318470.2
# 538   OTTMUST00000114309.1               2.0  ENSMUSE00001255264.2
#
#           exon_protein_id  exon_ccdsid     exon_ont  \
# 0                       .            .            .
# 1                       .            .            .
# 2    ENSMUSP00000052871.5  CCDS14908.1            .
# 3                       .            .  PGO:0000004
# 4    ENSMUSP00000027271.3  CCDS14947.1            .
# ..                    ...          ...          ...
# 534  ENSMUSP00000035170.7  CCDS52904.1            .
# 535  ENSMUSP00000139804.2            .            .
# 536  ENSMUSP00000140571.2            .            .
# 537                     .            .            .
# 538                     .            .            .
#
#                                 exon_unique_id
# 0      ENSMUSG00000037447.17_36346839_36351852
# 1       ENSMUSG00000119706.1_37044520_37044638
# 2       ENSMUSG00000050967.6_39657574_39662411
# 3       ENSMUSG00000100696.2_51977413_51977824
# 4      ENSMUSG00000026102.10_52824586_52829376
# ..                                         ...
# 534  ENSMUSG00000032560.15_104079087_104079149
# 535  ENSMUSG00000032560.15_104079087_104079149
# 536  ENSMUSG00000032560.15_104079087_104079150
# 537  ENSMUSG00000032560.15_104079087_104079149
# 538  ENSMUSG00000032582.15_107735451_107737658
#
# [539 rows x 37 columns]
# (539, 37)
# Unique CPDs : (293, 37)
# Unique SNVs : (291, 37)
# Unique exons : (521, 37)
# /shared/software/anaconda/anaconda3/lib/python3.10/site-packages/pybedtools/bedtool.py:3703: UserWarning: Default names for filetype bed are:
# ['chrom', 'start', 'end', 'name', 'score', 'strand', 'thickStart', 'thickEnd', 'itemRgb', 'blockCount', 'blockSizes', 'blockStarts']
# but file has 37 fields; you can supply custom names with the `names` kwarg
#   warn(
#     chr_name  CPD_start    CPD_end chr_name_SNV  SNV_start    SNV_end   ID  \
# 0       chr1   16299227   16299236         chr1   16299235   16299236  341
# 1       chr1   16299227   16299236         chr1   16299235   16299236  341
# 2       chr1   16299227   16299236         chr1   16299235   16299236  341
# 3       chr1   16299227   16299236         chr1   16299235   16299236  341
# 4       chr1   16299227   16299236         chr1   16299235   16299236  341
# ..       ...        ...        ...          ...        ...        ...  ...
# 548     chr9   99547822   99547831         chr9   99547830   99547831  334
# 549     chr9   99574234   99574243         chr9   99574242   99574243  335
# 550     chr9   99574234   99574243         chr9   99574242   99574243  335
# 551     chr9   99574234   99574243         chr9   99574242   99574243  335
# 552     chr9  107736479  107736488         chr9  107736479  107736480  341
#
#         SNV_Info  CPD_original_start  CPD_original_end  distance exon_seqname  \
# 0    U:CC[C>T]CA            16299231          16299232        -4         chr1
# 1    U:CC[C>T]CA            16299231          16299232        -4         chr1
# 2    U:CC[C>T]CA            16299231          16299232        -4         chr1
# 3    U:CC[C>T]CA            16299231          16299232        -4         chr1
# 4    U:CC[C>T]CA            16299231          16299232        -4         chr1
# ..           ...                 ...               ...       ...          ...
# 548  U:GC[C>T]TT            99547826          99547827        -4         chr9
# 549  U:TG[T>G]TT            99574238          99574239        -4         chr9
# 550  U:TG[T>G]TT            99574238          99574239        -4         chr9
# 551  U:TG[T>G]TT            99574238          99574239        -4         chr9
# 552  U:TC[T>C]TC           107736483         107736484         4         chr9
#
#      exon_start   exon_end exon_source exon_feature exon_score exon_strand  \
# 0      16298898   16300090      HAVANA         exon          .           -
# 1      16299025   16300090      HAVANA         exon          .           -
# 2      16299028   16300090      HAVANA         exon          .           -
# 3      16299034   16300090      HAVANA         exon          .           -
# 4      16299040   16300090      HAVANA         exon          .           -
# ..          ...        ...         ...          ...        ...         ...
# 548    99547768   99547907      HAVANA         exon          .           +
# 549    99571514   99574947      HAVANA         exon          .           -
# 550    99573873   99574947      HAVANA         exon          .           -
# 551    99574235   99574947      HAVANA         exon          .           -
# 552   107735451  107737658      HAVANA         exon          .           -
#
#     exon_frame           exon_gene_id  exon_gene_type exon_gene_name  \
# 0            .  ENSMUSG00000025920.20  protein_coding          Stau2
# 1            .  ENSMUSG00000025920.20  protein_coding          Stau2
# 2            .  ENSMUSG00000025920.20  protein_coding          Stau2
# 3            .  ENSMUSG00000025920.20  protein_coding          Stau2
# 4            .  ENSMUSG00000025920.20  protein_coding          Stau2
# ..         ...                    ...             ...            ...
# 548          .  ENSMUSG00000037784.15  protein_coding         Dzip1l
# 549          .  ENSMUSG00000032473.14  protein_coding         Cldn18
# 550          .  ENSMUSG00000032473.14  protein_coding         Cldn18
# 551          .  ENSMUSG00000032473.14  protein_coding         Cldn18
# 552          .  ENSMUSG00000032582.15  protein_coding           Rbm6
#
#      exon_level  exon_mgi_id       exon_havana_gene     exon_transcript_id  \
# 0           2.0  MGI:1352508   OTTMUSG00000033135.7   ENSMUST00000162751.8
# 1           2.0  MGI:1352508   OTTMUSG00000033135.7  ENSMUST00000054668.13
# 2           2.0  MGI:1352508   OTTMUSG00000033135.7   ENSMUST00000162627.8
# 3           2.0  MGI:1352508   OTTMUSG00000033135.7  ENSMUST00000027052.13
# 4           2.0  MGI:1352508   OTTMUSG00000033135.7   ENSMUST00000162435.8
# ..          ...          ...                    ...                    ...
# 548         2.0  MGI:1919757   OTTMUSG00000023471.4   ENSMUST00000112884.2
# 549         2.0  MGI:1929209   OTTMUSG00000028913.1  ENSMUST00000035048.12
# 550         2.0  MGI:1929209   OTTMUSG00000028913.1   ENSMUST00000112882.9
# 551         2.0  MGI:1929209   OTTMUSG00000028913.1   ENSMUST00000136429.8
# 552         2.0  MGI:1338037  OTTMUSG00000043552.16   ENSMUST00000182242.2
#
#     exon_transcript_type exon_transcript_name exon_transcript_support_level  \
# 0         protein_coding            Stau2-217                           1.0
# 1         protein_coding            Stau2-202                           5.0
# 2         protein_coding            Stau2-216                           5.0
# 3         protein_coding            Stau2-201                           1.0
# 4         protein_coding            Stau2-215                           5.0
# ..                   ...                  ...                           ...
# 548       protein_coding           Dzip1l-202                           5.0
# 549       protein_coding           Cldn18-201                           1.0
# 550       protein_coding           Cldn18-202                           1.0
# 551       protein_coding           Cldn18-204                           1.0
# 552      retained_intron             Rbm6-204                           1.0
#
#     exon_tag exon_havana_transcript  exon_exon_number          exon_exon_id  \
# 0       CCDS   OTTMUST00000082849.3              14.0  ENSMUSE00000854885.2
# 1       CCDS   OTTMUST00000086841.1              15.0  ENSMUSE00000852066.2
# 2       CCDS   OTTMUST00000086840.1              14.0  ENSMUSE00000864153.2
# 3       CCDS   OTTMUST00000082851.2              13.0  ENSMUSE00000469087.3
# 4       CCDS   OTTMUST00000082860.4              13.0  ENSMUSE00000851185.2
# ..       ...                    ...               ...                   ...
# 548     CCDS   OTTMUST00000057096.1              15.0  ENSMUSE00000383935.4
# 549     CCDS   OTTMUST00000071649.1               5.0  ENSMUSE00000324921.6
# 550     CCDS   OTTMUST00000071651.1               5.0  ENSMUSE00000776046.2
# 551     CCDS   OTTMUST00000071650.1               5.0  ENSMUSE00000817980.2
# 552        .   OTTMUST00000114309.1               2.0  ENSMUSE00001255264.2
#
#           exon_protein_id  exon_ccdsid exon_ont  \
# 0    ENSMUSP00000124505.2  CCDS14831.2        .
# 1    ENSMUSP00000053190.7  CCDS14831.2        .
# 2    ENSMUSP00000123781.2  CCDS48223.1        .
# 3    ENSMUSP00000027052.7  CCDS48223.1        .
# 4    ENSMUSP00000123827.2  CCDS48223.1        .
# ..                    ...          ...      ...
# 548  ENSMUSP00000108505.2  CCDS81060.1        .
# 549  ENSMUSP00000035048.6  CCDS23437.1        .
# 550  ENSMUSP00000108503.3  CCDS57694.1        .
# 551  ENSMUSP00000115782.2  CCDS57692.1        .
# 552                     .            .        .
#
#                                 exon_unique_id
# 0      ENSMUSG00000025920.20_16298898_16300090
# 1      ENSMUSG00000025920.20_16299025_16300090
# 2      ENSMUSG00000025920.20_16299028_16300090
# 3      ENSMUSG00000025920.20_16299034_16300090
# 4      ENSMUSG00000025920.20_16299040_16300090
# ..                                         ...
# 548    ENSMUSG00000037784.15_99547768_99547907
# 549    ENSMUSG00000032473.14_99571514_99574947
# 550    ENSMUSG00000032473.14_99573873_99574947
# 551    ENSMUSG00000032473.14_99574235_99574947
# 552  ENSMUSG00000032582.15_107735451_107737658
#
# [553 rows x 37 columns]
# (553, 37)
# Unique CPDs : (286, 37)
# Unique SNVs : (285, 37)
# Unique exons : (543, 37)

# %%
df_statistics_intersect
# Out:
#   Distance of SNVs from CPDs unique_CPDs unique_SNVs unique_EXON  \
# 0                          0         728         728        1337
# 1                          0         437         428         888
# 2                          0         324         318         587
# 3                          0         293         291         521
# 4                          0         286         285         543
#
#   unique_Intersected_data
# 0                    1501
# 1                     916
# 2                     601
# 3                     539
# 4                     553
