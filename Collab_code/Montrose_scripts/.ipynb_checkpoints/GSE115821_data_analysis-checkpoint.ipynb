# %%
import os
import numpy as np
import pandas as pd
import sklearn
from io import StringIO
from IPython.display import display
import scipy.stats as stats

# %%
data_path = "/data/private/pdutta/Collab_data/David_data/GSE91061_fpkm.csv"

# %%
df  = pd.read_csv(data_path)
# df = df.set_index('Gene')
# df.index.name = None

# %%
df
# Out:
#        Unnamed: 0  Pt1_Pre_AD101148-6  Pt1_On_AD174047-6  Pt10_Pre_E9047565-6  \
# 0               1            2.943714           3.595545             1.189983
# 1              10            0.000000           0.019562             0.000000
# 2             100           10.027219           4.170643            10.017708
# 3            1000            0.407255           0.040319             1.183365
# 4           10000           25.274036          36.018795            46.562887
# ...           ...                 ...                ...                  ...
# 22182        9991           16.965789          18.667341            21.137840
# 22183        9992            0.812618           0.545436             0.312037
# 22184        9993           17.815880          17.014036            22.524965
# 22185        9994            6.400214           8.110476             4.181956
# 22186        9997            0.156146           0.036990             0.000000
#
#        Pt10_On_E9047632-6  Pt101_Pre_AD486328-5  Pt101_On_AD681975-5  \
# 0                1.460591              1.785026             1.375918
# 1                0.039176              0.000000             0.100569
# 2               12.241966             27.412639            29.409310
# 3                3.737245              1.313282             2.645249
# 4               53.313169              8.721540             9.484339
# ...                   ...                   ...                  ...
# 22182           25.747246             30.886756            33.412759
# 22183            0.224884              0.288768             0.164944
# 22184           15.910671             17.062000            17.218676
# 22185            5.084711              9.135489             9.103528
# 22186            0.000000              0.221948             0.047541
#
#        Pt103_Pre_AE134058-2  Pt103_On_AE134059-6  Pt105_On_AE373241-6  ...  \
# 0                  7.734803             4.895584             1.084850  ...
# 1                  0.000000             0.000000             0.000000  ...
# 2                 19.336752             2.647676            11.945614  ...
# 3                  0.142493             0.020004             0.427601  ...
# 4                  5.047087            22.930653            16.334390  ...
# ...                     ...                  ...                  ...  ...
# 22182              6.239696            14.267890            13.314332  ...
# 22183              0.000000             0.297139             2.381893  ...
# 22184              9.683801            44.249193            16.548169  ...
# 22185              0.991609             3.695637             3.830822  ...
# 22186              0.576915             0.085643             0.109220  ...
#
#        Pt9_Pre_E9021024-6  Pt9_On_E9047644-7  Pt90_Pre_AD467873-6  \
# 0                1.062742           1.439649             2.606166
# 1                0.187474           0.205179             0.000000
# 2                6.106330           6.381909            13.046369
# 3               30.383779          37.943956             1.793913
# 4               29.089234          28.169557            13.643286
# ...                   ...                ...                  ...
# 22182           14.030045          12.760118            13.756137
# 22183            0.990757           0.581252             0.152328
# 22184           16.054513          17.802720            10.964174
# 22185            5.090835           4.823752             3.183242
# 22186            0.000000           0.070540             0.052686
#
#        Pt92_Pre_AE134060-5  Pt92_On_AE148750-5  Pt93_On_AE070988-5  \
# 0                 0.576973            1.387461            1.335126
# 1                 0.000000            0.000000            0.000000
# 2                13.869151           21.216114            1.682833
# 3                 3.697619            3.170839            0.256164
# 4                21.834762           18.416663           25.733070
# ...                    ...                 ...                 ...
# 22182            17.142448           17.345828           25.492576
# 22183             1.027950            0.334521            0.658582
# 22184            28.392757           17.645762           15.991433
# 22185             5.519505            5.910208            3.984750
# 22186             0.307256            0.347105            0.031637
#
#        Pt94_Pre_AD732850-6  Pt94_On_AE373242-6  Pt98_Pre_AD733586-8  \
# 0                 1.959790           43.853104             1.890756
# 1                 0.021556           11.777745             0.000000
# 2                 9.543218            4.421732             3.790089
# 3                 0.971044           10.310559             1.163395
# 4                19.154000           10.078965            21.396885
# ...                    ...                 ...                  ...
# 22182            12.780802            8.109449            12.906046
# 22183             0.459594            0.619786             0.443405
# 22184            15.392266           14.107856            14.109531
# 22185             3.328742            2.150460             2.604018
# 22186             0.081518            0.059546             0.039323
#
#        Pt98_On_AE086717-6
# 0                1.523350
# 1                0.000000
# 2                6.994346
# 3                0.832457
# 4               25.171776
# ...                   ...
# 22182           16.826491
# 22183            0.600486
# 22184           11.660228
# 22185            2.689529
# 22186            0.000000
#
# [22187 rows x 110 columns]

# %%
temp_df = df.loc[['PHGDH','SFXN1','SLC1A5']]
temp_df
# Out:
#         Pt1.baseline  Pt2.baseline  Pt4.baseline  Pt5.baseline  Pt6.baseline  \
# PHGDH      178.13350      12.83100    125.110000      161.8785      50.40410
# SFXN1       20.14255      26.15465      7.824695       20.8851      14.31120
# SLC1A5      53.88820      10.17109     10.613000       53.9192      10.07938
#
#         Pt7.baseline  Pt8.baseline  Pt9.baseline  Pt10.baseline  \
# PHGDH      103.41350      69.38070       38.1661       14.88905
# SFXN1        8.21688      17.22985       17.7206       18.93855
# SLC1A5     831.76650      69.47360       61.1779       77.93055
#
#         Pt12.baseline  ...  Pt25.baseline  Pt27A.baseline  Pt27B.baseline  \
# PHGDH        51.40225  ...       2.066750      293.837000       301.22950
# SFXN1         9.77528  ...       7.371015        2.033025         1.31603
# SLC1A5       64.15265  ...     120.689000       52.617150        39.34665
#
#         Pt28.baseline  Pt29.baseline  Pt31.baseline  Pt32.baseline  \
# PHGDH        53.68660       22.73570        22.1335       50.75010
# SFXN1        12.35185       10.05128        18.8179        7.06392
# SLC1A5       84.07135       97.20070       140.0520       82.62550
#
#         Pt35.baseline  Pt37.baseline  Pt38.baseline
# PHGDH        130.9870        7.05431        20.1907
# SFXN1         16.6373        5.14168        15.0603
# SLC1A5        99.3535       42.87030        56.5993
#
# [3 rows x 28 columns]

# %%
df_transposed = temp_df.T
df_transposed['mean'] = df_transposed.mean(axis=1)
df_transposed
# Out:
#                     PHGDH      SFXN1     SLC1A5        mean
# Pt1.baseline    178.13350  20.142550   53.88820   84.054750
# Pt2.baseline     12.83100  26.154650   10.17109   16.385580
# Pt4.baseline    125.11000   7.824695   10.61300   47.849232
# Pt5.baseline    161.87850  20.885100   53.91920   78.894267
# Pt6.baseline     50.40410  14.311200   10.07938   24.931560
# Pt7.baseline    103.41350   8.216880  831.76650  314.465627
# Pt8.baseline     69.38070  17.229850   69.47360   52.028050
# Pt9.baseline     38.16610  17.720600   61.17790   39.021533
# Pt10.baseline    14.88905  18.938550   77.93055   37.252717
# Pt12.baseline    51.40225   9.775280   64.15265   41.776727
# Pt13.baseline    13.29660   9.770205   24.62405   15.896952
# Pt14.baseline    21.93350  17.308900  117.14900   52.130467
# Pt15.baseline    32.30460  15.100100   95.36450   47.589733
# Pt16.OnTx       171.08400  15.790700  127.37900  104.751233
# Pt19.baseline   233.08650   5.727675  431.20100  223.338392
# Pt20.baseline    54.03325   7.417420   60.76985   40.740173
# Pt22.baseline    16.36940  10.583950   37.02740   21.326917
# Pt23.baseline    63.51005  14.784500  117.85450   65.383017
# Pt25.baseline     2.06675   7.371015  120.68900   43.375588
# Pt27A.baseline  293.83700   2.033025   52.61715  116.162392
# Pt27B.baseline  301.22950   1.316030   39.34665  113.964060
# Pt28.baseline    53.68660  12.351850   84.07135   50.036600
# Pt29.baseline    22.73570  10.051280   97.20070   43.329227
# Pt31.baseline    22.13350  18.817900  140.05200   60.334467
# Pt32.baseline    50.75010   7.063920   82.62550   46.813173
# Pt35.baseline   130.98700  16.637300   99.35350   82.325933
# Pt37.baseline     7.05431   5.141680   42.87030   18.355430
# Pt38.baseline    20.19070  15.060300   56.59930   30.616767

# %%
df_transposed['z_score'] = (df_transposed['mean']-df_transposed['mean'].mean())/df_transposed['mean'].std()

# %%
df_transposed
# Out:
#                     PHGDH      SFXN1     SLC1A5        mean   z_score
# Pt1.baseline    178.13350  20.142550   53.88820   84.054750  0.245188
# Pt2.baseline     12.83100  26.154650   10.17109   16.385580 -0.809681
# Pt4.baseline    125.11000   7.824695   10.61300   47.849232 -0.319206
# Pt5.baseline    161.87850  20.885100   53.91920   78.894267  0.164743
# Pt6.baseline     50.40410  14.311200   10.07938   24.931560 -0.676461
# Pt7.baseline    103.41350   8.216880  831.76650  314.465627  3.836976
# Pt8.baseline     69.38070  17.229850   69.47360   52.028050 -0.254064
# Pt9.baseline     38.16610  17.720600   61.17790   39.021533 -0.456818
# Pt10.baseline    14.88905  18.938550   77.93055   37.252717 -0.484391
# Pt12.baseline    51.40225   9.775280   64.15265   41.776727 -0.413868
# Pt13.baseline    13.29660   9.770205   24.62405   15.896952 -0.817298
# Pt14.baseline    21.93350  17.308900  117.14900   52.130467 -0.252467
# Pt15.baseline    32.30460  15.100100   95.36450   47.589733 -0.323251
# Pt16.OnTx       171.08400  15.790700  127.37900  104.751233  0.567818
# Pt19.baseline   233.08650   5.727675  431.20100  223.338392  2.416428
# Pt20.baseline    54.03325   7.417420   60.76985   40.740173 -0.430026
# Pt22.baseline    16.36940  10.583950   37.02740   21.326917 -0.732652
# Pt23.baseline    63.51005  14.784500  117.85450   65.383017 -0.045878
# Pt25.baseline     2.06675   7.371015  120.68900   43.375588 -0.388944
# Pt27A.baseline  293.83700   2.033025   52.61715  116.162392  0.745702
# Pt27B.baseline  301.22950   1.316030   39.34665  113.964060  0.711433
# Pt28.baseline    53.68660  12.351850   84.07135   50.036600 -0.285108
# Pt29.baseline    22.73570  10.051280   97.20070   43.329227 -0.389667
# Pt31.baseline    22.13350  18.817900  140.05200   60.334467 -0.124578
# Pt32.baseline    50.75010   7.063920   82.62550   46.813173 -0.335357
# Pt35.baseline   130.98700  16.637300   99.35350   82.325933  0.218238
# Pt37.baseline     7.05431   5.141680   42.87030   18.355430 -0.778974
# Pt38.baseline    20.19070  15.060300   56.59930   30.616767 -0.587836

# %%
df_response = pd.read_csv("/data/private/pdutta/Collab_data/David_data/GSE78220_response.csv", sep=",")

# %%
df_response['Patient ID'] = df_response['Patient ID'].astype(str) + '.baseline'
df_response = df_response.set_index('Patient ID')
df_response.index.name = None

# %%
df_response.groupby('Response').size()
# Out:
# Response
# NR    17
# R     22
# dtype: int64

# %%
df_merge = pd.merge(df_transposed, df_response, left_index=True, right_index=True)
df_merge
# Out:
#                     PHGDH      SFXN1     SLC1A5        mean   z_score Response
# Pt1.baseline    178.13350  20.142550   53.88820   84.054750  0.245188       NR
# Pt2.baseline     12.83100  26.154650   10.17109   16.385580 -0.809681        R
# Pt4.baseline    125.11000   7.824695   10.61300   47.849232 -0.319206        R
# Pt5.baseline    161.87850  20.885100   53.91920   78.894267  0.164743        R
# Pt6.baseline     50.40410  14.311200   10.07938   24.931560 -0.676461        R
# Pt7.baseline    103.41350   8.216880  831.76650  314.465627  3.836976       NR
# Pt8.baseline     69.38070  17.229850   69.47360   52.028050 -0.254064        R
# Pt9.baseline     38.16610  17.720600   61.17790   39.021533 -0.456818        R
# Pt10.baseline    14.88905  18.938550   77.93055   37.252717 -0.484391       NR
# Pt12.baseline    51.40225   9.775280   64.15265   41.776727 -0.413868       NR
# Pt13.baseline    13.29660   9.770205   24.62405   15.896952 -0.817298        R
# Pt14.baseline    21.93350  17.308900  117.14900   52.130467 -0.252467       NR
# Pt15.baseline    32.30460  15.100100   95.36450   47.589733 -0.323251        R
# Pt19.baseline   233.08650   5.727675  431.20100  223.338392  2.416428        R
# Pt20.baseline    54.03325   7.417420   60.76985   40.740173 -0.430026       NR
# Pt22.baseline    16.36940  10.583950   37.02740   21.326917 -0.732652       NR
# Pt23.baseline    63.51005  14.784500  117.85450   65.383017 -0.045878       NR
# Pt25.baseline     2.06675   7.371015  120.68900   43.375588 -0.388944       NR
# Pt27A.baseline  293.83700   2.033025   52.61715  116.162392  0.745702        R
# Pt27B.baseline  301.22950   1.316030   39.34665  113.964060  0.711433        R
# Pt28.baseline    53.68660  12.351850   84.07135   50.036600 -0.285108        R
# Pt29.baseline    22.73570  10.051280   97.20070   43.329227 -0.389667       NR
# Pt31.baseline    22.13350  18.817900  140.05200   60.334467 -0.124578       NR
# Pt32.baseline    50.75010   7.063920   82.62550   46.813173 -0.335357       NR
# Pt35.baseline   130.98700  16.637300   99.35350   82.325933  0.218238        R
# Pt37.baseline     7.05431   5.141680   42.87030   18.355430 -0.778974        R
# Pt38.baseline    20.19070  15.060300   56.59930   30.616767 -0.587836        R

# %%
df_merge.groupby('Response').size()
# Out:
# Response
# NR    12
# R     15
# dtype: int64

# %%
col_name= 'SFXN1'

# %%
val_list_3= df_merge[col_name].quantile([.25, .75]).values.tolist()
val_list_3
# Out:
# [47.743725, 98.27709999999999]

# %%
def group_3(row, val_list):
    if row[col_name] < val_list[0]:
        return 0
    elif val_list[0] <= row[col_name] < val_list[1]:
        return 1
    elif val_list[1] <= row[col_name]:
        return 2

# %%
df_merge['{}_three_clusters'.format(col_name)] = df_merge.apply(lambda row: group_3(row, val_list_3), axis=1)

# %%
df_merge
# Out:
#                     PHGDH      SFXN1     SLC1A5        mean   z_score  \
# Pt1.baseline    178.13350  20.142550   53.88820   84.054750  0.245188
# Pt2.baseline     12.83100  26.154650   10.17109   16.385580 -0.809681
# Pt4.baseline    125.11000   7.824695   10.61300   47.849232 -0.319206
# Pt5.baseline    161.87850  20.885100   53.91920   78.894267  0.164743
# Pt6.baseline     50.40410  14.311200   10.07938   24.931560 -0.676461
# Pt7.baseline    103.41350   8.216880  831.76650  314.465627  3.836976
# Pt8.baseline     69.38070  17.229850   69.47360   52.028050 -0.254064
# Pt9.baseline     38.16610  17.720600   61.17790   39.021533 -0.456818
# Pt10.baseline    14.88905  18.938550   77.93055   37.252717 -0.484391
# Pt12.baseline    51.40225   9.775280   64.15265   41.776727 -0.413868
# Pt13.baseline    13.29660   9.770205   24.62405   15.896952 -0.817298
# Pt14.baseline    21.93350  17.308900  117.14900   52.130467 -0.252467
# Pt15.baseline    32.30460  15.100100   95.36450   47.589733 -0.323251
# Pt19.baseline   233.08650   5.727675  431.20100  223.338392  2.416428
# Pt20.baseline    54.03325   7.417420   60.76985   40.740173 -0.430026
# Pt22.baseline    16.36940  10.583950   37.02740   21.326917 -0.732652
# Pt23.baseline    63.51005  14.784500  117.85450   65.383017 -0.045878
# Pt25.baseline     2.06675   7.371015  120.68900   43.375588 -0.388944
# Pt27A.baseline  293.83700   2.033025   52.61715  116.162392  0.745702
# Pt27B.baseline  301.22950   1.316030   39.34665  113.964060  0.711433
# Pt28.baseline    53.68660  12.351850   84.07135   50.036600 -0.285108
# Pt29.baseline    22.73570  10.051280   97.20070   43.329227 -0.389667
# Pt31.baseline    22.13350  18.817900  140.05200   60.334467 -0.124578
# Pt32.baseline    50.75010   7.063920   82.62550   46.813173 -0.335357
# Pt35.baseline   130.98700  16.637300   99.35350   82.325933  0.218238
# Pt37.baseline     7.05431   5.141680   42.87030   18.355430 -0.778974
# Pt38.baseline    20.19070  15.060300   56.59930   30.616767 -0.587836
#
#                Response  PHGDH_three_clusters  z_score_three_clusters  \
# Pt1.baseline         NR                     2                       2
# Pt2.baseline          R                     0                       0
# Pt4.baseline          R                     2                       1
# Pt5.baseline          R                     2                       2
# Pt6.baseline          R                     1                       0
# Pt7.baseline         NR                     1                       2
# Pt8.baseline          R                     1                       1
# Pt9.baseline          R                     1                       1
# Pt10.baseline        NR                     0                       0
# Pt12.baseline        NR                     1                       1
# Pt13.baseline         R                     0                       0
# Pt14.baseline        NR                     1                       1
# Pt15.baseline         R                     1                       1
# Pt19.baseline         R                     2                       2
# Pt20.baseline        NR                     1                       1
# Pt22.baseline        NR                     0                       0
# Pt23.baseline        NR                     1                       1
# Pt25.baseline        NR                     0                       1
# Pt27A.baseline        R                     2                       2
# Pt27B.baseline        R                     2                       2
# Pt28.baseline         R                     1                       1
# Pt29.baseline        NR                     1                       1
# Pt31.baseline        NR                     1                       1
# Pt32.baseline        NR                     1                       1
# Pt35.baseline         R                     2                       2
# Pt37.baseline         R                     0                       0
# Pt38.baseline         R                     0                       0
#
#                 SFXN1_three_clusters  SLC1A5_three_clusters
# Pt1.baseline                       2                      1
# Pt2.baseline                       2                      0
# Pt4.baseline                       1                      0
# Pt5.baseline                       2                      1
# Pt6.baseline                       1                      0
# Pt7.baseline                       1                      2
# Pt8.baseline                       1                      1
# Pt9.baseline                       2                      1
# Pt10.baseline                      2                      1
# Pt12.baseline                      1                      1
# Pt13.baseline                      1                      0
# Pt14.baseline                      2                      2
# Pt15.baseline                      1                      1
# Pt19.baseline                      0                      2
# Pt20.baseline                      0                      1
# Pt22.baseline                      1                      0
# Pt23.baseline                      1                      2
# Pt25.baseline                      0                      2
# Pt27A.baseline                     0                      1
# Pt27B.baseline                     0                      0
# Pt28.baseline                      1                      1
# Pt29.baseline                      1                      1
# Pt31.baseline                      2                      2
# Pt32.baseline                      0                      1
# Pt35.baseline                      1                      2
# Pt37.baseline                      0                      0
# Pt38.baseline                      1                      1

# %%
df_temp = df_merge.groupby(['Response','{}_three_clusters'.format(col_name)])[col_name].count().reset_index()
df_temp
# Out:
#   Response  SLC1A5_three_clusters  SLC1A5
# 0       NR                      0       1
# 1       NR                      1       6
# 2       NR                      2       5
# 3        R                      0       6
# 4        R                      1       7
# 5        R                      2       2

# %%
temp_numpy = df_temp[col_name].to_numpy()
C = np.reshape(temp_numpy, (-1, 3))
C
# Out:
# array([[1, 6, 5],
#        [6, 7, 2]])

# %%
df_temp = df_temp[df_temp['{}_three_clusters'.format(col_name)]!=1]
df_temp
# Out:
#   Response  SLC1A5_three_clusters  SLC1A5
# 0       NR                      0       1
# 2       NR                      2       5
# 3        R                      0       6
# 5        R                      2       2

# %%
temp_numpy = df_temp[col_name].to_numpy()
B = np.reshape(temp_numpy, (-1, 2))
B
# Out:
# array([[1, 5],
#        [6, 2]])

# %%
# importing packages
import scipy.stats as stats
  
#performing fishers exact test on the data
odd_ratio, p_value = stats.fisher_exact(B)
print('odd ratio is : ' + str(odd_ratio))
print('p_value is : ' + str(p_value))
# Out:
# odd ratio is : 0.06666666666666667
# p_value is : 0.10256410256410256

# %%
from scipy.stats import chisquare
from scipy.stats import ttest_ind

# %%
chisquare(C, axis=None)
# Out:
# Power_divergenceResult(statistic=6.555555555555555, pvalue=0.2558467570439726)

# %%
grp1 = df_merge[df_merge['Response']=="NR"][col_name].to_list()
grp2 = df_merge[df_merge['Response']=="R"][col_name].to_list()

# %%
ttest_ind(grp1, grp2)
# Out:
# Ttest_indResult(statistic=0.022599879878859235, pvalue=0.982148859977708)

# %%
col_name
# Out:
# 'SLC1A5'
